# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|███████████████████████████████████████▋| 993M/0.98G [00:09<00:00, 124MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:09<00:00, 113MB/s]

# %%
config = {"Seg_model":"VGG16UNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_vgg16
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = unet_vgg16(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 153s 2s/step - loss: -0.2846 - dice_metric: 0.2882 - jaccard_metric: 0.2384 - sensitivity_metric: 0.3243 - specificity_metric: 0.6981 - precision_metric: 0.3630 - recall_metric: 0.3243 - mean_average_precision: 0.1595 - val_loss: -0.3891 - val_dice_metric: 0.4166 - val_jaccard_metric: 0.3702 - val_sensitivity_metric: 0.4109 - val_specificity_metric: 0.7452 - val_precision_metric: 0.4433 - val_recall_metric: 0.4109 - val_mean_average_precision: 0.3122
# Epoch 2/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.4523 - dice_metric: 0.4773 - jaccard_metric: 0.4237 - sensitivity_metric: 0.4655 - specificity_metric: 0.7878 - precision_metric: 0.5167 - recall_metric: 0.4655 - mean_average_precision: 0.3351 - val_loss: -0.5420 - val_dice_metric: 0.5668 - val_jaccard_metric: 0.5144 - val_sensitivity_metric: 0.5569 - val_specificity_metric: 0.8741 - val_precision_metric: 0.6001 - val_recall_metric: 0.5569 - val_mean_average_precision: 0.4099
# Epoch 3/60
# 77/77 [==============================] - 116s 1s/step - loss: -0.5618 - dice_metric: 0.5789 - jaccard_metric: 0.5271 - sensitivity_metric: 0.5754 - specificity_metric: 0.8806 - precision_metric: 0.6022 - recall_metric: 0.5754 - mean_average_precision: 0.4283 - val_loss: -0.5820 - val_dice_metric: 0.5970 - val_jaccard_metric: 0.5500 - val_sensitivity_metric: 0.5834 - val_specificity_metric: 0.9023 - val_precision_metric: 0.6359 - val_recall_metric: 0.5834 - val_mean_average_precision: 0.4628
# Epoch 4/60
# 77/77 [==============================] - 122s 2s/step - loss: -0.5946 - dice_metric: 0.6079 - jaccard_metric: 0.5565 - sensitivity_metric: 0.6080 - specificity_metric: 0.9067 - precision_metric: 0.6309 - recall_metric: 0.6080 - mean_average_precision: 0.4653 - val_loss: -0.6073 - val_dice_metric: 0.6206 - val_jaccard_metric: 0.5754 - val_sensitivity_metric: 0.6136 - val_specificity_metric: 0.9301 - val_precision_metric: 0.6511 - val_recall_metric: 0.6136 - val_mean_average_precision: 0.4974
# Epoch 5/60
# 77/77 [==============================] - 114s 1s/step - loss: -0.6188 - dice_metric: 0.6320 - jaccard_metric: 0.5753 - sensitivity_metric: 0.6315 - specificity_metric: 0.9186 - precision_metric: 0.6584 - recall_metric: 0.6315 - mean_average_precision: 0.4802 - val_loss: -0.6361 - val_dice_metric: 0.6494 - val_jaccard_metric: 0.6015 - val_sensitivity_metric: 0.6443 - val_specificity_metric: 0.9442 - val_precision_metric: 0.6809 - val_recall_metric: 0.6443 - val_mean_average_precision: 0.5241
# Epoch 6/60
# 77/77 [==============================] - 119s 2s/step - loss: -0.6588 - dice_metric: 0.6741 - jaccard_metric: 0.6090 - sensitivity_metric: 0.6682 - specificity_metric: 0.9280 - precision_metric: 0.7036 - recall_metric: 0.6682 - mean_average_precision: 0.4935 - val_loss: -0.6739 - val_dice_metric: 0.6857 - val_jaccard_metric: 0.6344 - val_sensitivity_metric: 0.6737 - val_specificity_metric: 0.9450 - val_precision_metric: 0.7467 - val_recall_metric: 0.6737 - val_mean_average_precision: 0.5428
# Epoch 7/60
# 77/77 [==============================] - 118s 2s/step - loss: -0.6888 - dice_metric: 0.7027 - jaccard_metric: 0.6359 - sensitivity_metric: 0.6967 - specificity_metric: 0.9358 - precision_metric: 0.7294 - recall_metric: 0.6967 - mean_average_precision: 0.5126 - val_loss: -0.7033 - val_dice_metric: 0.7133 - val_jaccard_metric: 0.6603 - val_sensitivity_metric: 0.6995 - val_specificity_metric: 0.9500 - val_precision_metric: 0.7599 - val_recall_metric: 0.6995 - val_mean_average_precision: 0.5608
# Epoch 8/60
# 77/77 [==============================] - 109s 1s/step - loss: -0.7055 - dice_metric: 0.7181 - jaccard_metric: 0.6517 - sensitivity_metric: 0.7136 - specificity_metric: 0.9404 - precision_metric: 0.7405 - recall_metric: 0.7136 - mean_average_precision: 0.5282 - val_loss: -0.7223 - val_dice_metric: 0.7331 - val_jaccard_metric: 0.6811 - val_sensitivity_metric: 0.7215 - val_specificity_metric: 0.9576 - val_precision_metric: 0.7596 - val_recall_metric: 0.7215 - val_mean_average_precision: 0.5839
# Epoch 9/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7161 - dice_metric: 0.7274 - jaccard_metric: 0.6614 - sensitivity_metric: 0.7238 - specificity_metric: 0.9431 - precision_metric: 0.7478 - recall_metric: 0.7238 - mean_average_precision: 0.5389 - val_loss: -0.7318 - val_dice_metric: 0.7411 - val_jaccard_metric: 0.6890 - val_sensitivity_metric: 0.7292 - val_specificity_metric: 0.9588 - val_precision_metric: 0.7634 - val_recall_metric: 0.7292 - val_mean_average_precision: 0.5898
# Epoch 10/60
# 77/77 [==============================] - 117s 2s/step - loss: -0.7229 - dice_metric: 0.7334 - jaccard_metric: 0.6678 - sensitivity_metric: 0.7302 - specificity_metric: 0.9450 - precision_metric: 0.7521 - recall_metric: 0.7302 - mean_average_precision: 0.5461 - val_loss: -0.7350 - val_dice_metric: 0.7433 - val_jaccard_metric: 0.6905 - val_sensitivity_metric: 0.7354 - val_specificity_metric: 0.9604 - val_precision_metric: 0.7605 - val_recall_metric: 0.7354 - val_mean_average_precision: 0.5928
# Epoch 11/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7286 - dice_metric: 0.7376 - jaccard_metric: 0.6725 - sensitivity_metric: 0.7355 - specificity_metric: 0.9464 - precision_metric: 0.7563 - recall_metric: 0.7355 - mean_average_precision: 0.5521 - val_loss: -0.7410 - val_dice_metric: 0.7598 - val_jaccard_metric: 0.7091 - val_sensitivity_metric: 0.7424 - val_specificity_metric: 0.9636 - val_precision_metric: 0.7614 - val_recall_metric: 0.7424 - val_mean_average_precision: 0.6132
# Epoch 12/60
# 77/77 [==============================] - 116s 2s/step - loss: -0.7328 - dice_metric: 0.7414 - jaccard_metric: 0.6766 - sensitivity_metric: 0.7399 - specificity_metric: 0.9475 - precision_metric: 0.7591 - recall_metric: 0.7399 - mean_average_precision: 0.5571 - val_loss: -0.7425 - val_dice_metric: 0.7464 - val_jaccard_metric: 0.6951 - val_sensitivity_metric: 0.7422 - val_specificity_metric: 0.9626 - val_precision_metric: 0.7646 - val_recall_metric: 0.7422 - val_mean_average_precision: 0.5996
# Epoch 13/60
# 77/77 [==============================] - 115s 1s/step - loss: -0.7362 - dice_metric: 0.7445 - jaccard_metric: 0.6800 - sensitivity_metric: 0.7430 - specificity_metric: 0.9483 - precision_metric: 0.7614 - recall_metric: 0.7430 - mean_average_precision: 0.5609 - val_loss: -0.7423 - val_dice_metric: 0.7497 - val_jaccard_metric: 0.6980 - val_sensitivity_metric: 0.7458 - val_specificity_metric: 0.9646 - val_precision_metric: 0.7610 - val_recall_metric: 0.7458 - val_mean_average_precision: 0.6001
# Epoch 14/60
# 77/77 [==============================] - 119s 2s/step - loss: -0.7393 - dice_metric: 0.7471 - jaccard_metric: 0.6828 - sensitivity_metric: 0.7460 - specificity_metric: 0.9491 - precision_metric: 0.7635 - recall_metric: 0.7460 - mean_average_precision: 0.5647 - val_loss: -0.7468 - val_dice_metric: 0.7497 - val_jaccard_metric: 0.6998 - val_sensitivity_metric: 0.7513 - val_specificity_metric: 0.9668 - val_precision_metric: 0.7619 - val_recall_metric: 0.7513 - val_mean_average_precision: 0.6055
# Epoch 15/60
# 77/77 [==============================] - 107s 1s/step - loss: -0.7428 - dice_metric: 0.7502 - jaccard_metric: 0.6862 - sensitivity_metric: 0.7492 - specificity_metric: 0.9497 - precision_metric: 0.7660 - recall_metric: 0.7492 - mean_average_precision: 0.5684 - val_loss: -0.7447 - val_dice_metric: 0.7476 - val_jaccard_metric: 0.6958 - val_sensitivity_metric: 0.7489 - val_specificity_metric: 0.9668 - val_precision_metric: 0.7614 - val_recall_metric: 0.7489 - val_mean_average_precision: 0.5993
# Epoch 16/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7452 - dice_metric: 0.7528 - jaccard_metric: 0.6891 - sensitivity_metric: 0.7517 - specificity_metric: 0.9502 - precision_metric: 0.7678 - recall_metric: 0.7517 - mean_average_precision: 0.5721 - val_loss: -0.7476 - val_dice_metric: 0.7497 - val_jaccard_metric: 0.6994 - val_sensitivity_metric: 0.7526 - val_specificity_metric: 0.9678 - val_precision_metric: 0.7616 - val_recall_metric: 0.7526 - val_mean_average_precision: 0.6046
# Epoch 17/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7481 - dice_metric: 0.7555 - jaccard_metric: 0.6923 - sensitivity_metric: 0.7545 - specificity_metric: 0.9509 - precision_metric: 0.7701 - recall_metric: 0.7545 - mean_average_precision: 0.5765 - val_loss: -0.7497 - val_dice_metric: 0.7532 - val_jaccard_metric: 0.7034 - val_sensitivity_metric: 0.7567 - val_specificity_metric: 0.9698 - val_precision_metric: 0.7613 - val_recall_metric: 0.7567 - val_mean_average_precision: 0.6109
# Epoch 18/60
# 77/77 [==============================] - 117s 2s/step - loss: -0.7499 - dice_metric: 0.7570 - jaccard_metric: 0.6938 - sensitivity_metric: 0.7564 - specificity_metric: 0.9513 - precision_metric: 0.7713 - recall_metric: 0.7564 - mean_average_precision: 0.5779 - val_loss: -0.7522 - val_dice_metric: 0.7557 - val_jaccard_metric: 0.7070 - val_sensitivity_metric: 0.7568 - val_specificity_metric: 0.9690 - val_precision_metric: 0.7661 - val_recall_metric: 0.7568 - val_mean_average_precision: 0.6145
# Epoch 19/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7523 - dice_metric: 0.7584 - jaccard_metric: 0.6954 - sensitivity_metric: 0.7585 - specificity_metric: 0.9518 - precision_metric: 0.7731 - recall_metric: 0.7585 - mean_average_precision: 0.5801 - val_loss: -0.7530 - val_dice_metric: 0.7561 - val_jaccard_metric: 0.7076 - val_sensitivity_metric: 0.7594 - val_specificity_metric: 0.9703 - val_precision_metric: 0.7642 - val_recall_metric: 0.7594 - val_mean_average_precision: 0.6179
# Epoch 20/60
# 77/77 [==============================] - 120s 2s/step - loss: -0.7541 - dice_metric: 0.7600 - jaccard_metric: 0.6972 - sensitivity_metric: 0.7600 - specificity_metric: 0.9520 - precision_metric: 0.7741 - recall_metric: 0.7600 - mean_average_precision: 0.5821 - val_loss: -0.7554 - val_dice_metric: 0.7590 - val_jaccard_metric: 0.7116 - val_sensitivity_metric: 0.7605 - val_specificity_metric: 0.9702 - val_precision_metric: 0.7678 - val_recall_metric: 0.7605 - val_mean_average_precision: 0.6266
# Epoch 21/60
# 77/77 [==============================] - 109s 1s/step - loss: -0.7565 - dice_metric: 0.7620 - jaccard_metric: 0.6996 - sensitivity_metric: 0.7623 - specificity_metric: 0.9524 - precision_metric: 0.7760 - recall_metric: 0.7623 - mean_average_precision: 0.5858 - val_loss: -0.7563 - val_dice_metric: 0.7609 - val_jaccard_metric: 0.7136 - val_sensitivity_metric: 0.7609 - val_specificity_metric: 0.9703 - val_precision_metric: 0.7683 - val_recall_metric: 0.7609 - val_mean_average_precision: 0.6289
# Epoch 22/60
# 77/77 [==============================] - 118s 2s/step - loss: -0.7575 - dice_metric: 0.7632 - jaccard_metric: 0.7009 - sensitivity_metric: 0.7632 - specificity_metric: 0.9527 - precision_metric: 0.7765 - recall_metric: 0.7632 - mean_average_precision: 0.5872 - val_loss: -0.7571 - val_dice_metric: 0.7629 - val_jaccard_metric: 0.7157 - val_sensitivity_metric: 0.7630 - val_specificity_metric: 0.9717 - val_precision_metric: 0.7677 - val_recall_metric: 0.7630 - val_mean_average_precision: 0.6308
# Epoch 23/60
# 77/77 [==============================] - 117s 2s/step - loss: -0.7592 - dice_metric: 0.7648 - jaccard_metric: 0.7027 - sensitivity_metric: 0.7649 - specificity_metric: 0.9531 - precision_metric: 0.7780 - recall_metric: 0.7649 - mean_average_precision: 0.5896 - val_loss: -0.7550 - val_dice_metric: 0.7571 - val_jaccard_metric: 0.7092 - val_sensitivity_metric: 0.7640 - val_specificity_metric: 0.9722 - val_precision_metric: 0.7640 - val_recall_metric: 0.7640 - val_mean_average_precision: 0.6221
# Epoch 24/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.7598 - dice_metric: 0.7662 - jaccard_metric: 0.7041 - sensitivity_metric: 0.7657 - specificity_metric: 0.9534 - precision_metric: 0.7784 - recall_metric: 0.7657 - mean_average_precision: 0.5914 - val_loss: -0.7563 - val_dice_metric: 0.7583 - val_jaccard_metric: 0.7111 - val_sensitivity_metric: 0.7637 - val_specificity_metric: 0.9713 - val_precision_metric: 0.7659 - val_recall_metric: 0.7637 - val_mean_average_precision: 0.6265
# Epoch 25/60
# 77/77 [==============================] - 118s 2s/step - loss: -0.7617 - dice_metric: 0.7672 - jaccard_metric: 0.7055 - sensitivity_metric: 0.7676 - specificity_metric: 0.9536 - precision_metric: 0.7800 - recall_metric: 0.7676 - mean_average_precision: 0.5938 - val_loss: -0.7576 - val_dice_metric: 0.7603 - val_jaccard_metric: 0.7133 - val_sensitivity_metric: 0.7652 - val_specificity_metric: 0.9720 - val_precision_metric: 0.7662 - val_recall_metric: 0.7652 - val_mean_average_precision: 0.6289
# Epoch 26/60
# 77/77 [==============================] - 114s 1s/step - loss: -0.7631 - dice_metric: 0.7690 - jaccard_metric: 0.7074 - sensitivity_metric: 0.7686 - specificity_metric: 0.9539 - precision_metric: 0.7810 - recall_metric: 0.7686 - mean_average_precision: 0.5958 - val_loss: -0.7585 - val_dice_metric: 0.7621 - val_jaccard_metric: 0.7158 - val_sensitivity_metric: 0.7678 - val_specificity_metric: 0.9733 - val_precision_metric: 0.7664 - val_recall_metric: 0.7678 - val_mean_average_precision: 0.6349
# Epoch 27/60
# 77/77 [==============================] - 114s 1s/step - loss: -0.7642 - dice_metric: 0.7693 - jaccard_metric: 0.7078 - sensitivity_metric: 0.7698 - specificity_metric: 0.9541 - precision_metric: 0.7817 - recall_metric: 0.7698 - mean_average_precision: 0.5966 - val_loss: -0.7604 - val_dice_metric: 0.7817 - val_jaccard_metric: 0.7360 - val_sensitivity_metric: 0.7676 - val_specificity_metric: 0.9724 - val_precision_metric: 0.7688 - val_recall_metric: 0.7676 - val_mean_average_precision: 0.6557
# Epoch 28/60
# 77/77 [==============================] - 119s 2s/step - loss: -0.7650 - dice_metric: 0.7708 - jaccard_metric: 0.7095 - sensitivity_metric: 0.7707 - specificity_metric: 0.9542 - precision_metric: 0.7825 - recall_metric: 0.7707 - mean_average_precision: 0.5988 - val_loss: -0.7602 - val_dice_metric: 0.7627 - val_jaccard_metric: 0.7166 - val_sensitivity_metric: 0.7670 - val_specificity_metric: 0.9730 - val_precision_metric: 0.7691 - val_recall_metric: 0.7670 - val_mean_average_precision: 0.6338
# Epoch 29/60
# 77/77 [==============================] - 114s 1s/step - loss: -0.7664 - dice_metric: 0.7722 - jaccard_metric: 0.7113 - sensitivity_metric: 0.7719 - specificity_metric: 0.9545 - precision_metric: 0.7836 - recall_metric: 0.7719 - mean_average_precision: 0.6016 - val_loss: -0.7610 - val_dice_metric: 0.7830 - val_jaccard_metric: 0.7374 - val_sensitivity_metric: 0.7689 - val_specificity_metric: 0.9736 - val_precision_metric: 0.7677 - val_recall_metric: 0.7689 - val_mean_average_precision: 0.6578
# Epoch 30/60
# 77/77 [==============================] - 114s 1s/step - loss: -0.7673 - dice_metric: 0.7730 - jaccard_metric: 0.7120 - sensitivity_metric: 0.7729 - specificity_metric: 0.9547 - precision_metric: 0.7839 - recall_metric: 0.7729 - mean_average_precision: 0.6024 - val_loss: -0.7609 - val_dice_metric: 0.7622 - val_jaccard_metric: 0.7164 - val_sensitivity_metric: 0.7684 - val_specificity_metric: 0.9737 - val_precision_metric: 0.7690 - val_recall_metric: 0.7684 - val_mean_average_precision: 0.6357
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 112s 1s/step - loss: -0.7705 - dice_metric: 0.7754 - jaccard_metric: 0.7151 - sensitivity_metric: 0.7755 - specificity_metric: 0.9552 - precision_metric: 0.7862 - recall_metric: 0.7755 - mean_average_precision: 0.6069 - val_loss: -0.7628 - val_dice_metric: 0.7808 - val_jaccard_metric: 0.7357 - val_sensitivity_metric: 0.7672 - val_specificity_metric: 0.9723 - val_precision_metric: 0.7720 - val_recall_metric: 0.7672 - val_mean_average_precision: 0.6570
# Epoch 32/60
# 77/77 [==============================] - 116s 2s/step - loss: -0.7723 - dice_metric: 0.7786 - jaccard_metric: 0.7186 - sensitivity_metric: 0.7773 - specificity_metric: 0.9554 - precision_metric: 0.7879 - recall_metric: 0.7773 - mean_average_precision: 0.6111 - val_loss: -0.7631 - val_dice_metric: 0.7837 - val_jaccard_metric: 0.7388 - val_sensitivity_metric: 0.7675 - val_specificity_metric: 0.9723 - val_precision_metric: 0.7723 - val_recall_metric: 0.7675 - val_mean_average_precision: 0.6608
# Epoch 33/60
# 77/77 [==============================] - 116s 1s/step - loss: -0.7729 - dice_metric: 0.7795 - jaccard_metric: 0.7196 - sensitivity_metric: 0.7780 - specificity_metric: 0.9555 - precision_metric: 0.7882 - recall_metric: 0.7780 - mean_average_precision: 0.6125 - val_loss: -0.7634 - val_dice_metric: 0.7801 - val_jaccard_metric: 0.7354 - val_sensitivity_metric: 0.7678 - val_specificity_metric: 0.9724 - val_precision_metric: 0.7725 - val_recall_metric: 0.7678 - val_mean_average_precision: 0.6581
# Epoch 34/60
# 77/77 [==============================] - 114s 1s/step - loss: -0.7735 - dice_metric: 0.7792 - jaccard_metric: 0.7194 - sensitivity_metric: 0.7783 - specificity_metric: 0.9554 - precision_metric: 0.7892 - recall_metric: 0.7783 - mean_average_precision: 0.6124 - val_loss: -0.7635 - val_dice_metric: 0.7777 - val_jaccard_metric: 0.7330 - val_sensitivity_metric: 0.7678 - val_specificity_metric: 0.9721 - val_precision_metric: 0.7727 - val_recall_metric: 0.7678 - val_mean_average_precision: 0.6564
# Epoch 35/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7738 - dice_metric: 0.7788 - jaccard_metric: 0.7191 - sensitivity_metric: 0.7786 - specificity_metric: 0.9555 - precision_metric: 0.7894 - recall_metric: 0.7786 - mean_average_precision: 0.6130 - val_loss: -0.7636 - val_dice_metric: 0.7859 - val_jaccard_metric: 0.7412 - val_sensitivity_metric: 0.7676 - val_specificity_metric: 0.9722 - val_precision_metric: 0.7728 - val_recall_metric: 0.7676 - val_mean_average_precision: 0.6634
# Epoch 36/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.7739 - dice_metric: 0.7791 - jaccard_metric: 0.7194 - sensitivity_metric: 0.7786 - specificity_metric: 0.9555 - precision_metric: 0.7892 - recall_metric: 0.7786 - mean_average_precision: 0.6127 - val_loss: -0.7635 - val_dice_metric: 0.7778 - val_jaccard_metric: 0.7331 - val_sensitivity_metric: 0.7680 - val_specificity_metric: 0.9723 - val_precision_metric: 0.7727 - val_recall_metric: 0.7680 - val_mean_average_precision: 0.6546
# Epoch 37/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.7743 - dice_metric: 0.7800 - jaccard_metric: 0.7204 - sensitivity_metric: 0.7791 - specificity_metric: 0.9556 - precision_metric: 0.7899 - recall_metric: 0.7791 - mean_average_precision: 0.6139 - val_loss: -0.7637 - val_dice_metric: 0.7804 - val_jaccard_metric: 0.7358 - val_sensitivity_metric: 0.7678 - val_specificity_metric: 0.9721 - val_precision_metric: 0.7728 - val_recall_metric: 0.7678 - val_mean_average_precision: 0.6576
# Epoch 38/60
# 77/77 [==============================] - 119s 2s/step - loss: -0.7745 - dice_metric: 0.7810 - jaccard_metric: 0.7214 - sensitivity_metric: 0.7793 - specificity_metric: 0.9555 - precision_metric: 0.7899 - recall_metric: 0.7793 - mean_average_precision: 0.6149 - val_loss: -0.7638 - val_dice_metric: 0.7887 - val_jaccard_metric: 0.7441 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9723 - val_precision_metric: 0.7726 - val_recall_metric: 0.7682 - val_mean_average_precision: 0.6664
# Epoch 39/60
# 77/77 [==============================] - 112s 1s/step - loss: -0.7746 - dice_metric: 0.7801 - jaccard_metric: 0.7205 - sensitivity_metric: 0.7794 - specificity_metric: 0.9556 - precision_metric: 0.7898 - recall_metric: 0.7794 - mean_average_precision: 0.6140 - val_loss: -0.7638 - val_dice_metric: 0.7952 - val_jaccard_metric: 0.7506 - val_sensitivity_metric: 0.7680 - val_specificity_metric: 0.9723 - val_precision_metric: 0.7725 - val_recall_metric: 0.7680 - val_mean_average_precision: 0.6726
# Epoch 40/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7748 - dice_metric: 0.7819 - jaccard_metric: 0.7224 - sensitivity_metric: 0.7795 - specificity_metric: 0.9556 - precision_metric: 0.7902 - recall_metric: 0.7795 - mean_average_precision: 0.6162 - val_loss: -0.7639 - val_dice_metric: 0.7954 - val_jaccard_metric: 0.7508 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9724 - val_precision_metric: 0.7727 - val_recall_metric: 0.7682 - val_mean_average_precision: 0.6717
# Epoch 41/60
# 77/77 [==============================] - 115s 1s/step - loss: -0.7750 - dice_metric: 0.7807 - jaccard_metric: 0.7211 - sensitivity_metric: 0.7797 - specificity_metric: 0.9557 - precision_metric: 0.7903 - recall_metric: 0.7797 - mean_average_precision: 0.6148 - val_loss: -0.7639 - val_dice_metric: 0.8032 - val_jaccard_metric: 0.7586 - val_sensitivity_metric: 0.7680 - val_specificity_metric: 0.9723 - val_precision_metric: 0.7730 - val_recall_metric: 0.7680 - val_mean_average_precision: 0.6799
# Epoch 42/60
# 77/77 [==============================] - 119s 2s/step - loss: -0.7752 - dice_metric: 0.7817 - jaccard_metric: 0.7223 - sensitivity_metric: 0.7798 - specificity_metric: 0.9556 - precision_metric: 0.7907 - recall_metric: 0.7798 - mean_average_precision: 0.6163 - val_loss: -0.7640 - val_dice_metric: 0.7860 - val_jaccard_metric: 0.7415 - val_sensitivity_metric: 0.7687 - val_specificity_metric: 0.9724 - val_precision_metric: 0.7727 - val_recall_metric: 0.7687 - val_mean_average_precision: 0.6636
# Epoch 43/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.7755 - dice_metric: 0.7807 - jaccard_metric: 0.7213 - sensitivity_metric: 0.7801 - specificity_metric: 0.9557 - precision_metric: 0.7909 - recall_metric: 0.7801 - mean_average_precision: 0.6156 - val_loss: -0.7639 - val_dice_metric: 0.7897 - val_jaccard_metric: 0.7452 - val_sensitivity_metric: 0.7684 - val_specificity_metric: 0.9724 - val_precision_metric: 0.7725 - val_recall_metric: 0.7684 - val_mean_average_precision: 0.6668
# Epoch 44/60
# 77/77 [==============================] - 115s 1s/step - loss: -0.7759 - dice_metric: 0.7818 - jaccard_metric: 0.7224 - sensitivity_metric: 0.7805 - specificity_metric: 0.9557 - precision_metric: 0.7913 - recall_metric: 0.7805 - mean_average_precision: 0.6167 - val_loss: -0.7642 - val_dice_metric: 0.7834 - val_jaccard_metric: 0.7390 - val_sensitivity_metric: 0.7686 - val_specificity_metric: 0.9724 - val_precision_metric: 0.7729 - val_recall_metric: 0.7686 - val_mean_average_precision: 0.6619
# Epoch 45/60
# 77/77 [==============================] - 107s 1s/step - loss: -0.7760 - dice_metric: 0.7813 - jaccard_metric: 0.7220 - sensitivity_metric: 0.7805 - specificity_metric: 0.9557 - precision_metric: 0.7913 - recall_metric: 0.7805 - mean_average_precision: 0.6163 - val_loss: -0.7641 - val_dice_metric: 0.7887 - val_jaccard_metric: 0.7444 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9725 - val_precision_metric: 0.7728 - val_recall_metric: 0.7688 - val_mean_average_precision: 0.6666
# Epoch 46/60
# 77/77 [==============================] - 116s 1s/step - loss: -0.7762 - dice_metric: 0.7822 - jaccard_metric: 0.7229 - sensitivity_metric: 0.7806 - specificity_metric: 0.9557 - precision_metric: 0.7915 - recall_metric: 0.7806 - mean_average_precision: 0.6173 - val_loss: -0.7640 - val_dice_metric: 0.7886 - val_jaccard_metric: 0.7442 - val_sensitivity_metric: 0.7689 - val_specificity_metric: 0.9726 - val_precision_metric: 0.7725 - val_recall_metric: 0.7689 - val_mean_average_precision: 0.6655
# Epoch 47/60
# 77/77 [==============================] - 115s 1s/step - loss: -0.7761 - dice_metric: 0.7828 - jaccard_metric: 0.7234 - sensitivity_metric: 0.7807 - specificity_metric: 0.9557 - precision_metric: 0.7913 - recall_metric: 0.7807 - mean_average_precision: 0.6176 - val_loss: -0.7642 - val_dice_metric: 0.7956 - val_jaccard_metric: 0.7512 - val_sensitivity_metric: 0.7687 - val_specificity_metric: 0.9724 - val_precision_metric: 0.7728 - val_recall_metric: 0.7687 - val_mean_average_precision: 0.6731
# Epoch 48/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7766 - dice_metric: 0.7816 - jaccard_metric: 0.7223 - sensitivity_metric: 0.7809 - specificity_metric: 0.9558 - precision_metric: 0.7917 - recall_metric: 0.7809 - mean_average_precision: 0.6167 - val_loss: -0.7644 - val_dice_metric: 0.7836 - val_jaccard_metric: 0.7393 - val_sensitivity_metric: 0.7690 - val_specificity_metric: 0.9725 - val_precision_metric: 0.7728 - val_recall_metric: 0.7690 - val_mean_average_precision: 0.6614
# Epoch 49/60
# 77/77 [==============================] - 116s 1s/step - loss: -0.7767 - dice_metric: 0.7833 - jaccard_metric: 0.7240 - sensitivity_metric: 0.7813 - specificity_metric: 0.9559 - precision_metric: 0.7920 - recall_metric: 0.7813 - mean_average_precision: 0.6184 - val_loss: -0.7644 - val_dice_metric: 0.7878 - val_jaccard_metric: 0.7434 - val_sensitivity_metric: 0.7690 - val_specificity_metric: 0.9726 - val_precision_metric: 0.7725 - val_recall_metric: 0.7690 - val_mean_average_precision: 0.6656
# Epoch 50/60
# 77/77 [==============================] - 115s 1s/step - loss: -0.7769 - dice_metric: 0.7832 - jaccard_metric: 0.7240 - sensitivity_metric: 0.7812 - specificity_metric: 0.9558 - precision_metric: 0.7921 - recall_metric: 0.7812 - mean_average_precision: 0.6186 - val_loss: -0.7645 - val_dice_metric: 0.7984 - val_jaccard_metric: 0.7541 - val_sensitivity_metric: 0.7692 - val_specificity_metric: 0.9727 - val_precision_metric: 0.7728 - val_recall_metric: 0.7692 - val_mean_average_precision: 0.6760
# Epoch 51/60
# 77/77 [==============================] - 112s 1s/step - loss: -0.7773 - dice_metric: 0.7834 - jaccard_metric: 0.7242 - sensitivity_metric: 0.7817 - specificity_metric: 0.9559 - precision_metric: 0.7923 - recall_metric: 0.7817 - mean_average_precision: 0.6191 - val_loss: -0.7647 - val_dice_metric: 0.7974 - val_jaccard_metric: 0.7531 - val_sensitivity_metric: 0.7694 - val_specificity_metric: 0.9726 - val_precision_metric: 0.7731 - val_recall_metric: 0.7694 - val_mean_average_precision: 0.6757
# Epoch 52/60
# 77/77 [==============================] - 113s 1s/step - loss: -0.7774 - dice_metric: 0.7846 - jaccard_metric: 0.7254 - sensitivity_metric: 0.7818 - specificity_metric: 0.9559 - precision_metric: 0.7926 - recall_metric: 0.7818 - mean_average_precision: 0.6199 - val_loss: -0.7647 - val_dice_metric: 0.7948 - val_jaccard_metric: 0.7505 - val_sensitivity_metric: 0.7692 - val_specificity_metric: 0.9726 - val_precision_metric: 0.7733 - val_recall_metric: 0.7692 - val_mean_average_precision: 0.6725
# Epoch 53/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.7775 - dice_metric: 0.7829 - jaccard_metric: 0.7238 - sensitivity_metric: 0.7818 - specificity_metric: 0.9559 - precision_metric: 0.7927 - recall_metric: 0.7818 - mean_average_precision: 0.6188 - val_loss: -0.7649 - val_dice_metric: 0.7949 - val_jaccard_metric: 0.7506 - val_sensitivity_metric: 0.7695 - val_specificity_metric: 0.9727 - val_precision_metric: 0.7731 - val_recall_metric: 0.7695 - val_mean_average_precision: 0.6724
# Epoch 54/60
# 77/77 [==============================] - 122s 2s/step - loss: -0.7776 - dice_metric: 0.7837 - jaccard_metric: 0.7246 - sensitivity_metric: 0.7819 - specificity_metric: 0.9560 - precision_metric: 0.7926 - recall_metric: 0.7819 - mean_average_precision: 0.6197 - val_loss: -0.7647 - val_dice_metric: 0.7854 - val_jaccard_metric: 0.7411 - val_sensitivity_metric: 0.7691 - val_specificity_metric: 0.9725 - val_precision_metric: 0.7730 - val_recall_metric: 0.7691 - val_mean_average_precision: 0.6632
# Epoch 55/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.7779 - dice_metric: 0.7844 - jaccard_metric: 0.7253 - sensitivity_metric: 0.7823 - specificity_metric: 0.9560 - precision_metric: 0.7931 - recall_metric: 0.7823 - mean_average_precision: 0.6206 - val_loss: -0.7650 - val_dice_metric: 0.7961 - val_jaccard_metric: 0.7517 - val_sensitivity_metric: 0.7695 - val_specificity_metric: 0.9728 - val_precision_metric: 0.7729 - val_recall_metric: 0.7695 - val_mean_average_precision: 0.6735
# Epoch 56/60
# 77/77 [==============================] - 112s 1s/step - loss: -0.7780 - dice_metric: 0.7842 - jaccard_metric: 0.7251 - sensitivity_metric: 0.7825 - specificity_metric: 0.9561 - precision_metric: 0.7931 - recall_metric: 0.7825 - mean_average_precision: 0.6204 - val_loss: -0.7649 - val_dice_metric: 0.7910 - val_jaccard_metric: 0.7467 - val_sensitivity_metric: 0.7696 - val_specificity_metric: 0.9727 - val_precision_metric: 0.7729 - val_recall_metric: 0.7696 - val_mean_average_precision: 0.6687
# Epoch 57/60
# 77/77 [==============================] - 107s 1s/step - loss: -0.7783 - dice_metric: 0.7851 - jaccard_metric: 0.7261 - sensitivity_metric: 0.7826 - specificity_metric: 0.9561 - precision_metric: 0.7934 - recall_metric: 0.7826 - mean_average_precision: 0.6216 - val_loss: -0.7650 - val_dice_metric: 0.8001 - val_jaccard_metric: 0.7559 - val_sensitivity_metric: 0.7697 - val_specificity_metric: 0.9727 - val_precision_metric: 0.7730 - val_recall_metric: 0.7697 - val_mean_average_precision: 0.6781
# Epoch 58/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.7784 - dice_metric: 0.7853 - jaccard_metric: 0.7263 - sensitivity_metric: 0.7824 - specificity_metric: 0.9560 - precision_metric: 0.7937 - recall_metric: 0.7824 - mean_average_precision: 0.6216 - val_loss: -0.7650 - val_dice_metric: 0.8016 - val_jaccard_metric: 0.7573 - val_sensitivity_metric: 0.7698 - val_specificity_metric: 0.9728 - val_precision_metric: 0.7732 - val_recall_metric: 0.7698 - val_mean_average_precision: 0.6793
# Epoch 59/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.7786 - dice_metric: 0.7845 - jaccard_metric: 0.7254 - sensitivity_metric: 0.7828 - specificity_metric: 0.9560 - precision_metric: 0.7936 - recall_metric: 0.7828 - mean_average_precision: 0.6206 - val_loss: -0.7651 - val_dice_metric: 0.7978 - val_jaccard_metric: 0.7538 - val_sensitivity_metric: 0.7701 - val_specificity_metric: 0.9728 - val_precision_metric: 0.7733 - val_recall_metric: 0.7701 - val_mean_average_precision: 0.6767
# Epoch 60/60
# 77/77 [==============================] - 111s 1s/step - loss: -0.7790 - dice_metric: 0.7855 - jaccard_metric: 0.7266 - sensitivity_metric: 0.7831 - specificity_metric: 0.9561 - precision_metric: 0.7939 - recall_metric: 0.7831 - mean_average_precision: 0.6222 - val_loss: -0.7650 - val_dice_metric: 0.7938 - val_jaccard_metric: 0.7496 - val_sensitivity_metric: 0.7699 - val_specificity_metric: 0.9728 - val_precision_metric: 0.7730 - val_recall_metric: 0.7699 - val_mean_average_precision: 0.6728

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.81483, std: 0.30708
# Jaccard Index mean: 0.76733, std: 0.31274
# Sensitivity mean: 0.79489, std: 0.33185
# Specificity mean: 0.97231, std: 0.05572
# Precision mean: 0.80621, std: 0.32549
# Recall mean: 0.79489, std: 0.33185
# mAP@50 mean: 0.85593, std: 0.16513
# mAP@50-95 mean: 0.68192, std: 0.14765
