# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable
from tf_keras.applications import EfficientNetB3

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices:: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  98%|███████████████████████████████████████▏| 981M/0.98G [00:02<00:00, 317MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:02<00:00, 361MB/s]

# %%
config = {"Seg_model":"EffiSegNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":24,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-12-4d2165c92940>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
# Definition of layers for the neural network structure

DefaultConv2D = partial(layers.Conv2D,
                        kernel_size=3, activation='relu', padding="same")

DefaultPooling = partial(layers.MaxPool2D,
                        pool_size=2)

upsample = partial(layers.UpSampling2D, (2,2))

@register_keras_serializable(package="my_custom_losses")
class DiceCoefficient(Loss):
    def __init__(self, smooth=1., target_class= None, name='DiceCoefficient', **kwargs):
        self.smooth = smooth
        self.target_class = target_class
        super().__init__(name=name,**kwargs)

    def call(self, y_true, y_pred):
        intersection = K.sum(y_true * y_pred, axis=[1,2])
        union = K.sum(y_true,axis=[1,2]) + K.sum(y_pred,axis=[1,2])
        dice_coef = -(2. * intersection + self.smooth) /(union + self.smooth)
        
        if self.target_class != None:
            dice_coef = tf.gather(dice_coef,
                                  self.target_class, axis=1)
        else:
            dice_coef = K.mean(dice_coef,axis=-1)

        return dice_coef

    def get_config(self,):
        base_config = super().get_config()
        return {**base_config, "smooth": self.smooth,
                "target_class":self.target_class}

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)


@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

def kernel_initializer(seed):
    
    return tf.keras.initializers.GlorotUniform(seed=seed)


def residual_block(x, filters, kernel_initializer, block_name):
    
    shortcut = x
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_1')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_1')(x)
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_2')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_2')(x)
    x = layers.Add(name=f'ResAdd_{block_name}')([shortcut, x])
    x = layers.Activation('relu', name=f'ResAct_{block_name}')(x)
    return x

def EffiSegNet(inputs, input_shape, out_channels, activation):
    
    # Backbone (EfficientNetB3) - Use pre-trained weights from ImageNet
    backbone = EfficientNetB3(
        input_shape=input_shape,
        input_tensor=inputs,
        include_top=False,
        weights='imagenet')
    
    # Freeze backbone layers except BatchNormalization layers
    for layer in backbone.layers:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = False

    # Extract feature maps from different levels of the EfficientNetB3 backbone
    level_1 = backbone.get_layer('block2a_expand_activation').output  # Example: initial output
    level_2 = backbone.get_layer('block3a_expand_activation').output  # Example: intermediate output 1
    level_3 = backbone.get_layer('block4a_expand_activation').output  # Example: intermediate output 2
    level_4 = backbone.get_layer('block6a_expand_activation').output  # Example: intermediate output 3
    x       = backbone.get_layer('top_activation').output            # Last output (8x8 or similar)

    # Decoder - Upsampling path with skip connections to encoder features
    # First upsampling block
    x = upsample(name='Up60')(x)
    x = layers.Concatenate(name='Concat60')([level_4, x])
    x = DefaultConv2D(256, kernel_initializer=kernel_initializer(91), name='Conv60')(x)
    x = residual_block(x, 256, kernel_initializer(47), '60')  # Apply residual block

    # Second upsampling block
    x = upsample(name='Up70')(x)
    x = layers.Concatenate(name='Concat70')([level_3, x])
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(21), name='Conv70')(x)
    x = residual_block(x, 128, kernel_initializer(96), '70')  # Apply residual block

    # Third upsampling block
    x = upsample(name='Up80')(x)
    x = layers.Concatenate(name='Concat80')([level_2, x])
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(96), name='Conv80')(x)
    x = residual_block(x, 64, kernel_initializer(98), '80')  # Apply residual block

    # Fourth upsampling block
    x = upsample(name='Up90')(x)
    x = layers.Concatenate(name='Concat90')([level_1, x])
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(35), name='Conv90')(x)
    x = residual_block(x, 32, kernel_initializer(7), '90')  # Apply residual block

    # Final upsampling block - connect back to input
    x = upsample(name='Up100')(x)
    x = layers.Concatenate(name='Concat100')([inputs, x])
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(45), name='Conv100')(x)
    x = residual_block(x, 16, kernel_initializer(7), '100')  # Apply residual block

    # Final segmentation output with specified activation
    if activation == 'sparse_softmax':
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=sparse_softmax,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)
    else:
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=activation,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)

    return x

def Seg_Model(class_no=2, input_shape=(512, 512, 3), seg_model='EffiSegNet', activation='softmax'):
    
    # Input layer definition
    image_input = layers.Input(shape=input_shape, name='image_input')

    # Select and build the appropriate segmentation backbone
    if seg_model == 'EffiSegNet':
        # Use EfficientNet-based Res-UNet architecture
        seg_rm = EffiSegNet(image_input, input_shape, out_channels=class_no, activation=activation)
    else:
        # Raise error for unsupported model types
        raise ValueError(f"Unsupported segmentation model type: {seg_model}. Supported model is 'EffiSegNet'.")

    # Create and return the final model
    return Model(image_input, seg_rm, name=seg_model)

# %%
with strategy.scope():
    model = Seg_Model(class_no=config['Number of classes'],input_shape=config['Input size'], 
                 seg_model=config['Seg_model'], activation=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 1s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)


history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 103/103 [==============================] - 307s 2s/step - loss: -0.6298 - dice_metric: 0.6349 - jaccard_metric: 0.5697 - sensitivity_metric: 0.6554 - specificity_metric: 0.9273 - val_loss: -0.3260 - val_dice_metric: 0.3261 - val_jaccard_metric: 0.3192 - val_sensitivity_metric: 0.3333 - val_specificity_metric: 0.6667
# Epoch 2/60
# 103/103 [==============================] - 204s 2s/step - loss: -0.7262 - dice_metric: 0.7279 - jaccard_metric: 0.6591 - sensitivity_metric: 0.7379 - specificity_metric: 0.9504 - val_loss: -0.3260 - val_dice_metric: 0.3260 - val_jaccard_metric: 0.3192 - val_sensitivity_metric: 0.3333 - val_specificity_metric: 0.6667
# Epoch 3/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.7494 - dice_metric: 0.7507 - jaccard_metric: 0.6842 - sensitivity_metric: 0.7576 - specificity_metric: 0.9538 - val_loss: -0.3827 - val_dice_metric: 0.3824 - val_jaccard_metric: 0.3562 - val_sensitivity_metric: 0.3728 - val_specificity_metric: 0.6975
# Epoch 4/60
# 103/103 [==============================] - 196s 2s/step - loss: -0.7609 - dice_metric: 0.7627 - jaccard_metric: 0.6982 - sensitivity_metric: 0.7693 - specificity_metric: 0.9559 - val_loss: -0.5630 - val_dice_metric: 0.5641 - val_jaccard_metric: 0.4935 - val_sensitivity_metric: 0.5211 - val_specificity_metric: 0.8116
# Epoch 5/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7678 - dice_metric: 0.7714 - jaccard_metric: 0.7079 - sensitivity_metric: 0.7758 - specificity_metric: 0.9572 - val_loss: -0.6768 - val_dice_metric: 0.6820 - val_jaccard_metric: 0.6124 - val_sensitivity_metric: 0.6404 - val_specificity_metric: 0.8990
# Epoch 6/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7741 - dice_metric: 0.7788 - jaccard_metric: 0.7163 - sensitivity_metric: 0.7824 - specificity_metric: 0.9582 - val_loss: -0.7097 - val_dice_metric: 0.7365 - val_jaccard_metric: 0.6740 - val_sensitivity_metric: 0.6791 - val_specificity_metric: 0.9263
# Epoch 7/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7799 - dice_metric: 0.7837 - jaccard_metric: 0.7224 - sensitivity_metric: 0.7871 - specificity_metric: 0.9588 - val_loss: -0.7495 - val_dice_metric: 0.7679 - val_jaccard_metric: 0.7164 - val_sensitivity_metric: 0.7389 - val_specificity_metric: 0.9563
# Epoch 8/60
# 103/103 [==============================] - 204s 2s/step - loss: -0.7841 - dice_metric: 0.7892 - jaccard_metric: 0.7285 - sensitivity_metric: 0.7913 - specificity_metric: 0.9595 - val_loss: -0.7577 - val_dice_metric: 0.7641 - val_jaccard_metric: 0.7155 - val_sensitivity_metric: 0.7490 - val_specificity_metric: 0.9612
# Epoch 9/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.7874 - dice_metric: 0.7929 - jaccard_metric: 0.7329 - sensitivity_metric: 0.7946 - specificity_metric: 0.9599 - val_loss: -0.7598 - val_dice_metric: 0.7935 - val_jaccard_metric: 0.7463 - val_sensitivity_metric: 0.7647 - val_specificity_metric: 0.9714
# Epoch 10/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7891 - dice_metric: 0.7955 - jaccard_metric: 0.7357 - sensitivity_metric: 0.7961 - specificity_metric: 0.9603 - val_loss: -0.7639 - val_dice_metric: 0.7849 - val_jaccard_metric: 0.7390 - val_sensitivity_metric: 0.7655 - val_specificity_metric: 0.9708
# Epoch 11/60
# 103/103 [==============================] - 206s 2s/step - loss: -0.7892 - dice_metric: 0.7955 - jaccard_metric: 0.7358 - sensitivity_metric: 0.7957 - specificity_metric: 0.9602 - val_loss: -0.7647 - val_dice_metric: 0.7917 - val_jaccard_metric: 0.7471 - val_sensitivity_metric: 0.7758 - val_specificity_metric: 0.9774
# Epoch 12/60
# 103/103 [==============================] - 205s 2s/step - loss: -0.7919 - dice_metric: 0.7987 - jaccard_metric: 0.7399 - sensitivity_metric: 0.7987 - specificity_metric: 0.9607 - val_loss: -0.7655 - val_dice_metric: 0.7734 - val_jaccard_metric: 0.7290 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9727
# Epoch 13/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7958 - dice_metric: 0.8011 - jaccard_metric: 0.7430 - sensitivity_metric: 0.8021 - specificity_metric: 0.9611 - val_loss: -0.7645 - val_dice_metric: 0.7710 - val_jaccard_metric: 0.7257 - val_sensitivity_metric: 0.7724 - val_specificity_metric: 0.9752
# Epoch 14/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7966 - dice_metric: 0.8042 - jaccard_metric: 0.7463 - sensitivity_metric: 0.8036 - specificity_metric: 0.9615 - val_loss: -0.7658 - val_dice_metric: 0.8186 - val_jaccard_metric: 0.7745 - val_sensitivity_metric: 0.7676 - val_specificity_metric: 0.9718
# Epoch 15/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7997 - dice_metric: 0.8078 - jaccard_metric: 0.7506 - sensitivity_metric: 0.8054 - specificity_metric: 0.9616 - val_loss: -0.7667 - val_dice_metric: 0.7910 - val_jaccard_metric: 0.7478 - val_sensitivity_metric: 0.7625 - val_specificity_metric: 0.9671
# Epoch 16/60
# 103/103 [==============================] - 200s 2s/step - loss: -0.7963 - dice_metric: 0.8021 - jaccard_metric: 0.7439 - sensitivity_metric: 0.8028 - specificity_metric: 0.9614 - val_loss: -0.7667 - val_dice_metric: 0.7731 - val_jaccard_metric: 0.7291 - val_sensitivity_metric: 0.7747 - val_specificity_metric: 0.9761
# Epoch 17/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.7999 - dice_metric: 0.8050 - jaccard_metric: 0.7478 - sensitivity_metric: 0.8067 - specificity_metric: 0.9620 - val_loss: -0.7670 - val_dice_metric: 0.7946 - val_jaccard_metric: 0.7505 - val_sensitivity_metric: 0.7738 - val_specificity_metric: 0.9756
# Epoch 18/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8031 - dice_metric: 0.8098 - jaccard_metric: 0.7532 - sensitivity_metric: 0.8087 - specificity_metric: 0.9625 - val_loss: -0.7668 - val_dice_metric: 0.7866 - val_jaccard_metric: 0.7430 - val_sensitivity_metric: 0.7696 - val_specificity_metric: 0.9725
# Epoch 19/60
# 103/103 [==============================] - 199s 2s/step - loss: -0.8038 - dice_metric: 0.8100 - jaccard_metric: 0.7536 - sensitivity_metric: 0.8089 - specificity_metric: 0.9625 - val_loss: -0.7686 - val_dice_metric: 0.8001 - val_jaccard_metric: 0.7556 - val_sensitivity_metric: 0.7726 - val_specificity_metric: 0.9750
# Epoch 20/60
# 103/103 [==============================] - 200s 2s/step - loss: -0.8047 - dice_metric: 0.8114 - jaccard_metric: 0.7555 - sensitivity_metric: 0.8106 - specificity_metric: 0.9627 - val_loss: -0.7688 - val_dice_metric: 0.7712 - val_jaccard_metric: 0.7268 - val_sensitivity_metric: 0.7747 - val_specificity_metric: 0.9746
# Epoch 21/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8064 - dice_metric: 0.8164 - jaccard_metric: 0.7611 - sensitivity_metric: 0.8124 - specificity_metric: 0.9629 - val_loss: -0.7669 - val_dice_metric: 0.7731 - val_jaccard_metric: 0.7300 - val_sensitivity_metric: 0.7690 - val_specificity_metric: 0.9719
# Epoch 22/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.8071 - dice_metric: 0.8192 - jaccard_metric: 0.7636 - sensitivity_metric: 0.8127 - specificity_metric: 0.9631 - val_loss: -0.7684 - val_dice_metric: 0.7839 - val_jaccard_metric: 0.7415 - val_sensitivity_metric: 0.7746 - val_specificity_metric: 0.9759
# Epoch 23/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8072 - dice_metric: 0.8196 - jaccard_metric: 0.7646 - sensitivity_metric: 0.8128 - specificity_metric: 0.9630 - val_loss: -0.7687 - val_dice_metric: 0.7835 - val_jaccard_metric: 0.7405 - val_sensitivity_metric: 0.7744 - val_specificity_metric: 0.9742
# Epoch 24/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.8078 - dice_metric: 0.8202 - jaccard_metric: 0.7654 - sensitivity_metric: 0.8135 - specificity_metric: 0.9632 - val_loss: -0.7654 - val_dice_metric: 0.7717 - val_jaccard_metric: 0.7270 - val_sensitivity_metric: 0.7750 - val_specificity_metric: 0.9760
# Epoch 25/60
# 103/103 [==============================] - 205s 2s/step - loss: -0.8094 - dice_metric: 0.8225 - jaccard_metric: 0.7679 - sensitivity_metric: 0.8149 - specificity_metric: 0.9632 - val_loss: -0.7671 - val_dice_metric: 0.7909 - val_jaccard_metric: 0.7471 - val_sensitivity_metric: 0.7726 - val_specificity_metric: 0.9755
# Epoch 26/60
# 103/103 [==============================] - 199s 2s/step - loss: -0.8090 - dice_metric: 0.8150 - jaccard_metric: 0.7600 - sensitivity_metric: 0.8147 - specificity_metric: 0.9633 - val_loss: -0.7697 - val_dice_metric: 0.7775 - val_jaccard_metric: 0.7348 - val_sensitivity_metric: 0.7740 - val_specificity_metric: 0.9751
# Epoch 27/60
# 103/103 [==============================] - 195s 2s/step - loss: -0.8101 - dice_metric: 0.8205 - jaccard_metric: 0.7659 - sensitivity_metric: 0.8158 - specificity_metric: 0.9635 - val_loss: -0.7691 - val_dice_metric: 0.7903 - val_jaccard_metric: 0.7480 - val_sensitivity_metric: 0.7799 - val_specificity_metric: 0.9789
# Epoch 28/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8108 - dice_metric: 0.8210 - jaccard_metric: 0.7668 - sensitivity_metric: 0.8162 - specificity_metric: 0.9637 - val_loss: -0.7661 - val_dice_metric: 0.8286 - val_jaccard_metric: 0.7863 - val_sensitivity_metric: 0.7671 - val_specificity_metric: 0.9731
# Epoch 29/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8117 - dice_metric: 0.8210 - jaccard_metric: 0.7672 - sensitivity_metric: 0.8173 - specificity_metric: 0.9641 - val_loss: -0.7680 - val_dice_metric: 0.7785 - val_jaccard_metric: 0.7357 - val_sensitivity_metric: 0.7705 - val_specificity_metric: 0.9746
# Epoch 30/60
# 103/103 [==============================] - 196s 2s/step - loss: -0.8134 - dice_metric: 0.8233 - jaccard_metric: 0.7700 - sensitivity_metric: 0.8179 - specificity_metric: 0.9639 - val_loss: -0.7691 - val_dice_metric: 0.7795 - val_jaccard_metric: 0.7372 - val_sensitivity_metric: 0.7756 - val_specificity_metric: 0.9756
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8154 - dice_metric: 0.8282 - jaccard_metric: 0.7754 - sensitivity_metric: 0.8201 - specificity_metric: 0.9642 - val_loss: -0.7713 - val_dice_metric: 0.8002 - val_jaccard_metric: 0.7594 - val_sensitivity_metric: 0.7795 - val_specificity_metric: 0.9772
# Epoch 32/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8174 - dice_metric: 0.8306 - jaccard_metric: 0.7785 - sensitivity_metric: 0.8220 - specificity_metric: 0.9645 - val_loss: -0.7714 - val_dice_metric: 0.8003 - val_jaccard_metric: 0.7595 - val_sensitivity_metric: 0.7803 - val_specificity_metric: 0.9777
# Epoch 33/60
# 103/103 [==============================] - 200s 2s/step - loss: -0.8182 - dice_metric: 0.8346 - jaccard_metric: 0.7826 - sensitivity_metric: 0.8229 - specificity_metric: 0.9646 - val_loss: -0.7719 - val_dice_metric: 0.8258 - val_jaccard_metric: 0.7853 - val_sensitivity_metric: 0.7797 - val_specificity_metric: 0.9773
# Epoch 34/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.8187 - dice_metric: 0.8368 - jaccard_metric: 0.7851 - sensitivity_metric: 0.8234 - specificity_metric: 0.9646 - val_loss: -0.7713 - val_dice_metric: 0.8350 - val_jaccard_metric: 0.7943 - val_sensitivity_metric: 0.7790 - val_specificity_metric: 0.9770
# Epoch 35/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8192 - dice_metric: 0.8371 - jaccard_metric: 0.7853 - sensitivity_metric: 0.8238 - specificity_metric: 0.9646 - val_loss: -0.7713 - val_dice_metric: 0.8086 - val_jaccard_metric: 0.7680 - val_sensitivity_metric: 0.7780 - val_specificity_metric: 0.9765
# Epoch 36/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8198 - dice_metric: 0.8354 - jaccard_metric: 0.7839 - sensitivity_metric: 0.8243 - specificity_metric: 0.9647 - val_loss: -0.7723 - val_dice_metric: 0.8044 - val_jaccard_metric: 0.7637 - val_sensitivity_metric: 0.7813 - val_specificity_metric: 0.9776
# Epoch 37/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8200 - dice_metric: 0.8326 - jaccard_metric: 0.7811 - sensitivity_metric: 0.8245 - specificity_metric: 0.9647 - val_loss: -0.7718 - val_dice_metric: 0.8026 - val_jaccard_metric: 0.7614 - val_sensitivity_metric: 0.7814 - val_specificity_metric: 0.9783
# Epoch 38/60
# 103/103 [==============================] - 204s 2s/step - loss: -0.8205 - dice_metric: 0.8358 - jaccard_metric: 0.7843 - sensitivity_metric: 0.8251 - specificity_metric: 0.9647 - val_loss: -0.7727 - val_dice_metric: 0.8197 - val_jaccard_metric: 0.7790 - val_sensitivity_metric: 0.7815 - val_specificity_metric: 0.9777
# Epoch 39/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8205 - dice_metric: 0.8359 - jaccard_metric: 0.7845 - sensitivity_metric: 0.8252 - specificity_metric: 0.9649 - val_loss: -0.7721 - val_dice_metric: 0.8164 - val_jaccard_metric: 0.7755 - val_sensitivity_metric: 0.7807 - val_specificity_metric: 0.9778
# Epoch 40/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8212 - dice_metric: 0.8350 - jaccard_metric: 0.7838 - sensitivity_metric: 0.8255 - specificity_metric: 0.9647 - val_loss: -0.7721 - val_dice_metric: 0.8136 - val_jaccard_metric: 0.7728 - val_sensitivity_metric: 0.7808 - val_specificity_metric: 0.9778
# Epoch 41/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8211 - dice_metric: 0.8368 - jaccard_metric: 0.7855 - sensitivity_metric: 0.8256 - specificity_metric: 0.9649 - val_loss: -0.7723 - val_dice_metric: 0.8221 - val_jaccard_metric: 0.7814 - val_sensitivity_metric: 0.7807 - val_specificity_metric: 0.9778
# Epoch 42/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8210 - dice_metric: 0.8358 - jaccard_metric: 0.7846 - sensitivity_metric: 0.8256 - specificity_metric: 0.9650 - val_loss: -0.7724 - val_dice_metric: 0.8139 - val_jaccard_metric: 0.7732 - val_sensitivity_metric: 0.7803 - val_specificity_metric: 0.9774
# Epoch 43/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.8214 - dice_metric: 0.8352 - jaccard_metric: 0.7840 - sensitivity_metric: 0.8256 - specificity_metric: 0.9648 - val_loss: -0.7712 - val_dice_metric: 0.8112 - val_jaccard_metric: 0.7701 - val_sensitivity_metric: 0.7794 - val_specificity_metric: 0.9773
# Epoch 44/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8218 - dice_metric: 0.8359 - jaccard_metric: 0.7849 - sensitivity_metric: 0.8262 - specificity_metric: 0.9650 - val_loss: -0.7717 - val_dice_metric: 0.8216 - val_jaccard_metric: 0.7802 - val_sensitivity_metric: 0.7796 - val_specificity_metric: 0.9769
# Epoch 45/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.8220 - dice_metric: 0.8389 - jaccard_metric: 0.7880 - sensitivity_metric: 0.8262 - specificity_metric: 0.9650 - val_loss: -0.7721 - val_dice_metric: 0.8191 - val_jaccard_metric: 0.7783 - val_sensitivity_metric: 0.7802 - val_specificity_metric: 0.9776
# Epoch 46/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8223 - dice_metric: 0.8379 - jaccard_metric: 0.7870 - sensitivity_metric: 0.8264 - specificity_metric: 0.9650 - val_loss: -0.7726 - val_dice_metric: 0.8169 - val_jaccard_metric: 0.7759 - val_sensitivity_metric: 0.7820 - val_specificity_metric: 0.9781
# Epoch 47/60
# 103/103 [==============================] - 204s 2s/step - loss: -0.8224 - dice_metric: 0.8385 - jaccard_metric: 0.7877 - sensitivity_metric: 0.8265 - specificity_metric: 0.9650 - val_loss: -0.7719 - val_dice_metric: 0.8135 - val_jaccard_metric: 0.7724 - val_sensitivity_metric: 0.7798 - val_specificity_metric: 0.9773
# Epoch 48/60
# 103/103 [==============================] - 205s 2s/step - loss: -0.8226 - dice_metric: 0.8354 - jaccard_metric: 0.7846 - sensitivity_metric: 0.8266 - specificity_metric: 0.9651 - val_loss: -0.7722 - val_dice_metric: 0.8042 - val_jaccard_metric: 0.7627 - val_sensitivity_metric: 0.7807 - val_specificity_metric: 0.9772
# Epoch 49/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8232 - dice_metric: 0.8371 - jaccard_metric: 0.7864 - sensitivity_metric: 0.8273 - specificity_metric: 0.9651 - val_loss: -0.7719 - val_dice_metric: 0.8244 - val_jaccard_metric: 0.7834 - val_sensitivity_metric: 0.7800 - val_specificity_metric: 0.9775
# Epoch 50/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8233 - dice_metric: 0.8387 - jaccard_metric: 0.7880 - sensitivity_metric: 0.8271 - specificity_metric: 0.9651 - val_loss: -0.7727 - val_dice_metric: 0.8210 - val_jaccard_metric: 0.7802 - val_sensitivity_metric: 0.7813 - val_specificity_metric: 0.9777
# Epoch 51/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8233 - dice_metric: 0.8389 - jaccard_metric: 0.7881 - sensitivity_metric: 0.8274 - specificity_metric: 0.9651 - val_loss: -0.7724 - val_dice_metric: 0.8332 - val_jaccard_metric: 0.7924 - val_sensitivity_metric: 0.7808 - val_specificity_metric: 0.9779
# Epoch 52/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.8233 - dice_metric: 0.8375 - jaccard_metric: 0.7869 - sensitivity_metric: 0.8272 - specificity_metric: 0.9652 - val_loss: -0.7727 - val_dice_metric: 0.8142 - val_jaccard_metric: 0.7729 - val_sensitivity_metric: 0.7819 - val_specificity_metric: 0.9778
# Epoch 53/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8236 - dice_metric: 0.8379 - jaccard_metric: 0.7873 - sensitivity_metric: 0.8277 - specificity_metric: 0.9652 - val_loss: -0.7723 - val_dice_metric: 0.8328 - val_jaccard_metric: 0.7919 - val_sensitivity_metric: 0.7818 - val_specificity_metric: 0.9784
# Epoch 54/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8238 - dice_metric: 0.8393 - jaccard_metric: 0.7889 - sensitivity_metric: 0.8278 - specificity_metric: 0.9653 - val_loss: -0.7721 - val_dice_metric: 0.8289 - val_jaccard_metric: 0.7877 - val_sensitivity_metric: 0.7808 - val_specificity_metric: 0.9780
# Epoch 55/60
# 103/103 [==============================] - 201s 2s/step - loss: -0.8238 - dice_metric: 0.8393 - jaccard_metric: 0.7888 - sensitivity_metric: 0.8276 - specificity_metric: 0.9650 - val_loss: -0.7718 - val_dice_metric: 0.8189 - val_jaccard_metric: 0.7778 - val_sensitivity_metric: 0.7807 - val_specificity_metric: 0.9781
# Epoch 56/60
# 103/103 [==============================] - 198s 2s/step - loss: -0.8241 - dice_metric: 0.8413 - jaccard_metric: 0.7909 - sensitivity_metric: 0.8281 - specificity_metric: 0.9653 - val_loss: -0.7723 - val_dice_metric: 0.8122 - val_jaccard_metric: 0.7711 - val_sensitivity_metric: 0.7811 - val_specificity_metric: 0.9776
# Epoch 57/60
# 103/103 [==============================] - 202s 2s/step - loss: -0.8246 - dice_metric: 0.8415 - jaccard_metric: 0.7912 - sensitivity_metric: 0.8283 - specificity_metric: 0.9653 - val_loss: -0.7732 - val_dice_metric: 0.8159 - val_jaccard_metric: 0.7751 - val_sensitivity_metric: 0.7820 - val_specificity_metric: 0.9778
# Epoch 58/60
# 103/103 [==============================] - 207s 2s/step - loss: -0.8247 - dice_metric: 0.8429 - jaccard_metric: 0.7926 - sensitivity_metric: 0.8288 - specificity_metric: 0.9654 - val_loss: -0.7733 - val_dice_metric: 0.8091 - val_jaccard_metric: 0.7682 - val_sensitivity_metric: 0.7812 - val_specificity_metric: 0.9773
# Epoch 59/60
# 103/103 [==============================] - 203s 2s/step - loss: -0.8252 - dice_metric: 0.8421 - jaccard_metric: 0.7920 - sensitivity_metric: 0.8290 - specificity_metric: 0.9652 - val_loss: -0.7725 - val_dice_metric: 0.8125 - val_jaccard_metric: 0.7712 - val_sensitivity_metric: 0.7822 - val_specificity_metric: 0.9780
# Epoch 60/60
# 103/103 [==============================] - 199s 2s/step - loss: -0.8252 - dice_metric: 0.8406 - jaccard_metric: 0.7904 - sensitivity_metric: 0.8291 - specificity_metric: 0.9654 - val_loss: -0.7716 - val_dice_metric: 0.8105 - val_jaccard_metric: 0.7694 - val_sensitivity_metric: 0.7800 - val_specificity_metric: 0.9778

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (24, 512, 512, 3), Masks in the batch: (24, 512, 512, 3)
# <ipython-input-23-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.82524, standard deviation: 0.29998
# Jaccard Index mean: 0.77986, standard deviation: 0.30771
# Sensitivity mean: 0.80327, standard deviation: 0.33219
# Specificity mean: 0.97725, standard deviation: 0.04436
