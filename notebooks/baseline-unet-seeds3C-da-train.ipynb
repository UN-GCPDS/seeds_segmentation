# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  98%|███████████████████████████████████████▏| 981M/0.98G [00:06<00:00, 209MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:06<00:00, 152MB/s]

# %%
config = {"Seg_model":"UNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_baseline, fcn_baseline, segnet_baseline, res_unet_baseline
from seeds_segmentation.losses import DiceCoefficient 
from seeds_segmentation.metrics import DiceCoefficientMetric, Jaccard, Sensitivity, Specificity

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = unet_baseline(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 78s 650ms/step - loss: -0.2579 - dice_metric: 0.2810 - jaccard_metric: 0.2036 - sensitivity_metric: 0.4458 - specificity_metric: 0.8570 - val_loss: -0.2495 - val_dice_metric: 0.4729 - val_jaccard_metric: 0.4582 - val_sensitivity_metric: 0.3126 - val_specificity_metric: 0.7215
# Epoch 2/60
# 77/77 [==============================] - 43s 554ms/step - loss: -0.3252 - dice_metric: 0.3950 - jaccard_metric: 0.3255 - sensitivity_metric: 0.5486 - specificity_metric: 0.8946 - val_loss: -0.3086 - val_dice_metric: 0.3247 - val_jaccard_metric: 0.3166 - val_sensitivity_metric: 0.3304 - val_specificity_metric: 0.6653
# Epoch 3/60
# 77/77 [==============================] - 43s 559ms/step - loss: -0.3531 - dice_metric: 0.4215 - jaccard_metric: 0.3567 - sensitivity_metric: 0.5678 - specificity_metric: 0.8981 - val_loss: -0.3429 - val_dice_metric: 0.3533 - val_jaccard_metric: 0.3344 - val_sensitivity_metric: 0.3498 - val_specificity_metric: 0.6957
# Epoch 4/60
# 77/77 [==============================] - 44s 565ms/step - loss: -0.3782 - dice_metric: 0.4454 - jaccard_metric: 0.3821 - sensitivity_metric: 0.5851 - specificity_metric: 0.9036 - val_loss: -0.4549 - val_dice_metric: 0.4928 - val_jaccard_metric: 0.4371 - val_sensitivity_metric: 0.4965 - val_specificity_metric: 0.8615
# Epoch 5/60
# 77/77 [==============================] - 44s 564ms/step - loss: -0.3990 - dice_metric: 0.4700 - jaccard_metric: 0.4080 - sensitivity_metric: 0.6027 - specificity_metric: 0.9107 - val_loss: -0.4927 - val_dice_metric: 0.5194 - val_jaccard_metric: 0.4689 - val_sensitivity_metric: 0.5837 - val_specificity_metric: 0.9243
# Epoch 6/60
# 77/77 [==============================] - 44s 566ms/step - loss: -0.4149 - dice_metric: 0.4869 - jaccard_metric: 0.4269 - sensitivity_metric: 0.6137 - specificity_metric: 0.9151 - val_loss: -0.4727 - val_dice_metric: 0.4906 - val_jaccard_metric: 0.4362 - val_sensitivity_metric: 0.5963 - val_specificity_metric: 0.9171
# Epoch 7/60
# 77/77 [==============================] - 45s 579ms/step - loss: -0.4275 - dice_metric: 0.4973 - jaccard_metric: 0.4380 - sensitivity_metric: 0.6213 - specificity_metric: 0.9187 - val_loss: -0.4797 - val_dice_metric: 0.5012 - val_jaccard_metric: 0.4506 - val_sensitivity_metric: 0.5984 - val_specificity_metric: 0.9164
# Epoch 8/60
# 77/77 [==============================] - 44s 567ms/step - loss: -0.4402 - dice_metric: 0.5072 - jaccard_metric: 0.4489 - sensitivity_metric: 0.6286 - specificity_metric: 0.9218 - val_loss: -0.4404 - val_dice_metric: 0.4528 - val_jaccard_metric: 0.3957 - val_sensitivity_metric: 0.5845 - val_specificity_metric: 0.8984
# Epoch 9/60
# 77/77 [==============================] - 45s 580ms/step - loss: -0.4509 - dice_metric: 0.5172 - jaccard_metric: 0.4591 - sensitivity_metric: 0.6365 - specificity_metric: 0.9253 - val_loss: -0.4840 - val_dice_metric: 0.5054 - val_jaccard_metric: 0.4569 - val_sensitivity_metric: 0.6052 - val_specificity_metric: 0.9168
# Epoch 10/60
# 77/77 [==============================] - 43s 553ms/step - loss: -0.4610 - dice_metric: 0.5241 - jaccard_metric: 0.4659 - sensitivity_metric: 0.6427 - specificity_metric: 0.9273 - val_loss: -0.4926 - val_dice_metric: 0.5162 - val_jaccard_metric: 0.4674 - val_sensitivity_metric: 0.6140 - val_specificity_metric: 0.9228
# Epoch 11/60
# 77/77 [==============================] - 45s 574ms/step - loss: -0.4712 - dice_metric: 0.5326 - jaccard_metric: 0.4742 - sensitivity_metric: 0.6520 - specificity_metric: 0.9300 - val_loss: -0.4886 - val_dice_metric: 0.5126 - val_jaccard_metric: 0.4634 - val_sensitivity_metric: 0.6152 - val_specificity_metric: 0.9185
# Epoch 12/60
# 77/77 [==============================] - 43s 554ms/step - loss: -0.4814 - dice_metric: 0.5412 - jaccard_metric: 0.4819 - sensitivity_metric: 0.6631 - specificity_metric: 0.9324 - val_loss: -0.4972 - val_dice_metric: 0.5216 - val_jaccard_metric: 0.4714 - val_sensitivity_metric: 0.6234 - val_specificity_metric: 0.9214
# Epoch 13/60
# 77/77 [==============================] - 45s 581ms/step - loss: -0.4917 - dice_metric: 0.5499 - jaccard_metric: 0.4894 - sensitivity_metric: 0.6735 - specificity_metric: 0.9339 - val_loss: -0.5046 - val_dice_metric: 0.5297 - val_jaccard_metric: 0.4747 - val_sensitivity_metric: 0.6319 - val_specificity_metric: 0.9224
# Epoch 14/60
# 77/77 [==============================] - 45s 586ms/step - loss: -0.5019 - dice_metric: 0.5583 - jaccard_metric: 0.4965 - sensitivity_metric: 0.6836 - specificity_metric: 0.9354 - val_loss: -0.5115 - val_dice_metric: 0.5363 - val_jaccard_metric: 0.4799 - val_sensitivity_metric: 0.6284 - val_specificity_metric: 0.9235
# Epoch 15/60
# 77/77 [==============================] - 46s 590ms/step - loss: -0.5128 - dice_metric: 0.5682 - jaccard_metric: 0.5053 - sensitivity_metric: 0.6925 - specificity_metric: 0.9370 - val_loss: -0.5140 - val_dice_metric: 0.5387 - val_jaccard_metric: 0.4840 - val_sensitivity_metric: 0.6232 - val_specificity_metric: 0.9213
# Epoch 16/60
# 77/77 [==============================] - 44s 565ms/step - loss: -0.5237 - dice_metric: 0.5782 - jaccard_metric: 0.5139 - sensitivity_metric: 0.6969 - specificity_metric: 0.9384 - val_loss: -0.5245 - val_dice_metric: 0.5459 - val_jaccard_metric: 0.4901 - val_sensitivity_metric: 0.6319 - val_specificity_metric: 0.9254
# Epoch 17/60
# 77/77 [==============================] - 42s 543ms/step - loss: -0.5323 - dice_metric: 0.5855 - jaccard_metric: 0.5198 - sensitivity_metric: 0.6986 - specificity_metric: 0.9393 - val_loss: -0.5358 - val_dice_metric: 0.5575 - val_jaccard_metric: 0.5003 - val_sensitivity_metric: 0.6405 - val_specificity_metric: 0.9295
# Epoch 18/60
# 77/77 [==============================] - 45s 581ms/step - loss: -0.5415 - dice_metric: 0.5933 - jaccard_metric: 0.5266 - sensitivity_metric: 0.7008 - specificity_metric: 0.9397 - val_loss: -0.5339 - val_dice_metric: 0.5568 - val_jaccard_metric: 0.4985 - val_sensitivity_metric: 0.6389 - val_specificity_metric: 0.9225
# Epoch 19/60
# 77/77 [==============================] - 46s 593ms/step - loss: -0.5518 - dice_metric: 0.6042 - jaccard_metric: 0.5368 - sensitivity_metric: 0.7071 - specificity_metric: 0.9398 - val_loss: -0.5484 - val_dice_metric: 0.5709 - val_jaccard_metric: 0.5124 - val_sensitivity_metric: 0.6454 - val_specificity_metric: 0.9277
# Epoch 20/60
# 77/77 [==============================] - 44s 562ms/step - loss: -0.5607 - dice_metric: 0.6131 - jaccard_metric: 0.5450 - sensitivity_metric: 0.7100 - specificity_metric: 0.9395 - val_loss: -0.5488 - val_dice_metric: 0.5707 - val_jaccard_metric: 0.5127 - val_sensitivity_metric: 0.6432 - val_specificity_metric: 0.9233
# Epoch 21/60
# 77/77 [==============================] - 46s 601ms/step - loss: -0.5702 - dice_metric: 0.6209 - jaccard_metric: 0.5522 - sensitivity_metric: 0.7120 - specificity_metric: 0.9384 - val_loss: -0.5598 - val_dice_metric: 0.5805 - val_jaccard_metric: 0.5219 - val_sensitivity_metric: 0.6435 - val_specificity_metric: 0.9272
# Epoch 22/60
# 77/77 [==============================] - 44s 565ms/step - loss: -0.5783 - dice_metric: 0.6273 - jaccard_metric: 0.5584 - sensitivity_metric: 0.7152 - specificity_metric: 0.9382 - val_loss: -0.5639 - val_dice_metric: 0.5803 - val_jaccard_metric: 0.5194 - val_sensitivity_metric: 0.6438 - val_specificity_metric: 0.9297
# Epoch 23/60
# 77/77 [==============================] - 45s 578ms/step - loss: -0.5845 - dice_metric: 0.6309 - jaccard_metric: 0.5620 - sensitivity_metric: 0.7170 - specificity_metric: 0.9381 - val_loss: -0.5773 - val_dice_metric: 0.5938 - val_jaccard_metric: 0.5361 - val_sensitivity_metric: 0.6556 - val_specificity_metric: 0.9309
# Epoch 24/60
# 77/77 [==============================] - 47s 605ms/step - loss: -0.5922 - dice_metric: 0.6365 - jaccard_metric: 0.5676 - sensitivity_metric: 0.7204 - specificity_metric: 0.9383 - val_loss: -0.5786 - val_dice_metric: 0.5931 - val_jaccard_metric: 0.5341 - val_sensitivity_metric: 0.6608 - val_specificity_metric: 0.9288
# Epoch 25/60
# 77/77 [==============================] - 46s 593ms/step - loss: -0.6007 - dice_metric: 0.6464 - jaccard_metric: 0.5772 - sensitivity_metric: 0.7230 - specificity_metric: 0.9378 - val_loss: -0.5793 - val_dice_metric: 0.5965 - val_jaccard_metric: 0.5350 - val_sensitivity_metric: 0.6548 - val_specificity_metric: 0.9264
# Epoch 26/60
# 77/77 [==============================] - 47s 605ms/step - loss: -0.6092 - dice_metric: 0.6548 - jaccard_metric: 0.5855 - sensitivity_metric: 0.7244 - specificity_metric: 0.9378 - val_loss: -0.5879 - val_dice_metric: 0.6023 - val_jaccard_metric: 0.5409 - val_sensitivity_metric: 0.6556 - val_specificity_metric: 0.9282
# Epoch 27/60
# 77/77 [==============================] - 43s 553ms/step - loss: -0.6163 - dice_metric: 0.6606 - jaccard_metric: 0.5914 - sensitivity_metric: 0.7280 - specificity_metric: 0.9384 - val_loss: -0.5871 - val_dice_metric: 0.6013 - val_jaccard_metric: 0.5366 - val_sensitivity_metric: 0.6477 - val_specificity_metric: 0.9240
# Epoch 28/60
# 77/77 [==============================] - 44s 566ms/step - loss: -0.6229 - dice_metric: 0.6648 - jaccard_metric: 0.5957 - sensitivity_metric: 0.7305 - specificity_metric: 0.9390 - val_loss: -0.5965 - val_dice_metric: 0.6133 - val_jaccard_metric: 0.5503 - val_sensitivity_metric: 0.6648 - val_specificity_metric: 0.9325
# Epoch 29/60
# 77/77 [==============================] - 47s 602ms/step - loss: -0.6315 - dice_metric: 0.6763 - jaccard_metric: 0.6071 - sensitivity_metric: 0.7383 - specificity_metric: 0.9434 - val_loss: -0.6281 - val_dice_metric: 0.6545 - val_jaccard_metric: 0.5972 - val_sensitivity_metric: 0.6956 - val_specificity_metric: 0.9444
# Epoch 30/60
# 77/77 [==============================] - 45s 584ms/step - loss: -0.6409 - dice_metric: 0.6833 - jaccard_metric: 0.6148 - sensitivity_metric: 0.7420 - specificity_metric: 0.9433 - val_loss: -0.6292 - val_dice_metric: 0.6517 - val_jaccard_metric: 0.5908 - val_sensitivity_metric: 0.6845 - val_specificity_metric: 0.9445
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 44s 562ms/step - loss: -0.6493 - dice_metric: 0.6921 - jaccard_metric: 0.6245 - sensitivity_metric: 0.7481 - specificity_metric: 0.9439 - val_loss: -0.6360 - val_dice_metric: 0.6664 - val_jaccard_metric: 0.6097 - val_sensitivity_metric: 0.7095 - val_specificity_metric: 0.9464
# Epoch 32/60
# 77/77 [==============================] - 45s 586ms/step - loss: -0.6522 - dice_metric: 0.6951 - jaccard_metric: 0.6278 - sensitivity_metric: 0.7511 - specificity_metric: 0.9440 - val_loss: -0.6346 - val_dice_metric: 0.6671 - val_jaccard_metric: 0.6107 - val_sensitivity_metric: 0.7111 - val_specificity_metric: 0.9466
# Epoch 33/60
# 77/77 [==============================] - 45s 582ms/step - loss: -0.6539 - dice_metric: 0.6968 - jaccard_metric: 0.6298 - sensitivity_metric: 0.7522 - specificity_metric: 0.9439 - val_loss: -0.6339 - val_dice_metric: 0.6672 - val_jaccard_metric: 0.6108 - val_sensitivity_metric: 0.7117 - val_specificity_metric: 0.9466
# Epoch 34/60
# 77/77 [==============================] - 46s 599ms/step - loss: -0.6553 - dice_metric: 0.6981 - jaccard_metric: 0.6313 - sensitivity_metric: 0.7531 - specificity_metric: 0.9438 - val_loss: -0.6340 - val_dice_metric: 0.6677 - val_jaccard_metric: 0.6114 - val_sensitivity_metric: 0.7122 - val_specificity_metric: 0.9466
# Epoch 35/60
# 77/77 [==============================] - 46s 592ms/step - loss: -0.6565 - dice_metric: 0.6992 - jaccard_metric: 0.6326 - sensitivity_metric: 0.7537 - specificity_metric: 0.9438 - val_loss: -0.6340 - val_dice_metric: 0.6679 - val_jaccard_metric: 0.6117 - val_sensitivity_metric: 0.7128 - val_specificity_metric: 0.9465
# Epoch 36/60
# 77/77 [==============================] - 45s 581ms/step - loss: -0.6576 - dice_metric: 0.7001 - jaccard_metric: 0.6336 - sensitivity_metric: 0.7543 - specificity_metric: 0.9437 - val_loss: -0.6346 - val_dice_metric: 0.6683 - val_jaccard_metric: 0.6122 - val_sensitivity_metric: 0.7131 - val_specificity_metric: 0.9465
# Epoch 37/60
# 77/77 [==============================] - 46s 590ms/step - loss: -0.6587 - dice_metric: 0.7010 - jaccard_metric: 0.6347 - sensitivity_metric: 0.7549 - specificity_metric: 0.9437 - val_loss: -0.6351 - val_dice_metric: 0.6688 - val_jaccard_metric: 0.6128 - val_sensitivity_metric: 0.7135 - val_specificity_metric: 0.9464
# Epoch 38/60
# 77/77 [==============================] - 45s 579ms/step - loss: -0.6598 - dice_metric: 0.7018 - jaccard_metric: 0.6356 - sensitivity_metric: 0.7554 - specificity_metric: 0.9437 - val_loss: -0.6356 - val_dice_metric: 0.6690 - val_jaccard_metric: 0.6131 - val_sensitivity_metric: 0.7137 - val_specificity_metric: 0.9464
# Epoch 39/60
# 77/77 [==============================] - 47s 604ms/step - loss: -0.6607 - dice_metric: 0.7026 - jaccard_metric: 0.6365 - sensitivity_metric: 0.7559 - specificity_metric: 0.9437 - val_loss: -0.6366 - val_dice_metric: 0.6697 - val_jaccard_metric: 0.6137 - val_sensitivity_metric: 0.7142 - val_specificity_metric: 0.9466
# Epoch 40/60
# 77/77 [==============================] - 46s 595ms/step - loss: -0.6617 - dice_metric: 0.7034 - jaccard_metric: 0.6373 - sensitivity_metric: 0.7564 - specificity_metric: 0.9437 - val_loss: -0.6370 - val_dice_metric: 0.6698 - val_jaccard_metric: 0.6139 - val_sensitivity_metric: 0.7144 - val_specificity_metric: 0.9466
# Epoch 41/60
# 77/77 [==============================] - 46s 587ms/step - loss: -0.6626 - dice_metric: 0.7041 - jaccard_metric: 0.6381 - sensitivity_metric: 0.7568 - specificity_metric: 0.9436 - val_loss: -0.6374 - val_dice_metric: 0.6700 - val_jaccard_metric: 0.6141 - val_sensitivity_metric: 0.7145 - val_specificity_metric: 0.9464
# Epoch 42/60
# 77/77 [==============================] - 44s 567ms/step - loss: -0.6636 - dice_metric: 0.7048 - jaccard_metric: 0.6388 - sensitivity_metric: 0.7572 - specificity_metric: 0.9436 - val_loss: -0.6379 - val_dice_metric: 0.6703 - val_jaccard_metric: 0.6145 - val_sensitivity_metric: 0.7148 - val_specificity_metric: 0.9463
# Epoch 43/60
# 77/77 [==============================] - 45s 585ms/step - loss: -0.6645 - dice_metric: 0.7055 - jaccard_metric: 0.6396 - sensitivity_metric: 0.7578 - specificity_metric: 0.9436 - val_loss: -0.6386 - val_dice_metric: 0.6708 - val_jaccard_metric: 0.6149 - val_sensitivity_metric: 0.7151 - val_specificity_metric: 0.9464
# Epoch 44/60
# 77/77 [==============================] - 45s 580ms/step - loss: -0.6654 - dice_metric: 0.7061 - jaccard_metric: 0.6404 - sensitivity_metric: 0.7582 - specificity_metric: 0.9436 - val_loss: -0.6392 - val_dice_metric: 0.6712 - val_jaccard_metric: 0.6153 - val_sensitivity_metric: 0.7155 - val_specificity_metric: 0.9464
# Epoch 45/60
# 77/77 [==============================] - 44s 566ms/step - loss: -0.6663 - dice_metric: 0.7067 - jaccard_metric: 0.6410 - sensitivity_metric: 0.7586 - specificity_metric: 0.9436 - val_loss: -0.6398 - val_dice_metric: 0.6715 - val_jaccard_metric: 0.6158 - val_sensitivity_metric: 0.7158 - val_specificity_metric: 0.9464
# Epoch 46/60
# 77/77 [==============================] - 46s 596ms/step - loss: -0.6671 - dice_metric: 0.7074 - jaccard_metric: 0.6417 - sensitivity_metric: 0.7589 - specificity_metric: 0.9436 - val_loss: -0.6403 - val_dice_metric: 0.6718 - val_jaccard_metric: 0.6160 - val_sensitivity_metric: 0.7160 - val_specificity_metric: 0.9464
# Epoch 47/60
# 77/77 [==============================] - 49s 630ms/step - loss: -0.6680 - dice_metric: 0.7080 - jaccard_metric: 0.6425 - sensitivity_metric: 0.7594 - specificity_metric: 0.9436 - val_loss: -0.6410 - val_dice_metric: 0.6723 - val_jaccard_metric: 0.6166 - val_sensitivity_metric: 0.7164 - val_specificity_metric: 0.9464
# Epoch 48/60
# 77/77 [==============================] - 46s 599ms/step - loss: -0.6689 - dice_metric: 0.7087 - jaccard_metric: 0.6432 - sensitivity_metric: 0.7598 - specificity_metric: 0.9436 - val_loss: -0.6416 - val_dice_metric: 0.6727 - val_jaccard_metric: 0.6171 - val_sensitivity_metric: 0.7166 - val_specificity_metric: 0.9466
# Epoch 49/60
# 77/77 [==============================] - 45s 583ms/step - loss: -0.6697 - dice_metric: 0.7095 - jaccard_metric: 0.6441 - sensitivity_metric: 0.7603 - specificity_metric: 0.9438 - val_loss: -0.6430 - val_dice_metric: 0.6737 - val_jaccard_metric: 0.6180 - val_sensitivity_metric: 0.7169 - val_specificity_metric: 0.9471
# Epoch 50/60
# 77/77 [==============================] - 46s 594ms/step - loss: -0.6706 - dice_metric: 0.7101 - jaccard_metric: 0.6448 - sensitivity_metric: 0.7608 - specificity_metric: 0.9438 - val_loss: -0.6424 - val_dice_metric: 0.6731 - val_jaccard_metric: 0.6174 - val_sensitivity_metric: 0.7170 - val_specificity_metric: 0.9466
# Epoch 51/60
# 77/77 [==============================] - 44s 569ms/step - loss: -0.6715 - dice_metric: 0.7107 - jaccard_metric: 0.6455 - sensitivity_metric: 0.7611 - specificity_metric: 0.9437 - val_loss: -0.6430 - val_dice_metric: 0.6733 - val_jaccard_metric: 0.6177 - val_sensitivity_metric: 0.7173 - val_specificity_metric: 0.9465
# Epoch 52/60
# 77/77 [==============================] - 45s 583ms/step - loss: -0.6723 - dice_metric: 0.7113 - jaccard_metric: 0.6462 - sensitivity_metric: 0.7614 - specificity_metric: 0.9437 - val_loss: -0.6432 - val_dice_metric: 0.6734 - val_jaccard_metric: 0.6178 - val_sensitivity_metric: 0.7174 - val_specificity_metric: 0.9463
# Epoch 53/60
# 77/77 [==============================] - 44s 567ms/step - loss: -0.6731 - dice_metric: 0.7119 - jaccard_metric: 0.6468 - sensitivity_metric: 0.7617 - specificity_metric: 0.9437 - val_loss: -0.6440 - val_dice_metric: 0.6738 - val_jaccard_metric: 0.6183 - val_sensitivity_metric: 0.7177 - val_specificity_metric: 0.9465
# Epoch 54/60
# 77/77 [==============================] - 46s 591ms/step - loss: -0.6740 - dice_metric: 0.7124 - jaccard_metric: 0.6474 - sensitivity_metric: 0.7620 - specificity_metric: 0.9437 - val_loss: -0.6444 - val_dice_metric: 0.6741 - val_jaccard_metric: 0.6186 - val_sensitivity_metric: 0.7180 - val_specificity_metric: 0.9465
# Epoch 55/60
# 77/77 [==============================] - 43s 550ms/step - loss: -0.6748 - dice_metric: 0.7130 - jaccard_metric: 0.6481 - sensitivity_metric: 0.7624 - specificity_metric: 0.9437 - val_loss: -0.6449 - val_dice_metric: 0.6744 - val_jaccard_metric: 0.6191 - val_sensitivity_metric: 0.7181 - val_specificity_metric: 0.9465
# Epoch 56/60
# 77/77 [==============================] - 45s 575ms/step - loss: -0.6756 - dice_metric: 0.7136 - jaccard_metric: 0.6487 - sensitivity_metric: 0.7628 - specificity_metric: 0.9437 - val_loss: -0.6455 - val_dice_metric: 0.6747 - val_jaccard_metric: 0.6194 - val_sensitivity_metric: 0.7182 - val_specificity_metric: 0.9466
# Epoch 57/60
# 77/77 [==============================] - 45s 582ms/step - loss: -0.6763 - dice_metric: 0.7141 - jaccard_metric: 0.6493 - sensitivity_metric: 0.7631 - specificity_metric: 0.9437 - val_loss: -0.6455 - val_dice_metric: 0.6746 - val_jaccard_metric: 0.6193 - val_sensitivity_metric: 0.7180 - val_specificity_metric: 0.9463
# Epoch 58/60
# 77/77 [==============================] - 46s 588ms/step - loss: -0.6771 - dice_metric: 0.7147 - jaccard_metric: 0.6499 - sensitivity_metric: 0.7634 - specificity_metric: 0.9438 - val_loss: -0.6464 - val_dice_metric: 0.6752 - val_jaccard_metric: 0.6201 - val_sensitivity_metric: 0.7185 - val_specificity_metric: 0.9465
# Epoch 59/60
# 77/77 [==============================] - 45s 577ms/step - loss: -0.6779 - dice_metric: 0.7153 - jaccard_metric: 0.6506 - sensitivity_metric: 0.7639 - specificity_metric: 0.9439 - val_loss: -0.6472 - val_dice_metric: 0.6757 - val_jaccard_metric: 0.6205 - val_sensitivity_metric: 0.7190 - val_specificity_metric: 0.9466
# Epoch 60/60
# 77/77 [==============================] - 45s 578ms/step - loss: -0.6787 - dice_metric: 0.7158 - jaccard_metric: 0.6512 - sensitivity_metric: 0.7642 - specificity_metric: 0.9439 - val_loss: -0.6475 - val_dice_metric: 0.6757 - val_jaccard_metric: 0.6205 - val_sensitivity_metric: 0.7189 - val_specificity_metric: 0.9466

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.69321, standard deviation: 0.36891
# Jaccard Index mean: 0.63376, standard deviation: 0.37133
# Sensitivity mean: 0.74132, standard deviation: 0.34559
# Specificity mean: 0.94701, standard deviation: 0.13816
