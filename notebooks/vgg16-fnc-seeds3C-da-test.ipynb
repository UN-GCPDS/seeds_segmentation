# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|███████████████████████████████████████▉| 998M/0.98G [00:05<00:00, 257MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:05<00:00, 185MB/s]

# %%
config = {"Seg_model":"VGG16FCN","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import fcn_vgg16
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP

@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = fcn_vgg16(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 136s 1s/step - loss: -0.2799 - dice_metric: 0.3196 - jaccard_metric: 0.2298 - sensitivity_metric: 0.4545 - specificity_metric: 0.8429 - precision_metric: 0.4071 - recall_metric: 0.4545 - mean_average_precision: 0.0453 - val_loss: -0.1982 - val_dice_metric: 0.1610 - val_jaccard_metric: 0.0934 - val_sensitivity_metric: 0.3833 - val_specificity_metric: 0.8889 - val_precision_metric: 0.3742 - val_recall_metric: 0.3833 - val_mean_average_precision: 0.0000e+00
# Epoch 2/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.4301 - dice_metric: 0.5020 - jaccard_metric: 0.4216 - sensitivity_metric: 0.6057 - specificity_metric: 0.8989 - precision_metric: 0.5298 - recall_metric: 0.6057 - mean_average_precision: 0.2579 - val_loss: -0.3483 - val_dice_metric: 0.5464 - val_jaccard_metric: 0.4700 - val_sensitivity_metric: 0.5894 - val_specificity_metric: 0.9151 - val_precision_metric: 0.5653 - val_recall_metric: 0.5894 - val_mean_average_precision: 0.3261
# Epoch 3/60
# 77/77 [==============================] - 89s 1s/step - loss: -0.4999 - dice_metric: 0.5430 - jaccard_metric: 0.4720 - sensitivity_metric: 0.6571 - specificity_metric: 0.9109 - precision_metric: 0.5709 - recall_metric: 0.6571 - mean_average_precision: 0.3403 - val_loss: -0.4598 - val_dice_metric: 0.5651 - val_jaccard_metric: 0.4968 - val_sensitivity_metric: 0.6216 - val_specificity_metric: 0.9172 - val_precision_metric: 0.5836 - val_recall_metric: 0.6216 - val_mean_average_precision: 0.3728
# Epoch 4/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.5298 - dice_metric: 0.5605 - jaccard_metric: 0.4917 - sensitivity_metric: 0.6920 - specificity_metric: 0.9190 - precision_metric: 0.5863 - recall_metric: 0.6920 - mean_average_precision: 0.3701 - val_loss: -0.5186 - val_dice_metric: 0.5633 - val_jaccard_metric: 0.5007 - val_sensitivity_metric: 0.6495 - val_specificity_metric: 0.9220 - val_precision_metric: 0.5793 - val_recall_metric: 0.6495 - val_mean_average_precision: 0.3916
# Epoch 5/60
# 77/77 [==============================] - 94s 1s/step - loss: -0.5509 - dice_metric: 0.5773 - jaccard_metric: 0.5105 - sensitivity_metric: 0.7144 - specificity_metric: 0.9283 - precision_metric: 0.5971 - recall_metric: 0.7144 - mean_average_precision: 0.3956 - val_loss: -0.5534 - val_dice_metric: 0.5749 - val_jaccard_metric: 0.5154 - val_sensitivity_metric: 0.6635 - val_specificity_metric: 0.9302 - val_precision_metric: 0.5870 - val_recall_metric: 0.6635 - val_mean_average_precision: 0.4132
# Epoch 6/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.5788 - dice_metric: 0.6077 - jaccard_metric: 0.5400 - sensitivity_metric: 0.7258 - specificity_metric: 0.9336 - precision_metric: 0.6224 - recall_metric: 0.7258 - mean_average_precision: 0.4206 - val_loss: -0.5990 - val_dice_metric: 0.6129 - val_jaccard_metric: 0.5526 - val_sensitivity_metric: 0.6843 - val_specificity_metric: 0.9367 - val_precision_metric: 0.6291 - val_recall_metric: 0.6843 - val_mean_average_precision: 0.4420
# Epoch 7/60
# 77/77 [==============================] - 94s 1s/step - loss: -0.6045 - dice_metric: 0.6324 - jaccard_metric: 0.5648 - sensitivity_metric: 0.7336 - specificity_metric: 0.9359 - precision_metric: 0.6470 - recall_metric: 0.7336 - mean_average_precision: 0.4437 - val_loss: -0.6152 - val_dice_metric: 0.6245 - val_jaccard_metric: 0.5628 - val_sensitivity_metric: 0.6948 - val_specificity_metric: 0.9324 - val_precision_metric: 0.6451 - val_recall_metric: 0.6948 - val_mean_average_precision: 0.4525
# Epoch 8/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.6245 - dice_metric: 0.6502 - jaccard_metric: 0.5834 - sensitivity_metric: 0.7392 - specificity_metric: 0.9377 - precision_metric: 0.6655 - recall_metric: 0.7392 - mean_average_precision: 0.4632 - val_loss: -0.6335 - val_dice_metric: 0.6406 - val_jaccard_metric: 0.5814 - val_sensitivity_metric: 0.7040 - val_specificity_metric: 0.9353 - val_precision_metric: 0.6595 - val_recall_metric: 0.7040 - val_mean_average_precision: 0.4679
# Epoch 9/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.6414 - dice_metric: 0.6635 - jaccard_metric: 0.5979 - sensitivity_metric: 0.7432 - specificity_metric: 0.9377 - precision_metric: 0.6819 - recall_metric: 0.7432 - mean_average_precision: 0.4784 - val_loss: -0.6323 - val_dice_metric: 0.6385 - val_jaccard_metric: 0.5775 - val_sensitivity_metric: 0.7032 - val_specificity_metric: 0.9292 - val_precision_metric: 0.6630 - val_recall_metric: 0.7032 - val_mean_average_precision: 0.4589
# Epoch 10/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.6534 - dice_metric: 0.6726 - jaccard_metric: 0.6078 - sensitivity_metric: 0.7467 - specificity_metric: 0.9385 - precision_metric: 0.6925 - recall_metric: 0.7467 - mean_average_precision: 0.4899 - val_loss: -0.6311 - val_dice_metric: 0.6364 - val_jaccard_metric: 0.5748 - val_sensitivity_metric: 0.6961 - val_specificity_metric: 0.9216 - val_precision_metric: 0.6695 - val_recall_metric: 0.6961 - val_mean_average_precision: 0.4533
# Epoch 11/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.6628 - dice_metric: 0.6803 - jaccard_metric: 0.6162 - sensitivity_metric: 0.7508 - specificity_metric: 0.9405 - precision_metric: 0.7000 - recall_metric: 0.7508 - mean_average_precision: 0.5004 - val_loss: -0.6356 - val_dice_metric: 0.6394 - val_jaccard_metric: 0.5789 - val_sensitivity_metric: 0.6985 - val_specificity_metric: 0.9231 - val_precision_metric: 0.6709 - val_recall_metric: 0.6985 - val_mean_average_precision: 0.4623
# Epoch 12/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.6714 - dice_metric: 0.6881 - jaccard_metric: 0.6240 - sensitivity_metric: 0.7533 - specificity_metric: 0.9419 - precision_metric: 0.7072 - recall_metric: 0.7533 - mean_average_precision: 0.5090 - val_loss: -0.6330 - val_dice_metric: 0.6355 - val_jaccard_metric: 0.5740 - val_sensitivity_metric: 0.6935 - val_specificity_metric: 0.9193 - val_precision_metric: 0.6750 - val_recall_metric: 0.6935 - val_mean_average_precision: 0.4536
# Epoch 13/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.6805 - dice_metric: 0.6963 - jaccard_metric: 0.6324 - sensitivity_metric: 0.7574 - specificity_metric: 0.9434 - precision_metric: 0.7142 - recall_metric: 0.7574 - mean_average_precision: 0.5165 - val_loss: -0.6318 - val_dice_metric: 0.6329 - val_jaccard_metric: 0.5698 - val_sensitivity_metric: 0.6892 - val_specificity_metric: 0.9155 - val_precision_metric: 0.6796 - val_recall_metric: 0.6892 - val_mean_average_precision: 0.4423
# Epoch 14/60
# 77/77 [==============================] - 92s 1s/step - loss: -0.6892 - dice_metric: 0.7038 - jaccard_metric: 0.6403 - sensitivity_metric: 0.7619 - specificity_metric: 0.9449 - precision_metric: 0.7215 - recall_metric: 0.7619 - mean_average_precision: 0.5259 - val_loss: -0.6360 - val_dice_metric: 0.6366 - val_jaccard_metric: 0.5737 - val_sensitivity_metric: 0.6874 - val_specificity_metric: 0.9179 - val_precision_metric: 0.6840 - val_recall_metric: 0.6874 - val_mean_average_precision: 0.4464
# Epoch 15/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.6953 - dice_metric: 0.7088 - jaccard_metric: 0.6454 - sensitivity_metric: 0.7651 - specificity_metric: 0.9459 - precision_metric: 0.7262 - recall_metric: 0.7651 - mean_average_precision: 0.5315 - val_loss: -0.6467 - val_dice_metric: 0.6466 - val_jaccard_metric: 0.5867 - val_sensitivity_metric: 0.7033 - val_specificity_metric: 0.9276 - val_precision_metric: 0.6806 - val_recall_metric: 0.7033 - val_mean_average_precision: 0.4695
# Epoch 16/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.7019 - dice_metric: 0.7143 - jaccard_metric: 0.6516 - sensitivity_metric: 0.7685 - specificity_metric: 0.9474 - precision_metric: 0.7310 - recall_metric: 0.7685 - mean_average_precision: 0.5398 - val_loss: -0.6671 - val_dice_metric: 0.6682 - val_jaccard_metric: 0.6144 - val_sensitivity_metric: 0.7270 - val_specificity_metric: 0.9461 - val_precision_metric: 0.6869 - val_recall_metric: 0.7270 - val_mean_average_precision: 0.5204
# Epoch 17/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.7080 - dice_metric: 0.7196 - jaccard_metric: 0.6574 - sensitivity_metric: 0.7731 - specificity_metric: 0.9490 - precision_metric: 0.7354 - recall_metric: 0.7731 - mean_average_precision: 0.5476 - val_loss: -0.6578 - val_dice_metric: 0.6578 - val_jaccard_metric: 0.6013 - val_sensitivity_metric: 0.7136 - val_specificity_metric: 0.9332 - val_precision_metric: 0.6897 - val_recall_metric: 0.7136 - val_mean_average_precision: 0.4953
# Epoch 18/60
# 77/77 [==============================] - 91s 1s/step - loss: -0.7131 - dice_metric: 0.7250 - jaccard_metric: 0.6626 - sensitivity_metric: 0.7753 - specificity_metric: 0.9495 - precision_metric: 0.7392 - recall_metric: 0.7753 - mean_average_precision: 0.5521 - val_loss: -0.6827 - val_dice_metric: 0.6829 - val_jaccard_metric: 0.6248 - val_sensitivity_metric: 0.7033 - val_specificity_metric: 0.9259 - val_precision_metric: 0.7201 - val_recall_metric: 0.7033 - val_mean_average_precision: 0.5153
# Epoch 19/60
# 77/77 [==============================] - 93s 1s/step - loss: -0.7336 - dice_metric: 0.7475 - jaccard_metric: 0.6830 - sensitivity_metric: 0.7719 - specificity_metric: 0.9452 - precision_metric: 0.7623 - recall_metric: 0.7719 - mean_average_precision: 0.5646 - val_loss: -0.6939 - val_dice_metric: 0.6939 - val_jaccard_metric: 0.6362 - val_sensitivity_metric: 0.7164 - val_specificity_metric: 0.9320 - val_precision_metric: 0.7258 - val_recall_metric: 0.7164 - val_mean_average_precision: 0.5291
# Epoch 20/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.7421 - dice_metric: 0.7545 - jaccard_metric: 0.6909 - sensitivity_metric: 0.7773 - specificity_metric: 0.9475 - precision_metric: 0.7684 - recall_metric: 0.7773 - mean_average_precision: 0.5758 - val_loss: -0.6975 - val_dice_metric: 0.6966 - val_jaccard_metric: 0.6405 - val_sensitivity_metric: 0.7214 - val_specificity_metric: 0.9368 - val_precision_metric: 0.7243 - val_recall_metric: 0.7214 - val_mean_average_precision: 0.5407
# Epoch 21/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.7489 - dice_metric: 0.7599 - jaccard_metric: 0.6972 - sensitivity_metric: 0.7798 - specificity_metric: 0.9483 - precision_metric: 0.7742 - recall_metric: 0.7798 - mean_average_precision: 0.5843 - val_loss: -0.7072 - val_dice_metric: 0.7090 - val_jaccard_metric: 0.6547 - val_sensitivity_metric: 0.7294 - val_specificity_metric: 0.9446 - val_precision_metric: 0.7361 - val_recall_metric: 0.7294 - val_mean_average_precision: 0.5600
# Epoch 22/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.7529 - dice_metric: 0.7629 - jaccard_metric: 0.7008 - sensitivity_metric: 0.7825 - specificity_metric: 0.9497 - precision_metric: 0.7760 - recall_metric: 0.7825 - mean_average_precision: 0.5901 - val_loss: -0.7127 - val_dice_metric: 0.7120 - val_jaccard_metric: 0.6595 - val_sensitivity_metric: 0.7323 - val_specificity_metric: 0.9506 - val_precision_metric: 0.7304 - val_recall_metric: 0.7323 - val_mean_average_precision: 0.5638
# Epoch 23/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.7565 - dice_metric: 0.7661 - jaccard_metric: 0.7044 - sensitivity_metric: 0.7846 - specificity_metric: 0.9510 - precision_metric: 0.7783 - recall_metric: 0.7846 - mean_average_precision: 0.5947 - val_loss: -0.7171 - val_dice_metric: 0.7174 - val_jaccard_metric: 0.6653 - val_sensitivity_metric: 0.7376 - val_specificity_metric: 0.9508 - val_precision_metric: 0.7355 - val_recall_metric: 0.7376 - val_mean_average_precision: 0.5714
# Epoch 24/60
# 77/77 [==============================] - 90s 1s/step - loss: -0.7610 - dice_metric: 0.7697 - jaccard_metric: 0.7085 - sensitivity_metric: 0.7871 - specificity_metric: 0.9517 - precision_metric: 0.7815 - recall_metric: 0.7871 - mean_average_precision: 0.6003 - val_loss: -0.7249 - val_dice_metric: 0.7262 - val_jaccard_metric: 0.6751 - val_sensitivity_metric: 0.7460 - val_specificity_metric: 0.9528 - val_precision_metric: 0.7426 - val_recall_metric: 0.7460 - val_mean_average_precision: 0.5852
# Epoch 25/60
# 77/77 [==============================] - 94s 1s/step - loss: -0.7650 - dice_metric: 0.7731 - jaccard_metric: 0.7127 - sensitivity_metric: 0.7897 - specificity_metric: 0.9529 - precision_metric: 0.7846 - recall_metric: 0.7897 - mean_average_precision: 0.6061 - val_loss: -0.7335 - val_dice_metric: 0.7348 - val_jaccard_metric: 0.6840 - val_sensitivity_metric: 0.7461 - val_specificity_metric: 0.9542 - val_precision_metric: 0.7506 - val_recall_metric: 0.7461 - val_mean_average_precision: 0.5967
# Epoch 26/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.7664 - dice_metric: 0.7741 - jaccard_metric: 0.7138 - sensitivity_metric: 0.7912 - specificity_metric: 0.9539 - precision_metric: 0.7851 - recall_metric: 0.7912 - mean_average_precision: 0.6076 - val_loss: -0.7328 - val_dice_metric: 0.7350 - val_jaccard_metric: 0.6850 - val_sensitivity_metric: 0.7476 - val_specificity_metric: 0.9571 - val_precision_metric: 0.7497 - val_recall_metric: 0.7476 - val_mean_average_precision: 0.6004
# Epoch 27/60
# 77/77 [==============================] - 94s 1s/step - loss: -0.7692 - dice_metric: 0.7765 - jaccard_metric: 0.7165 - sensitivity_metric: 0.7943 - specificity_metric: 0.9555 - precision_metric: 0.7859 - recall_metric: 0.7943 - mean_average_precision: 0.6117 - val_loss: -0.7282 - val_dice_metric: 0.7275 - val_jaccard_metric: 0.6743 - val_sensitivity_metric: 0.7422 - val_specificity_metric: 0.9465 - val_precision_metric: 0.7523 - val_recall_metric: 0.7422 - val_mean_average_precision: 0.5775
# Epoch 28/60
# 77/77 [==============================] - 93s 1s/step - loss: -0.7712 - dice_metric: 0.7781 - jaccard_metric: 0.7181 - sensitivity_metric: 0.7942 - specificity_metric: 0.9559 - precision_metric: 0.7882 - recall_metric: 0.7942 - mean_average_precision: 0.6136 - val_loss: -0.7279 - val_dice_metric: 0.7286 - val_jaccard_metric: 0.6740 - val_sensitivity_metric: 0.7432 - val_specificity_metric: 0.9513 - val_precision_metric: 0.7466 - val_recall_metric: 0.7432 - val_mean_average_precision: 0.5741
# Epoch 29/60
# 77/77 [==============================] - 98s 1s/step - loss: -0.7755 - dice_metric: 0.7822 - jaccard_metric: 0.7229 - sensitivity_metric: 0.7968 - specificity_metric: 0.9564 - precision_metric: 0.7913 - recall_metric: 0.7968 - mean_average_precision: 0.6202 - val_loss: -0.7383 - val_dice_metric: 0.7414 - val_jaccard_metric: 0.6906 - val_sensitivity_metric: 0.7485 - val_specificity_metric: 0.9594 - val_precision_metric: 0.7582 - val_recall_metric: 0.7485 - val_mean_average_precision: 0.6035
# Epoch 30/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.7788 - dice_metric: 0.7849 - jaccard_metric: 0.7264 - sensitivity_metric: 0.7993 - specificity_metric: 0.9572 - precision_metric: 0.7940 - recall_metric: 0.7993 - mean_average_precision: 0.6250 - val_loss: -0.7424 - val_dice_metric: 0.7440 - val_jaccard_metric: 0.6929 - val_sensitivity_metric: 0.7562 - val_specificity_metric: 0.9638 - val_precision_metric: 0.7554 - val_recall_metric: 0.7562 - val_mean_average_precision: 0.6014
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 90s 1s/step - loss: -0.7841 - dice_metric: 0.7905 - jaccard_metric: 0.7329 - sensitivity_metric: 0.8050 - specificity_metric: 0.9589 - precision_metric: 0.7976 - recall_metric: 0.8050 - mean_average_precision: 0.6348 - val_loss: -0.7437 - val_dice_metric: 0.7457 - val_jaccard_metric: 0.6958 - val_sensitivity_metric: 0.7537 - val_specificity_metric: 0.9598 - val_precision_metric: 0.7608 - val_recall_metric: 0.7537 - val_mean_average_precision: 0.6080
# Epoch 32/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.7870 - dice_metric: 0.7932 - jaccard_metric: 0.7364 - sensitivity_metric: 0.8058 - specificity_metric: 0.9586 - precision_metric: 0.8011 - recall_metric: 0.8058 - mean_average_precision: 0.6399 - val_loss: -0.7423 - val_dice_metric: 0.7451 - val_jaccard_metric: 0.6948 - val_sensitivity_metric: 0.7531 - val_specificity_metric: 0.9586 - val_precision_metric: 0.7602 - val_recall_metric: 0.7531 - val_mean_average_precision: 0.6064
# Epoch 33/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.7882 - dice_metric: 0.7943 - jaccard_metric: 0.7376 - sensitivity_metric: 0.8066 - specificity_metric: 0.9584 - precision_metric: 0.8022 - recall_metric: 0.8066 - mean_average_precision: 0.6414 - val_loss: -0.7412 - val_dice_metric: 0.7443 - val_jaccard_metric: 0.6938 - val_sensitivity_metric: 0.7528 - val_specificity_metric: 0.9581 - val_precision_metric: 0.7594 - val_recall_metric: 0.7528 - val_mean_average_precision: 0.6048
# Epoch 34/60
# 77/77 [==============================] - 94s 1s/step - loss: -0.7891 - dice_metric: 0.7952 - jaccard_metric: 0.7387 - sensitivity_metric: 0.8071 - specificity_metric: 0.9584 - precision_metric: 0.8032 - recall_metric: 0.8071 - mean_average_precision: 0.6427 - val_loss: -0.7413 - val_dice_metric: 0.7443 - val_jaccard_metric: 0.6938 - val_sensitivity_metric: 0.7526 - val_specificity_metric: 0.9580 - val_precision_metric: 0.7594 - val_recall_metric: 0.7526 - val_mean_average_precision: 0.6049
# Epoch 35/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.7897 - dice_metric: 0.7959 - jaccard_metric: 0.7395 - sensitivity_metric: 0.8078 - specificity_metric: 0.9585 - precision_metric: 0.8037 - recall_metric: 0.8078 - mean_average_precision: 0.6442 - val_loss: -0.7414 - val_dice_metric: 0.7443 - val_jaccard_metric: 0.6938 - val_sensitivity_metric: 0.7525 - val_specificity_metric: 0.9580 - val_precision_metric: 0.7596 - val_recall_metric: 0.7525 - val_mean_average_precision: 0.6061
# Epoch 36/60
# 77/77 [==============================] - 92s 1s/step - loss: -0.7904 - dice_metric: 0.7965 - jaccard_metric: 0.7403 - sensitivity_metric: 0.8079 - specificity_metric: 0.9584 - precision_metric: 0.8048 - recall_metric: 0.8079 - mean_average_precision: 0.6455 - val_loss: -0.7417 - val_dice_metric: 0.7458 - val_jaccard_metric: 0.6952 - val_sensitivity_metric: 0.7524 - val_specificity_metric: 0.9579 - val_precision_metric: 0.7595 - val_recall_metric: 0.7524 - val_mean_average_precision: 0.6066
# Epoch 37/60
# 77/77 [==============================] - 93s 1s/step - loss: -0.7911 - dice_metric: 0.7971 - jaccard_metric: 0.7410 - sensitivity_metric: 0.8083 - specificity_metric: 0.9584 - precision_metric: 0.8054 - recall_metric: 0.8083 - mean_average_precision: 0.6464 - val_loss: -0.7423 - val_dice_metric: 0.7461 - val_jaccard_metric: 0.6957 - val_sensitivity_metric: 0.7527 - val_specificity_metric: 0.9583 - val_precision_metric: 0.7599 - val_recall_metric: 0.7527 - val_mean_average_precision: 0.6082
# Epoch 38/60
# 77/77 [==============================] - 93s 1s/step - loss: -0.7916 - dice_metric: 0.7976 - jaccard_metric: 0.7416 - sensitivity_metric: 0.8087 - specificity_metric: 0.9584 - precision_metric: 0.8060 - recall_metric: 0.8087 - mean_average_precision: 0.6473 - val_loss: -0.7420 - val_dice_metric: 0.7457 - val_jaccard_metric: 0.6952 - val_sensitivity_metric: 0.7522 - val_specificity_metric: 0.9580 - val_precision_metric: 0.7597 - val_recall_metric: 0.7522 - val_mean_average_precision: 0.6062
# Epoch 39/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.7922 - dice_metric: 0.7982 - jaccard_metric: 0.7423 - sensitivity_metric: 0.8090 - specificity_metric: 0.9584 - precision_metric: 0.8065 - recall_metric: 0.8090 - mean_average_precision: 0.6485 - val_loss: -0.7426 - val_dice_metric: 0.7463 - val_jaccard_metric: 0.6959 - val_sensitivity_metric: 0.7524 - val_specificity_metric: 0.9582 - val_precision_metric: 0.7603 - val_recall_metric: 0.7524 - val_mean_average_precision: 0.6075
# Epoch 40/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.7927 - dice_metric: 0.7987 - jaccard_metric: 0.7429 - sensitivity_metric: 0.8094 - specificity_metric: 0.9584 - precision_metric: 0.8071 - recall_metric: 0.8094 - mean_average_precision: 0.6494 - val_loss: -0.7429 - val_dice_metric: 0.7465 - val_jaccard_metric: 0.6961 - val_sensitivity_metric: 0.7525 - val_specificity_metric: 0.9583 - val_precision_metric: 0.7604 - val_recall_metric: 0.7525 - val_mean_average_precision: 0.6081
# Epoch 41/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.7932 - dice_metric: 0.7995 - jaccard_metric: 0.7437 - sensitivity_metric: 0.8097 - specificity_metric: 0.9585 - precision_metric: 0.8076 - recall_metric: 0.8097 - mean_average_precision: 0.6505 - val_loss: -0.7433 - val_dice_metric: 0.7482 - val_jaccard_metric: 0.6979 - val_sensitivity_metric: 0.7528 - val_specificity_metric: 0.9584 - val_precision_metric: 0.7608 - val_recall_metric: 0.7528 - val_mean_average_precision: 0.6106
# Epoch 42/60
# 77/77 [==============================] - 92s 1s/step - loss: -0.7937 - dice_metric: 0.7999 - jaccard_metric: 0.7443 - sensitivity_metric: 0.8101 - specificity_metric: 0.9585 - precision_metric: 0.8081 - recall_metric: 0.8101 - mean_average_precision: 0.6514 - val_loss: -0.7436 - val_dice_metric: 0.7484 - val_jaccard_metric: 0.6983 - val_sensitivity_metric: 0.7531 - val_specificity_metric: 0.9587 - val_precision_metric: 0.7609 - val_recall_metric: 0.7531 - val_mean_average_precision: 0.6115
# Epoch 43/60
# 77/77 [==============================] - 98s 1s/step - loss: -0.7942 - dice_metric: 0.8002 - jaccard_metric: 0.7447 - sensitivity_metric: 0.8105 - specificity_metric: 0.9586 - precision_metric: 0.8084 - recall_metric: 0.8105 - mean_average_precision: 0.6520 - val_loss: -0.7446 - val_dice_metric: 0.7494 - val_jaccard_metric: 0.6995 - val_sensitivity_metric: 0.7535 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7617 - val_recall_metric: 0.7535 - val_mean_average_precision: 0.6140
# Epoch 44/60
# 77/77 [==============================] - 98s 1s/step - loss: -0.7946 - dice_metric: 0.8007 - jaccard_metric: 0.7452 - sensitivity_metric: 0.8108 - specificity_metric: 0.9587 - precision_metric: 0.8089 - recall_metric: 0.8108 - mean_average_precision: 0.6530 - val_loss: -0.7440 - val_dice_metric: 0.7487 - val_jaccard_metric: 0.6986 - val_sensitivity_metric: 0.7534 - val_specificity_metric: 0.9589 - val_precision_metric: 0.7608 - val_recall_metric: 0.7534 - val_mean_average_precision: 0.6107
# Epoch 45/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.7951 - dice_metric: 0.8011 - jaccard_metric: 0.7458 - sensitivity_metric: 0.8112 - specificity_metric: 0.9588 - precision_metric: 0.8093 - recall_metric: 0.8112 - mean_average_precision: 0.6537 - val_loss: -0.7441 - val_dice_metric: 0.7475 - val_jaccard_metric: 0.6973 - val_sensitivity_metric: 0.7534 - val_specificity_metric: 0.9590 - val_precision_metric: 0.7607 - val_recall_metric: 0.7534 - val_mean_average_precision: 0.6106
# Epoch 46/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.7956 - dice_metric: 0.8016 - jaccard_metric: 0.7463 - sensitivity_metric: 0.8115 - specificity_metric: 0.9589 - precision_metric: 0.8097 - recall_metric: 0.8115 - mean_average_precision: 0.6547 - val_loss: -0.7443 - val_dice_metric: 0.7477 - val_jaccard_metric: 0.6976 - val_sensitivity_metric: 0.7535 - val_specificity_metric: 0.9593 - val_precision_metric: 0.7609 - val_recall_metric: 0.7535 - val_mean_average_precision: 0.6117
# Epoch 47/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.7960 - dice_metric: 0.8021 - jaccard_metric: 0.7469 - sensitivity_metric: 0.8119 - specificity_metric: 0.9590 - precision_metric: 0.8100 - recall_metric: 0.8119 - mean_average_precision: 0.6556 - val_loss: -0.7454 - val_dice_metric: 0.7488 - val_jaccard_metric: 0.6988 - val_sensitivity_metric: 0.7530 - val_specificity_metric: 0.9589 - val_precision_metric: 0.7630 - val_recall_metric: 0.7530 - val_mean_average_precision: 0.6132
# Epoch 48/60
# 77/77 [==============================] - 93s 1s/step - loss: -0.7963 - dice_metric: 0.8023 - jaccard_metric: 0.7472 - sensitivity_metric: 0.8122 - specificity_metric: 0.9591 - precision_metric: 0.8103 - recall_metric: 0.8122 - mean_average_precision: 0.6559 - val_loss: -0.7449 - val_dice_metric: 0.7483 - val_jaccard_metric: 0.6983 - val_sensitivity_metric: 0.7537 - val_specificity_metric: 0.9595 - val_precision_metric: 0.7615 - val_recall_metric: 0.7537 - val_mean_average_precision: 0.6128
# Epoch 49/60
# 77/77 [==============================] - 92s 1s/step - loss: -0.7969 - dice_metric: 0.8029 - jaccard_metric: 0.7479 - sensitivity_metric: 0.8125 - specificity_metric: 0.9591 - precision_metric: 0.8108 - recall_metric: 0.8125 - mean_average_precision: 0.6570 - val_loss: -0.7451 - val_dice_metric: 0.7485 - val_jaccard_metric: 0.6985 - val_sensitivity_metric: 0.7542 - val_specificity_metric: 0.9597 - val_precision_metric: 0.7615 - val_recall_metric: 0.7542 - val_mean_average_precision: 0.6118
# Epoch 50/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.7973 - dice_metric: 0.8033 - jaccard_metric: 0.7483 - sensitivity_metric: 0.8128 - specificity_metric: 0.9591 - precision_metric: 0.8112 - recall_metric: 0.8128 - mean_average_precision: 0.6576 - val_loss: -0.7453 - val_dice_metric: 0.7487 - val_jaccard_metric: 0.6987 - val_sensitivity_metric: 0.7544 - val_specificity_metric: 0.9597 - val_precision_metric: 0.7615 - val_recall_metric: 0.7544 - val_mean_average_precision: 0.6121
# Epoch 51/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.7978 - dice_metric: 0.8037 - jaccard_metric: 0.7488 - sensitivity_metric: 0.8131 - specificity_metric: 0.9592 - precision_metric: 0.8116 - recall_metric: 0.8131 - mean_average_precision: 0.6582 - val_loss: -0.7455 - val_dice_metric: 0.7490 - val_jaccard_metric: 0.6990 - val_sensitivity_metric: 0.7543 - val_specificity_metric: 0.9596 - val_precision_metric: 0.7620 - val_recall_metric: 0.7543 - val_mean_average_precision: 0.6115
# Epoch 52/60
# 77/77 [==============================] - 94s 1s/step - loss: -0.7982 - dice_metric: 0.8041 - jaccard_metric: 0.7493 - sensitivity_metric: 0.8134 - specificity_metric: 0.9592 - precision_metric: 0.8120 - recall_metric: 0.8134 - mean_average_precision: 0.6589 - val_loss: -0.7451 - val_dice_metric: 0.7484 - val_jaccard_metric: 0.6984 - val_sensitivity_metric: 0.7540 - val_specificity_metric: 0.9593 - val_precision_metric: 0.7616 - val_recall_metric: 0.7540 - val_mean_average_precision: 0.6109
# Epoch 53/60
# 77/77 [==============================] - 94s 1s/step - loss: -0.7986 - dice_metric: 0.8043 - jaccard_metric: 0.7496 - sensitivity_metric: 0.8138 - specificity_metric: 0.9593 - precision_metric: 0.8123 - recall_metric: 0.8138 - mean_average_precision: 0.6594 - val_loss: -0.7455 - val_dice_metric: 0.7488 - val_jaccard_metric: 0.6987 - val_sensitivity_metric: 0.7537 - val_specificity_metric: 0.9594 - val_precision_metric: 0.7621 - val_recall_metric: 0.7537 - val_mean_average_precision: 0.6110
# Epoch 54/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.7991 - dice_metric: 0.8049 - jaccard_metric: 0.7503 - sensitivity_metric: 0.8141 - specificity_metric: 0.9594 - precision_metric: 0.8127 - recall_metric: 0.8141 - mean_average_precision: 0.6605 - val_loss: -0.7459 - val_dice_metric: 0.7492 - val_jaccard_metric: 0.6993 - val_sensitivity_metric: 0.7540 - val_specificity_metric: 0.9594 - val_precision_metric: 0.7627 - val_recall_metric: 0.7540 - val_mean_average_precision: 0.6123
# Epoch 55/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.7994 - dice_metric: 0.8052 - jaccard_metric: 0.7506 - sensitivity_metric: 0.8146 - specificity_metric: 0.9596 - precision_metric: 0.8128 - recall_metric: 0.8146 - mean_average_precision: 0.6612 - val_loss: -0.7461 - val_dice_metric: 0.7493 - val_jaccard_metric: 0.6996 - val_sensitivity_metric: 0.7545 - val_specificity_metric: 0.9598 - val_precision_metric: 0.7624 - val_recall_metric: 0.7545 - val_mean_average_precision: 0.6134
# Epoch 56/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.8000 - dice_metric: 0.8059 - jaccard_metric: 0.7514 - sensitivity_metric: 0.8149 - specificity_metric: 0.9597 - precision_metric: 0.8133 - recall_metric: 0.8149 - mean_average_precision: 0.6619 - val_loss: -0.7460 - val_dice_metric: 0.7490 - val_jaccard_metric: 0.6991 - val_sensitivity_metric: 0.7541 - val_specificity_metric: 0.9594 - val_precision_metric: 0.7629 - val_recall_metric: 0.7541 - val_mean_average_precision: 0.6121
# Epoch 57/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.8003 - dice_metric: 0.8062 - jaccard_metric: 0.7518 - sensitivity_metric: 0.8153 - specificity_metric: 0.9598 - precision_metric: 0.8135 - recall_metric: 0.8153 - mean_average_precision: 0.6623 - val_loss: -0.7467 - val_dice_metric: 0.7497 - val_jaccard_metric: 0.7002 - val_sensitivity_metric: 0.7546 - val_specificity_metric: 0.9598 - val_precision_metric: 0.7644 - val_recall_metric: 0.7546 - val_mean_average_precision: 0.6151
# Epoch 58/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.8009 - dice_metric: 0.8069 - jaccard_metric: 0.7526 - sensitivity_metric: 0.8156 - specificity_metric: 0.9600 - precision_metric: 0.8141 - recall_metric: 0.8156 - mean_average_precision: 0.6634 - val_loss: -0.7470 - val_dice_metric: 0.7499 - val_jaccard_metric: 0.7005 - val_sensitivity_metric: 0.7554 - val_specificity_metric: 0.9606 - val_precision_metric: 0.7629 - val_recall_metric: 0.7554 - val_mean_average_precision: 0.6165
# Epoch 59/60
# 77/77 [==============================] - 91s 1s/step - loss: -0.8014 - dice_metric: 0.8074 - jaccard_metric: 0.7532 - sensitivity_metric: 0.8158 - specificity_metric: 0.9599 - precision_metric: 0.8146 - recall_metric: 0.8158 - mean_average_precision: 0.6644 - val_loss: -0.7467 - val_dice_metric: 0.7484 - val_jaccard_metric: 0.6989 - val_sensitivity_metric: 0.7553 - val_specificity_metric: 0.9605 - val_precision_metric: 0.7635 - val_recall_metric: 0.7553 - val_mean_average_precision: 0.6140
# Epoch 60/60
# 77/77 [==============================] - 93s 1s/step - loss: -0.8019 - dice_metric: 0.8078 - jaccard_metric: 0.7537 - sensitivity_metric: 0.8161 - specificity_metric: 0.9600 - precision_metric: 0.8150 - recall_metric: 0.8161 - mean_average_precision: 0.6652 - val_loss: -0.7466 - val_dice_metric: 0.7483 - val_jaccard_metric: 0.6987 - val_sensitivity_metric: 0.7549 - val_specificity_metric: 0.9601 - val_precision_metric: 0.7636 - val_recall_metric: 0.7549 - val_mean_average_precision: 0.6134

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.77212, std: 0.33687
# Jaccard Index mean: 0.71981, std: 0.33608
# Sensitivity mean: 0.78310, std: 0.32760
# Specificity mean: 0.96034, std: 0.08173
# Precision mean: 0.78817, std: 0.34254
# Recall mean: 0.78310, std: 0.32760
# mAP@50 mean: 0.81356, std: 0.16549
# mAP@50-95 mean: 0.62768, std: 0.15846
