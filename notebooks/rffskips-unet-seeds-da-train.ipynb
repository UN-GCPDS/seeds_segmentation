# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|████████████████████████████████████████▉| 997M/998M [00:10<00:00, 126MB/s]
# 100%|████████████████████████████████████████| 998M/998M [00:10<00:00, 99.6MB/s]

# %%
config = {"Seg_model":"RFFSkipsUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_rff_skips
from seeds_segmentation.losses import DiceCoefficient

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = unet_rff_skips(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])

### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 115s 993ms/step - loss: -0.2191 - dice_metric: 0.4175 - jaccard_metric: 0.3359 - sensitivity_metric: 0.6889 - specificity_metric: 0.6889 - precision_metric: 0.5876 - recall_metric: 0.6889 - mean_average_precision: 0.1910 - val_loss: -0.0641 - val_dice_metric: 0.4888 - val_jaccard_metric: 0.4782 - val_sensitivity_metric: 0.4990 - val_specificity_metric: 0.4990 - val_precision_metric: 0.4797 - val_recall_metric: 0.4990 - val_mean_average_precision: 0.4806
# Epoch 2/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.3617 - dice_metric: 0.5249 - jaccard_metric: 0.4599 - sensitivity_metric: 0.7539 - specificity_metric: 0.7539 - precision_metric: 0.6660 - recall_metric: 0.7539 - mean_average_precision: 0.3495 - val_loss: -0.0305 - val_dice_metric: 0.4893 - val_jaccard_metric: 0.4792 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000 - val_precision_metric: 0.4796 - val_recall_metric: 0.5000 - val_mean_average_precision: 0.4812
# Epoch 3/60
# 77/77 [==============================] - 71s 924ms/step - loss: -0.4151 - dice_metric: 0.5641 - jaccard_metric: 0.5043 - sensitivity_metric: 0.7696 - specificity_metric: 0.7696 - precision_metric: 0.6823 - recall_metric: 0.7696 - mean_average_precision: 0.4058 - val_loss: -0.1342 - val_dice_metric: 0.5612 - val_jaccard_metric: 0.5247 - val_sensitivity_metric: 0.5436 - val_specificity_metric: 0.5436 - val_precision_metric: 0.7783 - val_recall_metric: 0.5436 - val_mean_average_precision: 0.4837
# Epoch 4/60
# 77/77 [==============================] - 72s 928ms/step - loss: -0.4476 - dice_metric: 0.5926 - jaccard_metric: 0.5345 - sensitivity_metric: 0.7816 - specificity_metric: 0.7816 - precision_metric: 0.6985 - recall_metric: 0.7816 - mean_average_precision: 0.4385 - val_loss: -0.5333 - val_dice_metric: 0.7845 - val_jaccard_metric: 0.7159 - val_sensitivity_metric: 0.7345 - val_specificity_metric: 0.7345 - val_precision_metric: 0.9346 - val_recall_metric: 0.7345 - val_mean_average_precision: 0.5846
# Epoch 5/60
# 77/77 [==============================] - 70s 900ms/step - loss: -0.4736 - dice_metric: 0.6159 - jaccard_metric: 0.5589 - sensitivity_metric: 0.7912 - specificity_metric: 0.7912 - precision_metric: 0.7159 - recall_metric: 0.7912 - mean_average_precision: 0.4638 - val_loss: -0.7571 - val_dice_metric: 0.9068 - val_jaccard_metric: 0.8502 - val_sensitivity_metric: 0.8793 - val_specificity_metric: 0.8793 - val_precision_metric: 0.9526 - val_recall_metric: 0.8793 - val_mean_average_precision: 0.7492
# Epoch 6/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.4947 - dice_metric: 0.6338 - jaccard_metric: 0.5776 - sensitivity_metric: 0.7993 - specificity_metric: 0.7993 - precision_metric: 0.7281 - recall_metric: 0.7993 - mean_average_precision: 0.4846 - val_loss: -0.8028 - val_dice_metric: 0.9261 - val_jaccard_metric: 0.8774 - val_sensitivity_metric: 0.9217 - val_specificity_metric: 0.9217 - val_precision_metric: 0.9387 - val_recall_metric: 0.9217 - val_mean_average_precision: 0.7904
# Epoch 7/60
# 77/77 [==============================] - 71s 915ms/step - loss: -0.5140 - dice_metric: 0.6555 - jaccard_metric: 0.5994 - sensitivity_metric: 0.8100 - specificity_metric: 0.8100 - precision_metric: 0.7459 - recall_metric: 0.8100 - mean_average_precision: 0.5065 - val_loss: -0.8187 - val_dice_metric: 0.9314 - val_jaccard_metric: 0.8849 - val_sensitivity_metric: 0.9336 - val_specificity_metric: 0.9336 - val_precision_metric: 0.9345 - val_recall_metric: 0.9336 - val_mean_average_precision: 0.8057
# Epoch 8/60
# 77/77 [==============================] - 73s 939ms/step - loss: -0.5317 - dice_metric: 0.6734 - jaccard_metric: 0.6174 - sensitivity_metric: 0.8188 - specificity_metric: 0.8188 - precision_metric: 0.7590 - recall_metric: 0.8188 - mean_average_precision: 0.5254 - val_loss: -0.8287 - val_dice_metric: 0.9346 - val_jaccard_metric: 0.8897 - val_sensitivity_metric: 0.9354 - val_specificity_metric: 0.9354 - val_precision_metric: 0.9385 - val_recall_metric: 0.9354 - val_mean_average_precision: 0.8135
# Epoch 9/60
# 77/77 [==============================] - 71s 921ms/step - loss: -0.5482 - dice_metric: 0.6898 - jaccard_metric: 0.6339 - sensitivity_metric: 0.8271 - specificity_metric: 0.8271 - precision_metric: 0.7719 - recall_metric: 0.8271 - mean_average_precision: 0.5419 - val_loss: -0.8332 - val_dice_metric: 0.9367 - val_jaccard_metric: 0.8927 - val_sensitivity_metric: 0.9377 - val_specificity_metric: 0.9377 - val_precision_metric: 0.9400 - val_recall_metric: 0.9377 - val_mean_average_precision: 0.8182
# Epoch 10/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.5643 - dice_metric: 0.7035 - jaccard_metric: 0.6481 - sensitivity_metric: 0.8332 - specificity_metric: 0.8332 - precision_metric: 0.7834 - recall_metric: 0.8332 - mean_average_precision: 0.5571 - val_loss: -0.8349 - val_dice_metric: 0.9371 - val_jaccard_metric: 0.8937 - val_sensitivity_metric: 0.9360 - val_specificity_metric: 0.9360 - val_precision_metric: 0.9433 - val_recall_metric: 0.9360 - val_mean_average_precision: 0.8210
# Epoch 11/60
# 77/77 [==============================] - 69s 886ms/step - loss: -0.5791 - dice_metric: 0.7144 - jaccard_metric: 0.6593 - sensitivity_metric: 0.8379 - specificity_metric: 0.8379 - precision_metric: 0.7911 - recall_metric: 0.8379 - mean_average_precision: 0.5689 - val_loss: -0.8380 - val_dice_metric: 0.9387 - val_jaccard_metric: 0.8959 - val_sensitivity_metric: 0.9312 - val_specificity_metric: 0.9312 - val_precision_metric: 0.9512 - val_recall_metric: 0.9312 - val_mean_average_precision: 0.8264
# Epoch 12/60
# 77/77 [==============================] - 69s 885ms/step - loss: -0.5925 - dice_metric: 0.7263 - jaccard_metric: 0.6713 - sensitivity_metric: 0.8437 - specificity_metric: 0.8437 - precision_metric: 0.8005 - recall_metric: 0.8437 - mean_average_precision: 0.5811 - val_loss: -0.8409 - val_dice_metric: 0.9402 - val_jaccard_metric: 0.8980 - val_sensitivity_metric: 0.9299 - val_specificity_metric: 0.9299 - val_precision_metric: 0.9550 - val_recall_metric: 0.9299 - val_mean_average_precision: 0.8299
# Epoch 13/60
# 77/77 [==============================] - 71s 912ms/step - loss: -0.6046 - dice_metric: 0.7386 - jaccard_metric: 0.6836 - sensitivity_metric: 0.8496 - specificity_metric: 0.8496 - precision_metric: 0.8092 - recall_metric: 0.8496 - mean_average_precision: 0.5936 - val_loss: -0.8417 - val_dice_metric: 0.9394 - val_jaccard_metric: 0.8970 - val_sensitivity_metric: 0.9267 - val_specificity_metric: 0.9267 - val_precision_metric: 0.9575 - val_recall_metric: 0.9267 - val_mean_average_precision: 0.8273
# Epoch 14/60
# 77/77 [==============================] - 69s 898ms/step - loss: -0.6170 - dice_metric: 0.7489 - jaccard_metric: 0.6945 - sensitivity_metric: 0.8540 - specificity_metric: 0.8540 - precision_metric: 0.8160 - recall_metric: 0.8540 - mean_average_precision: 0.6055 - val_loss: -0.8485 - val_dice_metric: 0.9411 - val_jaccard_metric: 0.8994 - val_sensitivity_metric: 0.9291 - val_specificity_metric: 0.9291 - val_precision_metric: 0.9580 - val_recall_metric: 0.9291 - val_mean_average_precision: 0.8316
# Epoch 15/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.6288 - dice_metric: 0.7571 - jaccard_metric: 0.7029 - sensitivity_metric: 0.8581 - specificity_metric: 0.8581 - precision_metric: 0.8231 - recall_metric: 0.8581 - mean_average_precision: 0.6145 - val_loss: -0.8454 - val_dice_metric: 0.9396 - val_jaccard_metric: 0.8970 - val_sensitivity_metric: 0.9201 - val_specificity_metric: 0.9201 - val_precision_metric: 0.9656 - val_recall_metric: 0.9201 - val_mean_average_precision: 0.8289
# Epoch 16/60
# 77/77 [==============================] - 71s 920ms/step - loss: -0.6400 - dice_metric: 0.7660 - jaccard_metric: 0.7123 - sensitivity_metric: 0.8623 - specificity_metric: 0.8623 - precision_metric: 0.8295 - recall_metric: 0.8623 - mean_average_precision: 0.6246 - val_loss: -0.8505 - val_dice_metric: 0.9405 - val_jaccard_metric: 0.8983 - val_sensitivity_metric: 0.9218 - val_specificity_metric: 0.9218 - val_precision_metric: 0.9655 - val_recall_metric: 0.9218 - val_mean_average_precision: 0.8311
# Epoch 17/60
# 77/77 [==============================] - 73s 951ms/step - loss: -0.6503 - dice_metric: 0.7757 - jaccard_metric: 0.7222 - sensitivity_metric: 0.8674 - specificity_metric: 0.8674 - precision_metric: 0.8346 - recall_metric: 0.8674 - mean_average_precision: 0.6354 - val_loss: -0.8594 - val_dice_metric: 0.9431 - val_jaccard_metric: 0.9025 - val_sensitivity_metric: 0.9289 - val_specificity_metric: 0.9289 - val_precision_metric: 0.9624 - val_recall_metric: 0.9289 - val_mean_average_precision: 0.8391
# Epoch 18/60
# 77/77 [==============================] - 70s 910ms/step - loss: -0.6606 - dice_metric: 0.7815 - jaccard_metric: 0.7285 - sensitivity_metric: 0.8697 - specificity_metric: 0.8697 - precision_metric: 0.8402 - recall_metric: 0.8697 - mean_average_precision: 0.6431 - val_loss: -0.8640 - val_dice_metric: 0.9444 - val_jaccard_metric: 0.9046 - val_sensitivity_metric: 0.9332 - val_specificity_metric: 0.9332 - val_precision_metric: 0.9599 - val_recall_metric: 0.9332 - val_mean_average_precision: 0.8414
# Epoch 19/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.6695 - dice_metric: 0.7905 - jaccard_metric: 0.7375 - sensitivity_metric: 0.8744 - specificity_metric: 0.8744 - precision_metric: 0.8451 - recall_metric: 0.8744 - mean_average_precision: 0.6524 - val_loss: -0.8666 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9047 - val_sensitivity_metric: 0.9331 - val_specificity_metric: 0.9331 - val_precision_metric: 0.9604 - val_recall_metric: 0.9331 - val_mean_average_precision: 0.8424
# Epoch 20/60
# 77/77 [==============================] - 69s 884ms/step - loss: -0.6778 - dice_metric: 0.7973 - jaccard_metric: 0.7446 - sensitivity_metric: 0.8778 - specificity_metric: 0.8778 - precision_metric: 0.8497 - recall_metric: 0.8778 - mean_average_precision: 0.6599 - val_loss: -0.8700 - val_dice_metric: 0.9452 - val_jaccard_metric: 0.9058 - val_sensitivity_metric: 0.9403 - val_specificity_metric: 0.9403 - val_precision_metric: 0.9538 - val_recall_metric: 0.9403 - val_mean_average_precision: 0.8449
# Epoch 21/60
# 77/77 [==============================] - 71s 915ms/step - loss: -0.6871 - dice_metric: 0.8061 - jaccard_metric: 0.7533 - sensitivity_metric: 0.8816 - specificity_metric: 0.8816 - precision_metric: 0.8552 - recall_metric: 0.8816 - mean_average_precision: 0.6689 - val_loss: -0.8721 - val_dice_metric: 0.9459 - val_jaccard_metric: 0.9068 - val_sensitivity_metric: 0.9407 - val_specificity_metric: 0.9407 - val_precision_metric: 0.9546 - val_recall_metric: 0.9407 - val_mean_average_precision: 0.8447
# Epoch 22/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.6915 - dice_metric: 0.8178 - jaccard_metric: 0.7637 - sensitivity_metric: 0.8888 - specificity_metric: 0.8888 - precision_metric: 0.8592 - recall_metric: 0.8888 - mean_average_precision: 0.6761 - val_loss: -0.8738 - val_dice_metric: 0.9462 - val_jaccard_metric: 0.9074 - val_sensitivity_metric: 0.9439 - val_specificity_metric: 0.9439 - val_precision_metric: 0.9518 - val_recall_metric: 0.9439 - val_mean_average_precision: 0.8508
# Epoch 23/60
# 77/77 [==============================] - 73s 936ms/step - loss: -0.7016 - dice_metric: 0.8251 - jaccard_metric: 0.7713 - sensitivity_metric: 0.8920 - specificity_metric: 0.8920 - precision_metric: 0.8647 - recall_metric: 0.8920 - mean_average_precision: 0.6848 - val_loss: -0.8734 - val_dice_metric: 0.9454 - val_jaccard_metric: 0.9059 - val_sensitivity_metric: 0.9422 - val_specificity_metric: 0.9422 - val_precision_metric: 0.9521 - val_recall_metric: 0.9422 - val_mean_average_precision: 0.8451
# Epoch 24/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.7095 - dice_metric: 0.8322 - jaccard_metric: 0.7786 - sensitivity_metric: 0.8959 - specificity_metric: 0.8959 - precision_metric: 0.8682 - recall_metric: 0.8959 - mean_average_precision: 0.6914 - val_loss: -0.8728 - val_dice_metric: 0.9448 - val_jaccard_metric: 0.9049 - val_sensitivity_metric: 0.9479 - val_specificity_metric: 0.9479 - val_precision_metric: 0.9449 - val_recall_metric: 0.9479 - val_mean_average_precision: 0.8451
# Epoch 25/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.7163 - dice_metric: 0.8427 - jaccard_metric: 0.7888 - sensitivity_metric: 0.9017 - specificity_metric: 0.9017 - precision_metric: 0.8728 - recall_metric: 0.9017 - mean_average_precision: 0.7013 - val_loss: -0.8781 - val_dice_metric: 0.9460 - val_jaccard_metric: 0.9071 - val_sensitivity_metric: 0.9489 - val_specificity_metric: 0.9489 - val_precision_metric: 0.9463 - val_recall_metric: 0.9489 - val_mean_average_precision: 0.8489
# Epoch 26/60
# 77/77 [==============================] - 70s 899ms/step - loss: -0.7258 - dice_metric: 0.8517 - jaccard_metric: 0.7983 - sensitivity_metric: 0.9064 - specificity_metric: 0.9064 - precision_metric: 0.8774 - recall_metric: 0.9064 - mean_average_precision: 0.7114 - val_loss: -0.8813 - val_dice_metric: 0.9468 - val_jaccard_metric: 0.9082 - val_sensitivity_metric: 0.9415 - val_specificity_metric: 0.9415 - val_precision_metric: 0.9555 - val_recall_metric: 0.9415 - val_mean_average_precision: 0.8487
# Epoch 27/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.7368 - dice_metric: 0.8621 - jaccard_metric: 0.8094 - sensitivity_metric: 0.9112 - specificity_metric: 0.9112 - precision_metric: 0.8839 - recall_metric: 0.9112 - mean_average_precision: 0.7235 - val_loss: -0.8847 - val_dice_metric: 0.9476 - val_jaccard_metric: 0.9094 - val_sensitivity_metric: 0.9413 - val_specificity_metric: 0.9413 - val_precision_metric: 0.9574 - val_recall_metric: 0.9413 - val_mean_average_precision: 0.8524
# Epoch 28/60
# 77/77 [==============================] - 69s 898ms/step - loss: -0.7486 - dice_metric: 0.8693 - jaccard_metric: 0.8175 - sensitivity_metric: 0.9142 - specificity_metric: 0.9142 - precision_metric: 0.8895 - recall_metric: 0.9142 - mean_average_precision: 0.7339 - val_loss: -0.8839 - val_dice_metric: 0.9474 - val_jaccard_metric: 0.9092 - val_sensitivity_metric: 0.9388 - val_specificity_metric: 0.9388 - val_precision_metric: 0.9596 - val_recall_metric: 0.9388 - val_mean_average_precision: 0.8522
# Epoch 29/60
# 77/77 [==============================] - 67s 863ms/step - loss: -0.7578 - dice_metric: 0.8756 - jaccard_metric: 0.8244 - sensitivity_metric: 0.9168 - specificity_metric: 0.9168 - precision_metric: 0.8942 - recall_metric: 0.9168 - mean_average_precision: 0.7422 - val_loss: -0.8848 - val_dice_metric: 0.9474 - val_jaccard_metric: 0.9092 - val_sensitivity_metric: 0.9392 - val_specificity_metric: 0.9392 - val_precision_metric: 0.9594 - val_recall_metric: 0.9392 - val_mean_average_precision: 0.8534
# Epoch 30/60
# 77/77 [==============================] - 67s 866ms/step - loss: -0.7666 - dice_metric: 0.8801 - jaccard_metric: 0.8293 - sensitivity_metric: 0.9186 - specificity_metric: 0.9186 - precision_metric: 0.8973 - recall_metric: 0.9186 - mean_average_precision: 0.7481 - val_loss: -0.8825 - val_dice_metric: 0.9472 - val_jaccard_metric: 0.9088 - val_sensitivity_metric: 0.9361 - val_specificity_metric: 0.9361 - val_precision_metric: 0.9624 - val_recall_metric: 0.9361 - val_mean_average_precision: 0.8518
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 70s 906ms/step - loss: -0.7736 - dice_metric: 0.8855 - jaccard_metric: 0.8357 - sensitivity_metric: 0.9209 - specificity_metric: 0.9209 - precision_metric: 0.9017 - recall_metric: 0.9209 - mean_average_precision: 0.7567 - val_loss: -0.8769 - val_dice_metric: 0.9491 - val_jaccard_metric: 0.9117 - val_sensitivity_metric: 0.9464 - val_specificity_metric: 0.9464 - val_precision_metric: 0.9548 - val_recall_metric: 0.9464 - val_mean_average_precision: 0.8587
# Epoch 32/60
# 77/77 [==============================] - 71s 914ms/step - loss: -0.7760 - dice_metric: 0.8839 - jaccard_metric: 0.8345 - sensitivity_metric: 0.9200 - specificity_metric: 0.9200 - precision_metric: 0.9018 - recall_metric: 0.9200 - mean_average_precision: 0.7568 - val_loss: -0.8710 - val_dice_metric: 0.9491 - val_jaccard_metric: 0.9118 - val_sensitivity_metric: 0.9476 - val_specificity_metric: 0.9476 - val_precision_metric: 0.9536 - val_recall_metric: 0.9476 - val_mean_average_precision: 0.8583
# Epoch 33/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.7772 - dice_metric: 0.8840 - jaccard_metric: 0.8348 - sensitivity_metric: 0.9200 - specificity_metric: 0.9200 - precision_metric: 0.9023 - recall_metric: 0.9200 - mean_average_precision: 0.7575 - val_loss: -0.8682 - val_dice_metric: 0.9492 - val_jaccard_metric: 0.9119 - val_sensitivity_metric: 0.9483 - val_specificity_metric: 0.9483 - val_precision_metric: 0.9530 - val_recall_metric: 0.9483 - val_mean_average_precision: 0.8579
# Epoch 34/60
# 77/77 [==============================] - 70s 905ms/step - loss: -0.7783 - dice_metric: 0.8843 - jaccard_metric: 0.8352 - sensitivity_metric: 0.9200 - specificity_metric: 0.9200 - precision_metric: 0.9027 - recall_metric: 0.9200 - mean_average_precision: 0.7583 - val_loss: -0.8673 - val_dice_metric: 0.9493 - val_jaccard_metric: 0.9120 - val_sensitivity_metric: 0.9487 - val_specificity_metric: 0.9487 - val_precision_metric: 0.9528 - val_recall_metric: 0.9487 - val_mean_average_precision: 0.8583
# Epoch 35/60
# 77/77 [==============================] - 68s 878ms/step - loss: -0.7793 - dice_metric: 0.8845 - jaccard_metric: 0.8356 - sensitivity_metric: 0.9201 - specificity_metric: 0.9201 - precision_metric: 0.9031 - recall_metric: 0.9201 - mean_average_precision: 0.7588 - val_loss: -0.8672 - val_dice_metric: 0.9493 - val_jaccard_metric: 0.9121 - val_sensitivity_metric: 0.9489 - val_specificity_metric: 0.9489 - val_precision_metric: 0.9527 - val_recall_metric: 0.9489 - val_mean_average_precision: 0.8583
# Epoch 36/60
# 77/77 [==============================] - 70s 907ms/step - loss: -0.7803 - dice_metric: 0.8848 - jaccard_metric: 0.8359 - sensitivity_metric: 0.9201 - specificity_metric: 0.9201 - precision_metric: 0.9035 - recall_metric: 0.9201 - mean_average_precision: 0.7597 - val_loss: -0.8675 - val_dice_metric: 0.9494 - val_jaccard_metric: 0.9122 - val_sensitivity_metric: 0.9491 - val_specificity_metric: 0.9491 - val_precision_metric: 0.9526 - val_recall_metric: 0.9491 - val_mean_average_precision: 0.8583
# Epoch 37/60
# 77/77 [==============================] - 69s 885ms/step - loss: -0.7812 - dice_metric: 0.8851 - jaccard_metric: 0.8364 - sensitivity_metric: 0.9203 - specificity_metric: 0.9203 - precision_metric: 0.9039 - recall_metric: 0.9203 - mean_average_precision: 0.7602 - val_loss: -0.8680 - val_dice_metric: 0.9495 - val_jaccard_metric: 0.9123 - val_sensitivity_metric: 0.9491 - val_specificity_metric: 0.9491 - val_precision_metric: 0.9527 - val_recall_metric: 0.9491 - val_mean_average_precision: 0.8585
# Epoch 38/60
# 77/77 [==============================] - 70s 905ms/step - loss: -0.7821 - dice_metric: 0.8854 - jaccard_metric: 0.8367 - sensitivity_metric: 0.9203 - specificity_metric: 0.9203 - precision_metric: 0.9042 - recall_metric: 0.9203 - mean_average_precision: 0.7609 - val_loss: -0.8685 - val_dice_metric: 0.9496 - val_jaccard_metric: 0.9124 - val_sensitivity_metric: 0.9491 - val_specificity_metric: 0.9491 - val_precision_metric: 0.9530 - val_recall_metric: 0.9491 - val_mean_average_precision: 0.8587
# Epoch 39/60
# 77/77 [==============================] - 70s 902ms/step - loss: -0.7830 - dice_metric: 0.8856 - jaccard_metric: 0.8371 - sensitivity_metric: 0.9204 - specificity_metric: 0.9204 - precision_metric: 0.9045 - recall_metric: 0.9204 - mean_average_precision: 0.7616 - val_loss: -0.8691 - val_dice_metric: 0.9496 - val_jaccard_metric: 0.9125 - val_sensitivity_metric: 0.9491 - val_specificity_metric: 0.9491 - val_precision_metric: 0.9530 - val_recall_metric: 0.9491 - val_mean_average_precision: 0.8585
# Epoch 40/60
# 77/77 [==============================] - 67s 865ms/step - loss: -0.7839 - dice_metric: 0.8859 - jaccard_metric: 0.8375 - sensitivity_metric: 0.9205 - specificity_metric: 0.9205 - precision_metric: 0.9049 - recall_metric: 0.9205 - mean_average_precision: 0.7621 - val_loss: -0.8697 - val_dice_metric: 0.9497 - val_jaccard_metric: 0.9126 - val_sensitivity_metric: 0.9492 - val_specificity_metric: 0.9492 - val_precision_metric: 0.9531 - val_recall_metric: 0.9492 - val_mean_average_precision: 0.8590
# Epoch 41/60
# 77/77 [==============================] - 72s 934ms/step - loss: -0.7847 - dice_metric: 0.8862 - jaccard_metric: 0.8379 - sensitivity_metric: 0.9207 - specificity_metric: 0.9207 - precision_metric: 0.9052 - recall_metric: 0.9207 - mean_average_precision: 0.7628 - val_loss: -0.8702 - val_dice_metric: 0.9497 - val_jaccard_metric: 0.9127 - val_sensitivity_metric: 0.9491 - val_specificity_metric: 0.9491 - val_precision_metric: 0.9533 - val_recall_metric: 0.9491 - val_mean_average_precision: 0.8590
# Epoch 42/60
# 77/77 [==============================] - 70s 900ms/step - loss: -0.7855 - dice_metric: 0.8864 - jaccard_metric: 0.8382 - sensitivity_metric: 0.9208 - specificity_metric: 0.9208 - precision_metric: 0.9055 - recall_metric: 0.9208 - mean_average_precision: 0.7631 - val_loss: -0.8708 - val_dice_metric: 0.9498 - val_jaccard_metric: 0.9128 - val_sensitivity_metric: 0.9491 - val_specificity_metric: 0.9491 - val_precision_metric: 0.9534 - val_recall_metric: 0.9491 - val_mean_average_precision: 0.8594
# Epoch 43/60
# 77/77 [==============================] - 70s 904ms/step - loss: -0.7863 - dice_metric: 0.8867 - jaccard_metric: 0.8385 - sensitivity_metric: 0.9208 - specificity_metric: 0.9208 - precision_metric: 0.9057 - recall_metric: 0.9208 - mean_average_precision: 0.7637 - val_loss: -0.8713 - val_dice_metric: 0.9499 - val_jaccard_metric: 0.9129 - val_sensitivity_metric: 0.9492 - val_specificity_metric: 0.9492 - val_precision_metric: 0.9534 - val_recall_metric: 0.9492 - val_mean_average_precision: 0.8596
# Epoch 44/60
# 77/77 [==============================] - 72s 926ms/step - loss: -0.7871 - dice_metric: 0.8869 - jaccard_metric: 0.8388 - sensitivity_metric: 0.9209 - specificity_metric: 0.9209 - precision_metric: 0.9060 - recall_metric: 0.9209 - mean_average_precision: 0.7642 - val_loss: -0.8718 - val_dice_metric: 0.9499 - val_jaccard_metric: 0.9129 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493 - val_precision_metric: 0.9534 - val_recall_metric: 0.9493 - val_mean_average_precision: 0.8598
# Epoch 45/60
# 77/77 [==============================] - 73s 945ms/step - loss: -0.7879 - dice_metric: 0.8871 - jaccard_metric: 0.8391 - sensitivity_metric: 0.9210 - specificity_metric: 0.9210 - precision_metric: 0.9063 - recall_metric: 0.9210 - mean_average_precision: 0.7647 - val_loss: -0.8724 - val_dice_metric: 0.9500 - val_jaccard_metric: 0.9130 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493 - val_precision_metric: 0.9535 - val_recall_metric: 0.9493 - val_mean_average_precision: 0.8598
# Epoch 46/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.7887 - dice_metric: 0.8873 - jaccard_metric: 0.8394 - sensitivity_metric: 0.9211 - specificity_metric: 0.9211 - precision_metric: 0.9065 - recall_metric: 0.9211 - mean_average_precision: 0.7651 - val_loss: -0.8729 - val_dice_metric: 0.9500 - val_jaccard_metric: 0.9131 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493 - val_precision_metric: 0.9535 - val_recall_metric: 0.9493 - val_mean_average_precision: 0.8600
# Epoch 47/60
# 77/77 [==============================] - 69s 888ms/step - loss: -0.7895 - dice_metric: 0.8875 - jaccard_metric: 0.8397 - sensitivity_metric: 0.9212 - specificity_metric: 0.9212 - precision_metric: 0.9068 - recall_metric: 0.9212 - mean_average_precision: 0.7657 - val_loss: -0.8734 - val_dice_metric: 0.9500 - val_jaccard_metric: 0.9131 - val_sensitivity_metric: 0.9494 - val_specificity_metric: 0.9494 - val_precision_metric: 0.9536 - val_recall_metric: 0.9494 - val_mean_average_precision: 0.8600
# Epoch 48/60
# 77/77 [==============================] - 69s 884ms/step - loss: -0.7902 - dice_metric: 0.8878 - jaccard_metric: 0.8400 - sensitivity_metric: 0.9213 - specificity_metric: 0.9213 - precision_metric: 0.9070 - recall_metric: 0.9213 - mean_average_precision: 0.7661 - val_loss: -0.8739 - val_dice_metric: 0.9501 - val_jaccard_metric: 0.9132 - val_sensitivity_metric: 0.9495 - val_specificity_metric: 0.9495 - val_precision_metric: 0.9535 - val_recall_metric: 0.9495 - val_mean_average_precision: 0.8602
# Epoch 49/60
# 77/77 [==============================] - 70s 909ms/step - loss: -0.7909 - dice_metric: 0.8880 - jaccard_metric: 0.8403 - sensitivity_metric: 0.9214 - specificity_metric: 0.9214 - precision_metric: 0.9073 - recall_metric: 0.9214 - mean_average_precision: 0.7668 - val_loss: -0.8743 - val_dice_metric: 0.9501 - val_jaccard_metric: 0.9132 - val_sensitivity_metric: 0.9495 - val_specificity_metric: 0.9495 - val_precision_metric: 0.9535 - val_recall_metric: 0.9495 - val_mean_average_precision: 0.8600
# Epoch 50/60
# 77/77 [==============================] - 73s 937ms/step - loss: -0.7917 - dice_metric: 0.8883 - jaccard_metric: 0.8407 - sensitivity_metric: 0.9215 - specificity_metric: 0.9215 - precision_metric: 0.9076 - recall_metric: 0.9215 - mean_average_precision: 0.7672 - val_loss: -0.8748 - val_dice_metric: 0.9501 - val_jaccard_metric: 0.9133 - val_sensitivity_metric: 0.9496 - val_specificity_metric: 0.9496 - val_precision_metric: 0.9535 - val_recall_metric: 0.9496 - val_mean_average_precision: 0.8600
# Epoch 51/60
# 77/77 [==============================] - 68s 883ms/step - loss: -0.7924 - dice_metric: 0.8885 - jaccard_metric: 0.8409 - sensitivity_metric: 0.9216 - specificity_metric: 0.9216 - precision_metric: 0.9078 - recall_metric: 0.9216 - mean_average_precision: 0.7675 - val_loss: -0.8753 - val_dice_metric: 0.9502 - val_jaccard_metric: 0.9133 - val_sensitivity_metric: 0.9496 - val_specificity_metric: 0.9496 - val_precision_metric: 0.9536 - val_recall_metric: 0.9496 - val_mean_average_precision: 0.8598
# Epoch 52/60
# 77/77 [==============================] - 68s 878ms/step - loss: -0.7931 - dice_metric: 0.8887 - jaccard_metric: 0.8412 - sensitivity_metric: 0.9217 - specificity_metric: 0.9217 - precision_metric: 0.9080 - recall_metric: 0.9217 - mean_average_precision: 0.7680 - val_loss: -0.8757 - val_dice_metric: 0.9502 - val_jaccard_metric: 0.9134 - val_sensitivity_metric: 0.9498 - val_specificity_metric: 0.9498 - val_precision_metric: 0.9534 - val_recall_metric: 0.9498 - val_mean_average_precision: 0.8596
# Epoch 53/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.7938 - dice_metric: 0.8889 - jaccard_metric: 0.8415 - sensitivity_metric: 0.9218 - specificity_metric: 0.9218 - precision_metric: 0.9083 - recall_metric: 0.9218 - mean_average_precision: 0.7683 - val_loss: -0.8761 - val_dice_metric: 0.9502 - val_jaccard_metric: 0.9134 - val_sensitivity_metric: 0.9499 - val_specificity_metric: 0.9499 - val_precision_metric: 0.9534 - val_recall_metric: 0.9499 - val_mean_average_precision: 0.8596
# Epoch 54/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.7945 - dice_metric: 0.8893 - jaccard_metric: 0.8419 - sensitivity_metric: 0.9220 - specificity_metric: 0.9220 - precision_metric: 0.9085 - recall_metric: 0.9220 - mean_average_precision: 0.7689 - val_loss: -0.8765 - val_dice_metric: 0.9503 - val_jaccard_metric: 0.9135 - val_sensitivity_metric: 0.9500 - val_specificity_metric: 0.9500 - val_precision_metric: 0.9533 - val_recall_metric: 0.9500 - val_mean_average_precision: 0.8598
# Epoch 55/60
# 77/77 [==============================] - 69s 897ms/step - loss: -0.7952 - dice_metric: 0.8895 - jaccard_metric: 0.8423 - sensitivity_metric: 0.9221 - specificity_metric: 0.9221 - precision_metric: 0.9088 - recall_metric: 0.9221 - mean_average_precision: 0.7693 - val_loss: -0.8770 - val_dice_metric: 0.9503 - val_jaccard_metric: 0.9136 - val_sensitivity_metric: 0.9500 - val_specificity_metric: 0.9500 - val_precision_metric: 0.9535 - val_recall_metric: 0.9500 - val_mean_average_precision: 0.8602
# Epoch 56/60
# 77/77 [==============================] - 69s 888ms/step - loss: -0.7959 - dice_metric: 0.8900 - jaccard_metric: 0.8427 - sensitivity_metric: 0.9223 - specificity_metric: 0.9223 - precision_metric: 0.9091 - recall_metric: 0.9223 - mean_average_precision: 0.7700 - val_loss: -0.8774 - val_dice_metric: 0.9503 - val_jaccard_metric: 0.9136 - val_sensitivity_metric: 0.9501 - val_specificity_metric: 0.9501 - val_precision_metric: 0.9534 - val_recall_metric: 0.9501 - val_mean_average_precision: 0.8600
# Epoch 57/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.7966 - dice_metric: 0.8902 - jaccard_metric: 0.8430 - sensitivity_metric: 0.9224 - specificity_metric: 0.9224 - precision_metric: 0.9093 - recall_metric: 0.9224 - mean_average_precision: 0.7704 - val_loss: -0.8778 - val_dice_metric: 0.9504 - val_jaccard_metric: 0.9137 - val_sensitivity_metric: 0.9500 - val_specificity_metric: 0.9500 - val_precision_metric: 0.9536 - val_recall_metric: 0.9500 - val_mean_average_precision: 0.8608
# Epoch 58/60
# 77/77 [==============================] - 71s 911ms/step - loss: -0.7973 - dice_metric: 0.8907 - jaccard_metric: 0.8435 - sensitivity_metric: 0.9227 - specificity_metric: 0.9227 - precision_metric: 0.9096 - recall_metric: 0.9227 - mean_average_precision: 0.7709 - val_loss: -0.8781 - val_dice_metric: 0.9504 - val_jaccard_metric: 0.9137 - val_sensitivity_metric: 0.9502 - val_specificity_metric: 0.9502 - val_precision_metric: 0.9534 - val_recall_metric: 0.9502 - val_mean_average_precision: 0.8604
# Epoch 59/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.7980 - dice_metric: 0.8912 - jaccard_metric: 0.8441 - sensitivity_metric: 0.9229 - specificity_metric: 0.9229 - precision_metric: 0.9099 - recall_metric: 0.9229 - mean_average_precision: 0.7716 - val_loss: -0.8785 - val_dice_metric: 0.9505 - val_jaccard_metric: 0.9138 - val_sensitivity_metric: 0.9501 - val_specificity_metric: 0.9501 - val_precision_metric: 0.9537 - val_recall_metric: 0.9501 - val_mean_average_precision: 0.8610
# Epoch 60/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.7987 - dice_metric: 0.8915 - jaccard_metric: 0.8445 - sensitivity_metric: 0.9230 - specificity_metric: 0.9230 - precision_metric: 0.9101 - recall_metric: 0.9230 - mean_average_precision: 0.7721 - val_loss: -0.8787 - val_dice_metric: 0.9504 - val_jaccard_metric: 0.9138 - val_sensitivity_metric: 0.9504 - val_specificity_metric: 0.9504 - val_precision_metric: 0.9533 - val_recall_metric: 0.9504 - val_mean_average_precision: 0.8606

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.94945, std: 0.07520
# Jaccard Index mean: 0.91221, std: 0.11863
# Sensitivity mean: 0.94936, std: 0.08793
# Specificity mean: 0.94936, std: 0.08793
# Precision mean: 0.95157, std: 0.06626
# Recall mean: 0.94936, std: 0.08793
# mAP@50 mean: 0.99153, std: 0.06454
# mAP@50-95 mean: 0.85890, std: 0.12137
