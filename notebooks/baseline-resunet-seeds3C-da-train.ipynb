# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|███████████████████████████████████████▋| 992M/0.98G [00:03<00:00, 305MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:03<00:00, 298MB/s]

# %%
config = {"Seg_model":"ResUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_baseline, fcn_baseline, res_unet_baseline
from seeds_segmentation.losses import DiceCoefficient 
from seeds_segmentation.metrics import DiceCoefficientMetric, Jaccard, Sensitivity, Specificity

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP

@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = res_unet_baseline(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 141s 1s/step - loss: -0.2400 - dice_metric: 0.2288 - jaccard_metric: 0.1568 - sensitivity_metric: 0.2483 - specificity_metric: 0.8640 - precision_metric: 0.3693 - recall_metric: 0.2483 - mean_average_precision: 0.0209 - val_loss: -0.2243 - val_dice_metric: 0.1580 - val_jaccard_metric: 0.1580 - val_sensitivity_metric: 6.4224e-07 - val_specificity_metric: 1.0000 - val_precision_metric: 0.0631 - val_recall_metric: 6.4224e-07 - val_mean_average_precision: 0.1580
# Epoch 2/60
# 77/77 [==============================] - 74s 959ms/step - loss: -0.3015 - dice_metric: 0.3957 - jaccard_metric: 0.3153 - sensitivity_metric: 0.4222 - specificity_metric: 0.8934 - precision_metric: 0.4512 - recall_metric: 0.4222 - mean_average_precision: 0.1508 - val_loss: -0.2725 - val_dice_metric: 0.4679 - val_jaccard_metric: 0.4605 - val_sensitivity_metric: 0.3313 - val_specificity_metric: 0.6785 - val_precision_metric: 0.3213 - val_recall_metric: 0.3313 - val_mean_average_precision: 0.4624
# Epoch 3/60
# 77/77 [==============================] - 74s 957ms/step - loss: -0.3466 - dice_metric: 0.4731 - jaccard_metric: 0.4031 - sensitivity_metric: 0.5004 - specificity_metric: 0.9111 - precision_metric: 0.4962 - recall_metric: 0.5004 - mean_average_precision: 0.2629 - val_loss: -0.3114 - val_dice_metric: 0.3749 - val_jaccard_metric: 0.3596 - val_sensitivity_metric: 0.3376 - val_specificity_metric: 0.7390 - val_precision_metric: 0.5171 - val_recall_metric: 0.3376 - val_mean_average_precision: 0.3517
# Epoch 4/60
# 77/77 [==============================] - 74s 953ms/step - loss: -0.3794 - dice_metric: 0.5112 - jaccard_metric: 0.4508 - sensitivity_metric: 0.5391 - specificity_metric: 0.9226 - precision_metric: 0.5179 - recall_metric: 0.5391 - mean_average_precision: 0.3349 - val_loss: -0.3703 - val_dice_metric: 0.4873 - val_jaccard_metric: 0.4314 - val_sensitivity_metric: 0.4534 - val_specificity_metric: 0.8646 - val_precision_metric: 0.5731 - val_recall_metric: 0.4534 - val_mean_average_precision: 0.3249
# Epoch 5/60
# 77/77 [==============================] - 73s 942ms/step - loss: -0.4066 - dice_metric: 0.5358 - jaccard_metric: 0.4825 - sensitivity_metric: 0.5647 - specificity_metric: 0.9325 - precision_metric: 0.5318 - recall_metric: 0.5647 - mean_average_precision: 0.3832 - val_loss: -0.4126 - val_dice_metric: 0.5401 - val_jaccard_metric: 0.4943 - val_sensitivity_metric: 0.5462 - val_specificity_metric: 0.9297 - val_precision_metric: 0.5557 - val_recall_metric: 0.5462 - val_mean_average_precision: 0.4135
# Epoch 6/60
# 77/77 [==============================] - 75s 973ms/step - loss: -0.4319 - dice_metric: 0.5523 - jaccard_metric: 0.5043 - sensitivity_metric: 0.5889 - specificity_metric: 0.9423 - precision_metric: 0.5391 - recall_metric: 0.5889 - mean_average_precision: 0.4179 - val_loss: -0.4295 - val_dice_metric: 0.5571 - val_jaccard_metric: 0.5093 - val_sensitivity_metric: 0.5776 - val_specificity_metric: 0.9463 - val_precision_metric: 0.5618 - val_recall_metric: 0.5776 - val_mean_average_precision: 0.4289
# Epoch 7/60
# 77/77 [==============================] - 74s 959ms/step - loss: -0.4539 - dice_metric: 0.5702 - jaccard_metric: 0.5239 - sensitivity_metric: 0.6264 - specificity_metric: 0.9510 - precision_metric: 0.5493 - recall_metric: 0.6264 - mean_average_precision: 0.4440 - val_loss: -0.4477 - val_dice_metric: 0.5786 - val_jaccard_metric: 0.5327 - val_sensitivity_metric: 0.6237 - val_specificity_metric: 0.9543 - val_precision_metric: 0.5625 - val_recall_metric: 0.6237 - val_mean_average_precision: 0.4548
# Epoch 8/60
# 77/77 [==============================] - 72s 933ms/step - loss: -0.4705 - dice_metric: 0.5791 - jaccard_metric: 0.5352 - sensitivity_metric: 0.6332 - specificity_metric: 0.9501 - precision_metric: 0.5582 - recall_metric: 0.6332 - mean_average_precision: 0.4596 - val_loss: -0.4630 - val_dice_metric: 0.5802 - val_jaccard_metric: 0.5366 - val_sensitivity_metric: 0.6374 - val_specificity_metric: 0.9593 - val_precision_metric: 0.5581 - val_recall_metric: 0.6374 - val_mean_average_precision: 0.4635
# Epoch 9/60
# 77/77 [==============================] - 73s 945ms/step - loss: -0.4843 - dice_metric: 0.5863 - jaccard_metric: 0.5438 - sensitivity_metric: 0.6355 - specificity_metric: 0.9490 - precision_metric: 0.5666 - recall_metric: 0.6355 - mean_average_precision: 0.4695 - val_loss: -0.4768 - val_dice_metric: 0.5945 - val_jaccard_metric: 0.5525 - val_sensitivity_metric: 0.6427 - val_specificity_metric: 0.9612 - val_precision_metric: 0.5614 - val_recall_metric: 0.6427 - val_mean_average_precision: 0.4799
# Epoch 10/60
# 77/77 [==============================] - 73s 950ms/step - loss: -0.4966 - dice_metric: 0.5908 - jaccard_metric: 0.5492 - sensitivity_metric: 0.6367 - specificity_metric: 0.9479 - precision_metric: 0.5746 - recall_metric: 0.6367 - mean_average_precision: 0.4765 - val_loss: -0.4897 - val_dice_metric: 0.6098 - val_jaccard_metric: 0.5693 - val_sensitivity_metric: 0.6426 - val_specificity_metric: 0.9595 - val_precision_metric: 0.5711 - val_recall_metric: 0.6426 - val_mean_average_precision: 0.4974
# Epoch 11/60
# 77/77 [==============================] - 76s 981ms/step - loss: -0.5078 - dice_metric: 0.5942 - jaccard_metric: 0.5533 - sensitivity_metric: 0.6373 - specificity_metric: 0.9468 - precision_metric: 0.5830 - recall_metric: 0.6373 - mean_average_precision: 0.4813 - val_loss: -0.5013 - val_dice_metric: 0.6166 - val_jaccard_metric: 0.5773 - val_sensitivity_metric: 0.6417 - val_specificity_metric: 0.9578 - val_precision_metric: 0.5778 - val_recall_metric: 0.6417 - val_mean_average_precision: 0.5060
# Epoch 12/60
# 77/77 [==============================] - 75s 965ms/step - loss: -0.5180 - dice_metric: 0.5976 - jaccard_metric: 0.5571 - sensitivity_metric: 0.6376 - specificity_metric: 0.9459 - precision_metric: 0.5896 - recall_metric: 0.6376 - mean_average_precision: 0.4857 - val_loss: -0.5117 - val_dice_metric: 0.6251 - val_jaccard_metric: 0.5865 - val_sensitivity_metric: 0.6423 - val_specificity_metric: 0.9575 - val_precision_metric: 0.5857 - val_recall_metric: 0.6423 - val_mean_average_precision: 0.5157
# Epoch 13/60
# 77/77 [==============================] - 72s 934ms/step - loss: -0.5273 - dice_metric: 0.6012 - jaccard_metric: 0.5606 - sensitivity_metric: 0.6381 - specificity_metric: 0.9454 - precision_metric: 0.5978 - recall_metric: 0.6381 - mean_average_precision: 0.4896 - val_loss: -0.5218 - val_dice_metric: 0.6302 - val_jaccard_metric: 0.5930 - val_sensitivity_metric: 0.6408 - val_specificity_metric: 0.9561 - val_precision_metric: 0.5957 - val_recall_metric: 0.6408 - val_mean_average_precision: 0.5257
# Epoch 14/60
# 77/77 [==============================] - 74s 954ms/step - loss: -0.5359 - dice_metric: 0.6063 - jaccard_metric: 0.5649 - sensitivity_metric: 0.6394 - specificity_metric: 0.9454 - precision_metric: 0.6065 - recall_metric: 0.6394 - mean_average_precision: 0.4934 - val_loss: -0.5308 - val_dice_metric: 0.6348 - val_jaccard_metric: 0.5978 - val_sensitivity_metric: 0.6423 - val_specificity_metric: 0.9569 - val_precision_metric: 0.6012 - val_recall_metric: 0.6423 - val_mean_average_precision: 0.5307
# Epoch 15/60
# 77/77 [==============================] - 75s 961ms/step - loss: -0.5443 - dice_metric: 0.6119 - jaccard_metric: 0.5688 - sensitivity_metric: 0.6425 - specificity_metric: 0.9464 - precision_metric: 0.6163 - recall_metric: 0.6425 - mean_average_precision: 0.4959 - val_loss: -0.5385 - val_dice_metric: 0.6354 - val_jaccard_metric: 0.5981 - val_sensitivity_metric: 0.6442 - val_specificity_metric: 0.9579 - val_precision_metric: 0.6048 - val_recall_metric: 0.6442 - val_mean_average_precision: 0.5303
# Epoch 16/60
# 77/77 [==============================] - 76s 980ms/step - loss: -0.5527 - dice_metric: 0.6198 - jaccard_metric: 0.5737 - sensitivity_metric: 0.6488 - specificity_metric: 0.9480 - precision_metric: 0.6285 - recall_metric: 0.6488 - mean_average_precision: 0.4977 - val_loss: -0.5464 - val_dice_metric: 0.6328 - val_jaccard_metric: 0.5944 - val_sensitivity_metric: 0.6457 - val_specificity_metric: 0.9583 - val_precision_metric: 0.6148 - val_recall_metric: 0.6457 - val_mean_average_precision: 0.5257
# Epoch 17/60
# 77/77 [==============================] - 75s 970ms/step - loss: -0.5617 - dice_metric: 0.6303 - jaccard_metric: 0.5791 - sensitivity_metric: 0.6614 - specificity_metric: 0.9507 - precision_metric: 0.6383 - recall_metric: 0.6614 - mean_average_precision: 0.4971 - val_loss: -0.5533 - val_dice_metric: 0.6129 - val_jaccard_metric: 0.5714 - val_sensitivity_metric: 0.6505 - val_specificity_metric: 0.9598 - val_precision_metric: 0.6233 - val_recall_metric: 0.6505 - val_mean_average_precision: 0.4993
# Epoch 18/60
# 77/77 [==============================] - 75s 962ms/step - loss: -0.5731 - dice_metric: 0.6450 - jaccard_metric: 0.5865 - sensitivity_metric: 0.6855 - specificity_metric: 0.9548 - precision_metric: 0.6441 - recall_metric: 0.6855 - mean_average_precision: 0.4944 - val_loss: -0.5555 - val_dice_metric: 0.6108 - val_jaccard_metric: 0.5631 - val_sensitivity_metric: 0.6587 - val_specificity_metric: 0.9628 - val_precision_metric: 0.6106 - val_recall_metric: 0.6587 - val_mean_average_precision: 0.4803
# Epoch 19/60
# 77/77 [==============================] - 74s 959ms/step - loss: -0.5861 - dice_metric: 0.6541 - jaccard_metric: 0.5915 - sensitivity_metric: 0.7081 - specificity_metric: 0.9583 - precision_metric: 0.6480 - recall_metric: 0.7081 - mean_average_precision: 0.4919 - val_loss: -0.5618 - val_dice_metric: 0.6167 - val_jaccard_metric: 0.5649 - val_sensitivity_metric: 0.6668 - val_specificity_metric: 0.9654 - val_precision_metric: 0.6058 - val_recall_metric: 0.6668 - val_mean_average_precision: 0.4767
# Epoch 20/60
# 77/77 [==============================] - 77s 988ms/step - loss: -0.5960 - dice_metric: 0.6583 - jaccard_metric: 0.5943 - sensitivity_metric: 0.7152 - specificity_metric: 0.9594 - precision_metric: 0.6520 - recall_metric: 0.7152 - mean_average_precision: 0.4915 - val_loss: -0.5829 - val_dice_metric: 0.6334 - val_jaccard_metric: 0.5800 - val_sensitivity_metric: 0.6872 - val_specificity_metric: 0.9685 - val_precision_metric: 0.6148 - val_recall_metric: 0.6872 - val_mean_average_precision: 0.4905
# Epoch 21/60
# 77/77 [==============================] - 75s 960ms/step - loss: -0.6106 - dice_metric: 0.6704 - jaccard_metric: 0.6049 - sensitivity_metric: 0.7260 - specificity_metric: 0.9596 - precision_metric: 0.6641 - recall_metric: 0.7260 - mean_average_precision: 0.4972 - val_loss: -0.6001 - val_dice_metric: 0.6479 - val_jaccard_metric: 0.5934 - val_sensitivity_metric: 0.6993 - val_specificity_metric: 0.9702 - val_precision_metric: 0.6322 - val_recall_metric: 0.6993 - val_mean_average_precision: 0.5037
# Epoch 22/60
# 77/77 [==============================] - 75s 965ms/step - loss: -0.6229 - dice_metric: 0.6799 - jaccard_metric: 0.6131 - sensitivity_metric: 0.7302 - specificity_metric: 0.9588 - precision_metric: 0.6742 - recall_metric: 0.7302 - mean_average_precision: 0.5007 - val_loss: -0.6168 - val_dice_metric: 0.6661 - val_jaccard_metric: 0.6099 - val_sensitivity_metric: 0.7055 - val_specificity_metric: 0.9690 - val_precision_metric: 0.6559 - val_recall_metric: 0.7055 - val_mean_average_precision: 0.5133
# Epoch 23/60
# 77/77 [==============================] - 73s 946ms/step - loss: -0.6327 - dice_metric: 0.6868 - jaccard_metric: 0.6191 - sensitivity_metric: 0.7278 - specificity_metric: 0.9567 - precision_metric: 0.6838 - recall_metric: 0.7278 - mean_average_precision: 0.5017 - val_loss: -0.6271 - val_dice_metric: 0.6746 - val_jaccard_metric: 0.6180 - val_sensitivity_metric: 0.7108 - val_specificity_metric: 0.9686 - val_precision_metric: 0.6695 - val_recall_metric: 0.7108 - val_mean_average_precision: 0.5186
# Epoch 24/60
# 77/77 [==============================] - 73s 939ms/step - loss: -0.6457 - dice_metric: 0.6983 - jaccard_metric: 0.6302 - sensitivity_metric: 0.7279 - specificity_metric: 0.9537 - precision_metric: 0.6988 - recall_metric: 0.7279 - mean_average_precision: 0.5085 - val_loss: -0.6432 - val_dice_metric: 0.6930 - val_jaccard_metric: 0.6356 - val_sensitivity_metric: 0.7143 - val_specificity_metric: 0.9658 - val_precision_metric: 0.6934 - val_recall_metric: 0.7143 - val_mean_average_precision: 0.5315
# Epoch 25/60
# 77/77 [==============================] - 74s 947ms/step - loss: -0.6608 - dice_metric: 0.7116 - jaccard_metric: 0.6439 - sensitivity_metric: 0.7311 - specificity_metric: 0.9504 - precision_metric: 0.7166 - recall_metric: 0.7311 - mean_average_precision: 0.5212 - val_loss: -0.6491 - val_dice_metric: 0.6942 - val_jaccard_metric: 0.6377 - val_sensitivity_metric: 0.7154 - val_specificity_metric: 0.9654 - val_precision_metric: 0.6969 - val_recall_metric: 0.7154 - val_mean_average_precision: 0.5343
# Epoch 26/60
# 77/77 [==============================] - 75s 964ms/step - loss: -0.6715 - dice_metric: 0.7180 - jaccard_metric: 0.6502 - sensitivity_metric: 0.7326 - specificity_metric: 0.9485 - precision_metric: 0.7272 - recall_metric: 0.7326 - mean_average_precision: 0.5256 - val_loss: -0.6540 - val_dice_metric: 0.6914 - val_jaccard_metric: 0.6348 - val_sensitivity_metric: 0.7112 - val_specificity_metric: 0.9624 - val_precision_metric: 0.6990 - val_recall_metric: 0.7112 - val_mean_average_precision: 0.5308
# Epoch 27/60
# 77/77 [==============================] - 73s 943ms/step - loss: -0.6776 - dice_metric: 0.7185 - jaccard_metric: 0.6509 - sensitivity_metric: 0.7309 - specificity_metric: 0.9472 - precision_metric: 0.7307 - recall_metric: 0.7309 - mean_average_precision: 0.5262 - val_loss: -0.6609 - val_dice_metric: 0.6957 - val_jaccard_metric: 0.6368 - val_sensitivity_metric: 0.7113 - val_specificity_metric: 0.9611 - val_precision_metric: 0.7050 - val_recall_metric: 0.7113 - val_mean_average_precision: 0.5257
# Epoch 28/60
# 77/77 [==============================] - 72s 921ms/step - loss: -0.6853 - dice_metric: 0.7227 - jaccard_metric: 0.6549 - sensitivity_metric: 0.7329 - specificity_metric: 0.9466 - precision_metric: 0.7364 - recall_metric: 0.7329 - mean_average_precision: 0.5289 - val_loss: -0.6670 - val_dice_metric: 0.6950 - val_jaccard_metric: 0.6389 - val_sensitivity_metric: 0.7125 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7077 - val_recall_metric: 0.7125 - val_mean_average_precision: 0.5349
# Epoch 29/60
# 77/77 [==============================] - 74s 953ms/step - loss: -0.6961 - dice_metric: 0.7304 - jaccard_metric: 0.6634 - sensitivity_metric: 0.7376 - specificity_metric: 0.9457 - precision_metric: 0.7448 - recall_metric: 0.7376 - mean_average_precision: 0.5396 - val_loss: -0.6666 - val_dice_metric: 0.6937 - val_jaccard_metric: 0.6369 - val_sensitivity_metric: 0.7131 - val_specificity_metric: 0.9602 - val_precision_metric: 0.7073 - val_recall_metric: 0.7131 - val_mean_average_precision: 0.5308
# Epoch 30/60
# 77/77 [==============================] - 75s 963ms/step - loss: -0.7029 - dice_metric: 0.7336 - jaccard_metric: 0.6667 - sensitivity_metric: 0.7396 - specificity_metric: 0.9451 - precision_metric: 0.7497 - recall_metric: 0.7396 - mean_average_precision: 0.5422 - val_loss: -0.6692 - val_dice_metric: 0.6929 - val_jaccard_metric: 0.6362 - val_sensitivity_metric: 0.7086 - val_specificity_metric: 0.9574 - val_precision_metric: 0.7148 - val_recall_metric: 0.7086 - val_mean_average_precision: 0.5288
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 73s 942ms/step - loss: -0.7106 - dice_metric: 0.7395 - jaccard_metric: 0.6739 - sensitivity_metric: 0.7439 - specificity_metric: 0.9451 - precision_metric: 0.7556 - recall_metric: 0.7439 - mean_average_precision: 0.5519 - val_loss: -0.6920 - val_dice_metric: 0.7210 - val_jaccard_metric: 0.6669 - val_sensitivity_metric: 0.7228 - val_specificity_metric: 0.9581 - val_precision_metric: 0.7351 - val_recall_metric: 0.7228 - val_mean_average_precision: 0.5671
# Epoch 32/60
# 77/77 [==============================] - 75s 974ms/step - loss: -0.7171 - dice_metric: 0.7468 - jaccard_metric: 0.6819 - sensitivity_metric: 0.7497 - specificity_metric: 0.9456 - precision_metric: 0.7619 - recall_metric: 0.7497 - mean_average_precision: 0.5614 - val_loss: -0.6937 - val_dice_metric: 0.7210 - val_jaccard_metric: 0.6668 - val_sensitivity_metric: 0.7248 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7342 - val_recall_metric: 0.7248 - val_mean_average_precision: 0.5657
# Epoch 33/60
# 77/77 [==============================] - 75s 965ms/step - loss: -0.7191 - dice_metric: 0.7488 - jaccard_metric: 0.6841 - sensitivity_metric: 0.7511 - specificity_metric: 0.9455 - precision_metric: 0.7641 - recall_metric: 0.7511 - mean_average_precision: 0.5642 - val_loss: -0.6945 - val_dice_metric: 0.7215 - val_jaccard_metric: 0.6671 - val_sensitivity_metric: 0.7253 - val_specificity_metric: 0.9592 - val_precision_metric: 0.7340 - val_recall_metric: 0.7253 - val_mean_average_precision: 0.5660
# Epoch 34/60
# 77/77 [==============================] - 75s 963ms/step - loss: -0.7206 - dice_metric: 0.7501 - jaccard_metric: 0.6856 - sensitivity_metric: 0.7520 - specificity_metric: 0.9455 - precision_metric: 0.7657 - recall_metric: 0.7520 - mean_average_precision: 0.5659 - val_loss: -0.6951 - val_dice_metric: 0.7215 - val_jaccard_metric: 0.6672 - val_sensitivity_metric: 0.7256 - val_specificity_metric: 0.9593 - val_precision_metric: 0.7337 - val_recall_metric: 0.7256 - val_mean_average_precision: 0.5655
# Epoch 35/60
# 77/77 [==============================] - 73s 944ms/step - loss: -0.7220 - dice_metric: 0.7513 - jaccard_metric: 0.6870 - sensitivity_metric: 0.7529 - specificity_metric: 0.9455 - precision_metric: 0.7669 - recall_metric: 0.7529 - mean_average_precision: 0.5677 - val_loss: -0.6955 - val_dice_metric: 0.7215 - val_jaccard_metric: 0.6671 - val_sensitivity_metric: 0.7256 - val_specificity_metric: 0.9593 - val_precision_metric: 0.7336 - val_recall_metric: 0.7256 - val_mean_average_precision: 0.5657
# Epoch 36/60
# 77/77 [==============================] - 76s 981ms/step - loss: -0.7232 - dice_metric: 0.7523 - jaccard_metric: 0.6881 - sensitivity_metric: 0.7535 - specificity_metric: 0.9455 - precision_metric: 0.7681 - recall_metric: 0.7535 - mean_average_precision: 0.5691 - val_loss: -0.6960 - val_dice_metric: 0.7215 - val_jaccard_metric: 0.6672 - val_sensitivity_metric: 0.7258 - val_specificity_metric: 0.9593 - val_precision_metric: 0.7335 - val_recall_metric: 0.7258 - val_mean_average_precision: 0.5658
# Epoch 37/60
# 77/77 [==============================] - 75s 968ms/step - loss: -0.7243 - dice_metric: 0.7532 - jaccard_metric: 0.6891 - sensitivity_metric: 0.7542 - specificity_metric: 0.9455 - precision_metric: 0.7691 - recall_metric: 0.7542 - mean_average_precision: 0.5703 - val_loss: -0.6964 - val_dice_metric: 0.7216 - val_jaccard_metric: 0.6672 - val_sensitivity_metric: 0.7258 - val_specificity_metric: 0.9593 - val_precision_metric: 0.7335 - val_recall_metric: 0.7258 - val_mean_average_precision: 0.5658
# Epoch 38/60
# 77/77 [==============================] - 75s 966ms/step - loss: -0.7254 - dice_metric: 0.7540 - jaccard_metric: 0.6900 - sensitivity_metric: 0.7548 - specificity_metric: 0.9455 - precision_metric: 0.7700 - recall_metric: 0.7548 - mean_average_precision: 0.5715 - val_loss: -0.6968 - val_dice_metric: 0.7217 - val_jaccard_metric: 0.6672 - val_sensitivity_metric: 0.7257 - val_specificity_metric: 0.9592 - val_precision_metric: 0.7337 - val_recall_metric: 0.7257 - val_mean_average_precision: 0.5647
# Epoch 39/60
# 77/77 [==============================] - 73s 944ms/step - loss: -0.7264 - dice_metric: 0.7547 - jaccard_metric: 0.6908 - sensitivity_metric: 0.7553 - specificity_metric: 0.9455 - precision_metric: 0.7708 - recall_metric: 0.7553 - mean_average_precision: 0.5726 - val_loss: -0.6972 - val_dice_metric: 0.7217 - val_jaccard_metric: 0.6673 - val_sensitivity_metric: 0.7257 - val_specificity_metric: 0.9592 - val_precision_metric: 0.7338 - val_recall_metric: 0.7257 - val_mean_average_precision: 0.5645
# Epoch 40/60
# 77/77 [==============================] - 74s 950ms/step - loss: -0.7274 - dice_metric: 0.7554 - jaccard_metric: 0.6916 - sensitivity_metric: 0.7558 - specificity_metric: 0.9455 - precision_metric: 0.7716 - recall_metric: 0.7558 - mean_average_precision: 0.5738 - val_loss: -0.6976 - val_dice_metric: 0.7219 - val_jaccard_metric: 0.6675 - val_sensitivity_metric: 0.7258 - val_specificity_metric: 0.9592 - val_precision_metric: 0.7340 - val_recall_metric: 0.7258 - val_mean_average_precision: 0.5647
# Epoch 41/60
# 77/77 [==============================] - 75s 971ms/step - loss: -0.7283 - dice_metric: 0.7561 - jaccard_metric: 0.6924 - sensitivity_metric: 0.7563 - specificity_metric: 0.9455 - precision_metric: 0.7725 - recall_metric: 0.7563 - mean_average_precision: 0.5749 - val_loss: -0.6979 - val_dice_metric: 0.7218 - val_jaccard_metric: 0.6675 - val_sensitivity_metric: 0.7258 - val_specificity_metric: 0.9592 - val_precision_metric: 0.7340 - val_recall_metric: 0.7258 - val_mean_average_precision: 0.5641
# Epoch 42/60
# 77/77 [==============================] - 75s 964ms/step - loss: -0.7292 - dice_metric: 0.7569 - jaccard_metric: 0.6933 - sensitivity_metric: 0.7567 - specificity_metric: 0.9455 - precision_metric: 0.7734 - recall_metric: 0.7567 - mean_average_precision: 0.5760 - val_loss: -0.6984 - val_dice_metric: 0.7219 - val_jaccard_metric: 0.6676 - val_sensitivity_metric: 0.7258 - val_specificity_metric: 0.9592 - val_precision_metric: 0.7341 - val_recall_metric: 0.7258 - val_mean_average_precision: 0.5648
# Epoch 43/60
# 77/77 [==============================] - 75s 969ms/step - loss: -0.7301 - dice_metric: 0.7576 - jaccard_metric: 0.6941 - sensitivity_metric: 0.7572 - specificity_metric: 0.9455 - precision_metric: 0.7741 - recall_metric: 0.7572 - mean_average_precision: 0.5769 - val_loss: -0.6988 - val_dice_metric: 0.7220 - val_jaccard_metric: 0.6677 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9592 - val_precision_metric: 0.7343 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5644
# Epoch 44/60
# 77/77 [==============================] - 77s 988ms/step - loss: -0.7310 - dice_metric: 0.7583 - jaccard_metric: 0.6948 - sensitivity_metric: 0.7576 - specificity_metric: 0.9455 - precision_metric: 0.7748 - recall_metric: 0.7576 - mean_average_precision: 0.5780 - val_loss: -0.6992 - val_dice_metric: 0.7221 - val_jaccard_metric: 0.6678 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7344 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5649
# Epoch 45/60
# 77/77 [==============================] - 77s 997ms/step - loss: -0.7319 - dice_metric: 0.7588 - jaccard_metric: 0.6955 - sensitivity_metric: 0.7580 - specificity_metric: 0.9454 - precision_metric: 0.7756 - recall_metric: 0.7580 - mean_average_precision: 0.5789 - val_loss: -0.6996 - val_dice_metric: 0.7221 - val_jaccard_metric: 0.6678 - val_sensitivity_metric: 0.7258 - val_specificity_metric: 0.9590 - val_precision_metric: 0.7345 - val_recall_metric: 0.7258 - val_mean_average_precision: 0.5653
# Epoch 46/60
# 77/77 [==============================] - 75s 970ms/step - loss: -0.7328 - dice_metric: 0.7594 - jaccard_metric: 0.6961 - sensitivity_metric: 0.7584 - specificity_metric: 0.9454 - precision_metric: 0.7762 - recall_metric: 0.7584 - mean_average_precision: 0.5796 - val_loss: -0.7001 - val_dice_metric: 0.7222 - val_jaccard_metric: 0.6680 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7346 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5648
# Epoch 47/60
# 77/77 [==============================] - 75s 965ms/step - loss: -0.7336 - dice_metric: 0.7601 - jaccard_metric: 0.6968 - sensitivity_metric: 0.7587 - specificity_metric: 0.9454 - precision_metric: 0.7769 - recall_metric: 0.7587 - mean_average_precision: 0.5806 - val_loss: -0.7005 - val_dice_metric: 0.7223 - val_jaccard_metric: 0.6681 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9590 - val_precision_metric: 0.7348 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5658
# Epoch 48/60
# 77/77 [==============================] - 74s 957ms/step - loss: -0.7344 - dice_metric: 0.7607 - jaccard_metric: 0.6975 - sensitivity_metric: 0.7591 - specificity_metric: 0.9454 - precision_metric: 0.7776 - recall_metric: 0.7591 - mean_average_precision: 0.5814 - val_loss: -0.7008 - val_dice_metric: 0.7223 - val_jaccard_metric: 0.6682 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9590 - val_precision_metric: 0.7348 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5665
# Epoch 49/60
# 77/77 [==============================] - 73s 948ms/step - loss: -0.7352 - dice_metric: 0.7613 - jaccard_metric: 0.6981 - sensitivity_metric: 0.7595 - specificity_metric: 0.9454 - precision_metric: 0.7781 - recall_metric: 0.7595 - mean_average_precision: 0.5822 - val_loss: -0.7009 - val_dice_metric: 0.7221 - val_jaccard_metric: 0.6680 - val_sensitivity_metric: 0.7257 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7347 - val_recall_metric: 0.7257 - val_mean_average_precision: 0.5663
# Epoch 50/60
# 77/77 [==============================] - 74s 958ms/step - loss: -0.7361 - dice_metric: 0.7619 - jaccard_metric: 0.6988 - sensitivity_metric: 0.7599 - specificity_metric: 0.9454 - precision_metric: 0.7789 - recall_metric: 0.7599 - mean_average_precision: 0.5831 - val_loss: -0.7015 - val_dice_metric: 0.7223 - val_jaccard_metric: 0.6682 - val_sensitivity_metric: 0.7261 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7346 - val_recall_metric: 0.7261 - val_mean_average_precision: 0.5668
# Epoch 51/60
# 77/77 [==============================] - 76s 987ms/step - loss: -0.7369 - dice_metric: 0.7624 - jaccard_metric: 0.6994 - sensitivity_metric: 0.7603 - specificity_metric: 0.9454 - precision_metric: 0.7795 - recall_metric: 0.7603 - mean_average_precision: 0.5839 - val_loss: -0.7020 - val_dice_metric: 0.7222 - val_jaccard_metric: 0.6680 - val_sensitivity_metric: 0.7260 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7344 - val_recall_metric: 0.7260 - val_mean_average_precision: 0.5660
# Epoch 52/60
# 77/77 [==============================] - 76s 976ms/step - loss: -0.7377 - dice_metric: 0.7630 - jaccard_metric: 0.7000 - sensitivity_metric: 0.7607 - specificity_metric: 0.9454 - precision_metric: 0.7801 - recall_metric: 0.7607 - mean_average_precision: 0.5844 - val_loss: -0.7024 - val_dice_metric: 0.7223 - val_jaccard_metric: 0.6680 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9590 - val_precision_metric: 0.7345 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5655
# Epoch 53/60
# 77/77 [==============================] - 76s 984ms/step - loss: -0.7385 - dice_metric: 0.7635 - jaccard_metric: 0.7006 - sensitivity_metric: 0.7611 - specificity_metric: 0.9454 - precision_metric: 0.7807 - recall_metric: 0.7611 - mean_average_precision: 0.5852 - val_loss: -0.7027 - val_dice_metric: 0.7223 - val_jaccard_metric: 0.6680 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9591 - val_precision_metric: 0.7345 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5655
# Epoch 54/60
# 77/77 [==============================] - 75s 968ms/step - loss: -0.7393 - dice_metric: 0.7640 - jaccard_metric: 0.7012 - sensitivity_metric: 0.7614 - specificity_metric: 0.9454 - precision_metric: 0.7812 - recall_metric: 0.7614 - mean_average_precision: 0.5861 - val_loss: -0.7032 - val_dice_metric: 0.7224 - val_jaccard_metric: 0.6681 - val_sensitivity_metric: 0.7261 - val_specificity_metric: 0.9590 - val_precision_metric: 0.7345 - val_recall_metric: 0.7261 - val_mean_average_precision: 0.5659
# Epoch 55/60
# 77/77 [==============================] - 72s 925ms/step - loss: -0.7400 - dice_metric: 0.7644 - jaccard_metric: 0.7017 - sensitivity_metric: 0.7617 - specificity_metric: 0.9454 - precision_metric: 0.7818 - recall_metric: 0.7617 - mean_average_precision: 0.5867 - val_loss: -0.7036 - val_dice_metric: 0.7225 - val_jaccard_metric: 0.6682 - val_sensitivity_metric: 0.7263 - val_specificity_metric: 0.9590 - val_precision_metric: 0.7345 - val_recall_metric: 0.7263 - val_mean_average_precision: 0.5662
# Epoch 56/60
# 77/77 [==============================] - 75s 970ms/step - loss: -0.7408 - dice_metric: 0.7649 - jaccard_metric: 0.7022 - sensitivity_metric: 0.7620 - specificity_metric: 0.9454 - precision_metric: 0.7824 - recall_metric: 0.7620 - mean_average_precision: 0.5874 - val_loss: -0.7041 - val_dice_metric: 0.7227 - val_jaccard_metric: 0.6683 - val_sensitivity_metric: 0.7264 - val_specificity_metric: 0.9589 - val_precision_metric: 0.7346 - val_recall_metric: 0.7264 - val_mean_average_precision: 0.5662
# Epoch 57/60
# 77/77 [==============================] - 76s 981ms/step - loss: -0.7415 - dice_metric: 0.7653 - jaccard_metric: 0.7027 - sensitivity_metric: 0.7623 - specificity_metric: 0.9454 - precision_metric: 0.7829 - recall_metric: 0.7623 - mean_average_precision: 0.5880 - val_loss: -0.7046 - val_dice_metric: 0.7229 - val_jaccard_metric: 0.6686 - val_sensitivity_metric: 0.7262 - val_specificity_metric: 0.9588 - val_precision_metric: 0.7351 - val_recall_metric: 0.7262 - val_mean_average_precision: 0.5664
# Epoch 58/60
# 77/77 [==============================] - 74s 951ms/step - loss: -0.7422 - dice_metric: 0.7658 - jaccard_metric: 0.7032 - sensitivity_metric: 0.7626 - specificity_metric: 0.9454 - precision_metric: 0.7834 - recall_metric: 0.7626 - mean_average_precision: 0.5885 - val_loss: -0.7049 - val_dice_metric: 0.7229 - val_jaccard_metric: 0.6687 - val_sensitivity_metric: 0.7259 - val_specificity_metric: 0.9587 - val_precision_metric: 0.7355 - val_recall_metric: 0.7259 - val_mean_average_precision: 0.5660
# Epoch 59/60
# 77/77 [==============================] - 74s 949ms/step - loss: -0.7429 - dice_metric: 0.7662 - jaccard_metric: 0.7036 - sensitivity_metric: 0.7629 - specificity_metric: 0.9453 - precision_metric: 0.7839 - recall_metric: 0.7629 - mean_average_precision: 0.5892 - val_loss: -0.7053 - val_dice_metric: 0.7230 - val_jaccard_metric: 0.6689 - val_sensitivity_metric: 0.7261 - val_specificity_metric: 0.9588 - val_precision_metric: 0.7355 - val_recall_metric: 0.7261 - val_mean_average_precision: 0.5667
# Epoch 60/60
# 77/77 [==============================] - 75s 964ms/step - loss: -0.7436 - dice_metric: 0.7668 - jaccard_metric: 0.7042 - sensitivity_metric: 0.7631 - specificity_metric: 0.9453 - precision_metric: 0.7844 - recall_metric: 0.7631 - mean_average_precision: 0.5900 - val_loss: -0.7055 - val_dice_metric: 0.7242 - val_jaccard_metric: 0.6702 - val_sensitivity_metric: 0.7260 - val_specificity_metric: 0.9589 - val_precision_metric: 0.7356 - val_recall_metric: 0.7260 - val_mean_average_precision: 0.5685

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.74074, std: 0.34121
# Jaccard Index mean: 0.68176, std: 0.35077
# Sensitivity mean: 0.74376, std: 0.35396
# Specificity mean: 0.95489, std: 0.10274
# Precision mean: 0.75792, std: 0.33287
# Recall mean: 0.74376, std: 0.35396
# mAP@50 mean: 0.72881, std: 0.16779
# mAP@50-95 mean: 0.57090, std: 0.13788
