# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|███████████████████████████████████████▉| 999M/0.98G [00:13<00:00, 104MB/s]
# 100%|██████████████████████████████████████| 0.98G/0.98G [00:13<00:00, 79.7MB/s]

# %%
config = {"Seg_model":"FCNMobV2","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import fcn_mobilenetv2
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = fcn_mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 105s 983ms/step - loss: -0.2608 - dice_metric: 0.2909 - jaccard_metric: 0.2034 - sensitivity_metric: 0.4447 - specificity_metric: 0.8361 - val_loss: -0.2422 - val_dice_metric: 0.3204 - val_jaccard_metric: 0.2154 - val_sensitivity_metric: 0.3025 - val_specificity_metric: 0.8952
# Epoch 2/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.4147 - dice_metric: 0.4933 - jaccard_metric: 0.3998 - sensitivity_metric: 0.5680 - specificity_metric: 0.8479 - val_loss: -0.3646 - val_dice_metric: 0.5416 - val_jaccard_metric: 0.4572 - val_sensitivity_metric: 0.5439 - val_specificity_metric: 0.8492
# Epoch 3/60
# 77/77 [==============================] - 68s 880ms/step - loss: -0.4928 - dice_metric: 0.5358 - jaccard_metric: 0.4497 - sensitivity_metric: 0.5852 - specificity_metric: 0.8375 - val_loss: -0.4622 - val_dice_metric: 0.5477 - val_jaccard_metric: 0.4626 - val_sensitivity_metric: 0.5505 - val_specificity_metric: 0.8302
# Epoch 4/60
# 77/77 [==============================] - 71s 918ms/step - loss: -0.5213 - dice_metric: 0.5497 - jaccard_metric: 0.4675 - sensitivity_metric: 0.6017 - specificity_metric: 0.8427 - val_loss: -0.5214 - val_dice_metric: 0.5599 - val_jaccard_metric: 0.4791 - val_sensitivity_metric: 0.5649 - val_specificity_metric: 0.8399
# Epoch 5/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.5374 - dice_metric: 0.5596 - jaccard_metric: 0.4802 - sensitivity_metric: 0.6148 - specificity_metric: 0.8489 - val_loss: -0.5478 - val_dice_metric: 0.5676 - val_jaccard_metric: 0.4897 - val_sensitivity_metric: 0.5788 - val_specificity_metric: 0.8460
# Epoch 6/60
# 77/77 [==============================] - 67s 868ms/step - loss: -0.5487 - dice_metric: 0.5673 - jaccard_metric: 0.4903 - sensitivity_metric: 0.6256 - specificity_metric: 0.8538 - val_loss: -0.5606 - val_dice_metric: 0.5722 - val_jaccard_metric: 0.4964 - val_sensitivity_metric: 0.5904 - val_specificity_metric: 0.8511
# Epoch 7/60
# 77/77 [==============================] - 67s 860ms/step - loss: -0.5578 - dice_metric: 0.5737 - jaccard_metric: 0.4987 - sensitivity_metric: 0.6355 - specificity_metric: 0.8579 - val_loss: -0.5715 - val_dice_metric: 0.5787 - val_jaccard_metric: 0.5063 - val_sensitivity_metric: 0.6013 - val_specificity_metric: 0.8586
# Epoch 8/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.5648 - dice_metric: 0.5786 - jaccard_metric: 0.5053 - sensitivity_metric: 0.6437 - specificity_metric: 0.8614 - val_loss: -0.5751 - val_dice_metric: 0.5807 - val_jaccard_metric: 0.5097 - val_sensitivity_metric: 0.6040 - val_specificity_metric: 0.8617
# Epoch 9/60
# 77/77 [==============================] - 70s 904ms/step - loss: -0.5702 - dice_metric: 0.5822 - jaccard_metric: 0.5101 - sensitivity_metric: 0.6492 - specificity_metric: 0.8639 - val_loss: -0.5795 - val_dice_metric: 0.5837 - val_jaccard_metric: 0.5143 - val_sensitivity_metric: 0.6152 - val_specificity_metric: 0.8686
# Epoch 10/60
# 77/77 [==============================] - 69s 889ms/step - loss: -0.5743 - dice_metric: 0.5846 - jaccard_metric: 0.5133 - sensitivity_metric: 0.6523 - specificity_metric: 0.8659 - val_loss: -0.5838 - val_dice_metric: 0.5866 - val_jaccard_metric: 0.5179 - val_sensitivity_metric: 0.6249 - val_specificity_metric: 0.8709
# Epoch 11/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.5776 - dice_metric: 0.5865 - jaccard_metric: 0.5159 - sensitivity_metric: 0.6552 - specificity_metric: 0.8675 - val_loss: -0.5875 - val_dice_metric: 0.5903 - val_jaccard_metric: 0.5231 - val_sensitivity_metric: 0.6353 - val_specificity_metric: 0.8757
# Epoch 12/60
# 77/77 [==============================] - 67s 868ms/step - loss: -0.5801 - dice_metric: 0.5879 - jaccard_metric: 0.5181 - sensitivity_metric: 0.6568 - specificity_metric: 0.8688 - val_loss: -0.5898 - val_dice_metric: 0.5922 - val_jaccard_metric: 0.5255 - val_sensitivity_metric: 0.6448 - val_specificity_metric: 0.8782
# Epoch 13/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.5829 - dice_metric: 0.5899 - jaccard_metric: 0.5207 - sensitivity_metric: 0.6600 - specificity_metric: 0.8700 - val_loss: -0.5912 - val_dice_metric: 0.5927 - val_jaccard_metric: 0.5262 - val_sensitivity_metric: 0.6456 - val_specificity_metric: 0.8790
# Epoch 14/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.5856 - dice_metric: 0.5919 - jaccard_metric: 0.5235 - sensitivity_metric: 0.6630 - specificity_metric: 0.8714 - val_loss: -0.5920 - val_dice_metric: 0.5940 - val_jaccard_metric: 0.5282 - val_sensitivity_metric: 0.6468 - val_specificity_metric: 0.8801
# Epoch 15/60
# 77/77 [==============================] - 68s 885ms/step - loss: -0.5881 - dice_metric: 0.5938 - jaccard_metric: 0.5262 - sensitivity_metric: 0.6667 - specificity_metric: 0.8725 - val_loss: -0.5936 - val_dice_metric: 0.5955 - val_jaccard_metric: 0.5304 - val_sensitivity_metric: 0.6495 - val_specificity_metric: 0.8824
# Epoch 16/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.5899 - dice_metric: 0.5951 - jaccard_metric: 0.5279 - sensitivity_metric: 0.6682 - specificity_metric: 0.8734 - val_loss: -0.5940 - val_dice_metric: 0.5961 - val_jaccard_metric: 0.5317 - val_sensitivity_metric: 0.6458 - val_specificity_metric: 0.8818
# Epoch 17/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.5917 - dice_metric: 0.5964 - jaccard_metric: 0.5297 - sensitivity_metric: 0.6708 - specificity_metric: 0.8742 - val_loss: -0.5946 - val_dice_metric: 0.5964 - val_jaccard_metric: 0.5320 - val_sensitivity_metric: 0.6472 - val_specificity_metric: 0.8829
# Epoch 18/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.5931 - dice_metric: 0.5974 - jaccard_metric: 0.5311 - sensitivity_metric: 0.6727 - specificity_metric: 0.8746 - val_loss: -0.5965 - val_dice_metric: 0.5971 - val_jaccard_metric: 0.5329 - val_sensitivity_metric: 0.6503 - val_specificity_metric: 0.8838
# Epoch 19/60
# 77/77 [==============================] - 70s 904ms/step - loss: -0.5949 - dice_metric: 0.5988 - jaccard_metric: 0.5331 - sensitivity_metric: 0.6755 - specificity_metric: 0.8751 - val_loss: -0.5976 - val_dice_metric: 0.5988 - val_jaccard_metric: 0.5349 - val_sensitivity_metric: 0.6553 - val_specificity_metric: 0.8850
# Epoch 20/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.5963 - dice_metric: 0.5999 - jaccard_metric: 0.5346 - sensitivity_metric: 0.6777 - specificity_metric: 0.8756 - val_loss: -0.5969 - val_dice_metric: 0.5979 - val_jaccard_metric: 0.5336 - val_sensitivity_metric: 0.6515 - val_specificity_metric: 0.8830
# Epoch 21/60
# 77/77 [==============================] - 70s 902ms/step - loss: -0.5972 - dice_metric: 0.6005 - jaccard_metric: 0.5356 - sensitivity_metric: 0.6792 - specificity_metric: 0.8763 - val_loss: -0.5973 - val_dice_metric: 0.5988 - val_jaccard_metric: 0.5347 - val_sensitivity_metric: 0.6526 - val_specificity_metric: 0.8839
# Epoch 22/60
# 77/77 [==============================] - 69s 886ms/step - loss: -0.5988 - dice_metric: 0.6018 - jaccard_metric: 0.5375 - sensitivity_metric: 0.6814 - specificity_metric: 0.8767 - val_loss: -0.5981 - val_dice_metric: 0.5991 - val_jaccard_metric: 0.5355 - val_sensitivity_metric: 0.6527 - val_specificity_metric: 0.8848
# Epoch 23/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.6001 - dice_metric: 0.6030 - jaccard_metric: 0.5391 - sensitivity_metric: 0.6835 - specificity_metric: 0.8772 - val_loss: -0.5981 - val_dice_metric: 0.5994 - val_jaccard_metric: 0.5362 - val_sensitivity_metric: 0.6509 - val_specificity_metric: 0.8859
# Epoch 24/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.6014 - dice_metric: 0.6046 - jaccard_metric: 0.5414 - sensitivity_metric: 0.6856 - specificity_metric: 0.8789 - val_loss: -0.6021 - val_dice_metric: 0.6024 - val_jaccard_metric: 0.5401 - val_sensitivity_metric: 0.6537 - val_specificity_metric: 0.8881
# Epoch 25/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.6089 - dice_metric: 0.6141 - jaccard_metric: 0.5542 - sensitivity_metric: 0.6977 - specificity_metric: 0.8901 - val_loss: -0.6144 - val_dice_metric: 0.6164 - val_jaccard_metric: 0.5592 - val_sensitivity_metric: 0.6716 - val_specificity_metric: 0.9034
# Epoch 26/60
# 77/77 [==============================] - 68s 885ms/step - loss: -0.6300 - dice_metric: 0.6382 - jaccard_metric: 0.5801 - sensitivity_metric: 0.7265 - specificity_metric: 0.9111 - val_loss: -0.6557 - val_dice_metric: 0.6586 - val_jaccard_metric: 0.6009 - val_sensitivity_metric: 0.6941 - val_specificity_metric: 0.9213
# Epoch 27/60
# 77/77 [==============================] - 70s 910ms/step - loss: -0.6757 - dice_metric: 0.6883 - jaccard_metric: 0.6276 - sensitivity_metric: 0.7506 - specificity_metric: 0.9292 - val_loss: -0.6490 - val_dice_metric: 0.6537 - val_jaccard_metric: 0.5925 - val_sensitivity_metric: 0.6909 - val_specificity_metric: 0.9173
# Epoch 28/60
# 77/77 [==============================] - 70s 908ms/step - loss: -0.6948 - dice_metric: 0.7064 - jaccard_metric: 0.6463 - sensitivity_metric: 0.7570 - specificity_metric: 0.9360 - val_loss: -0.6665 - val_dice_metric: 0.6643 - val_jaccard_metric: 0.6033 - val_sensitivity_metric: 0.7130 - val_specificity_metric: 0.9278
# Epoch 29/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.7083 - dice_metric: 0.7190 - jaccard_metric: 0.6593 - sensitivity_metric: 0.7637 - specificity_metric: 0.9400 - val_loss: -0.6671 - val_dice_metric: 0.6635 - val_jaccard_metric: 0.6018 - val_sensitivity_metric: 0.7147 - val_specificity_metric: 0.9308
# Epoch 30/60
# 77/77 [==============================] - 67s 864ms/step - loss: -0.7199 - dice_metric: 0.7299 - jaccard_metric: 0.6710 - sensitivity_metric: 0.7718 - specificity_metric: 0.9435 - val_loss: -0.6718 - val_dice_metric: 0.6678 - val_jaccard_metric: 0.6069 - val_sensitivity_metric: 0.7265 - val_specificity_metric: 0.9351
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.7302 - dice_metric: 0.7398 - jaccard_metric: 0.6821 - sensitivity_metric: 0.7806 - specificity_metric: 0.9465 - val_loss: -0.6776 - val_dice_metric: 0.6749 - val_jaccard_metric: 0.6170 - val_sensitivity_metric: 0.7290 - val_specificity_metric: 0.9348
# Epoch 32/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.7338 - dice_metric: 0.7438 - jaccard_metric: 0.6868 - sensitivity_metric: 0.7841 - specificity_metric: 0.9471 - val_loss: -0.6764 - val_dice_metric: 0.6745 - val_jaccard_metric: 0.6164 - val_sensitivity_metric: 0.7275 - val_specificity_metric: 0.9338
# Epoch 33/60
# 77/77 [==============================] - 69s 898ms/step - loss: -0.7356 - dice_metric: 0.7457 - jaccard_metric: 0.6888 - sensitivity_metric: 0.7856 - specificity_metric: 0.9475 - val_loss: -0.6753 - val_dice_metric: 0.6738 - val_jaccard_metric: 0.6155 - val_sensitivity_metric: 0.7271 - val_specificity_metric: 0.9332
# Epoch 34/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.7371 - dice_metric: 0.7472 - jaccard_metric: 0.6904 - sensitivity_metric: 0.7868 - specificity_metric: 0.9478 - val_loss: -0.6747 - val_dice_metric: 0.6735 - val_jaccard_metric: 0.6150 - val_sensitivity_metric: 0.7266 - val_specificity_metric: 0.9328
# Epoch 35/60
# 77/77 [==============================] - 69s 898ms/step - loss: -0.7385 - dice_metric: 0.7486 - jaccard_metric: 0.6918 - sensitivity_metric: 0.7879 - specificity_metric: 0.9482 - val_loss: -0.6748 - val_dice_metric: 0.6737 - val_jaccard_metric: 0.6152 - val_sensitivity_metric: 0.7267 - val_specificity_metric: 0.9329
# Epoch 36/60
# 77/77 [==============================] - 69s 893ms/step - loss: -0.7397 - dice_metric: 0.7497 - jaccard_metric: 0.6930 - sensitivity_metric: 0.7889 - specificity_metric: 0.9485 - val_loss: -0.6749 - val_dice_metric: 0.6740 - val_jaccard_metric: 0.6155 - val_sensitivity_metric: 0.7268 - val_specificity_metric: 0.9329
# Epoch 37/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.7408 - dice_metric: 0.7508 - jaccard_metric: 0.6941 - sensitivity_metric: 0.7899 - specificity_metric: 0.9488 - val_loss: -0.6751 - val_dice_metric: 0.6742 - val_jaccard_metric: 0.6158 - val_sensitivity_metric: 0.7271 - val_specificity_metric: 0.9332
# Epoch 38/60
# 77/77 [==============================] - 67s 861ms/step - loss: -0.7420 - dice_metric: 0.7519 - jaccard_metric: 0.6952 - sensitivity_metric: 0.7909 - specificity_metric: 0.9491 - val_loss: -0.6753 - val_dice_metric: 0.6744 - val_jaccard_metric: 0.6161 - val_sensitivity_metric: 0.7272 - val_specificity_metric: 0.9333
# Epoch 39/60
# 77/77 [==============================] - 67s 864ms/step - loss: -0.7431 - dice_metric: 0.7530 - jaccard_metric: 0.6964 - sensitivity_metric: 0.7919 - specificity_metric: 0.9495 - val_loss: -0.6756 - val_dice_metric: 0.6747 - val_jaccard_metric: 0.6164 - val_sensitivity_metric: 0.7274 - val_specificity_metric: 0.9336
# Epoch 40/60
# 77/77 [==============================] - 67s 868ms/step - loss: -0.7442 - dice_metric: 0.7542 - jaccard_metric: 0.6976 - sensitivity_metric: 0.7929 - specificity_metric: 0.9499 - val_loss: -0.6758 - val_dice_metric: 0.6749 - val_jaccard_metric: 0.6166 - val_sensitivity_metric: 0.7277 - val_specificity_metric: 0.9338
# Epoch 41/60
# 77/77 [==============================] - 67s 871ms/step - loss: -0.7453 - dice_metric: 0.7553 - jaccard_metric: 0.6987 - sensitivity_metric: 0.7939 - specificity_metric: 0.9502 - val_loss: -0.6766 - val_dice_metric: 0.6756 - val_jaccard_metric: 0.6173 - val_sensitivity_metric: 0.7287 - val_specificity_metric: 0.9343
# Epoch 42/60
# 77/77 [==============================] - 68s 877ms/step - loss: -0.7464 - dice_metric: 0.7563 - jaccard_metric: 0.6997 - sensitivity_metric: 0.7948 - specificity_metric: 0.9505 - val_loss: -0.6776 - val_dice_metric: 0.6766 - val_jaccard_metric: 0.6182 - val_sensitivity_metric: 0.7292 - val_specificity_metric: 0.9347
# Epoch 43/60
# 77/77 [==============================] - 69s 895ms/step - loss: -0.7475 - dice_metric: 0.7576 - jaccard_metric: 0.7009 - sensitivity_metric: 0.7958 - specificity_metric: 0.9510 - val_loss: -0.6796 - val_dice_metric: 0.6787 - val_jaccard_metric: 0.6201 - val_sensitivity_metric: 0.7297 - val_specificity_metric: 0.9351
# Epoch 44/60
# 77/77 [==============================] - 67s 872ms/step - loss: -0.7487 - dice_metric: 0.7589 - jaccard_metric: 0.7022 - sensitivity_metric: 0.7967 - specificity_metric: 0.9513 - val_loss: -0.6805 - val_dice_metric: 0.6796 - val_jaccard_metric: 0.6211 - val_sensitivity_metric: 0.7301 - val_specificity_metric: 0.9356
# Epoch 45/60
# 77/77 [==============================] - 67s 873ms/step - loss: -0.7499 - dice_metric: 0.7600 - jaccard_metric: 0.7033 - sensitivity_metric: 0.7975 - specificity_metric: 0.9516 - val_loss: -0.6812 - val_dice_metric: 0.6801 - val_jaccard_metric: 0.6217 - val_sensitivity_metric: 0.7304 - val_specificity_metric: 0.9359
# Epoch 46/60
# 77/77 [==============================] - 65s 843ms/step - loss: -0.7509 - dice_metric: 0.7609 - jaccard_metric: 0.7042 - sensitivity_metric: 0.7983 - specificity_metric: 0.9519 - val_loss: -0.6816 - val_dice_metric: 0.6805 - val_jaccard_metric: 0.6223 - val_sensitivity_metric: 0.7307 - val_specificity_metric: 0.9363
# Epoch 47/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.7519 - dice_metric: 0.7618 - jaccard_metric: 0.7051 - sensitivity_metric: 0.7991 - specificity_metric: 0.9521 - val_loss: -0.6818 - val_dice_metric: 0.6806 - val_jaccard_metric: 0.6225 - val_sensitivity_metric: 0.7305 - val_specificity_metric: 0.9364
# Epoch 48/60
# 77/77 [==============================] - 69s 899ms/step - loss: -0.7528 - dice_metric: 0.7627 - jaccard_metric: 0.7061 - sensitivity_metric: 0.8000 - specificity_metric: 0.9524 - val_loss: -0.6822 - val_dice_metric: 0.6810 - val_jaccard_metric: 0.6230 - val_sensitivity_metric: 0.7308 - val_specificity_metric: 0.9369
# Epoch 49/60
# 77/77 [==============================] - 67s 871ms/step - loss: -0.7538 - dice_metric: 0.7636 - jaccard_metric: 0.7070 - sensitivity_metric: 0.8008 - specificity_metric: 0.9527 - val_loss: -0.6824 - val_dice_metric: 0.6812 - val_jaccard_metric: 0.6233 - val_sensitivity_metric: 0.7312 - val_specificity_metric: 0.9373
# Epoch 50/60
# 77/77 [==============================] - 67s 872ms/step - loss: -0.7547 - dice_metric: 0.7645 - jaccard_metric: 0.7078 - sensitivity_metric: 0.8016 - specificity_metric: 0.9529 - val_loss: -0.6827 - val_dice_metric: 0.6814 - val_jaccard_metric: 0.6235 - val_sensitivity_metric: 0.7314 - val_specificity_metric: 0.9375
# Epoch 51/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.7556 - dice_metric: 0.7653 - jaccard_metric: 0.7086 - sensitivity_metric: 0.8024 - specificity_metric: 0.9531 - val_loss: -0.6829 - val_dice_metric: 0.6816 - val_jaccard_metric: 0.6237 - val_sensitivity_metric: 0.7315 - val_specificity_metric: 0.9376
# Epoch 52/60
# 77/77 [==============================] - 68s 873ms/step - loss: -0.7564 - dice_metric: 0.7661 - jaccard_metric: 0.7094 - sensitivity_metric: 0.8032 - specificity_metric: 0.9534 - val_loss: -0.6833 - val_dice_metric: 0.6820 - val_jaccard_metric: 0.6242 - val_sensitivity_metric: 0.7317 - val_specificity_metric: 0.9379
# Epoch 53/60
# 77/77 [==============================] - 68s 886ms/step - loss: -0.7573 - dice_metric: 0.7669 - jaccard_metric: 0.7102 - sensitivity_metric: 0.8040 - specificity_metric: 0.9537 - val_loss: -0.6838 - val_dice_metric: 0.6824 - val_jaccard_metric: 0.6248 - val_sensitivity_metric: 0.7319 - val_specificity_metric: 0.9383
# Epoch 54/60
# 77/77 [==============================] - 67s 861ms/step - loss: -0.7582 - dice_metric: 0.7677 - jaccard_metric: 0.7110 - sensitivity_metric: 0.8048 - specificity_metric: 0.9539 - val_loss: -0.6842 - val_dice_metric: 0.6827 - val_jaccard_metric: 0.6251 - val_sensitivity_metric: 0.7320 - val_specificity_metric: 0.9384
# Epoch 55/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.7590 - dice_metric: 0.7684 - jaccard_metric: 0.7118 - sensitivity_metric: 0.8055 - specificity_metric: 0.9541 - val_loss: -0.6845 - val_dice_metric: 0.6830 - val_jaccard_metric: 0.6254 - val_sensitivity_metric: 0.7320 - val_specificity_metric: 0.9387
# Epoch 56/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.7599 - dice_metric: 0.7692 - jaccard_metric: 0.7126 - sensitivity_metric: 0.8062 - specificity_metric: 0.9544 - val_loss: -0.6851 - val_dice_metric: 0.6836 - val_jaccard_metric: 0.6262 - val_sensitivity_metric: 0.7326 - val_specificity_metric: 0.9394
# Epoch 57/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.7607 - dice_metric: 0.7700 - jaccard_metric: 0.7133 - sensitivity_metric: 0.8070 - specificity_metric: 0.9546 - val_loss: -0.6855 - val_dice_metric: 0.6839 - val_jaccard_metric: 0.6266 - val_sensitivity_metric: 0.7329 - val_specificity_metric: 0.9399
# Epoch 58/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.7615 - dice_metric: 0.7707 - jaccard_metric: 0.7141 - sensitivity_metric: 0.8077 - specificity_metric: 0.9548 - val_loss: -0.6861 - val_dice_metric: 0.6845 - val_jaccard_metric: 0.6273 - val_sensitivity_metric: 0.7334 - val_specificity_metric: 0.9404
# Epoch 59/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.7623 - dice_metric: 0.7714 - jaccard_metric: 0.7148 - sensitivity_metric: 0.8083 - specificity_metric: 0.9549 - val_loss: -0.6865 - val_dice_metric: 0.6848 - val_jaccard_metric: 0.6276 - val_sensitivity_metric: 0.7337 - val_specificity_metric: 0.9407
# Epoch 60/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.7630 - dice_metric: 0.7720 - jaccard_metric: 0.7155 - sensitivity_metric: 0.8089 - specificity_metric: 0.9551 - val_loss: -0.6869 - val_dice_metric: 0.6851 - val_jaccard_metric: 0.6280 - val_sensitivity_metric: 0.7339 - val_specificity_metric: 0.9409

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.69750, standard deviation: 0.36944
# Jaccard Index mean: 0.63719, standard deviation: 0.36163
# Sensitivity mean: 0.76682, standard deviation: 0.32013
# Specificity mean: 0.94443, standard deviation: 0.07879
