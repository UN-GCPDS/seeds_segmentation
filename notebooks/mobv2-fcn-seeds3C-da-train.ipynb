# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|███████████████████████████████████████▌| 989M/0.98G [00:10<00:00, 161MB/s]
# 100%|██████████████████████████████████████| 0.98G/0.98G [00:10<00:00, 98.3MB/s]

# %%
config = {"Seg_model":"FCNMobV2","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import fcn_mobilenetv2
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = fcn_mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 93s 816ms/step - loss: -0.2608 - dice_metric: 0.2909 - jaccard_metric: 0.2034 - sensitivity_metric: 0.4447 - specificity_metric: 0.8361 - precision_metric: 0.3927 - recall_metric: 0.4447 - mean_average_precision: 0.0290 - val_loss: -0.2421 - val_dice_metric: 0.3195 - val_jaccard_metric: 0.2146 - val_sensitivity_metric: 0.3019 - val_specificity_metric: 0.8950 - val_precision_metric: 0.5650 - val_recall_metric: 0.3019 - val_mean_average_precision: 2.6042e-04
# Epoch 2/60
# 77/77 [==============================] - 55s 708ms/step - loss: -0.4148 - dice_metric: 0.4933 - jaccard_metric: 0.3998 - sensitivity_metric: 0.5682 - specificity_metric: 0.8479 - precision_metric: 0.5468 - recall_metric: 0.5682 - mean_average_precision: 0.1906 - val_loss: -0.3652 - val_dice_metric: 0.5419 - val_jaccard_metric: 0.4579 - val_sensitivity_metric: 0.5431 - val_specificity_metric: 0.8500 - val_precision_metric: 0.6150 - val_recall_metric: 0.5431 - val_mean_average_precision: 0.2820
# Epoch 3/60
# 77/77 [==============================] - 56s 728ms/step - loss: -0.4930 - dice_metric: 0.5360 - jaccard_metric: 0.4500 - sensitivity_metric: 0.5859 - specificity_metric: 0.8377 - precision_metric: 0.5985 - recall_metric: 0.5859 - mean_average_precision: 0.2652 - val_loss: -0.4609 - val_dice_metric: 0.5461 - val_jaccard_metric: 0.4604 - val_sensitivity_metric: 0.5494 - val_specificity_metric: 0.8284 - val_precision_metric: 0.6394 - val_recall_metric: 0.5494 - val_mean_average_precision: 0.2842
# Epoch 4/60
# 77/77 [==============================] - 59s 760ms/step - loss: -0.5215 - dice_metric: 0.5499 - jaccard_metric: 0.4677 - sensitivity_metric: 0.6024 - specificity_metric: 0.8428 - precision_metric: 0.6102 - recall_metric: 0.6024 - mean_average_precision: 0.2976 - val_loss: -0.5220 - val_dice_metric: 0.5599 - val_jaccard_metric: 0.4790 - val_sensitivity_metric: 0.5636 - val_specificity_metric: 0.8395 - val_precision_metric: 0.6414 - val_recall_metric: 0.5636 - val_mean_average_precision: 0.3197
# Epoch 5/60
# 77/77 [==============================] - 57s 734ms/step - loss: -0.5379 - dice_metric: 0.5603 - jaccard_metric: 0.4810 - sensitivity_metric: 0.6162 - specificity_metric: 0.8488 - precision_metric: 0.6168 - recall_metric: 0.6162 - mean_average_precision: 0.3219 - val_loss: -0.5503 - val_dice_metric: 0.5691 - val_jaccard_metric: 0.4917 - val_sensitivity_metric: 0.5814 - val_specificity_metric: 0.8476 - val_precision_metric: 0.6455 - val_recall_metric: 0.5814 - val_mean_average_precision: 0.3473
# Epoch 6/60
# 77/77 [==============================] - 54s 691ms/step - loss: -0.5488 - dice_metric: 0.5673 - jaccard_metric: 0.4902 - sensitivity_metric: 0.6266 - specificity_metric: 0.8538 - precision_metric: 0.6208 - recall_metric: 0.6266 - mean_average_precision: 0.3401 - val_loss: -0.5641 - val_dice_metric: 0.5757 - val_jaccard_metric: 0.5017 - val_sensitivity_metric: 0.5955 - val_specificity_metric: 0.8558 - val_precision_metric: 0.6459 - val_recall_metric: 0.5955 - val_mean_average_precision: 0.3645
# Epoch 7/60
# 77/77 [==============================] - 56s 722ms/step - loss: -0.5579 - dice_metric: 0.5738 - jaccard_metric: 0.4989 - sensitivity_metric: 0.6362 - specificity_metric: 0.8580 - precision_metric: 0.6247 - recall_metric: 0.6362 - mean_average_precision: 0.3559 - val_loss: -0.5713 - val_dice_metric: 0.5792 - val_jaccard_metric: 0.5069 - val_sensitivity_metric: 0.6040 - val_specificity_metric: 0.8588 - val_precision_metric: 0.6467 - val_recall_metric: 0.6040 - val_mean_average_precision: 0.3726
# Epoch 8/60
# 77/77 [==============================] - 57s 735ms/step - loss: -0.5643 - dice_metric: 0.5781 - jaccard_metric: 0.5046 - sensitivity_metric: 0.6429 - specificity_metric: 0.8612 - precision_metric: 0.6271 - recall_metric: 0.6429 - mean_average_precision: 0.3673 - val_loss: -0.5769 - val_dice_metric: 0.5827 - val_jaccard_metric: 0.5123 - val_sensitivity_metric: 0.6131 - val_specificity_metric: 0.8643 - val_precision_metric: 0.6473 - val_recall_metric: 0.6131 - val_mean_average_precision: 0.3831
# Epoch 9/60
# 77/77 [==============================] - 54s 700ms/step - loss: -0.5695 - dice_metric: 0.5815 - jaccard_metric: 0.5091 - sensitivity_metric: 0.6477 - specificity_metric: 0.8639 - precision_metric: 0.6291 - recall_metric: 0.6477 - mean_average_precision: 0.3760 - val_loss: -0.5810 - val_dice_metric: 0.5851 - val_jaccard_metric: 0.5161 - val_sensitivity_metric: 0.6196 - val_specificity_metric: 0.8696 - val_precision_metric: 0.6447 - val_recall_metric: 0.6196 - val_mean_average_precision: 0.3917
# Epoch 10/60
# 77/77 [==============================] - 57s 730ms/step - loss: -0.5737 - dice_metric: 0.5840 - jaccard_metric: 0.5126 - sensitivity_metric: 0.6509 - specificity_metric: 0.8657 - precision_metric: 0.6303 - recall_metric: 0.6509 - mean_average_precision: 0.3831 - val_loss: -0.5845 - val_dice_metric: 0.5875 - val_jaccard_metric: 0.5197 - val_sensitivity_metric: 0.6287 - val_specificity_metric: 0.8755 - val_precision_metric: 0.6410 - val_recall_metric: 0.6287 - val_mean_average_precision: 0.4026
# Epoch 11/60
# 77/77 [==============================] - 57s 740ms/step - loss: -0.5772 - dice_metric: 0.5860 - jaccard_metric: 0.5155 - sensitivity_metric: 0.6538 - specificity_metric: 0.8674 - precision_metric: 0.6311 - recall_metric: 0.6538 - mean_average_precision: 0.3896 - val_loss: -0.5879 - val_dice_metric: 0.5906 - val_jaccard_metric: 0.5232 - val_sensitivity_metric: 0.6374 - val_specificity_metric: 0.8745 - val_precision_metric: 0.6501 - val_recall_metric: 0.6374 - val_mean_average_precision: 0.4091
# Epoch 12/60
# 77/77 [==============================] - 58s 750ms/step - loss: -0.5811 - dice_metric: 0.5890 - jaccard_metric: 0.5196 - sensitivity_metric: 0.6589 - specificity_metric: 0.8691 - precision_metric: 0.6333 - recall_metric: 0.6589 - mean_average_precision: 0.3972 - val_loss: -0.5890 - val_dice_metric: 0.5906 - val_jaccard_metric: 0.5230 - val_sensitivity_metric: 0.6392 - val_specificity_metric: 0.8751 - val_precision_metric: 0.6521 - val_recall_metric: 0.6392 - val_mean_average_precision: 0.4051
# Epoch 13/60
# 77/77 [==============================] - 56s 723ms/step - loss: -0.5834 - dice_metric: 0.5904 - jaccard_metric: 0.5215 - sensitivity_metric: 0.6604 - specificity_metric: 0.8703 - precision_metric: 0.6341 - recall_metric: 0.6604 - mean_average_precision: 0.4003 - val_loss: -0.5902 - val_dice_metric: 0.5921 - val_jaccard_metric: 0.5250 - val_sensitivity_metric: 0.6412 - val_specificity_metric: 0.8765 - val_precision_metric: 0.6536 - val_recall_metric: 0.6412 - val_mean_average_precision: 0.4077
# Epoch 14/60
# 77/77 [==============================] - 53s 685ms/step - loss: -0.5859 - dice_metric: 0.5922 - jaccard_metric: 0.5240 - sensitivity_metric: 0.6634 - specificity_metric: 0.8714 - precision_metric: 0.6354 - recall_metric: 0.6634 - mean_average_precision: 0.4038 - val_loss: -0.5913 - val_dice_metric: 0.5932 - val_jaccard_metric: 0.5269 - val_sensitivity_metric: 0.6402 - val_specificity_metric: 0.8765 - val_precision_metric: 0.6507 - val_recall_metric: 0.6402 - val_mean_average_precision: 0.4092
# Epoch 15/60
# 77/77 [==============================] - 57s 737ms/step - loss: -0.5876 - dice_metric: 0.5933 - jaccard_metric: 0.5254 - sensitivity_metric: 0.6654 - specificity_metric: 0.8725 - precision_metric: 0.6360 - recall_metric: 0.6654 - mean_average_precision: 0.4049 - val_loss: -0.5924 - val_dice_metric: 0.5942 - val_jaccard_metric: 0.5284 - val_sensitivity_metric: 0.6398 - val_specificity_metric: 0.8764 - val_precision_metric: 0.6505 - val_recall_metric: 0.6398 - val_mean_average_precision: 0.4104
# Epoch 16/60
# 77/77 [==============================] - 56s 720ms/step - loss: -0.5895 - dice_metric: 0.5946 - jaccard_metric: 0.5273 - sensitivity_metric: 0.6678 - specificity_metric: 0.8733 - precision_metric: 0.6371 - recall_metric: 0.6678 - mean_average_precision: 0.4067 - val_loss: -0.5948 - val_dice_metric: 0.5958 - val_jaccard_metric: 0.5309 - val_sensitivity_metric: 0.6504 - val_specificity_metric: 0.8820 - val_precision_metric: 0.6474 - val_recall_metric: 0.6504 - val_mean_average_precision: 0.4154
# Epoch 17/60
# 77/77 [==============================] - 54s 702ms/step - loss: -0.5917 - dice_metric: 0.5964 - jaccard_metric: 0.5297 - sensitivity_metric: 0.6714 - specificity_metric: 0.8740 - precision_metric: 0.6385 - recall_metric: 0.6714 - mean_average_precision: 0.4099 - val_loss: -0.5965 - val_dice_metric: 0.5977 - val_jaccard_metric: 0.5332 - val_sensitivity_metric: 0.6543 - val_specificity_metric: 0.8840 - val_precision_metric: 0.6488 - val_recall_metric: 0.6543 - val_mean_average_precision: 0.4171
# Epoch 18/60
# 77/77 [==============================] - 58s 746ms/step - loss: -0.5937 - dice_metric: 0.5980 - jaccard_metric: 0.5319 - sensitivity_metric: 0.6743 - specificity_metric: 0.8746 - precision_metric: 0.6398 - recall_metric: 0.6743 - mean_average_precision: 0.4130 - val_loss: -0.5970 - val_dice_metric: 0.5991 - val_jaccard_metric: 0.5354 - val_sensitivity_metric: 0.6591 - val_specificity_metric: 0.8865 - val_precision_metric: 0.6472 - val_recall_metric: 0.6591 - val_mean_average_precision: 0.4220
# Epoch 19/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.5952 - dice_metric: 0.5991 - jaccard_metric: 0.5335 - sensitivity_metric: 0.6764 - specificity_metric: 0.8752 - precision_metric: 0.6406 - recall_metric: 0.6764 - mean_average_precision: 0.4150 - val_loss: -0.5974 - val_dice_metric: 0.5988 - val_jaccard_metric: 0.5348 - val_sensitivity_metric: 0.6557 - val_specificity_metric: 0.8845 - val_precision_metric: 0.6502 - val_recall_metric: 0.6557 - val_mean_average_precision: 0.4189
# Epoch 20/60
# 77/77 [==============================] - 55s 711ms/step - loss: -0.5964 - dice_metric: 0.6000 - jaccard_metric: 0.5347 - sensitivity_metric: 0.6779 - specificity_metric: 0.8758 - precision_metric: 0.6410 - recall_metric: 0.6779 - mean_average_precision: 0.4164 - val_loss: -0.5968 - val_dice_metric: 0.5983 - val_jaccard_metric: 0.5340 - val_sensitivity_metric: 0.6544 - val_specificity_metric: 0.8848 - val_precision_metric: 0.6506 - val_recall_metric: 0.6544 - val_mean_average_precision: 0.4167
# Epoch 21/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.5976 - dice_metric: 0.6009 - jaccard_metric: 0.5361 - sensitivity_metric: 0.6794 - specificity_metric: 0.8761 - precision_metric: 0.6420 - recall_metric: 0.6794 - mean_average_precision: 0.4183 - val_loss: -0.5976 - val_dice_metric: 0.5982 - val_jaccard_metric: 0.5342 - val_sensitivity_metric: 0.6532 - val_specificity_metric: 0.8853 - val_precision_metric: 0.6470 - val_recall_metric: 0.6532 - val_mean_average_precision: 0.4166
# Epoch 22/60
# 77/77 [==============================] - 53s 684ms/step - loss: -0.5985 - dice_metric: 0.6015 - jaccard_metric: 0.5370 - sensitivity_metric: 0.6804 - specificity_metric: 0.8766 - precision_metric: 0.6423 - recall_metric: 0.6804 - mean_average_precision: 0.4194 - val_loss: -0.5981 - val_dice_metric: 0.5988 - val_jaccard_metric: 0.5350 - val_sensitivity_metric: 0.6554 - val_specificity_metric: 0.8862 - val_precision_metric: 0.6478 - val_recall_metric: 0.6554 - val_mean_average_precision: 0.4172
# Epoch 23/60
# 77/77 [==============================] - 57s 738ms/step - loss: -0.5995 - dice_metric: 0.6024 - jaccard_metric: 0.5383 - sensitivity_metric: 0.6821 - specificity_metric: 0.8770 - precision_metric: 0.6430 - recall_metric: 0.6821 - mean_average_precision: 0.4212 - val_loss: -0.5993 - val_dice_metric: 0.6005 - val_jaccard_metric: 0.5377 - val_sensitivity_metric: 0.6568 - val_specificity_metric: 0.8879 - val_precision_metric: 0.6463 - val_recall_metric: 0.6568 - val_mean_average_precision: 0.4217
# Epoch 24/60
# 77/77 [==============================] - 56s 719ms/step - loss: -0.6014 - dice_metric: 0.6045 - jaccard_metric: 0.5413 - sensitivity_metric: 0.6853 - specificity_metric: 0.8789 - precision_metric: 0.6439 - recall_metric: 0.6853 - mean_average_precision: 0.4299 - val_loss: -0.6025 - val_dice_metric: 0.6033 - val_jaccard_metric: 0.5416 - val_sensitivity_metric: 0.6540 - val_specificity_metric: 0.8897 - val_precision_metric: 0.6476 - val_recall_metric: 0.6540 - val_mean_average_precision: 0.4427
# Epoch 25/60
# 77/77 [==============================] - 55s 708ms/step - loss: -0.6090 - dice_metric: 0.6142 - jaccard_metric: 0.5543 - sensitivity_metric: 0.6976 - specificity_metric: 0.8906 - precision_metric: 0.6451 - recall_metric: 0.6976 - mean_average_precision: 0.4599 - val_loss: -0.6151 - val_dice_metric: 0.6171 - val_jaccard_metric: 0.5607 - val_sensitivity_metric: 0.6734 - val_specificity_metric: 0.9069 - val_precision_metric: 0.6466 - val_recall_metric: 0.6734 - val_mean_average_precision: 0.4701
# Epoch 26/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.6293 - dice_metric: 0.6373 - jaccard_metric: 0.5789 - sensitivity_metric: 0.7297 - specificity_metric: 0.9122 - precision_metric: 0.6545 - recall_metric: 0.7297 - mean_average_precision: 0.4904 - val_loss: -0.6426 - val_dice_metric: 0.6463 - val_jaccard_metric: 0.5865 - val_sensitivity_metric: 0.6823 - val_specificity_metric: 0.9122 - val_precision_metric: 0.6770 - val_recall_metric: 0.6823 - val_mean_average_precision: 0.4928
# Epoch 27/60
# 77/77 [==============================] - 56s 721ms/step - loss: -0.6775 - dice_metric: 0.6907 - jaccard_metric: 0.6300 - sensitivity_metric: 0.7540 - specificity_metric: 0.9296 - precision_metric: 0.7002 - recall_metric: 0.7540 - mean_average_precision: 0.5305 - val_loss: -0.6428 - val_dice_metric: 0.6523 - val_jaccard_metric: 0.5880 - val_sensitivity_metric: 0.7081 - val_specificity_metric: 0.9232 - val_precision_metric: 0.6720 - val_recall_metric: 0.7081 - val_mean_average_precision: 0.4775
# Epoch 28/60
# 77/77 [==============================] - 57s 737ms/step - loss: -0.6966 - dice_metric: 0.7089 - jaccard_metric: 0.6484 - sensitivity_metric: 0.7611 - specificity_metric: 0.9363 - precision_metric: 0.7173 - recall_metric: 0.7611 - mean_average_precision: 0.5468 - val_loss: -0.6694 - val_dice_metric: 0.6688 - val_jaccard_metric: 0.6088 - val_sensitivity_metric: 0.7174 - val_specificity_metric: 0.9318 - val_precision_metric: 0.6904 - val_recall_metric: 0.7174 - val_mean_average_precision: 0.5104
# Epoch 29/60
# 77/77 [==============================] - 58s 754ms/step - loss: -0.7107 - dice_metric: 0.7219 - jaccard_metric: 0.6623 - sensitivity_metric: 0.7686 - specificity_metric: 0.9403 - precision_metric: 0.7294 - recall_metric: 0.7686 - mean_average_precision: 0.5623 - val_loss: -0.6763 - val_dice_metric: 0.6733 - val_jaccard_metric: 0.6138 - val_sensitivity_metric: 0.7203 - val_specificity_metric: 0.9336 - val_precision_metric: 0.6951 - val_recall_metric: 0.7203 - val_mean_average_precision: 0.5153
# Epoch 30/60
# 77/77 [==============================] - 54s 700ms/step - loss: -0.7193 - dice_metric: 0.7290 - jaccard_metric: 0.6693 - sensitivity_metric: 0.7723 - specificity_metric: 0.9428 - precision_metric: 0.7363 - recall_metric: 0.7723 - mean_average_precision: 0.5678 - val_loss: -0.6809 - val_dice_metric: 0.6770 - val_jaccard_metric: 0.6172 - val_sensitivity_metric: 0.7244 - val_specificity_metric: 0.9362 - val_precision_metric: 0.6927 - val_recall_metric: 0.7244 - val_mean_average_precision: 0.5194
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 59s 758ms/step - loss: -0.7300 - dice_metric: 0.7391 - jaccard_metric: 0.6814 - sensitivity_metric: 0.7782 - specificity_metric: 0.9447 - precision_metric: 0.7455 - recall_metric: 0.7782 - mean_average_precision: 0.5843 - val_loss: -0.6855 - val_dice_metric: 0.6832 - val_jaccard_metric: 0.6253 - val_sensitivity_metric: 0.7314 - val_specificity_metric: 0.9365 - val_precision_metric: 0.7042 - val_recall_metric: 0.7314 - val_mean_average_precision: 0.5278
# Epoch 32/60
# 77/77 [==============================] - 56s 724ms/step - loss: -0.7339 - dice_metric: 0.7435 - jaccard_metric: 0.6865 - sensitivity_metric: 0.7828 - specificity_metric: 0.9458 - precision_metric: 0.7494 - recall_metric: 0.7828 - mean_average_precision: 0.5911 - val_loss: -0.6835 - val_dice_metric: 0.6819 - val_jaccard_metric: 0.6235 - val_sensitivity_metric: 0.7308 - val_specificity_metric: 0.9356 - val_precision_metric: 0.7047 - val_recall_metric: 0.7308 - val_mean_average_precision: 0.5260
# Epoch 33/60
# 77/77 [==============================] - 59s 761ms/step - loss: -0.7358 - dice_metric: 0.7455 - jaccard_metric: 0.6888 - sensitivity_metric: 0.7845 - specificity_metric: 0.9464 - precision_metric: 0.7512 - recall_metric: 0.7845 - mean_average_precision: 0.5942 - val_loss: -0.6827 - val_dice_metric: 0.6814 - val_jaccard_metric: 0.6228 - val_sensitivity_metric: 0.7304 - val_specificity_metric: 0.9353 - val_precision_metric: 0.7049 - val_recall_metric: 0.7304 - val_mean_average_precision: 0.5266
# Epoch 34/60
# 77/77 [==============================] - 55s 712ms/step - loss: -0.7373 - dice_metric: 0.7470 - jaccard_metric: 0.6905 - sensitivity_metric: 0.7858 - specificity_metric: 0.9468 - precision_metric: 0.7525 - recall_metric: 0.7858 - mean_average_precision: 0.5962 - val_loss: -0.6818 - val_dice_metric: 0.6806 - val_jaccard_metric: 0.6218 - val_sensitivity_metric: 0.7296 - val_specificity_metric: 0.9348 - val_precision_metric: 0.7046 - val_recall_metric: 0.7296 - val_mean_average_precision: 0.5248
# Epoch 35/60
# 77/77 [==============================] - 56s 718ms/step - loss: -0.7386 - dice_metric: 0.7483 - jaccard_metric: 0.6919 - sensitivity_metric: 0.7868 - specificity_metric: 0.9472 - precision_metric: 0.7537 - recall_metric: 0.7868 - mean_average_precision: 0.5977 - val_loss: -0.6812 - val_dice_metric: 0.6802 - val_jaccard_metric: 0.6213 - val_sensitivity_metric: 0.7288 - val_specificity_metric: 0.9348 - val_precision_metric: 0.7044 - val_recall_metric: 0.7288 - val_mean_average_precision: 0.5240
# Epoch 36/60
# 77/77 [==============================] - 58s 754ms/step - loss: -0.7396 - dice_metric: 0.7493 - jaccard_metric: 0.6929 - sensitivity_metric: 0.7876 - specificity_metric: 0.9477 - precision_metric: 0.7546 - recall_metric: 0.7876 - mean_average_precision: 0.5988 - val_loss: -0.6814 - val_dice_metric: 0.6805 - val_jaccard_metric: 0.6216 - val_sensitivity_metric: 0.7291 - val_specificity_metric: 0.9346 - val_precision_metric: 0.7051 - val_recall_metric: 0.7291 - val_mean_average_precision: 0.5239
# Epoch 37/60
# 77/77 [==============================] - 56s 722ms/step - loss: -0.7408 - dice_metric: 0.7505 - jaccard_metric: 0.6942 - sensitivity_metric: 0.7887 - specificity_metric: 0.9481 - precision_metric: 0.7554 - recall_metric: 0.7887 - mean_average_precision: 0.6007 - val_loss: -0.6816 - val_dice_metric: 0.6808 - val_jaccard_metric: 0.6218 - val_sensitivity_metric: 0.7291 - val_specificity_metric: 0.9350 - val_precision_metric: 0.7055 - val_recall_metric: 0.7291 - val_mean_average_precision: 0.5250
# Epoch 38/60
# 77/77 [==============================] - 53s 684ms/step - loss: -0.7419 - dice_metric: 0.7517 - jaccard_metric: 0.6954 - sensitivity_metric: 0.7897 - specificity_metric: 0.9485 - precision_metric: 0.7564 - recall_metric: 0.7897 - mean_average_precision: 0.6019 - val_loss: -0.6814 - val_dice_metric: 0.6807 - val_jaccard_metric: 0.6217 - val_sensitivity_metric: 0.7287 - val_specificity_metric: 0.9351 - val_precision_metric: 0.7055 - val_recall_metric: 0.7287 - val_mean_average_precision: 0.5251
# Epoch 39/60
# 77/77 [==============================] - 60s 770ms/step - loss: -0.7430 - dice_metric: 0.7527 - jaccard_metric: 0.6965 - sensitivity_metric: 0.7906 - specificity_metric: 0.9489 - precision_metric: 0.7573 - recall_metric: 0.7906 - mean_average_precision: 0.6032 - val_loss: -0.6815 - val_dice_metric: 0.6809 - val_jaccard_metric: 0.6219 - val_sensitivity_metric: 0.7286 - val_specificity_metric: 0.9352 - val_precision_metric: 0.7056 - val_recall_metric: 0.7286 - val_mean_average_precision: 0.5235
# Epoch 40/60
# 77/77 [==============================] - 54s 698ms/step - loss: -0.7441 - dice_metric: 0.7538 - jaccard_metric: 0.6976 - sensitivity_metric: 0.7916 - specificity_metric: 0.9492 - precision_metric: 0.7581 - recall_metric: 0.7916 - mean_average_precision: 0.6045 - val_loss: -0.6818 - val_dice_metric: 0.6813 - val_jaccard_metric: 0.6223 - val_sensitivity_metric: 0.7292 - val_specificity_metric: 0.9355 - val_precision_metric: 0.7060 - val_recall_metric: 0.7292 - val_mean_average_precision: 0.5238
# Epoch 41/60
# 77/77 [==============================] - 59s 757ms/step - loss: -0.7451 - dice_metric: 0.7547 - jaccard_metric: 0.6986 - sensitivity_metric: 0.7924 - specificity_metric: 0.9496 - precision_metric: 0.7589 - recall_metric: 0.7924 - mean_average_precision: 0.6058 - val_loss: -0.6821 - val_dice_metric: 0.6816 - val_jaccard_metric: 0.6227 - val_sensitivity_metric: 0.7294 - val_specificity_metric: 0.9357 - val_precision_metric: 0.7061 - val_recall_metric: 0.7294 - val_mean_average_precision: 0.5233
# Epoch 42/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.7461 - dice_metric: 0.7557 - jaccard_metric: 0.6996 - sensitivity_metric: 0.7933 - specificity_metric: 0.9499 - precision_metric: 0.7597 - recall_metric: 0.7933 - mean_average_precision: 0.6069 - val_loss: -0.6824 - val_dice_metric: 0.6821 - val_jaccard_metric: 0.6232 - val_sensitivity_metric: 0.7298 - val_specificity_metric: 0.9359 - val_precision_metric: 0.7064 - val_recall_metric: 0.7298 - val_mean_average_precision: 0.5238
# Epoch 43/60
# 77/77 [==============================] - 56s 726ms/step - loss: -0.7471 - dice_metric: 0.7567 - jaccard_metric: 0.7006 - sensitivity_metric: 0.7942 - specificity_metric: 0.9503 - precision_metric: 0.7605 - recall_metric: 0.7942 - mean_average_precision: 0.6082 - val_loss: -0.6827 - val_dice_metric: 0.6825 - val_jaccard_metric: 0.6236 - val_sensitivity_metric: 0.7301 - val_specificity_metric: 0.9363 - val_precision_metric: 0.7067 - val_recall_metric: 0.7301 - val_mean_average_precision: 0.5250
# Epoch 44/60
# 77/77 [==============================] - 57s 737ms/step - loss: -0.7481 - dice_metric: 0.7576 - jaccard_metric: 0.7016 - sensitivity_metric: 0.7950 - specificity_metric: 0.9505 - precision_metric: 0.7612 - recall_metric: 0.7950 - mean_average_precision: 0.6092 - val_loss: -0.6829 - val_dice_metric: 0.6828 - val_jaccard_metric: 0.6239 - val_sensitivity_metric: 0.7303 - val_specificity_metric: 0.9363 - val_precision_metric: 0.7069 - val_recall_metric: 0.7303 - val_mean_average_precision: 0.5255
# Epoch 45/60
# 77/77 [==============================] - 55s 714ms/step - loss: -0.7490 - dice_metric: 0.7585 - jaccard_metric: 0.7024 - sensitivity_metric: 0.7957 - specificity_metric: 0.9508 - precision_metric: 0.7619 - recall_metric: 0.7957 - mean_average_precision: 0.6101 - val_loss: -0.6834 - val_dice_metric: 0.6834 - val_jaccard_metric: 0.6246 - val_sensitivity_metric: 0.7307 - val_specificity_metric: 0.9366 - val_precision_metric: 0.7074 - val_recall_metric: 0.7307 - val_mean_average_precision: 0.5266
# Epoch 46/60
# 77/77 [==============================] - 56s 723ms/step - loss: -0.7500 - dice_metric: 0.7594 - jaccard_metric: 0.7034 - sensitivity_metric: 0.7966 - specificity_metric: 0.9511 - precision_metric: 0.7627 - recall_metric: 0.7966 - mean_average_precision: 0.6110 - val_loss: -0.6837 - val_dice_metric: 0.6837 - val_jaccard_metric: 0.6249 - val_sensitivity_metric: 0.7308 - val_specificity_metric: 0.9368 - val_precision_metric: 0.7077 - val_recall_metric: 0.7308 - val_mean_average_precision: 0.5266
# Epoch 47/60
# 77/77 [==============================] - 58s 749ms/step - loss: -0.7509 - dice_metric: 0.7603 - jaccard_metric: 0.7043 - sensitivity_metric: 0.7974 - specificity_metric: 0.9514 - precision_metric: 0.7634 - recall_metric: 0.7974 - mean_average_precision: 0.6120 - val_loss: -0.6839 - val_dice_metric: 0.6839 - val_jaccard_metric: 0.6251 - val_sensitivity_metric: 0.7310 - val_specificity_metric: 0.9370 - val_precision_metric: 0.7076 - val_recall_metric: 0.7310 - val_mean_average_precision: 0.5270
# Epoch 48/60
# 77/77 [==============================] - 59s 760ms/step - loss: -0.7518 - dice_metric: 0.7612 - jaccard_metric: 0.7052 - sensitivity_metric: 0.7982 - specificity_metric: 0.9517 - precision_metric: 0.7641 - recall_metric: 0.7982 - mean_average_precision: 0.6129 - val_loss: -0.6843 - val_dice_metric: 0.6842 - val_jaccard_metric: 0.6256 - val_sensitivity_metric: 0.7314 - val_specificity_metric: 0.9373 - val_precision_metric: 0.7078 - val_recall_metric: 0.7314 - val_mean_average_precision: 0.5274
# Epoch 49/60
# 77/77 [==============================] - 56s 726ms/step - loss: -0.7528 - dice_metric: 0.7620 - jaccard_metric: 0.7060 - sensitivity_metric: 0.7990 - specificity_metric: 0.9520 - precision_metric: 0.7648 - recall_metric: 0.7990 - mean_average_precision: 0.6139 - val_loss: -0.6845 - val_dice_metric: 0.6844 - val_jaccard_metric: 0.6257 - val_sensitivity_metric: 0.7315 - val_specificity_metric: 0.9375 - val_precision_metric: 0.7077 - val_recall_metric: 0.7315 - val_mean_average_precision: 0.5273
# Epoch 50/60
# 77/77 [==============================] - 58s 753ms/step - loss: -0.7536 - dice_metric: 0.7628 - jaccard_metric: 0.7068 - sensitivity_metric: 0.7997 - specificity_metric: 0.9522 - precision_metric: 0.7655 - recall_metric: 0.7997 - mean_average_precision: 0.6147 - val_loss: -0.6849 - val_dice_metric: 0.6847 - val_jaccard_metric: 0.6261 - val_sensitivity_metric: 0.7320 - val_specificity_metric: 0.9379 - val_precision_metric: 0.7077 - val_recall_metric: 0.7320 - val_mean_average_precision: 0.5274
# Epoch 51/60
# 77/77 [==============================] - 55s 716ms/step - loss: -0.7544 - dice_metric: 0.7636 - jaccard_metric: 0.7076 - sensitivity_metric: 0.8005 - specificity_metric: 0.9525 - precision_metric: 0.7661 - recall_metric: 0.8005 - mean_average_precision: 0.6158 - val_loss: -0.6848 - val_dice_metric: 0.6846 - val_jaccard_metric: 0.6259 - val_sensitivity_metric: 0.7319 - val_specificity_metric: 0.9378 - val_precision_metric: 0.7075 - val_recall_metric: 0.7319 - val_mean_average_precision: 0.5274
# Epoch 52/60
# 77/77 [==============================] - 55s 709ms/step - loss: -0.7553 - dice_metric: 0.7644 - jaccard_metric: 0.7084 - sensitivity_metric: 0.8013 - specificity_metric: 0.9527 - precision_metric: 0.7667 - recall_metric: 0.8013 - mean_average_precision: 0.6163 - val_loss: -0.6854 - val_dice_metric: 0.6851 - val_jaccard_metric: 0.6266 - val_sensitivity_metric: 0.7324 - val_specificity_metric: 0.9383 - val_precision_metric: 0.7076 - val_recall_metric: 0.7324 - val_mean_average_precision: 0.5275
# Epoch 53/60
# 77/77 [==============================] - 53s 692ms/step - loss: -0.7562 - dice_metric: 0.7652 - jaccard_metric: 0.7093 - sensitivity_metric: 0.8021 - specificity_metric: 0.9530 - precision_metric: 0.7674 - recall_metric: 0.8021 - mean_average_precision: 0.6173 - val_loss: -0.6858 - val_dice_metric: 0.6855 - val_jaccard_metric: 0.6271 - val_sensitivity_metric: 0.7326 - val_specificity_metric: 0.9386 - val_precision_metric: 0.7078 - val_recall_metric: 0.7326 - val_mean_average_precision: 0.5292
# Epoch 54/60
# 77/77 [==============================] - 55s 715ms/step - loss: -0.7571 - dice_metric: 0.7661 - jaccard_metric: 0.7101 - sensitivity_metric: 0.8029 - specificity_metric: 0.9533 - precision_metric: 0.7681 - recall_metric: 0.8029 - mean_average_precision: 0.6179 - val_loss: -0.6861 - val_dice_metric: 0.6858 - val_jaccard_metric: 0.6274 - val_sensitivity_metric: 0.7328 - val_specificity_metric: 0.9388 - val_precision_metric: 0.7078 - val_recall_metric: 0.7328 - val_mean_average_precision: 0.5290
# Epoch 55/60
# 77/77 [==============================] - 55s 715ms/step - loss: -0.7580 - dice_metric: 0.7670 - jaccard_metric: 0.7110 - sensitivity_metric: 0.8037 - specificity_metric: 0.9535 - precision_metric: 0.7688 - recall_metric: 0.8037 - mean_average_precision: 0.6190 - val_loss: -0.6864 - val_dice_metric: 0.6861 - val_jaccard_metric: 0.6278 - val_sensitivity_metric: 0.7330 - val_specificity_metric: 0.9391 - val_precision_metric: 0.7080 - val_recall_metric: 0.7330 - val_mean_average_precision: 0.5288
# Epoch 56/60
# 77/77 [==============================] - 58s 744ms/step - loss: -0.7589 - dice_metric: 0.7679 - jaccard_metric: 0.7119 - sensitivity_metric: 0.8044 - specificity_metric: 0.9538 - precision_metric: 0.7695 - recall_metric: 0.8044 - mean_average_precision: 0.6201 - val_loss: -0.6867 - val_dice_metric: 0.6863 - val_jaccard_metric: 0.6281 - val_sensitivity_metric: 0.7331 - val_specificity_metric: 0.9395 - val_precision_metric: 0.7077 - val_recall_metric: 0.7331 - val_mean_average_precision: 0.5296
# Epoch 57/60
# 77/77 [==============================] - 56s 727ms/step - loss: -0.7597 - dice_metric: 0.7687 - jaccard_metric: 0.7127 - sensitivity_metric: 0.8052 - specificity_metric: 0.9540 - precision_metric: 0.7702 - recall_metric: 0.8052 - mean_average_precision: 0.6208 - val_loss: -0.6868 - val_dice_metric: 0.6863 - val_jaccard_metric: 0.6281 - val_sensitivity_metric: 0.7330 - val_specificity_metric: 0.9395 - val_precision_metric: 0.7077 - val_recall_metric: 0.7330 - val_mean_average_precision: 0.5296
# Epoch 58/60
# 77/77 [==============================] - 55s 713ms/step - loss: -0.7606 - dice_metric: 0.7694 - jaccard_metric: 0.7134 - sensitivity_metric: 0.8059 - specificity_metric: 0.9542 - precision_metric: 0.7708 - recall_metric: 0.8059 - mean_average_precision: 0.6214 - val_loss: -0.6870 - val_dice_metric: 0.6865 - val_jaccard_metric: 0.6284 - val_sensitivity_metric: 0.7331 - val_specificity_metric: 0.9397 - val_precision_metric: 0.7077 - val_recall_metric: 0.7331 - val_mean_average_precision: 0.5306
# Epoch 59/60
# 77/77 [==============================] - 57s 732ms/step - loss: -0.7614 - dice_metric: 0.7701 - jaccard_metric: 0.7141 - sensitivity_metric: 0.8066 - specificity_metric: 0.9545 - precision_metric: 0.7714 - recall_metric: 0.8066 - mean_average_precision: 0.6221 - val_loss: -0.6873 - val_dice_metric: 0.6868 - val_jaccard_metric: 0.6286 - val_sensitivity_metric: 0.7329 - val_specificity_metric: 0.9401 - val_precision_metric: 0.7077 - val_recall_metric: 0.7329 - val_mean_average_precision: 0.5312
# Epoch 60/60
# 77/77 [==============================] - 58s 745ms/step - loss: -0.7622 - dice_metric: 0.7709 - jaccard_metric: 0.7149 - sensitivity_metric: 0.8073 - specificity_metric: 0.9547 - precision_metric: 0.7721 - recall_metric: 0.8073 - mean_average_precision: 0.6231 - val_loss: -0.6879 - val_dice_metric: 0.6874 - val_jaccard_metric: 0.6294 - val_sensitivity_metric: 0.7334 - val_specificity_metric: 0.9405 - val_precision_metric: 0.7080 - val_recall_metric: 0.7334 - val_mean_average_precision: 0.5322

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.69838, std: 0.36775
# Jaccard Index mean: 0.63728, std: 0.35987
# Sensitivity mean: 0.76532, std: 0.31896
# Specificity mean: 0.94403, std: 0.07964
# Precision mean: 0.71174, std: 0.39150
# Recall mean: 0.76532, std: 0.31896
# mAP@50 mean: 0.71469, std: 0.14572
# mAP@50-95 mean: 0.53446, std: 0.13529
