# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|███████████████████████████████████████▊| 996M/0.98G [00:09<00:00, 170MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:09<00:00, 105MB/s]

# %%
config = {"Seg_model":"MobV2ResUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import res_unet_mobilenetv2
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP

@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = res_unet_mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 96s 804ms/step - loss: -0.1912 - dice_metric: 0.0894 - jaccard_metric: 0.0499 - sensitivity_metric: 0.1273 - specificity_metric: 0.9144 - precision_metric: 0.3510 - recall_metric: 0.1273 - mean_average_precision: 0.0000e+00 - val_loss: -0.2062 - val_dice_metric: 0.2071 - val_jaccard_metric: 0.1245 - val_sensitivity_metric: 0.2723 - val_specificity_metric: 0.8837 - val_precision_metric: 0.3792 - val_recall_metric: 0.2723 - val_mean_average_precision: 0.0000e+00
# Epoch 2/60
# 77/77 [==============================] - 59s 759ms/step - loss: -0.2160 - dice_metric: 0.1912 - jaccard_metric: 0.1281 - sensitivity_metric: 0.2497 - specificity_metric: 0.9253 - precision_metric: 0.4091 - recall_metric: 0.2497 - mean_average_precision: 0.0072 - val_loss: -0.2173 - val_dice_metric: 0.1981 - val_jaccard_metric: 0.1362 - val_sensitivity_metric: 0.2839 - val_specificity_metric: 0.9416 - val_precision_metric: 0.4253 - val_recall_metric: 0.2839 - val_mean_average_precision: 0.0109
# Epoch 3/60
# 77/77 [==============================] - 58s 751ms/step - loss: -0.2356 - dice_metric: 0.2671 - jaccard_metric: 0.1865 - sensitivity_metric: 0.3179 - specificity_metric: 0.9431 - precision_metric: 0.4763 - recall_metric: 0.3179 - mean_average_precision: 0.0294 - val_loss: -0.2407 - val_dice_metric: 0.2637 - val_jaccard_metric: 0.1926 - val_sensitivity_metric: 0.3036 - val_specificity_metric: 0.9520 - val_precision_metric: 0.5005 - val_recall_metric: 0.3036 - val_mean_average_precision: 0.0562
# Epoch 4/60
# 77/77 [==============================] - 57s 730ms/step - loss: -0.2571 - dice_metric: 0.3686 - jaccard_metric: 0.2637 - sensitivity_metric: 0.3891 - specificity_metric: 0.9382 - precision_metric: 0.5075 - recall_metric: 0.3891 - mean_average_precision: 0.0415 - val_loss: -0.2748 - val_dice_metric: 0.4131 - val_jaccard_metric: 0.3049 - val_sensitivity_metric: 0.4103 - val_specificity_metric: 0.9489 - val_precision_metric: 0.5313 - val_recall_metric: 0.4103 - val_mean_average_precision: 0.0605
# Epoch 5/60
# 77/77 [==============================] - 56s 727ms/step - loss: -0.2844 - dice_metric: 0.4482 - jaccard_metric: 0.3403 - sensitivity_metric: 0.4469 - specificity_metric: 0.9439 - precision_metric: 0.5358 - recall_metric: 0.4469 - mean_average_precision: 0.0821 - val_loss: -0.3067 - val_dice_metric: 0.4986 - val_jaccard_metric: 0.4023 - val_sensitivity_metric: 0.4947 - val_specificity_metric: 0.9606 - val_precision_metric: 0.5561 - val_recall_metric: 0.4947 - val_mean_average_precision: 0.1885
# Epoch 6/60
# 77/77 [==============================] - 60s 769ms/step - loss: -0.3151 - dice_metric: 0.5158 - jaccard_metric: 0.4125 - sensitivity_metric: 0.5224 - specificity_metric: 0.9806 - precision_metric: 0.5850 - recall_metric: 0.5224 - mean_average_precision: 0.1806 - val_loss: -0.3376 - val_dice_metric: 0.5333 - val_jaccard_metric: 0.4453 - val_sensitivity_metric: 0.5399 - val_specificity_metric: 0.9866 - val_precision_metric: 0.5933 - val_recall_metric: 0.5399 - val_mean_average_precision: 0.2624
# Epoch 7/60
# 77/77 [==============================] - 58s 747ms/step - loss: -0.3426 - dice_metric: 0.5449 - jaccard_metric: 0.4372 - sensitivity_metric: 0.5549 - specificity_metric: 0.9867 - precision_metric: 0.6031 - recall_metric: 0.5549 - mean_average_precision: 0.2033 - val_loss: -0.3610 - val_dice_metric: 0.5696 - val_jaccard_metric: 0.4815 - val_sensitivity_metric: 0.5545 - val_specificity_metric: 0.9869 - val_precision_metric: 0.6466 - val_recall_metric: 0.5545 - val_mean_average_precision: 0.3066
# Epoch 8/60
# 77/77 [==============================] - 60s 769ms/step - loss: -0.3684 - dice_metric: 0.5989 - jaccard_metric: 0.4959 - sensitivity_metric: 0.6329 - specificity_metric: 0.9865 - precision_metric: 0.6233 - recall_metric: 0.6329 - mean_average_precision: 0.2799 - val_loss: -0.3815 - val_dice_metric: 0.6245 - val_jaccard_metric: 0.5528 - val_sensitivity_metric: 0.6273 - val_specificity_metric: 0.9869 - val_precision_metric: 0.6647 - val_recall_metric: 0.6273 - val_mean_average_precision: 0.4302
# Epoch 9/60
# 77/77 [==============================] - 59s 755ms/step - loss: -0.3939 - dice_metric: 0.6412 - jaccard_metric: 0.5487 - sensitivity_metric: 0.6823 - specificity_metric: 0.9861 - precision_metric: 0.6435 - recall_metric: 0.6823 - mean_average_precision: 0.3665 - val_loss: -0.4081 - val_dice_metric: 0.6910 - val_jaccard_metric: 0.6193 - val_sensitivity_metric: 0.7101 - val_specificity_metric: 0.9885 - val_precision_metric: 0.6918 - val_recall_metric: 0.7101 - val_mean_average_precision: 0.4887
# Epoch 10/60
# 77/77 [==============================] - 57s 738ms/step - loss: -0.4185 - dice_metric: 0.6773 - jaccard_metric: 0.5992 - sensitivity_metric: 0.7268 - specificity_metric: 0.9848 - precision_metric: 0.6598 - recall_metric: 0.7268 - mean_average_precision: 0.4561 - val_loss: -0.4311 - val_dice_metric: 0.7068 - val_jaccard_metric: 0.6464 - val_sensitivity_metric: 0.7550 - val_specificity_metric: 0.9893 - val_precision_metric: 0.6840 - val_recall_metric: 0.7550 - val_mean_average_precision: 0.5418
# Epoch 11/60
# 77/77 [==============================] - 60s 777ms/step - loss: -0.4423 - dice_metric: 0.6992 - jaccard_metric: 0.6321 - sensitivity_metric: 0.7548 - specificity_metric: 0.9836 - precision_metric: 0.6717 - recall_metric: 0.7548 - mean_average_precision: 0.5122 - val_loss: -0.4544 - val_dice_metric: 0.7148 - val_jaccard_metric: 0.6590 - val_sensitivity_metric: 0.7584 - val_specificity_metric: 0.9874 - val_precision_metric: 0.6921 - val_recall_metric: 0.7584 - val_mean_average_precision: 0.5585
# Epoch 12/60
# 77/77 [==============================] - 59s 763ms/step - loss: -0.4653 - dice_metric: 0.7073 - jaccard_metric: 0.6420 - sensitivity_metric: 0.7600 - specificity_metric: 0.9827 - precision_metric: 0.6811 - recall_metric: 0.7600 - mean_average_precision: 0.5233 - val_loss: -0.4741 - val_dice_metric: 0.7175 - val_jaccard_metric: 0.6629 - val_sensitivity_metric: 0.7633 - val_specificity_metric: 0.9879 - val_precision_metric: 0.6945 - val_recall_metric: 0.7633 - val_mean_average_precision: 0.5639
# Epoch 13/60
# 77/77 [==============================] - 58s 745ms/step - loss: -0.4874 - dice_metric: 0.7130 - jaccard_metric: 0.6489 - sensitivity_metric: 0.7625 - specificity_metric: 0.9817 - precision_metric: 0.6887 - recall_metric: 0.7625 - mean_average_precision: 0.5316 - val_loss: -0.4943 - val_dice_metric: 0.7241 - val_jaccard_metric: 0.6716 - val_sensitivity_metric: 0.7635 - val_specificity_metric: 0.9867 - val_precision_metric: 0.7036 - val_recall_metric: 0.7635 - val_mean_average_precision: 0.5747
# Epoch 14/60
# 77/77 [==============================] - 58s 753ms/step - loss: -0.5095 - dice_metric: 0.7209 - jaccard_metric: 0.6579 - sensitivity_metric: 0.7668 - specificity_metric: 0.9809 - precision_metric: 0.6977 - recall_metric: 0.7668 - mean_average_precision: 0.5421 - val_loss: -0.5128 - val_dice_metric: 0.7238 - val_jaccard_metric: 0.6712 - val_sensitivity_metric: 0.7687 - val_specificity_metric: 0.9876 - val_precision_metric: 0.7009 - val_recall_metric: 0.7687 - val_mean_average_precision: 0.5737
# Epoch 15/60
# 77/77 [==============================] - 62s 797ms/step - loss: -0.5298 - dice_metric: 0.7249 - jaccard_metric: 0.6627 - sensitivity_metric: 0.7671 - specificity_metric: 0.9797 - precision_metric: 0.7045 - recall_metric: 0.7671 - mean_average_precision: 0.5477 - val_loss: -0.5299 - val_dice_metric: 0.7277 - val_jaccard_metric: 0.6770 - val_sensitivity_metric: 0.7634 - val_specificity_metric: 0.9860 - val_precision_metric: 0.7111 - val_recall_metric: 0.7634 - val_mean_average_precision: 0.5840
# Epoch 16/60
# 77/77 [==============================] - 58s 754ms/step - loss: -0.5501 - dice_metric: 0.7298 - jaccard_metric: 0.6686 - sensitivity_metric: 0.7680 - specificity_metric: 0.9784 - precision_metric: 0.7116 - recall_metric: 0.7680 - mean_average_precision: 0.5553 - val_loss: -0.5494 - val_dice_metric: 0.7369 - val_jaccard_metric: 0.6878 - val_sensitivity_metric: 0.7635 - val_specificity_metric: 0.9834 - val_precision_metric: 0.7253 - val_recall_metric: 0.7635 - val_mean_average_precision: 0.5978
# Epoch 17/60
# 77/77 [==============================] - 59s 761ms/step - loss: -0.5712 - dice_metric: 0.7369 - jaccard_metric: 0.6763 - sensitivity_metric: 0.7709 - specificity_metric: 0.9769 - precision_metric: 0.7210 - recall_metric: 0.7709 - mean_average_precision: 0.5645 - val_loss: -0.5661 - val_dice_metric: 0.7386 - val_jaccard_metric: 0.6892 - val_sensitivity_metric: 0.7597 - val_specificity_metric: 0.9817 - val_precision_metric: 0.7331 - val_recall_metric: 0.7597 - val_mean_average_precision: 0.5964
# Epoch 18/60
# 77/77 [==============================] - 58s 749ms/step - loss: -0.5926 - dice_metric: 0.7427 - jaccard_metric: 0.6832 - sensitivity_metric: 0.7722 - specificity_metric: 0.9752 - precision_metric: 0.7300 - recall_metric: 0.7722 - mean_average_precision: 0.5731 - val_loss: -0.5838 - val_dice_metric: 0.7376 - val_jaccard_metric: 0.6896 - val_sensitivity_metric: 0.7526 - val_specificity_metric: 0.9801 - val_precision_metric: 0.7347 - val_recall_metric: 0.7526 - val_mean_average_precision: 0.6016
# Epoch 19/60
# 77/77 [==============================] - 60s 772ms/step - loss: -0.6120 - dice_metric: 0.7473 - jaccard_metric: 0.6880 - sensitivity_metric: 0.7736 - specificity_metric: 0.9737 - precision_metric: 0.7370 - recall_metric: 0.7736 - mean_average_precision: 0.5790 - val_loss: -0.6071 - val_dice_metric: 0.7436 - val_jaccard_metric: 0.6954 - val_sensitivity_metric: 0.7606 - val_specificity_metric: 0.9798 - val_precision_metric: 0.7394 - val_recall_metric: 0.7606 - val_mean_average_precision: 0.6062
# Epoch 20/60
# 77/77 [==============================] - 60s 780ms/step - loss: -0.6294 - dice_metric: 0.7511 - jaccard_metric: 0.6922 - sensitivity_metric: 0.7745 - specificity_metric: 0.9723 - precision_metric: 0.7428 - recall_metric: 0.7745 - mean_average_precision: 0.5849 - val_loss: -0.6238 - val_dice_metric: 0.7398 - val_jaccard_metric: 0.6917 - val_sensitivity_metric: 0.7631 - val_specificity_metric: 0.9816 - val_precision_metric: 0.7321 - val_recall_metric: 0.7631 - val_mean_average_precision: 0.6045
# Epoch 21/60
# 77/77 [==============================] - 59s 761ms/step - loss: -0.6453 - dice_metric: 0.7553 - jaccard_metric: 0.6966 - sensitivity_metric: 0.7757 - specificity_metric: 0.9710 - precision_metric: 0.7484 - recall_metric: 0.7757 - mean_average_precision: 0.5896 - val_loss: -0.6409 - val_dice_metric: 0.7537 - val_jaccard_metric: 0.7067 - val_sensitivity_metric: 0.7650 - val_specificity_metric: 0.9801 - val_precision_metric: 0.7408 - val_recall_metric: 0.7650 - val_mean_average_precision: 0.6209
# Epoch 22/60
# 77/77 [==============================] - 59s 759ms/step - loss: -0.6590 - dice_metric: 0.7603 - jaccard_metric: 0.7016 - sensitivity_metric: 0.7761 - specificity_metric: 0.9699 - precision_metric: 0.7524 - recall_metric: 0.7761 - mean_average_precision: 0.5948 - val_loss: -0.6554 - val_dice_metric: 0.7784 - val_jaccard_metric: 0.7320 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9800 - val_precision_metric: 0.7436 - val_recall_metric: 0.7682 - val_mean_average_precision: 0.6475
# Epoch 23/60
# 77/77 [==============================] - 59s 762ms/step - loss: -0.6730 - dice_metric: 0.7697 - jaccard_metric: 0.7113 - sensitivity_metric: 0.7785 - specificity_metric: 0.9689 - precision_metric: 0.7583 - recall_metric: 0.7785 - mean_average_precision: 0.6055 - val_loss: -0.6665 - val_dice_metric: 0.8142 - val_jaccard_metric: 0.7682 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9803 - val_precision_metric: 0.7475 - val_recall_metric: 0.7688 - val_mean_average_precision: 0.6854
# Epoch 24/60
# 77/77 [==============================] - 60s 773ms/step - loss: -0.6836 - dice_metric: 0.7711 - jaccard_metric: 0.7126 - sensitivity_metric: 0.7784 - specificity_metric: 0.9681 - precision_metric: 0.7607 - recall_metric: 0.7784 - mean_average_precision: 0.6066 - val_loss: -0.6770 - val_dice_metric: 0.8118 - val_jaccard_metric: 0.7666 - val_sensitivity_metric: 0.7674 - val_specificity_metric: 0.9798 - val_precision_metric: 0.7522 - val_recall_metric: 0.7674 - val_mean_average_precision: 0.6853
# Epoch 25/60
# 77/77 [==============================] - 61s 793ms/step - loss: -0.6943 - dice_metric: 0.7763 - jaccard_metric: 0.7179 - sensitivity_metric: 0.7798 - specificity_metric: 0.9672 - precision_metric: 0.7644 - recall_metric: 0.7798 - mean_average_precision: 0.6126 - val_loss: -0.6852 - val_dice_metric: 0.8140 - val_jaccard_metric: 0.7675 - val_sensitivity_metric: 0.7653 - val_specificity_metric: 0.9784 - val_precision_metric: 0.7507 - val_recall_metric: 0.7653 - val_mean_average_precision: 0.6825
# Epoch 26/60
# 77/77 [==============================] - 60s 770ms/step - loss: -0.7047 - dice_metric: 0.7777 - jaccard_metric: 0.7195 - sensitivity_metric: 0.7824 - specificity_metric: 0.9665 - precision_metric: 0.7687 - recall_metric: 0.7824 - mean_average_precision: 0.6148 - val_loss: -0.6947 - val_dice_metric: 0.7857 - val_jaccard_metric: 0.7386 - val_sensitivity_metric: 0.7692 - val_specificity_metric: 0.9792 - val_precision_metric: 0.7487 - val_recall_metric: 0.7692 - val_mean_average_precision: 0.6525
# Epoch 27/60
# 77/77 [==============================] - 56s 726ms/step - loss: -0.7127 - dice_metric: 0.7786 - jaccard_metric: 0.7201 - sensitivity_metric: 0.7830 - specificity_metric: 0.9658 - precision_metric: 0.7710 - recall_metric: 0.7830 - mean_average_precision: 0.6150 - val_loss: -0.7012 - val_dice_metric: 0.8006 - val_jaccard_metric: 0.7556 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9778 - val_precision_metric: 0.7573 - val_recall_metric: 0.7682 - val_mean_average_precision: 0.6761
# Epoch 28/60
# 77/77 [==============================] - 59s 764ms/step - loss: -0.7201 - dice_metric: 0.7800 - jaccard_metric: 0.7214 - sensitivity_metric: 0.7845 - specificity_metric: 0.9653 - precision_metric: 0.7742 - recall_metric: 0.7845 - mean_average_precision: 0.6159 - val_loss: -0.7075 - val_dice_metric: 0.7939 - val_jaccard_metric: 0.7469 - val_sensitivity_metric: 0.7716 - val_specificity_metric: 0.9789 - val_precision_metric: 0.7537 - val_recall_metric: 0.7716 - val_mean_average_precision: 0.6606
# Epoch 29/60
# 77/77 [==============================] - 60s 778ms/step - loss: -0.7275 - dice_metric: 0.7841 - jaccard_metric: 0.7254 - sensitivity_metric: 0.7868 - specificity_metric: 0.9648 - precision_metric: 0.7775 - recall_metric: 0.7868 - mean_average_precision: 0.6200 - val_loss: -0.7133 - val_dice_metric: 0.7869 - val_jaccard_metric: 0.7396 - val_sensitivity_metric: 0.7707 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7570 - val_recall_metric: 0.7707 - val_mean_average_precision: 0.6517
# Epoch 30/60
# 77/77 [==============================] - 58s 751ms/step - loss: -0.7338 - dice_metric: 0.7906 - jaccard_metric: 0.7321 - sensitivity_metric: 0.7882 - specificity_metric: 0.9644 - precision_metric: 0.7798 - recall_metric: 0.7882 - mean_average_precision: 0.6276 - val_loss: -0.7171 - val_dice_metric: 0.7889 - val_jaccard_metric: 0.7413 - val_sensitivity_metric: 0.7700 - val_specificity_metric: 0.9771 - val_precision_metric: 0.7570 - val_recall_metric: 0.7700 - val_mean_average_precision: 0.6535
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 57s 740ms/step - loss: -0.7395 - dice_metric: 0.7965 - jaccard_metric: 0.7385 - sensitivity_metric: 0.7920 - specificity_metric: 0.9649 - precision_metric: 0.7837 - recall_metric: 0.7920 - mean_average_precision: 0.6349 - val_loss: -0.7215 - val_dice_metric: 0.8036 - val_jaccard_metric: 0.7582 - val_sensitivity_metric: 0.7709 - val_specificity_metric: 0.9769 - val_precision_metric: 0.7640 - val_recall_metric: 0.7709 - val_mean_average_precision: 0.6770
# Epoch 32/60
# 77/77 [==============================] - 58s 753ms/step - loss: -0.7410 - dice_metric: 0.7978 - jaccard_metric: 0.7403 - sensitivity_metric: 0.7925 - specificity_metric: 0.9646 - precision_metric: 0.7856 - recall_metric: 0.7925 - mean_average_precision: 0.6385 - val_loss: -0.7223 - val_dice_metric: 0.7970 - val_jaccard_metric: 0.7511 - val_sensitivity_metric: 0.7712 - val_specificity_metric: 0.9773 - val_precision_metric: 0.7611 - val_recall_metric: 0.7712 - val_mean_average_precision: 0.6683
# Epoch 33/60
# 77/77 [==============================] - 56s 726ms/step - loss: -0.7421 - dice_metric: 0.7990 - jaccard_metric: 0.7417 - sensitivity_metric: 0.7930 - specificity_metric: 0.9645 - precision_metric: 0.7862 - recall_metric: 0.7930 - mean_average_precision: 0.6402 - val_loss: -0.7231 - val_dice_metric: 0.8001 - val_jaccard_metric: 0.7544 - val_sensitivity_metric: 0.7715 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7613 - val_recall_metric: 0.7715 - val_mean_average_precision: 0.6728
# Epoch 34/60
# 77/77 [==============================] - 61s 787ms/step - loss: -0.7430 - dice_metric: 0.7994 - jaccard_metric: 0.7421 - sensitivity_metric: 0.7935 - specificity_metric: 0.9645 - precision_metric: 0.7870 - recall_metric: 0.7935 - mean_average_precision: 0.6405 - val_loss: -0.7237 - val_dice_metric: 0.8050 - val_jaccard_metric: 0.7598 - val_sensitivity_metric: 0.7722 - val_specificity_metric: 0.9775 - val_precision_metric: 0.7622 - val_recall_metric: 0.7722 - val_mean_average_precision: 0.6794
# Epoch 35/60
# 77/77 [==============================] - 58s 748ms/step - loss: -0.7437 - dice_metric: 0.8004 - jaccard_metric: 0.7432 - sensitivity_metric: 0.7934 - specificity_metric: 0.9644 - precision_metric: 0.7874 - recall_metric: 0.7934 - mean_average_precision: 0.6417 - val_loss: -0.7244 - val_dice_metric: 0.8039 - val_jaccard_metric: 0.7588 - val_sensitivity_metric: 0.7723 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7623 - val_recall_metric: 0.7723 - val_mean_average_precision: 0.6789
# Epoch 36/60
# 77/77 [==============================] - 59s 767ms/step - loss: -0.7445 - dice_metric: 0.8001 - jaccard_metric: 0.7430 - sensitivity_metric: 0.7939 - specificity_metric: 0.9644 - precision_metric: 0.7878 - recall_metric: 0.7939 - mean_average_precision: 0.6419 - val_loss: -0.7250 - val_dice_metric: 0.8040 - val_jaccard_metric: 0.7590 - val_sensitivity_metric: 0.7726 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7623 - val_recall_metric: 0.7726 - val_mean_average_precision: 0.6793
# Epoch 37/60
# 77/77 [==============================] - 61s 784ms/step - loss: -0.7453 - dice_metric: 0.8010 - jaccard_metric: 0.7440 - sensitivity_metric: 0.7944 - specificity_metric: 0.9644 - precision_metric: 0.7884 - recall_metric: 0.7944 - mean_average_precision: 0.6433 - val_loss: -0.7255 - val_dice_metric: 0.8042 - val_jaccard_metric: 0.7592 - val_sensitivity_metric: 0.7727 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7624 - val_recall_metric: 0.7727 - val_mean_average_precision: 0.6796
# Epoch 38/60
# 77/77 [==============================] - 59s 761ms/step - loss: -0.7458 - dice_metric: 0.8014 - jaccard_metric: 0.7443 - sensitivity_metric: 0.7944 - specificity_metric: 0.9643 - precision_metric: 0.7887 - recall_metric: 0.7944 - mean_average_precision: 0.6433 - val_loss: -0.7260 - val_dice_metric: 0.8018 - val_jaccard_metric: 0.7569 - val_sensitivity_metric: 0.7726 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7629 - val_recall_metric: 0.7726 - val_mean_average_precision: 0.6773
# Epoch 39/60
# 77/77 [==============================] - 56s 726ms/step - loss: -0.7464 - dice_metric: 0.8030 - jaccard_metric: 0.7461 - sensitivity_metric: 0.7944 - specificity_metric: 0.9643 - precision_metric: 0.7886 - recall_metric: 0.7944 - mean_average_precision: 0.6455 - val_loss: -0.7264 - val_dice_metric: 0.8017 - val_jaccard_metric: 0.7569 - val_sensitivity_metric: 0.7726 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7628 - val_recall_metric: 0.7726 - val_mean_average_precision: 0.6777
# Epoch 40/60
# 77/77 [==============================] - 60s 772ms/step - loss: -0.7472 - dice_metric: 0.8031 - jaccard_metric: 0.7462 - sensitivity_metric: 0.7946 - specificity_metric: 0.9643 - precision_metric: 0.7892 - recall_metric: 0.7946 - mean_average_precision: 0.6461 - val_loss: -0.7270 - val_dice_metric: 0.8016 - val_jaccard_metric: 0.7569 - val_sensitivity_metric: 0.7720 - val_specificity_metric: 0.9771 - val_precision_metric: 0.7632 - val_recall_metric: 0.7720 - val_mean_average_precision: 0.6769
# Epoch 41/60
# 77/77 [==============================] - 56s 719ms/step - loss: -0.7480 - dice_metric: 0.8050 - jaccard_metric: 0.7481 - sensitivity_metric: 0.7950 - specificity_metric: 0.9642 - precision_metric: 0.7899 - recall_metric: 0.7950 - mean_average_precision: 0.6476 - val_loss: -0.7274 - val_dice_metric: 0.8031 - val_jaccard_metric: 0.7583 - val_sensitivity_metric: 0.7720 - val_specificity_metric: 0.9771 - val_precision_metric: 0.7638 - val_recall_metric: 0.7720 - val_mean_average_precision: 0.6784
# Epoch 42/60
# 77/77 [==============================] - 57s 732ms/step - loss: -0.7485 - dice_metric: 0.8014 - jaccard_metric: 0.7445 - sensitivity_metric: 0.7948 - specificity_metric: 0.9641 - precision_metric: 0.7901 - recall_metric: 0.7948 - mean_average_precision: 0.6442 - val_loss: -0.7279 - val_dice_metric: 0.8031 - val_jaccard_metric: 0.7584 - val_sensitivity_metric: 0.7725 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7635 - val_recall_metric: 0.7725 - val_mean_average_precision: 0.6786
# Epoch 43/60
# 77/77 [==============================] - 55s 715ms/step - loss: -0.7491 - dice_metric: 0.8044 - jaccard_metric: 0.7475 - sensitivity_metric: 0.7954 - specificity_metric: 0.9642 - precision_metric: 0.7900 - recall_metric: 0.7954 - mean_average_precision: 0.6471 - val_loss: -0.7285 - val_dice_metric: 0.8057 - val_jaccard_metric: 0.7611 - val_sensitivity_metric: 0.7727 - val_specificity_metric: 0.9774 - val_precision_metric: 0.7631 - val_recall_metric: 0.7727 - val_mean_average_precision: 0.6817
# Epoch 44/60
# 77/77 [==============================] - 53s 684ms/step - loss: -0.7498 - dice_metric: 0.8035 - jaccard_metric: 0.7467 - sensitivity_metric: 0.7956 - specificity_metric: 0.9643 - precision_metric: 0.7902 - recall_metric: 0.7956 - mean_average_precision: 0.6465 - val_loss: -0.7287 - val_dice_metric: 0.8056 - val_jaccard_metric: 0.7611 - val_sensitivity_metric: 0.7724 - val_specificity_metric: 0.9773 - val_precision_metric: 0.7633 - val_recall_metric: 0.7724 - val_mean_average_precision: 0.6825
# Epoch 45/60
# 77/77 [==============================] - 54s 701ms/step - loss: -0.7503 - dice_metric: 0.8037 - jaccard_metric: 0.7469 - sensitivity_metric: 0.7954 - specificity_metric: 0.9641 - precision_metric: 0.7906 - recall_metric: 0.7954 - mean_average_precision: 0.6470 - val_loss: -0.7286 - val_dice_metric: 0.8063 - val_jaccard_metric: 0.7615 - val_sensitivity_metric: 0.7719 - val_specificity_metric: 0.9775 - val_precision_metric: 0.7626 - val_recall_metric: 0.7719 - val_mean_average_precision: 0.6811
# Epoch 46/60
# 77/77 [==============================] - 56s 723ms/step - loss: -0.7510 - dice_metric: 0.8051 - jaccard_metric: 0.7483 - sensitivity_metric: 0.7957 - specificity_metric: 0.9641 - precision_metric: 0.7908 - recall_metric: 0.7957 - mean_average_precision: 0.6483 - val_loss: -0.7296 - val_dice_metric: 0.8050 - val_jaccard_metric: 0.7602 - val_sensitivity_metric: 0.7719 - val_specificity_metric: 0.9773 - val_precision_metric: 0.7625 - val_recall_metric: 0.7719 - val_mean_average_precision: 0.6809
# Epoch 47/60
# 77/77 [==============================] - 57s 732ms/step - loss: -0.7515 - dice_metric: 0.8041 - jaccard_metric: 0.7473 - sensitivity_metric: 0.7956 - specificity_metric: 0.9640 - precision_metric: 0.7911 - recall_metric: 0.7956 - mean_average_precision: 0.6480 - val_loss: -0.7299 - val_dice_metric: 0.8041 - val_jaccard_metric: 0.7595 - val_sensitivity_metric: 0.7716 - val_specificity_metric: 0.9771 - val_precision_metric: 0.7632 - val_recall_metric: 0.7716 - val_mean_average_precision: 0.6808
# Epoch 48/60
# 77/77 [==============================] - 60s 771ms/step - loss: -0.7523 - dice_metric: 0.8049 - jaccard_metric: 0.7482 - sensitivity_metric: 0.7959 - specificity_metric: 0.9641 - precision_metric: 0.7915 - recall_metric: 0.7959 - mean_average_precision: 0.6487 - val_loss: -0.7304 - val_dice_metric: 0.8038 - val_jaccard_metric: 0.7592 - val_sensitivity_metric: 0.7718 - val_specificity_metric: 0.9773 - val_precision_metric: 0.7625 - val_recall_metric: 0.7718 - val_mean_average_precision: 0.6797
# Epoch 49/60
# 77/77 [==============================] - 58s 749ms/step - loss: -0.7528 - dice_metric: 0.8039 - jaccard_metric: 0.7472 - sensitivity_metric: 0.7960 - specificity_metric: 0.9640 - precision_metric: 0.7917 - recall_metric: 0.7960 - mean_average_precision: 0.6475 - val_loss: -0.7309 - val_dice_metric: 0.8055 - val_jaccard_metric: 0.7610 - val_sensitivity_metric: 0.7718 - val_specificity_metric: 0.9771 - val_precision_metric: 0.7632 - val_recall_metric: 0.7718 - val_mean_average_precision: 0.6821
# Epoch 50/60
# 77/77 [==============================] - 58s 749ms/step - loss: -0.7534 - dice_metric: 0.8047 - jaccard_metric: 0.7481 - sensitivity_metric: 0.7963 - specificity_metric: 0.9640 - precision_metric: 0.7920 - recall_metric: 0.7963 - mean_average_precision: 0.6487 - val_loss: -0.7314 - val_dice_metric: 0.8073 - val_jaccard_metric: 0.7630 - val_sensitivity_metric: 0.7718 - val_specificity_metric: 0.9770 - val_precision_metric: 0.7642 - val_recall_metric: 0.7718 - val_mean_average_precision: 0.6851
# Epoch 51/60
# 77/77 [==============================] - 59s 756ms/step - loss: -0.7539 - dice_metric: 0.8048 - jaccard_metric: 0.7482 - sensitivity_metric: 0.7961 - specificity_metric: 0.9639 - precision_metric: 0.7924 - recall_metric: 0.7961 - mean_average_precision: 0.6484 - val_loss: -0.7321 - val_dice_metric: 0.8046 - val_jaccard_metric: 0.7603 - val_sensitivity_metric: 0.7720 - val_specificity_metric: 0.9770 - val_precision_metric: 0.7639 - val_recall_metric: 0.7720 - val_mean_average_precision: 0.6823
# Epoch 52/60
# 77/77 [==============================] - 60s 781ms/step - loss: -0.7545 - dice_metric: 0.8058 - jaccard_metric: 0.7492 - sensitivity_metric: 0.7964 - specificity_metric: 0.9639 - precision_metric: 0.7925 - recall_metric: 0.7964 - mean_average_precision: 0.6497 - val_loss: -0.7325 - val_dice_metric: 0.8073 - val_jaccard_metric: 0.7630 - val_sensitivity_metric: 0.7724 - val_specificity_metric: 0.9772 - val_precision_metric: 0.7637 - val_recall_metric: 0.7724 - val_mean_average_precision: 0.6855
# Epoch 53/60
# 77/77 [==============================] - 59s 768ms/step - loss: -0.7553 - dice_metric: 0.8069 - jaccard_metric: 0.7504 - sensitivity_metric: 0.7969 - specificity_metric: 0.9640 - precision_metric: 0.7927 - recall_metric: 0.7969 - mean_average_precision: 0.6512 - val_loss: -0.7325 - val_dice_metric: 0.8056 - val_jaccard_metric: 0.7612 - val_sensitivity_metric: 0.7715 - val_specificity_metric: 0.9770 - val_precision_metric: 0.7638 - val_recall_metric: 0.7715 - val_mean_average_precision: 0.6820
# Epoch 54/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.7558 - dice_metric: 0.8064 - jaccard_metric: 0.7499 - sensitivity_metric: 0.7966 - specificity_metric: 0.9638 - precision_metric: 0.7929 - recall_metric: 0.7966 - mean_average_precision: 0.6506 - val_loss: -0.7331 - val_dice_metric: 0.8043 - val_jaccard_metric: 0.7599 - val_sensitivity_metric: 0.7717 - val_specificity_metric: 0.9769 - val_precision_metric: 0.7640 - val_recall_metric: 0.7717 - val_mean_average_precision: 0.6821
# Epoch 55/60
# 77/77 [==============================] - 60s 775ms/step - loss: -0.7564 - dice_metric: 0.8062 - jaccard_metric: 0.7498 - sensitivity_metric: 0.7969 - specificity_metric: 0.9639 - precision_metric: 0.7931 - recall_metric: 0.7969 - mean_average_precision: 0.6509 - val_loss: -0.7336 - val_dice_metric: 0.8057 - val_jaccard_metric: 0.7614 - val_sensitivity_metric: 0.7720 - val_specificity_metric: 0.9770 - val_precision_metric: 0.7636 - val_recall_metric: 0.7720 - val_mean_average_precision: 0.6837
# Epoch 56/60
# 77/77 [==============================] - 58s 742ms/step - loss: -0.7569 - dice_metric: 0.8078 - jaccard_metric: 0.7513 - sensitivity_metric: 0.7970 - specificity_metric: 0.9638 - precision_metric: 0.7934 - recall_metric: 0.7970 - mean_average_precision: 0.6519 - val_loss: -0.7341 - val_dice_metric: 0.8060 - val_jaccard_metric: 0.7617 - val_sensitivity_metric: 0.7722 - val_specificity_metric: 0.9770 - val_precision_metric: 0.7633 - val_recall_metric: 0.7722 - val_mean_average_precision: 0.6845
# Epoch 57/60
# 77/77 [==============================] - 61s 785ms/step - loss: -0.7575 - dice_metric: 0.8080 - jaccard_metric: 0.7516 - sensitivity_metric: 0.7969 - specificity_metric: 0.9637 - precision_metric: 0.7938 - recall_metric: 0.7969 - mean_average_precision: 0.6526 - val_loss: -0.7344 - val_dice_metric: 0.8057 - val_jaccard_metric: 0.7614 - val_sensitivity_metric: 0.7715 - val_specificity_metric: 0.9768 - val_precision_metric: 0.7637 - val_recall_metric: 0.7715 - val_mean_average_precision: 0.6834
# Epoch 58/60
# 77/77 [==============================] - 60s 769ms/step - loss: -0.7581 - dice_metric: 0.8074 - jaccard_metric: 0.7511 - sensitivity_metric: 0.7974 - specificity_metric: 0.9638 - precision_metric: 0.7939 - recall_metric: 0.7974 - mean_average_precision: 0.6521 - val_loss: -0.7346 - val_dice_metric: 0.8056 - val_jaccard_metric: 0.7612 - val_sensitivity_metric: 0.7714 - val_specificity_metric: 0.9768 - val_precision_metric: 0.7638 - val_recall_metric: 0.7714 - val_mean_average_precision: 0.6826
# Epoch 59/60
# 77/77 [==============================] - 61s 781ms/step - loss: -0.7586 - dice_metric: 0.8079 - jaccard_metric: 0.7514 - sensitivity_metric: 0.7975 - specificity_metric: 0.9637 - precision_metric: 0.7941 - recall_metric: 0.7975 - mean_average_precision: 0.6525 - val_loss: -0.7352 - val_dice_metric: 0.8043 - val_jaccard_metric: 0.7598 - val_sensitivity_metric: 0.7713 - val_specificity_metric: 0.9768 - val_precision_metric: 0.7641 - val_recall_metric: 0.7713 - val_mean_average_precision: 0.6819
# Epoch 60/60
# 77/77 [==============================] - 58s 745ms/step - loss: -0.7592 - dice_metric: 0.8083 - jaccard_metric: 0.7520 - sensitivity_metric: 0.7974 - specificity_metric: 0.9637 - precision_metric: 0.7944 - recall_metric: 0.7974 - mean_average_precision: 0.6533 - val_loss: -0.7356 - val_dice_metric: 0.8060 - val_jaccard_metric: 0.7617 - val_sensitivity_metric: 0.7716 - val_specificity_metric: 0.9768 - val_precision_metric: 0.7645 - val_recall_metric: 0.7716 - val_mean_average_precision: 0.6839

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.82117, std: 0.29827
# Jaccard Index mean: 0.77275, std: 0.30600
# Sensitivity mean: 0.80076, std: 0.33173
# Specificity mean: 0.97651, std: 0.04399
# Precision mean: 0.79614, std: 0.32603
# Recall mean: 0.80076, std: 0.33173
# mAP@50 mean: 0.86723, std: 0.16318
# mAP@50-95 mean: 0.68503, std: 0.15608
