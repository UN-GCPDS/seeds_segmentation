# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|███████████████████████████████████████▋| 991M/0.98G [00:07<00:00, 165MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:07<00:00, 139MB/s]

# %%
config = {"Seg_model":"VGG16","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import vgg16
from seeds_segmentation.losses import DiceCoefficient

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP

@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = vgg16(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 88s 909ms/step - loss: -0.2495 - dice_metric: 0.2976 - jaccard_metric: 0.2662 - sensitivity_metric: 0.3016 - specificity_metric: 0.6945 - precision_metric: 0.3329 - recall_metric: 0.3016 - mean_average_precision: 0.2139 - val_loss: -0.2976 - val_dice_metric: 0.3359 - val_jaccard_metric: 0.3234 - val_sensitivity_metric: 0.3407 - val_specificity_metric: 0.6746 - val_precision_metric: 0.3655 - val_recall_metric: 0.3407 - val_mean_average_precision: 0.3205
# Epoch 2/60
# 77/77 [==============================] - 60s 769ms/step - loss: -0.3213 - dice_metric: 0.3631 - jaccard_metric: 0.3278 - sensitivity_metric: 0.3774 - specificity_metric: 0.7137 - precision_metric: 0.3670 - recall_metric: 0.3774 - mean_average_precision: 0.2916 - val_loss: -0.3559 - val_dice_metric: 0.3959 - val_jaccard_metric: 0.3518 - val_sensitivity_metric: 0.4065 - val_specificity_metric: 0.7594 - val_precision_metric: 0.4065 - val_recall_metric: 0.4065 - val_mean_average_precision: 0.3046
# Epoch 3/60
# 77/77 [==============================] - 63s 810ms/step - loss: -0.3620 - dice_metric: 0.3963 - jaccard_metric: 0.3496 - sensitivity_metric: 0.4182 - specificity_metric: 0.7574 - precision_metric: 0.4023 - recall_metric: 0.4182 - mean_average_precision: 0.2965 - val_loss: -0.4033 - val_dice_metric: 0.4376 - val_jaccard_metric: 0.3843 - val_sensitivity_metric: 0.4434 - val_specificity_metric: 0.7929 - val_precision_metric: 0.4518 - val_recall_metric: 0.4434 - val_mean_average_precision: 0.3161
# Epoch 4/60
# 77/77 [==============================] - 61s 789ms/step - loss: -0.3921 - dice_metric: 0.4220 - jaccard_metric: 0.3679 - sensitivity_metric: 0.4490 - specificity_metric: 0.7900 - precision_metric: 0.4242 - recall_metric: 0.4490 - mean_average_precision: 0.3014 - val_loss: -0.4203 - val_dice_metric: 0.4487 - val_jaccard_metric: 0.3911 - val_sensitivity_metric: 0.4684 - val_specificity_metric: 0.8237 - val_precision_metric: 0.4547 - val_recall_metric: 0.4684 - val_mean_average_precision: 0.3118
# Epoch 5/60
# 77/77 [==============================] - 61s 784ms/step - loss: -0.4036 - dice_metric: 0.4307 - jaccard_metric: 0.3748 - sensitivity_metric: 0.4564 - specificity_metric: 0.7988 - precision_metric: 0.4351 - recall_metric: 0.4564 - mean_average_precision: 0.3054 - val_loss: -0.4289 - val_dice_metric: 0.4549 - val_jaccard_metric: 0.3952 - val_sensitivity_metric: 0.4793 - val_specificity_metric: 0.8400 - val_precision_metric: 0.4623 - val_recall_metric: 0.4793 - val_mean_average_precision: 0.3104
# Epoch 6/60
# 77/77 [==============================] - 63s 812ms/step - loss: -0.4170 - dice_metric: 0.4419 - jaccard_metric: 0.3838 - sensitivity_metric: 0.4628 - specificity_metric: 0.8127 - precision_metric: 0.4471 - recall_metric: 0.4628 - mean_average_precision: 0.3091 - val_loss: -0.4547 - val_dice_metric: 0.4838 - val_jaccard_metric: 0.4205 - val_sensitivity_metric: 0.5448 - val_specificity_metric: 0.9084 - val_precision_metric: 0.4705 - val_recall_metric: 0.5448 - val_mean_average_precision: 0.3221
# Epoch 7/60
# 77/77 [==============================] - 62s 803ms/step - loss: -0.4393 - dice_metric: 0.4650 - jaccard_metric: 0.4032 - sensitivity_metric: 0.4993 - specificity_metric: 0.8454 - precision_metric: 0.4612 - recall_metric: 0.4993 - mean_average_precision: 0.3168 - val_loss: -0.4803 - val_dice_metric: 0.5072 - val_jaccard_metric: 0.4435 - val_sensitivity_metric: 0.5378 - val_specificity_metric: 0.8908 - val_precision_metric: 0.5056 - val_recall_metric: 0.5378 - val_mean_average_precision: 0.3426
# Epoch 8/60
# 77/77 [==============================] - 64s 823ms/step - loss: -0.4713 - dice_metric: 0.4997 - jaccard_metric: 0.4332 - sensitivity_metric: 0.5307 - specificity_metric: 0.8440 - precision_metric: 0.5003 - recall_metric: 0.5307 - mean_average_precision: 0.3318 - val_loss: -0.5311 - val_dice_metric: 0.6104 - val_jaccard_metric: 0.5398 - val_sensitivity_metric: 0.6233 - val_specificity_metric: 0.9054 - val_precision_metric: 0.5411 - val_recall_metric: 0.6233 - val_mean_average_precision: 0.4181
# Epoch 9/60
# 77/77 [==============================] - 62s 806ms/step - loss: -0.5039 - dice_metric: 0.5477 - jaccard_metric: 0.4753 - sensitivity_metric: 0.5602 - specificity_metric: 0.8457 - precision_metric: 0.5331 - recall_metric: 0.5602 - mean_average_precision: 0.3562 - val_loss: -0.5554 - val_dice_metric: 0.7028 - val_jaccard_metric: 0.6342 - val_sensitivity_metric: 0.5734 - val_specificity_metric: 0.8550 - val_precision_metric: 0.6186 - val_recall_metric: 0.5734 - val_mean_average_precision: 0.5099
# Epoch 10/60
# 77/77 [==============================] - 62s 803ms/step - loss: -0.5190 - dice_metric: 0.5720 - jaccard_metric: 0.4980 - sensitivity_metric: 0.5710 - specificity_metric: 0.8485 - precision_metric: 0.5487 - recall_metric: 0.5710 - mean_average_precision: 0.3731 - val_loss: -0.5726 - val_dice_metric: 0.7074 - val_jaccard_metric: 0.6371 - val_sensitivity_metric: 0.6189 - val_specificity_metric: 0.8895 - val_precision_metric: 0.6049 - val_recall_metric: 0.6189 - val_mean_average_precision: 0.5049
# Epoch 11/60
# 77/77 [==============================] - 62s 797ms/step - loss: -0.5289 - dice_metric: 0.5779 - jaccard_metric: 0.5030 - sensitivity_metric: 0.5785 - specificity_metric: 0.8510 - precision_metric: 0.5594 - recall_metric: 0.5785 - mean_average_precision: 0.3752 - val_loss: -0.5795 - val_dice_metric: 0.7141 - val_jaccard_metric: 0.6432 - val_sensitivity_metric: 0.6371 - val_specificity_metric: 0.9024 - val_precision_metric: 0.5999 - val_recall_metric: 0.6371 - val_mean_average_precision: 0.5115
# Epoch 12/60
# 77/77 [==============================] - 63s 816ms/step - loss: -0.5376 - dice_metric: 0.5876 - jaccard_metric: 0.5118 - sensitivity_metric: 0.5845 - specificity_metric: 0.8534 - precision_metric: 0.5691 - recall_metric: 0.5845 - mean_average_precision: 0.3815 - val_loss: -0.5913 - val_dice_metric: 0.7027 - val_jaccard_metric: 0.6321 - val_sensitivity_metric: 0.6217 - val_specificity_metric: 0.8876 - val_precision_metric: 0.6313 - val_recall_metric: 0.6217 - val_mean_average_precision: 0.5001
# Epoch 13/60
# 77/77 [==============================] - 61s 787ms/step - loss: -0.5444 - dice_metric: 0.5959 - jaccard_metric: 0.5199 - sensitivity_metric: 0.5884 - specificity_metric: 0.8549 - precision_metric: 0.5773 - recall_metric: 0.5884 - mean_average_precision: 0.3886 - val_loss: -0.5962 - val_dice_metric: 0.6834 - val_jaccard_metric: 0.6117 - val_sensitivity_metric: 0.6307 - val_specificity_metric: 0.8955 - val_precision_metric: 0.6316 - val_recall_metric: 0.6307 - val_mean_average_precision: 0.4758
# Epoch 14/60
# 77/77 [==============================] - 62s 801ms/step - loss: -0.5509 - dice_metric: 0.5999 - jaccard_metric: 0.5234 - sensitivity_metric: 0.5931 - specificity_metric: 0.8567 - precision_metric: 0.5847 - recall_metric: 0.5931 - mean_average_precision: 0.3902 - val_loss: -0.6001 - val_dice_metric: 0.6430 - val_jaccard_metric: 0.5716 - val_sensitivity_metric: 0.6352 - val_specificity_metric: 0.8993 - val_precision_metric: 0.6340 - val_recall_metric: 0.6352 - val_mean_average_precision: 0.4334
# Epoch 15/60
# 77/77 [==============================] - 61s 786ms/step - loss: -0.5557 - dice_metric: 0.6044 - jaccard_metric: 0.5276 - sensitivity_metric: 0.5958 - specificity_metric: 0.8580 - precision_metric: 0.5913 - recall_metric: 0.5958 - mean_average_precision: 0.3931 - val_loss: -0.6047 - val_dice_metric: 0.7073 - val_jaccard_metric: 0.6362 - val_sensitivity_metric: 0.6531 - val_specificity_metric: 0.9107 - val_precision_metric: 0.6268 - val_recall_metric: 0.6531 - val_mean_average_precision: 0.4985
# Epoch 16/60
# 77/77 [==============================] - 62s 794ms/step - loss: -0.5596 - dice_metric: 0.6104 - jaccard_metric: 0.5334 - sensitivity_metric: 0.5988 - specificity_metric: 0.8588 - precision_metric: 0.5954 - recall_metric: 0.5988 - mean_average_precision: 0.3978 - val_loss: -0.6096 - val_dice_metric: 0.6636 - val_jaccard_metric: 0.5925 - val_sensitivity_metric: 0.6422 - val_specificity_metric: 0.9027 - val_precision_metric: 0.6422 - val_recall_metric: 0.6422 - val_mean_average_precision: 0.4534
# Epoch 17/60
# 77/77 [==============================] - 62s 803ms/step - loss: -0.5625 - dice_metric: 0.6148 - jaccard_metric: 0.5378 - sensitivity_metric: 0.6005 - specificity_metric: 0.8599 - precision_metric: 0.5990 - recall_metric: 0.6005 - mean_average_precision: 0.4016 - val_loss: -0.6142 - val_dice_metric: 0.7501 - val_jaccard_metric: 0.6807 - val_sensitivity_metric: 0.6393 - val_specificity_metric: 0.8994 - val_precision_metric: 0.6568 - val_recall_metric: 0.6393 - val_mean_average_precision: 0.5464
# Epoch 18/60
# 77/77 [==============================] - 61s 784ms/step - loss: -0.5639 - dice_metric: 0.6167 - jaccard_metric: 0.5400 - sensitivity_metric: 0.6012 - specificity_metric: 0.8613 - precision_metric: 0.6025 - recall_metric: 0.6012 - mean_average_precision: 0.4044 - val_loss: -0.6157 - val_dice_metric: 0.6592 - val_jaccard_metric: 0.5889 - val_sensitivity_metric: 0.6385 - val_specificity_metric: 0.8992 - val_precision_metric: 0.6583 - val_recall_metric: 0.6385 - val_mean_average_precision: 0.4512
# Epoch 19/60
# 77/77 [==============================] - 59s 758ms/step - loss: -0.5678 - dice_metric: 0.6210 - jaccard_metric: 0.5440 - sensitivity_metric: 0.6035 - specificity_metric: 0.8622 - precision_metric: 0.6068 - recall_metric: 0.6035 - mean_average_precision: 0.4067 - val_loss: -0.6182 - val_dice_metric: 0.7050 - val_jaccard_metric: 0.6357 - val_sensitivity_metric: 0.6431 - val_specificity_metric: 0.9040 - val_precision_metric: 0.6600 - val_recall_metric: 0.6431 - val_mean_average_precision: 0.4989
# Epoch 20/60
# 77/77 [==============================] - 61s 791ms/step - loss: -0.5727 - dice_metric: 0.6219 - jaccard_metric: 0.5446 - sensitivity_metric: 0.6064 - specificity_metric: 0.8630 - precision_metric: 0.6122 - recall_metric: 0.6064 - mean_average_precision: 0.4060 - val_loss: -0.6208 - val_dice_metric: 0.7335 - val_jaccard_metric: 0.6645 - val_sensitivity_metric: 0.6575 - val_specificity_metric: 0.9138 - val_precision_metric: 0.6521 - val_recall_metric: 0.6575 - val_mean_average_precision: 0.5318
# Epoch 21/60
# 77/77 [==============================] - 62s 796ms/step - loss: -0.5772 - dice_metric: 0.6282 - jaccard_metric: 0.5507 - sensitivity_metric: 0.6104 - specificity_metric: 0.8648 - precision_metric: 0.6163 - recall_metric: 0.6104 - mean_average_precision: 0.4109 - val_loss: -0.6223 - val_dice_metric: 0.7264 - val_jaccard_metric: 0.6569 - val_sensitivity_metric: 0.6640 - val_specificity_metric: 0.9183 - val_precision_metric: 0.6472 - val_recall_metric: 0.6640 - val_mean_average_precision: 0.5214
# Epoch 22/60
# 77/77 [==============================] - 60s 776ms/step - loss: -0.5794 - dice_metric: 0.6310 - jaccard_metric: 0.5533 - sensitivity_metric: 0.6121 - specificity_metric: 0.8655 - precision_metric: 0.6194 - recall_metric: 0.6121 - mean_average_precision: 0.4133 - val_loss: -0.6256 - val_dice_metric: 0.7110 - val_jaccard_metric: 0.6418 - val_sensitivity_metric: 0.6647 - val_specificity_metric: 0.9181 - val_precision_metric: 0.6509 - val_recall_metric: 0.6647 - val_mean_average_precision: 0.5064
# Epoch 23/60
# 77/77 [==============================] - 63s 818ms/step - loss: -0.5811 - dice_metric: 0.6289 - jaccard_metric: 0.5512 - sensitivity_metric: 0.6137 - specificity_metric: 0.8664 - precision_metric: 0.6210 - recall_metric: 0.6137 - mean_average_precision: 0.4100 - val_loss: -0.6245 - val_dice_metric: 0.7454 - val_jaccard_metric: 0.6774 - val_sensitivity_metric: 0.6467 - val_specificity_metric: 0.9060 - val_precision_metric: 0.6682 - val_recall_metric: 0.6467 - val_mean_average_precision: 0.5452
# Epoch 24/60
# 77/77 [==============================] - 64s 824ms/step - loss: -0.5826 - dice_metric: 0.6332 - jaccard_metric: 0.5555 - sensitivity_metric: 0.6149 - specificity_metric: 0.8671 - precision_metric: 0.6234 - recall_metric: 0.6149 - mean_average_precision: 0.4141 - val_loss: -0.6301 - val_dice_metric: 0.7509 - val_jaccard_metric: 0.6828 - val_sensitivity_metric: 0.6554 - val_specificity_metric: 0.9113 - val_precision_metric: 0.6698 - val_recall_metric: 0.6554 - val_mean_average_precision: 0.5494
# Epoch 25/60
# 77/77 [==============================] - 62s 798ms/step - loss: -0.5841 - dice_metric: 0.6373 - jaccard_metric: 0.5597 - sensitivity_metric: 0.6159 - specificity_metric: 0.8681 - precision_metric: 0.6257 - recall_metric: 0.6159 - mean_average_precision: 0.4181 - val_loss: -0.6284 - val_dice_metric: 0.7304 - val_jaccard_metric: 0.6614 - val_sensitivity_metric: 0.6612 - val_specificity_metric: 0.9171 - val_precision_metric: 0.6603 - val_recall_metric: 0.6612 - val_mean_average_precision: 0.5256
# Epoch 26/60
# 77/77 [==============================] - 60s 774ms/step - loss: -0.5859 - dice_metric: 0.6350 - jaccard_metric: 0.5574 - sensitivity_metric: 0.6168 - specificity_metric: 0.8688 - precision_metric: 0.6277 - recall_metric: 0.6168 - mean_average_precision: 0.4157 - val_loss: -0.6305 - val_dice_metric: 0.7283 - val_jaccard_metric: 0.6599 - val_sensitivity_metric: 0.6607 - val_specificity_metric: 0.9171 - val_precision_metric: 0.6651 - val_recall_metric: 0.6607 - val_mean_average_precision: 0.5261
# Epoch 27/60
# 77/77 [==============================] - 61s 787ms/step - loss: -0.5867 - dice_metric: 0.6366 - jaccard_metric: 0.5590 - sensitivity_metric: 0.6183 - specificity_metric: 0.8698 - precision_metric: 0.6282 - recall_metric: 0.6183 - mean_average_precision: 0.4175 - val_loss: -0.6336 - val_dice_metric: 0.6870 - val_jaccard_metric: 0.6183 - val_sensitivity_metric: 0.6619 - val_specificity_metric: 0.9155 - val_precision_metric: 0.6661 - val_recall_metric: 0.6619 - val_mean_average_precision: 0.4835
# Epoch 28/60
# 77/77 [==============================] - 61s 791ms/step - loss: -0.5907 - dice_metric: 0.6411 - jaccard_metric: 0.5633 - sensitivity_metric: 0.6213 - specificity_metric: 0.8705 - precision_metric: 0.6319 - recall_metric: 0.6213 - mean_average_precision: 0.4204 - val_loss: -0.6368 - val_dice_metric: 0.6930 - val_jaccard_metric: 0.6243 - val_sensitivity_metric: 0.6640 - val_specificity_metric: 0.9161 - val_precision_metric: 0.6715 - val_recall_metric: 0.6640 - val_mean_average_precision: 0.4900
# Epoch 29/60
# 77/77 [==============================] - 58s 748ms/step - loss: -0.5937 - dice_metric: 0.6410 - jaccard_metric: 0.5630 - sensitivity_metric: 0.6235 - specificity_metric: 0.8713 - precision_metric: 0.6353 - recall_metric: 0.6235 - mean_average_precision: 0.4194 - val_loss: -0.6398 - val_dice_metric: 0.7175 - val_jaccard_metric: 0.6498 - val_sensitivity_metric: 0.6587 - val_specificity_metric: 0.9111 - val_precision_metric: 0.6830 - val_recall_metric: 0.6587 - val_mean_average_precision: 0.5179
# Epoch 30/60
# 77/77 [==============================] - 60s 777ms/step - loss: -0.5969 - dice_metric: 0.6510 - jaccard_metric: 0.5727 - sensitivity_metric: 0.6263 - specificity_metric: 0.8725 - precision_metric: 0.6383 - recall_metric: 0.6263 - mean_average_precision: 0.4282 - val_loss: -0.6402 - val_dice_metric: 0.7274 - val_jaccard_metric: 0.6593 - val_sensitivity_metric: 0.6531 - val_specificity_metric: 0.9062 - val_precision_metric: 0.6921 - val_recall_metric: 0.6531 - val_mean_average_precision: 0.5251
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 61s 787ms/step - loss: -0.6029 - dice_metric: 0.6516 - jaccard_metric: 0.5731 - sensitivity_metric: 0.6293 - specificity_metric: 0.8728 - precision_metric: 0.6452 - recall_metric: 0.6293 - mean_average_precision: 0.4280 - val_loss: -0.6444 - val_dice_metric: 0.7465 - val_jaccard_metric: 0.6792 - val_sensitivity_metric: 0.6690 - val_specificity_metric: 0.9170 - val_precision_metric: 0.6806 - val_recall_metric: 0.6690 - val_mean_average_precision: 0.5491
# Epoch 32/60
# 77/77 [==============================] - 61s 788ms/step - loss: -0.6044 - dice_metric: 0.6546 - jaccard_metric: 0.5761 - sensitivity_metric: 0.6308 - specificity_metric: 0.8736 - precision_metric: 0.6462 - recall_metric: 0.6308 - mean_average_precision: 0.4308 - val_loss: -0.6452 - val_dice_metric: 0.7538 - val_jaccard_metric: 0.6866 - val_sensitivity_metric: 0.6704 - val_specificity_metric: 0.9178 - val_precision_metric: 0.6807 - val_recall_metric: 0.6704 - val_mean_average_precision: 0.5556
# Epoch 33/60
# 77/77 [==============================] - 60s 770ms/step - loss: -0.6051 - dice_metric: 0.6574 - jaccard_metric: 0.5789 - sensitivity_metric: 0.6314 - specificity_metric: 0.8740 - precision_metric: 0.6472 - recall_metric: 0.6314 - mean_average_precision: 0.4334 - val_loss: -0.6453 - val_dice_metric: 0.7458 - val_jaccard_metric: 0.6786 - val_sensitivity_metric: 0.6695 - val_specificity_metric: 0.9171 - val_precision_metric: 0.6815 - val_recall_metric: 0.6695 - val_mean_average_precision: 0.5474
# Epoch 34/60
# 77/77 [==============================] - 61s 787ms/step - loss: -0.6057 - dice_metric: 0.6577 - jaccard_metric: 0.5792 - sensitivity_metric: 0.6318 - specificity_metric: 0.8741 - precision_metric: 0.6479 - recall_metric: 0.6318 - mean_average_precision: 0.4336 - val_loss: -0.6465 - val_dice_metric: 0.7539 - val_jaccard_metric: 0.6869 - val_sensitivity_metric: 0.6691 - val_specificity_metric: 0.9166 - val_precision_metric: 0.6852 - val_recall_metric: 0.6691 - val_mean_average_precision: 0.5559
# Epoch 35/60
# 77/77 [==============================] - 59s 755ms/step - loss: -0.6061 - dice_metric: 0.6605 - jaccard_metric: 0.5819 - sensitivity_metric: 0.6319 - specificity_metric: 0.8739 - precision_metric: 0.6486 - recall_metric: 0.6319 - mean_average_precision: 0.4359 - val_loss: -0.6464 - val_dice_metric: 0.7538 - val_jaccard_metric: 0.6869 - val_sensitivity_metric: 0.6692 - val_specificity_metric: 0.9165 - val_precision_metric: 0.6848 - val_recall_metric: 0.6692 - val_mean_average_precision: 0.5557
# Epoch 36/60
# 77/77 [==============================] - 61s 788ms/step - loss: -0.6064 - dice_metric: 0.6611 - jaccard_metric: 0.5826 - sensitivity_metric: 0.6324 - specificity_metric: 0.8742 - precision_metric: 0.6487 - recall_metric: 0.6324 - mean_average_precision: 0.4368 - val_loss: -0.6470 - val_dice_metric: 0.7609 - val_jaccard_metric: 0.6940 - val_sensitivity_metric: 0.6696 - val_specificity_metric: 0.9169 - val_precision_metric: 0.6858 - val_recall_metric: 0.6696 - val_mean_average_precision: 0.5627
# Epoch 37/60
# 77/77 [==============================] - 63s 816ms/step - loss: -0.6067 - dice_metric: 0.6614 - jaccard_metric: 0.5829 - sensitivity_metric: 0.6325 - specificity_metric: 0.8744 - precision_metric: 0.6495 - recall_metric: 0.6325 - mean_average_precision: 0.4369 - val_loss: -0.6471 - val_dice_metric: 0.7558 - val_jaccard_metric: 0.6890 - val_sensitivity_metric: 0.6677 - val_specificity_metric: 0.9155 - val_precision_metric: 0.6879 - val_recall_metric: 0.6677 - val_mean_average_precision: 0.5583
# Epoch 38/60
# 77/77 [==============================] - 62s 799ms/step - loss: -0.6073 - dice_metric: 0.6620 - jaccard_metric: 0.5835 - sensitivity_metric: 0.6328 - specificity_metric: 0.8744 - precision_metric: 0.6501 - recall_metric: 0.6328 - mean_average_precision: 0.4375 - val_loss: -0.6474 - val_dice_metric: 0.7531 - val_jaccard_metric: 0.6863 - val_sensitivity_metric: 0.6689 - val_specificity_metric: 0.9163 - val_precision_metric: 0.6863 - val_recall_metric: 0.6689 - val_mean_average_precision: 0.5559
# Epoch 39/60
# 77/77 [==============================] - 60s 771ms/step - loss: -0.6074 - dice_metric: 0.6592 - jaccard_metric: 0.5807 - sensitivity_metric: 0.6325 - specificity_metric: 0.8743 - precision_metric: 0.6509 - recall_metric: 0.6325 - mean_average_precision: 0.4342 - val_loss: -0.6476 - val_dice_metric: 0.7575 - val_jaccard_metric: 0.6907 - val_sensitivity_metric: 0.6702 - val_specificity_metric: 0.9171 - val_precision_metric: 0.6861 - val_recall_metric: 0.6702 - val_mean_average_precision: 0.5603
# Epoch 40/60
# 77/77 [==============================] - 65s 844ms/step - loss: -0.6080 - dice_metric: 0.6618 - jaccard_metric: 0.5833 - sensitivity_metric: 0.6334 - specificity_metric: 0.8748 - precision_metric: 0.6506 - recall_metric: 0.6334 - mean_average_precision: 0.4370 - val_loss: -0.6479 - val_dice_metric: 0.7564 - val_jaccard_metric: 0.6896 - val_sensitivity_metric: 0.6692 - val_specificity_metric: 0.9163 - val_precision_metric: 0.6874 - val_recall_metric: 0.6692 - val_mean_average_precision: 0.5583
# Epoch 41/60
# 77/77 [==============================] - 60s 773ms/step - loss: -0.6081 - dice_metric: 0.6617 - jaccard_metric: 0.5832 - sensitivity_metric: 0.6331 - specificity_metric: 0.8744 - precision_metric: 0.6512 - recall_metric: 0.6331 - mean_average_precision: 0.4368 - val_loss: -0.6481 - val_dice_metric: 0.7615 - val_jaccard_metric: 0.6947 - val_sensitivity_metric: 0.6704 - val_specificity_metric: 0.9174 - val_precision_metric: 0.6861 - val_recall_metric: 0.6704 - val_mean_average_precision: 0.5644
# Epoch 42/60
# 77/77 [==============================] - 61s 782ms/step - loss: -0.6084 - dice_metric: 0.6617 - jaccard_metric: 0.5831 - sensitivity_metric: 0.6336 - specificity_metric: 0.8749 - precision_metric: 0.6514 - recall_metric: 0.6336 - mean_average_precision: 0.4363 - val_loss: -0.6485 - val_dice_metric: 0.7633 - val_jaccard_metric: 0.6967 - val_sensitivity_metric: 0.6673 - val_specificity_metric: 0.9148 - val_precision_metric: 0.6907 - val_recall_metric: 0.6673 - val_mean_average_precision: 0.5671
# Epoch 43/60
# 77/77 [==============================] - 63s 807ms/step - loss: -0.6091 - dice_metric: 0.6639 - jaccard_metric: 0.5854 - sensitivity_metric: 0.6341 - specificity_metric: 0.8749 - precision_metric: 0.6521 - recall_metric: 0.6341 - mean_average_precision: 0.4385 - val_loss: -0.6486 - val_dice_metric: 0.7582 - val_jaccard_metric: 0.6915 - val_sensitivity_metric: 0.6693 - val_specificity_metric: 0.9164 - val_precision_metric: 0.6884 - val_recall_metric: 0.6693 - val_mean_average_precision: 0.5620
# Epoch 44/60
# 77/77 [==============================] - 62s 802ms/step - loss: -0.6094 - dice_metric: 0.6631 - jaccard_metric: 0.5845 - sensitivity_metric: 0.6343 - specificity_metric: 0.8750 - precision_metric: 0.6524 - recall_metric: 0.6343 - mean_average_precision: 0.4380 - val_loss: -0.6489 - val_dice_metric: 0.7652 - val_jaccard_metric: 0.6987 - val_sensitivity_metric: 0.6703 - val_specificity_metric: 0.9169 - val_precision_metric: 0.6888 - val_recall_metric: 0.6703 - val_mean_average_precision: 0.5685
# Epoch 45/60
# 77/77 [==============================] - 62s 804ms/step - loss: -0.6095 - dice_metric: 0.6633 - jaccard_metric: 0.5847 - sensitivity_metric: 0.6346 - specificity_metric: 0.8751 - precision_metric: 0.6524 - recall_metric: 0.6346 - mean_average_precision: 0.4378 - val_loss: -0.6491 - val_dice_metric: 0.7612 - val_jaccard_metric: 0.6946 - val_sensitivity_metric: 0.6691 - val_specificity_metric: 0.9160 - val_precision_metric: 0.6898 - val_recall_metric: 0.6691 - val_mean_average_precision: 0.5638
# Epoch 46/60
# 77/77 [==============================] - 61s 784ms/step - loss: -0.6096 - dice_metric: 0.6627 - jaccard_metric: 0.5841 - sensitivity_metric: 0.6345 - specificity_metric: 0.8752 - precision_metric: 0.6525 - recall_metric: 0.6345 - mean_average_precision: 0.4372 - val_loss: -0.6490 - val_dice_metric: 0.7584 - val_jaccard_metric: 0.6918 - val_sensitivity_metric: 0.6718 - val_specificity_metric: 0.9183 - val_precision_metric: 0.6861 - val_recall_metric: 0.6718 - val_mean_average_precision: 0.5622
# Epoch 47/60
# 77/77 [==============================] - 60s 775ms/step - loss: -0.6101 - dice_metric: 0.6627 - jaccard_metric: 0.5841 - sensitivity_metric: 0.6348 - specificity_metric: 0.8753 - precision_metric: 0.6536 - recall_metric: 0.6348 - mean_average_precision: 0.4370 - val_loss: -0.6494 - val_dice_metric: 0.7640 - val_jaccard_metric: 0.6974 - val_sensitivity_metric: 0.6710 - val_specificity_metric: 0.9177 - val_precision_metric: 0.6880 - val_recall_metric: 0.6710 - val_mean_average_precision: 0.5677
# Epoch 48/60
# 77/77 [==============================] - 61s 787ms/step - loss: -0.6105 - dice_metric: 0.6642 - jaccard_metric: 0.5856 - sensitivity_metric: 0.6350 - specificity_metric: 0.8752 - precision_metric: 0.6540 - recall_metric: 0.6350 - mean_average_precision: 0.4385 - val_loss: -0.6491 - val_dice_metric: 0.7506 - val_jaccard_metric: 0.6839 - val_sensitivity_metric: 0.6719 - val_specificity_metric: 0.9183 - val_precision_metric: 0.6861 - val_recall_metric: 0.6719 - val_mean_average_precision: 0.5535
# Epoch 49/60
# 77/77 [==============================] - 62s 792ms/step - loss: -0.6107 - dice_metric: 0.6638 - jaccard_metric: 0.5852 - sensitivity_metric: 0.6353 - specificity_metric: 0.8755 - precision_metric: 0.6541 - recall_metric: 0.6353 - mean_average_precision: 0.4381 - val_loss: -0.6497 - val_dice_metric: 0.7590 - val_jaccard_metric: 0.6923 - val_sensitivity_metric: 0.6717 - val_specificity_metric: 0.9183 - val_precision_metric: 0.6875 - val_recall_metric: 0.6717 - val_mean_average_precision: 0.5624
# Epoch 50/60
# 77/77 [==============================] - 58s 747ms/step - loss: -0.6114 - dice_metric: 0.6641 - jaccard_metric: 0.5855 - sensitivity_metric: 0.6361 - specificity_metric: 0.8758 - precision_metric: 0.6545 - recall_metric: 0.6361 - mean_average_precision: 0.4385 - val_loss: -0.6497 - val_dice_metric: 0.7525 - val_jaccard_metric: 0.6859 - val_sensitivity_metric: 0.6704 - val_specificity_metric: 0.9172 - val_precision_metric: 0.6888 - val_recall_metric: 0.6704 - val_mean_average_precision: 0.5549
# Epoch 51/60
# 77/77 [==============================] - 62s 799ms/step - loss: -0.6115 - dice_metric: 0.6652 - jaccard_metric: 0.5866 - sensitivity_metric: 0.6357 - specificity_metric: 0.8757 - precision_metric: 0.6548 - recall_metric: 0.6357 - mean_average_precision: 0.4392 - val_loss: -0.6501 - val_dice_metric: 0.7567 - val_jaccard_metric: 0.6902 - val_sensitivity_metric: 0.6696 - val_specificity_metric: 0.9165 - val_precision_metric: 0.6906 - val_recall_metric: 0.6696 - val_mean_average_precision: 0.5595
# Epoch 52/60
# 77/77 [==============================] - 59s 761ms/step - loss: -0.6119 - dice_metric: 0.6659 - jaccard_metric: 0.5873 - sensitivity_metric: 0.6360 - specificity_metric: 0.8758 - precision_metric: 0.6555 - recall_metric: 0.6360 - mean_average_precision: 0.4403 - val_loss: -0.6502 - val_dice_metric: 0.7568 - val_jaccard_metric: 0.6902 - val_sensitivity_metric: 0.6724 - val_specificity_metric: 0.9186 - val_precision_metric: 0.6874 - val_recall_metric: 0.6724 - val_mean_average_precision: 0.5602
# Epoch 53/60
# 77/77 [==============================] - 63s 817ms/step - loss: -0.6123 - dice_metric: 0.6654 - jaccard_metric: 0.5867 - sensitivity_metric: 0.6363 - specificity_metric: 0.8759 - precision_metric: 0.6559 - recall_metric: 0.6363 - mean_average_precision: 0.4394 - val_loss: -0.6504 - val_dice_metric: 0.7542 - val_jaccard_metric: 0.6877 - val_sensitivity_metric: 0.6723 - val_specificity_metric: 0.9183 - val_precision_metric: 0.6875 - val_recall_metric: 0.6723 - val_mean_average_precision: 0.5579
# Epoch 54/60
# 77/77 [==============================] - 62s 795ms/step - loss: -0.6124 - dice_metric: 0.6659 - jaccard_metric: 0.5872 - sensitivity_metric: 0.6366 - specificity_metric: 0.8759 - precision_metric: 0.6556 - recall_metric: 0.6366 - mean_average_precision: 0.4397 - val_loss: -0.6506 - val_dice_metric: 0.7622 - val_jaccard_metric: 0.6958 - val_sensitivity_metric: 0.6709 - val_specificity_metric: 0.9173 - val_precision_metric: 0.6896 - val_recall_metric: 0.6709 - val_mean_average_precision: 0.5651
# Epoch 55/60
# 77/77 [==============================] - 61s 789ms/step - loss: -0.6126 - dice_metric: 0.6657 - jaccard_metric: 0.5870 - sensitivity_metric: 0.6366 - specificity_metric: 0.8759 - precision_metric: 0.6563 - recall_metric: 0.6366 - mean_average_precision: 0.4395 - val_loss: -0.6505 - val_dice_metric: 0.7504 - val_jaccard_metric: 0.6838 - val_sensitivity_metric: 0.6725 - val_specificity_metric: 0.9184 - val_precision_metric: 0.6872 - val_recall_metric: 0.6725 - val_mean_average_precision: 0.5538
# Epoch 56/60
# 77/77 [==============================] - 60s 770ms/step - loss: -0.6132 - dice_metric: 0.6680 - jaccard_metric: 0.5894 - sensitivity_metric: 0.6370 - specificity_metric: 0.8761 - precision_metric: 0.6570 - recall_metric: 0.6370 - mean_average_precision: 0.4417 - val_loss: -0.6509 - val_dice_metric: 0.7611 - val_jaccard_metric: 0.6945 - val_sensitivity_metric: 0.6736 - val_specificity_metric: 0.9195 - val_precision_metric: 0.6871 - val_recall_metric: 0.6736 - val_mean_average_precision: 0.5648
# Epoch 57/60
# 77/77 [==============================] - 61s 791ms/step - loss: -0.6135 - dice_metric: 0.6644 - jaccard_metric: 0.5857 - sensitivity_metric: 0.6373 - specificity_metric: 0.8764 - precision_metric: 0.6571 - recall_metric: 0.6373 - mean_average_precision: 0.4380 - val_loss: -0.6510 - val_dice_metric: 0.7561 - val_jaccard_metric: 0.6895 - val_sensitivity_metric: 0.6749 - val_specificity_metric: 0.9202 - val_precision_metric: 0.6861 - val_recall_metric: 0.6749 - val_mean_average_precision: 0.5592
# Epoch 58/60
# 77/77 [==============================] - 60s 767ms/step - loss: -0.6136 - dice_metric: 0.6661 - jaccard_metric: 0.5873 - sensitivity_metric: 0.6376 - specificity_metric: 0.8765 - precision_metric: 0.6570 - recall_metric: 0.6376 - mean_average_precision: 0.4394 - val_loss: -0.6518 - val_dice_metric: 0.7656 - val_jaccard_metric: 0.6992 - val_sensitivity_metric: 0.6725 - val_specificity_metric: 0.9187 - val_precision_metric: 0.6897 - val_recall_metric: 0.6725 - val_mean_average_precision: 0.5698
# Epoch 59/60
# 77/77 [==============================] - 63s 811ms/step - loss: -0.6141 - dice_metric: 0.6663 - jaccard_metric: 0.5876 - sensitivity_metric: 0.6377 - specificity_metric: 0.8763 - precision_metric: 0.6578 - recall_metric: 0.6377 - mean_average_precision: 0.4399 - val_loss: -0.6520 - val_dice_metric: 0.7619 - val_jaccard_metric: 0.6957 - val_sensitivity_metric: 0.6710 - val_specificity_metric: 0.9171 - val_precision_metric: 0.6916 - val_recall_metric: 0.6710 - val_mean_average_precision: 0.5661
# Epoch 60/60
# 77/77 [==============================] - 64s 820ms/step - loss: -0.6142 - dice_metric: 0.6667 - jaccard_metric: 0.5880 - sensitivity_metric: 0.6377 - specificity_metric: 0.8763 - precision_metric: 0.6578 - recall_metric: 0.6377 - mean_average_precision: 0.4403 - val_loss: -0.6523 - val_dice_metric: 0.7520 - val_jaccard_metric: 0.6855 - val_sensitivity_metric: 0.6747 - val_specificity_metric: 0.9196 - val_precision_metric: 0.6883 - val_recall_metric: 0.6747 - val_mean_average_precision: 0.5552

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.74920, std: 0.29636
# Jaccard Index mean: 0.67403, std: 0.32390
# Sensitivity mean: 0.69309, std: 0.34014
# Specificity mean: 0.91286, std: 0.15043
# Precision mean: 0.71485, std: 0.32984
# Recall mean: 0.69309, std: 0.34014
# mAP@50 mean: 0.68079, std: 0.23925
# mAP@50-95 mean: 0.52458, std: 0.18592
