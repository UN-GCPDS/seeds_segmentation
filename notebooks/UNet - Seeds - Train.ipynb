# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|████████████████████████████████████████▉| 995M/998M [00:07<00:00, 194MB/s]
# 100%|█████████████████████████████████████████| 998M/998M [00:07<00:00, 133MB/s]

# %%
config = {"Seg_model":"UNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
ResNet34, preprocess_input = Classifiers.get('resnet34')

# Definition of layers for the neural network structure

DefaultConv2D = partial(layers.Conv2D,
                        kernel_size=3, activation='relu', padding="same")

DefaultPooling = partial(layers.MaxPool2D,
                        pool_size=2)


upsample = partial(layers.UpSampling2D, (2,2))

@register_keras_serializable(package="my_custom_losses")
class DiceCoefficient(Loss):
    def __init__(self, smooth=1., target_class= None, name='DiceCoefficient', **kwargs):
        self.smooth = smooth
        self.target_class = target_class
        super().__init__(name=name,**kwargs)

    def call(self, y_true, y_pred):
        intersection = K.sum(y_true * y_pred, axis=[1,2])
        union = K.sum(y_true,axis=[1,2]) + K.sum(y_pred,axis=[1,2])
        dice_coef = -(2. * intersection + self.smooth) /(union + self.smooth)
        
        if self.target_class != None:
            dice_coef = tf.gather(dice_coef,
                                  self.target_class, axis=1)
        else:
            dice_coef = K.mean(dice_coef,axis=-1)

        return dice_coef

    def get_config(self,):
        base_config = super().get_config()
        return {**base_config, "smooth": self.smooth,
                "target_class":self.target_class}

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)


@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

def kernel_initializer(seed):
    
    return tf.keras.initializers.GlorotUniform(seed=seed)


def residual_block(x, filters, kernel_initializer, block_name):
    
    shortcut = x
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_1')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_1')(x)
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_2')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_2')(x)
    x = layers.Add(name=f'ResAdd_{block_name}')([shortcut, x])
    x = layers.Activation('relu', name=f'ResAct_{block_name}')(x)
    return x

def UNet(inputs, out_channels, activation):
    
    # Encoder - Downsampling path with increasing filter numbers
    # Each level follows: Conv -> Dropout -> BatchNorm -> Conv -> Dropout -> BatchNorm -> Pooling

    x = layers.BatchNormalization(name='Batch00')(inputs)
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(34), name='Conv10')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch10')(x)
    x = level_1 = DefaultConv2D(8, kernel_initializer=kernel_initializer(4), name='Conv11')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch11')(x)
    x = DefaultPooling(name='Pool10')(x)  # 128x128 -> 64x64

    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(56), name='Conv20')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch20')(x)
    x = level_2 = DefaultConv2D(16, kernel_initializer=kernel_initializer(32), name='Conv21')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch22')(x)
    x = DefaultPooling(name='Pool20')(x)  # 64x64 -> 32x32

    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(87), name='Conv30')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch30')(x)
    x = level_3 = DefaultConv2D(32, kernel_initializer=kernel_initializer(30), name='Conv31')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch31')(x)
    x = DefaultPooling(name='Pool30')(x)  # 32x32 -> 16x16

    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(79), name='Conv40')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch40')(x)
    x = level_4 = DefaultConv2D(64, kernel_initializer=kernel_initializer(81), name='Conv41')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch41')(x)
    x = DefaultPooling(name='Pool40')(x)  # 16x16 -> 8x8

    # Decoder - Upsampling path with decreasing filter numbers
    # Each level follows: Conv -> Dropout -> BatchNorm -> Conv -> Dropout -> BatchNorm
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(89), name='Conv50')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch50')(x)
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(42), name='Conv51')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch51')(x)

    # Upsampling and skip connection with level_4 features
    x = upsample(name='Up60')(x)  # 8x8 -> 16x16
    x = layers.Concatenate(name='Concat60')([level_4, x])
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(91), name='Conv60')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch60')(x)
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(47), name='Conv61')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch61')(x)

    # Upsampling and skip connection with level_3 features
    x = upsample(name='Up70')(x)  # 16x16 -> 32x32
    x = layers.Concatenate(name='Concat70')([level_3, x])
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(21), name='Conv70')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch70')(x)
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(96), name='Conv71')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch71')(x)

    # Upsampling and skip connection with level_2 features
    x = upsample(name='Up80')(x)  # 32x32 -> 64x64
    x = layers.Concatenate(name='Concat80')([level_2, x])
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(96), name='Conv80')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch80')(x)
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(98), name='Conv81')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch81')(x)

    # Upsampling and skip connection with level_1 features
    x = upsample(name='Up90')(x)  # 64x64 -> 128x128
    x = layers.Concatenate(name='Concat90')([level_1, x])
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(35), name='Conv90')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch90')(x)
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(7), name='Conv91')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch91')(x)

    # Final segmentation output with specified activation
    if activation == 'sparse_softmax':
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=sparse_softmax,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)
    else:
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=activation,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)

    return x


def ResUNet(inputs, input_shape, out_channels,activation):
    
    # Backbone (ResNet34) - Use pre-trained weights from ImageNet
    backbone = ResNet34(
        input_shape=input_shape,
        input_tensor=inputs,
        include_top=False,
        weights='imagenet')

    # Freeze backbone layers except BatchNormalization layers
    # This allows the model to adapt to the new domain while retaining learned features
    for layer in backbone.layers:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = False

    # Extract feature maps from different levels of the ResNet backbone
    level_1 = backbone.layers[5].output   # 128x128x64
    level_2 = backbone.layers[37].output  # 64x64x64
    level_3 = backbone.layers[74].output  # 32x32x128
    level_4 = backbone.layers[129].output # 16x16x256
    x = backbone.layers[157].output       # 8x8x512

    # Decoder - Upsampling path with skip connections to encoder features
    # First upsampling block
    x = upsample(name='Up60')(x)
    x = layers.Concatenate(name='Concat60')([level_4, x])
    x = DefaultConv2D(256, kernel_initializer=kernel_initializer(91) , name='Conv60')(x)
    x = residual_block(x, 256, kernel_initializer(47), '60')  # Apply residual block

    # Second upsampling block
    x = upsample(name='Up70')(x)
    x = layers.Concatenate(name='Concat70')([level_3, x])
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(21), name='Conv70')(x)
    x = residual_block(x, 128, kernel_initializer(96), '70')  # Apply residual block

    # Third upsampling block
    x = upsample(name='Up80')(x)
    x = layers.Concatenate(name='Concat80')([level_2, x])
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(96), name='Conv80')(x)
    x = residual_block(x, 64, kernel_initializer(98), '80')  # Apply residual block

    # Fourth upsampling block
    x = upsample(name='Up90')(x)
    x = layers.Concatenate(name='Concat90')([level_1, x])
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(35), name='Conv90')(x)
    x = residual_block(x, 32, kernel_initializer(7), '90')  # Apply residual block

    # Final upsampling block - connect back to input
    x = upsample(name='Up100')(x)
    x = layers.Concatenate(name='Concat100')([inputs, x])
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(45), name='Conv100')(x)
    x = residual_block(x, 16, kernel_initializer(7), '100')  # Apply residual block

    # Final segmentation output with specified activation
    if activation == 'sparse_softmax':
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=sparse_softmax,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)
    else:
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=activation,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)

    return x

def Seg_Model(class_no=2, input_shape=(512, 512, 3), seg_model='ResUNet', activation='softmax'):
    
    # Input layer definition
    image_input = layers.Input(shape=input_shape, name='image_input')

    # Select and build the appropriate segmentation backbone
    if seg_model == 'ResUNet':
        # Use ResNet-based UNet architecture
        seg_rm = ResUNet(image_input, input_shape, out_channels=class_no, activation=activation)
    elif seg_model == 'UNet':
        # Use standard UNet architecture
        seg_rm = UNet(image_input, out_channels=class_no, activation=activation)
    else:
        # Raise error for unsupported model types
        raise ValueError(f"Unsupported segmentation model type: {seg_model}. Supported models are 'ResUNet' and 'UNet'.")

    # Create and return the final model
    return Model(image_input, seg_rm, name=seg_model)

# %%
with strategy.scope():
    model = Seg_Model(class_no=config['Number of classes'],input_shape=config['Input size'], 
                 seg_model=config['Seg_model'], activation=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 96s 882ms/step - loss: -0.1421 - dice_metric: 0.3672 - jaccard_metric: 0.2671 - sensitivity_metric: 0.6561 - specificity_metric: 0.6561 - val_loss: -0.0550 - val_dice_metric: 0.4892 - val_jaccard_metric: 0.4789 - val_sensitivity_metric: 0.4997 - val_specificity_metric: 0.4997
# Epoch 2/60
# 77/77 [==============================] - 67s 870ms/step - loss: -0.2529 - dice_metric: 0.4114 - jaccard_metric: 0.3399 - sensitivity_metric: 0.7056 - specificity_metric: 0.7056 - val_loss: -0.0051 - val_dice_metric: 0.4893 - val_jaccard_metric: 0.4792 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 3/60
# 77/77 [==============================] - 67s 865ms/step - loss: -0.3063 - dice_metric: 0.4600 - jaccard_metric: 0.3923 - sensitivity_metric: 0.7239 - specificity_metric: 0.7239 - val_loss: -0.0186 - val_dice_metric: 0.4968 - val_jaccard_metric: 0.4828 - val_sensitivity_metric: 0.5043 - val_specificity_metric: 0.5043
# Epoch 4/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.3380 - dice_metric: 0.4944 - jaccard_metric: 0.4279 - sensitivity_metric: 0.7407 - specificity_metric: 0.7407 - val_loss: -0.1588 - val_dice_metric: 0.5635 - val_jaccard_metric: 0.5244 - val_sensitivity_metric: 0.5673 - val_specificity_metric: 0.5673
# Epoch 5/60
# 77/77 [==============================] - 65s 835ms/step - loss: -0.3619 - dice_metric: 0.5224 - jaccard_metric: 0.4561 - sensitivity_metric: 0.7552 - specificity_metric: 0.7552 - val_loss: -0.2170 - val_dice_metric: 0.5376 - val_jaccard_metric: 0.4779 - val_sensitivity_metric: 0.5630 - val_specificity_metric: 0.5630
# Epoch 6/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.3815 - dice_metric: 0.5423 - jaccard_metric: 0.4767 - sensitivity_metric: 0.7645 - specificity_metric: 0.7645 - val_loss: -0.3713 - val_dice_metric: 0.5977 - val_jaccard_metric: 0.5248 - val_sensitivity_metric: 0.6375 - val_specificity_metric: 0.6375
# Epoch 7/60
# 77/77 [==============================] - 67s 868ms/step - loss: -0.3992 - dice_metric: 0.5571 - jaccard_metric: 0.4927 - sensitivity_metric: 0.7710 - specificity_metric: 0.7710 - val_loss: -0.4412 - val_dice_metric: 0.6112 - val_jaccard_metric: 0.5347 - val_sensitivity_metric: 0.7116 - val_specificity_metric: 0.7116
# Epoch 8/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.4137 - dice_metric: 0.5703 - jaccard_metric: 0.5064 - sensitivity_metric: 0.7773 - specificity_metric: 0.7773 - val_loss: -0.4639 - val_dice_metric: 0.5929 - val_jaccard_metric: 0.5186 - val_sensitivity_metric: 0.7229 - val_specificity_metric: 0.7229
# Epoch 9/60
# 77/77 [==============================] - 69s 895ms/step - loss: -0.4275 - dice_metric: 0.5920 - jaccard_metric: 0.5274 - sensitivity_metric: 0.7907 - specificity_metric: 0.7907 - val_loss: -0.4721 - val_dice_metric: 0.5764 - val_jaccard_metric: 0.5081 - val_sensitivity_metric: 0.7189 - val_specificity_metric: 0.7189
# Epoch 10/60
# 77/77 [==============================] - 67s 859ms/step - loss: -0.4425 - dice_metric: 0.6042 - jaccard_metric: 0.5405 - sensitivity_metric: 0.7959 - specificity_metric: 0.7959 - val_loss: -0.4757 - val_dice_metric: 0.5414 - val_jaccard_metric: 0.4855 - val_sensitivity_metric: 0.7142 - val_specificity_metric: 0.7142
# Epoch 11/60
# 77/77 [==============================] - 65s 836ms/step - loss: -0.4589 - dice_metric: 0.6121 - jaccard_metric: 0.5507 - sensitivity_metric: 0.7970 - specificity_metric: 0.7970 - val_loss: -0.4790 - val_dice_metric: 0.5524 - val_jaccard_metric: 0.4933 - val_sensitivity_metric: 0.7197 - val_specificity_metric: 0.7197
# Epoch 12/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.4723 - dice_metric: 0.6207 - jaccard_metric: 0.5607 - sensitivity_metric: 0.8003 - specificity_metric: 0.8003 - val_loss: -0.4743 - val_dice_metric: 0.5559 - val_jaccard_metric: 0.4935 - val_sensitivity_metric: 0.7136 - val_specificity_metric: 0.7136
# Epoch 13/60
# 77/77 [==============================] - 65s 835ms/step - loss: -0.4841 - dice_metric: 0.6322 - jaccard_metric: 0.5724 - sensitivity_metric: 0.8056 - specificity_metric: 0.8056 - val_loss: -0.4866 - val_dice_metric: 0.5793 - val_jaccard_metric: 0.5147 - val_sensitivity_metric: 0.7247 - val_specificity_metric: 0.7247
# Epoch 14/60
# 77/77 [==============================] - 69s 889ms/step - loss: -0.4957 - dice_metric: 0.6318 - jaccard_metric: 0.5741 - sensitivity_metric: 0.8022 - specificity_metric: 0.8022 - val_loss: -0.4849 - val_dice_metric: 0.5829 - val_jaccard_metric: 0.5159 - val_sensitivity_metric: 0.7247 - val_specificity_metric: 0.7247
# Epoch 15/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.5040 - dice_metric: 0.6433 - jaccard_metric: 0.5850 - sensitivity_metric: 0.8090 - specificity_metric: 0.8090 - val_loss: -0.4864 - val_dice_metric: 0.5861 - val_jaccard_metric: 0.5190 - val_sensitivity_metric: 0.7177 - val_specificity_metric: 0.7177
# Epoch 16/60
# 77/77 [==============================] - 66s 854ms/step - loss: -0.5122 - dice_metric: 0.6468 - jaccard_metric: 0.5891 - sensitivity_metric: 0.8099 - specificity_metric: 0.8099 - val_loss: -0.4728 - val_dice_metric: 0.5533 - val_jaccard_metric: 0.4899 - val_sensitivity_metric: 0.7105 - val_specificity_metric: 0.7105
# Epoch 17/60
# 77/77 [==============================] - 65s 843ms/step - loss: -0.5190 - dice_metric: 0.6577 - jaccard_metric: 0.5997 - sensitivity_metric: 0.8156 - specificity_metric: 0.8156 - val_loss: -0.4645 - val_dice_metric: 0.5441 - val_jaccard_metric: 0.4802 - val_sensitivity_metric: 0.7038 - val_specificity_metric: 0.7038
# Epoch 18/60
# 77/77 [==============================] - 67s 865ms/step - loss: -0.5319 - dice_metric: 0.6560 - jaccard_metric: 0.6006 - sensitivity_metric: 0.8120 - specificity_metric: 0.8120 - val_loss: -0.4765 - val_dice_metric: 0.5692 - val_jaccard_metric: 0.5019 - val_sensitivity_metric: 0.7141 - val_specificity_metric: 0.7141
# Epoch 19/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.5400 - dice_metric: 0.6600 - jaccard_metric: 0.6054 - sensitivity_metric: 0.8131 - specificity_metric: 0.8131 - val_loss: -0.4751 - val_dice_metric: 0.5743 - val_jaccard_metric: 0.5036 - val_sensitivity_metric: 0.7201 - val_specificity_metric: 0.7201
# Epoch 20/60
# 77/77 [==============================] - 65s 838ms/step - loss: -0.5468 - dice_metric: 0.6671 - jaccard_metric: 0.6125 - sensitivity_metric: 0.8169 - specificity_metric: 0.8169 - val_loss: -0.4848 - val_dice_metric: 0.6029 - val_jaccard_metric: 0.5308 - val_sensitivity_metric: 0.7169 - val_specificity_metric: 0.7169
# Epoch 21/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.5547 - dice_metric: 0.6678 - jaccard_metric: 0.6144 - sensitivity_metric: 0.8150 - specificity_metric: 0.8150 - val_loss: -0.4677 - val_dice_metric: 0.5825 - val_jaccard_metric: 0.5095 - val_sensitivity_metric: 0.7105 - val_specificity_metric: 0.7105
# Epoch 22/60
# 77/77 [==============================] - 71s 921ms/step - loss: -0.5610 - dice_metric: 0.6690 - jaccard_metric: 0.6165 - sensitivity_metric: 0.8146 - specificity_metric: 0.8146 - val_loss: -0.4782 - val_dice_metric: 0.5833 - val_jaccard_metric: 0.5113 - val_sensitivity_metric: 0.7186 - val_specificity_metric: 0.7186
# Epoch 23/60
# 77/77 [==============================] - 69s 884ms/step - loss: -0.5659 - dice_metric: 0.6741 - jaccard_metric: 0.6217 - sensitivity_metric: 0.8172 - specificity_metric: 0.8172 - val_loss: -0.4926 - val_dice_metric: 0.6115 - val_jaccard_metric: 0.5397 - val_sensitivity_metric: 0.7218 - val_specificity_metric: 0.7218
# Epoch 24/60
# 77/77 [==============================] - 66s 849ms/step - loss: -0.5723 - dice_metric: 0.6757 - jaccard_metric: 0.6238 - sensitivity_metric: 0.8170 - specificity_metric: 0.8170 - val_loss: -0.4752 - val_dice_metric: 0.5947 - val_jaccard_metric: 0.5207 - val_sensitivity_metric: 0.7127 - val_specificity_metric: 0.7127
# Epoch 25/60
# 77/77 [==============================] - 64s 828ms/step - loss: -0.5782 - dice_metric: 0.6801 - jaccard_metric: 0.6285 - sensitivity_metric: 0.8191 - specificity_metric: 0.8191 - val_loss: -0.5006 - val_dice_metric: 0.6153 - val_jaccard_metric: 0.5436 - val_sensitivity_metric: 0.7283 - val_specificity_metric: 0.7283
# Epoch 26/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.5828 - dice_metric: 0.6966 - jaccard_metric: 0.6431 - sensitivity_metric: 0.8287 - specificity_metric: 0.8287 - val_loss: -0.4925 - val_dice_metric: 0.6093 - val_jaccard_metric: 0.5396 - val_sensitivity_metric: 0.7115 - val_specificity_metric: 0.7115
# Epoch 27/60
# 77/77 [==============================] - 69s 889ms/step - loss: -0.5891 - dice_metric: 0.6941 - jaccard_metric: 0.6420 - sensitivity_metric: 0.8266 - specificity_metric: 0.8266 - val_loss: -0.5069 - val_dice_metric: 0.6075 - val_jaccard_metric: 0.5405 - val_sensitivity_metric: 0.7266 - val_specificity_metric: 0.7266
# Epoch 28/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.5957 - dice_metric: 0.7001 - jaccard_metric: 0.6481 - sensitivity_metric: 0.8295 - specificity_metric: 0.8295 - val_loss: -0.5026 - val_dice_metric: 0.6257 - val_jaccard_metric: 0.5567 - val_sensitivity_metric: 0.7208 - val_specificity_metric: 0.7208
# Epoch 29/60
# 77/77 [==============================] - 68s 873ms/step - loss: -0.6003 - dice_metric: 0.7034 - jaccard_metric: 0.6513 - sensitivity_metric: 0.8309 - specificity_metric: 0.8309 - val_loss: -0.5137 - val_dice_metric: 0.6078 - val_jaccard_metric: 0.5416 - val_sensitivity_metric: 0.7414 - val_specificity_metric: 0.7414
# Epoch 30/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.6059 - dice_metric: 0.7092 - jaccard_metric: 0.6573 - sensitivity_metric: 0.8338 - specificity_metric: 0.8338 - val_loss: -0.5147 - val_dice_metric: 0.6131 - val_jaccard_metric: 0.5453 - val_sensitivity_metric: 0.7440 - val_specificity_metric: 0.7440
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.6111 - dice_metric: 0.7083 - jaccard_metric: 0.6577 - sensitivity_metric: 0.8326 - specificity_metric: 0.8326 - val_loss: -0.5099 - val_dice_metric: 0.6219 - val_jaccard_metric: 0.5520 - val_sensitivity_metric: 0.7354 - val_specificity_metric: 0.7354
# Epoch 32/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.6125 - dice_metric: 0.7124 - jaccard_metric: 0.6613 - sensitivity_metric: 0.8351 - specificity_metric: 0.8351 - val_loss: -0.5095 - val_dice_metric: 0.6168 - val_jaccard_metric: 0.5469 - val_sensitivity_metric: 0.7391 - val_specificity_metric: 0.7391
# Epoch 33/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.6134 - dice_metric: 0.7144 - jaccard_metric: 0.6632 - sensitivity_metric: 0.8364 - specificity_metric: 0.8364 - val_loss: -0.5078 - val_dice_metric: 0.6147 - val_jaccard_metric: 0.5441 - val_sensitivity_metric: 0.7391 - val_specificity_metric: 0.7391
# Epoch 34/60
# 77/77 [==============================] - 64s 818ms/step - loss: -0.6141 - dice_metric: 0.7155 - jaccard_metric: 0.6642 - sensitivity_metric: 0.8368 - specificity_metric: 0.8368 - val_loss: -0.5082 - val_dice_metric: 0.6181 - val_jaccard_metric: 0.5467 - val_sensitivity_metric: 0.7395 - val_specificity_metric: 0.7395
# Epoch 35/60
# 77/77 [==============================] - 66s 854ms/step - loss: -0.6148 - dice_metric: 0.7184 - jaccard_metric: 0.6668 - sensitivity_metric: 0.8390 - specificity_metric: 0.8390 - val_loss: -0.5076 - val_dice_metric: 0.6213 - val_jaccard_metric: 0.5471 - val_sensitivity_metric: 0.7522 - val_specificity_metric: 0.7522
# Epoch 36/60
# 77/77 [==============================] - 65s 834ms/step - loss: -0.6160 - dice_metric: 0.7203 - jaccard_metric: 0.6688 - sensitivity_metric: 0.8395 - specificity_metric: 0.8395 - val_loss: -0.5092 - val_dice_metric: 0.6303 - val_jaccard_metric: 0.5550 - val_sensitivity_metric: 0.7513 - val_specificity_metric: 0.7513
# Epoch 37/60
# 77/77 [==============================] - 68s 871ms/step - loss: -0.6177 - dice_metric: 0.7226 - jaccard_metric: 0.6709 - sensitivity_metric: 0.8408 - specificity_metric: 0.8408 - val_loss: -0.5098 - val_dice_metric: 0.6423 - val_jaccard_metric: 0.5659 - val_sensitivity_metric: 0.7567 - val_specificity_metric: 0.7567
# Epoch 38/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.6190 - dice_metric: 0.7241 - jaccard_metric: 0.6724 - sensitivity_metric: 0.8414 - specificity_metric: 0.8414 - val_loss: -0.5091 - val_dice_metric: 0.6437 - val_jaccard_metric: 0.5672 - val_sensitivity_metric: 0.7544 - val_specificity_metric: 0.7544
# Epoch 39/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.6202 - dice_metric: 0.7244 - jaccard_metric: 0.6729 - sensitivity_metric: 0.8412 - specificity_metric: 0.8412 - val_loss: -0.5112 - val_dice_metric: 0.6527 - val_jaccard_metric: 0.5763 - val_sensitivity_metric: 0.7572 - val_specificity_metric: 0.7572
# Epoch 40/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.6207 - dice_metric: 0.7249 - jaccard_metric: 0.6733 - sensitivity_metric: 0.8413 - specificity_metric: 0.8413 - val_loss: -0.5096 - val_dice_metric: 0.6458 - val_jaccard_metric: 0.5693 - val_sensitivity_metric: 0.7561 - val_specificity_metric: 0.7561
# Epoch 41/60
# 77/77 [==============================] - 69s 894ms/step - loss: -0.6216 - dice_metric: 0.7244 - jaccard_metric: 0.6731 - sensitivity_metric: 0.8408 - specificity_metric: 0.8408 - val_loss: -0.5111 - val_dice_metric: 0.6497 - val_jaccard_metric: 0.5730 - val_sensitivity_metric: 0.7559 - val_specificity_metric: 0.7559
# Epoch 42/60
# 77/77 [==============================] - 65s 839ms/step - loss: -0.6224 - dice_metric: 0.7243 - jaccard_metric: 0.6732 - sensitivity_metric: 0.8407 - specificity_metric: 0.8407 - val_loss: -0.5107 - val_dice_metric: 0.6465 - val_jaccard_metric: 0.5702 - val_sensitivity_metric: 0.7574 - val_specificity_metric: 0.7574
# Epoch 43/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.6231 - dice_metric: 0.7246 - jaccard_metric: 0.6735 - sensitivity_metric: 0.8407 - specificity_metric: 0.8407 - val_loss: -0.5101 - val_dice_metric: 0.6499 - val_jaccard_metric: 0.5731 - val_sensitivity_metric: 0.7550 - val_specificity_metric: 0.7550
# Epoch 44/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.6237 - dice_metric: 0.7250 - jaccard_metric: 0.6740 - sensitivity_metric: 0.8410 - specificity_metric: 0.8410 - val_loss: -0.5100 - val_dice_metric: 0.6520 - val_jaccard_metric: 0.5752 - val_sensitivity_metric: 0.7532 - val_specificity_metric: 0.7532
# Epoch 45/60
# 77/77 [==============================] - 69s 885ms/step - loss: -0.6244 - dice_metric: 0.7254 - jaccard_metric: 0.6744 - sensitivity_metric: 0.8410 - specificity_metric: 0.8410 - val_loss: -0.5086 - val_dice_metric: 0.6512 - val_jaccard_metric: 0.5742 - val_sensitivity_metric: 0.7546 - val_specificity_metric: 0.7546
# Epoch 46/60
# 77/77 [==============================] - 68s 872ms/step - loss: -0.6252 - dice_metric: 0.7260 - jaccard_metric: 0.6750 - sensitivity_metric: 0.8414 - specificity_metric: 0.8414 - val_loss: -0.5111 - val_dice_metric: 0.6545 - val_jaccard_metric: 0.5778 - val_sensitivity_metric: 0.7572 - val_specificity_metric: 0.7572
# Epoch 47/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.6255 - dice_metric: 0.7262 - jaccard_metric: 0.6752 - sensitivity_metric: 0.8413 - specificity_metric: 0.8413 - val_loss: -0.5095 - val_dice_metric: 0.6525 - val_jaccard_metric: 0.5757 - val_sensitivity_metric: 0.7531 - val_specificity_metric: 0.7531
# Epoch 48/60
# 77/77 [==============================] - 68s 880ms/step - loss: -0.6266 - dice_metric: 0.7270 - jaccard_metric: 0.6760 - sensitivity_metric: 0.8417 - specificity_metric: 0.8417 - val_loss: -0.5095 - val_dice_metric: 0.6529 - val_jaccard_metric: 0.5761 - val_sensitivity_metric: 0.7536 - val_specificity_metric: 0.7536
# Epoch 49/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.6268 - dice_metric: 0.7276 - jaccard_metric: 0.6766 - sensitivity_metric: 0.8421 - specificity_metric: 0.8421 - val_loss: -0.5100 - val_dice_metric: 0.6571 - val_jaccard_metric: 0.5804 - val_sensitivity_metric: 0.7511 - val_specificity_metric: 0.7511
# Epoch 50/60
# 77/77 [==============================] - 67s 863ms/step - loss: -0.6280 - dice_metric: 0.7269 - jaccard_metric: 0.6763 - sensitivity_metric: 0.8414 - specificity_metric: 0.8414 - val_loss: -0.5091 - val_dice_metric: 0.6539 - val_jaccard_metric: 0.5769 - val_sensitivity_metric: 0.7517 - val_specificity_metric: 0.7517
# Epoch 51/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.6284 - dice_metric: 0.7277 - jaccard_metric: 0.6769 - sensitivity_metric: 0.8418 - specificity_metric: 0.8418 - val_loss: -0.5108 - val_dice_metric: 0.6529 - val_jaccard_metric: 0.5762 - val_sensitivity_metric: 0.7546 - val_specificity_metric: 0.7546
# Epoch 52/60
# 77/77 [==============================] - 65s 836ms/step - loss: -0.6292 - dice_metric: 0.7282 - jaccard_metric: 0.6775 - sensitivity_metric: 0.8423 - specificity_metric: 0.8423 - val_loss: -0.5105 - val_dice_metric: 0.6550 - val_jaccard_metric: 0.5782 - val_sensitivity_metric: 0.7538 - val_specificity_metric: 0.7538
# Epoch 53/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.6297 - dice_metric: 0.7287 - jaccard_metric: 0.6780 - sensitivity_metric: 0.8423 - specificity_metric: 0.8423 - val_loss: -0.5108 - val_dice_metric: 0.6542 - val_jaccard_metric: 0.5774 - val_sensitivity_metric: 0.7531 - val_specificity_metric: 0.7531
# Epoch 54/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.6304 - dice_metric: 0.7288 - jaccard_metric: 0.6782 - sensitivity_metric: 0.8424 - specificity_metric: 0.8424 - val_loss: -0.5090 - val_dice_metric: 0.6514 - val_jaccard_metric: 0.5744 - val_sensitivity_metric: 0.7510 - val_specificity_metric: 0.7510
# Epoch 55/60
# 77/77 [==============================] - 68s 871ms/step - loss: -0.6311 - dice_metric: 0.7293 - jaccard_metric: 0.6787 - sensitivity_metric: 0.8426 - specificity_metric: 0.8426 - val_loss: -0.5096 - val_dice_metric: 0.6530 - val_jaccard_metric: 0.5760 - val_sensitivity_metric: 0.7520 - val_specificity_metric: 0.7520
# Epoch 56/60
# 77/77 [==============================] - 66s 854ms/step - loss: -0.6316 - dice_metric: 0.7296 - jaccard_metric: 0.6790 - sensitivity_metric: 0.8425 - specificity_metric: 0.8425 - val_loss: -0.5091 - val_dice_metric: 0.6501 - val_jaccard_metric: 0.5729 - val_sensitivity_metric: 0.7514 - val_specificity_metric: 0.7514
# Epoch 57/60
# 77/77 [==============================] - 65s 839ms/step - loss: -0.6324 - dice_metric: 0.7297 - jaccard_metric: 0.6792 - sensitivity_metric: 0.8426 - specificity_metric: 0.8426 - val_loss: -0.5093 - val_dice_metric: 0.6515 - val_jaccard_metric: 0.5743 - val_sensitivity_metric: 0.7533 - val_specificity_metric: 0.7533
# Epoch 58/60
# 77/77 [==============================] - 69s 888ms/step - loss: -0.6327 - dice_metric: 0.7308 - jaccard_metric: 0.6802 - sensitivity_metric: 0.8433 - specificity_metric: 0.8433 - val_loss: -0.5094 - val_dice_metric: 0.6494 - val_jaccard_metric: 0.5724 - val_sensitivity_metric: 0.7509 - val_specificity_metric: 0.7509
# Epoch 59/60
# 77/77 [==============================] - 66s 854ms/step - loss: -0.6338 - dice_metric: 0.7307 - jaccard_metric: 0.6804 - sensitivity_metric: 0.8432 - specificity_metric: 0.8432 - val_loss: -0.5094 - val_dice_metric: 0.6517 - val_jaccard_metric: 0.5747 - val_sensitivity_metric: 0.7482 - val_specificity_metric: 0.7482
# Epoch 60/60
# 77/77 [==============================] - 69s 894ms/step - loss: -0.6339 - dice_metric: 0.7311 - jaccard_metric: 0.6806 - sensitivity_metric: 0.8432 - specificity_metric: 0.8432 - val_loss: -0.5094 - val_dice_metric: 0.6526 - val_jaccard_metric: 0.5755 - val_sensitivity_metric: 0.7472 - val_specificity_metric: 0.7472

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-19-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.67455, standard deviation: 0.34505
# Jaccard Index mean: 0.60085, standard deviation: 0.35856
# Sensitivity mean: 0.76881, standard deviation: 0.23571
# Specificity mean: 0.76881, standard deviation: 0.23571
