# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|███████████████████████████████████████▉| 995M/998M [00:12<00:00, 79.8MB/s]
# 100%|████████████████████████████████████████| 998M/998M [00:12<00:00, 84.1MB/s]

# %%
config = {"Seg_model":"RFFSkipsFCN","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import fcn_rff_skips
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP

@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = fcn_rff_skips(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 73s 632ms/step - loss: -0.0865 - dice_metric: 0.3331 - jaccard_metric: 0.2280 - sensitivity_metric: 0.5142 - specificity_metric: 0.5142 - precision_metric: 0.5023 - recall_metric: 0.5142 - mean_average_precision: 0.0060 - val_loss: -0.0766 - val_dice_metric: 0.4279 - val_jaccard_metric: 0.3413 - val_sensitivity_metric: 0.4994 - val_specificity_metric: 0.4994 - val_precision_metric: 0.5000 - val_recall_metric: 0.4994 - val_mean_average_precision: 0.1695
# Epoch 2/60
# 77/77 [==============================] - 40s 519ms/step - loss: -0.1095 - dice_metric: 0.4956 - jaccard_metric: 0.3922 - sensitivity_metric: 0.7293 - specificity_metric: 0.7293 - precision_metric: 0.5485 - recall_metric: 0.7293 - mean_average_precision: 0.2070 - val_loss: -0.0765 - val_dice_metric: 0.4893 - val_jaccard_metric: 0.4792 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000 - val_precision_metric: 0.4797 - val_recall_metric: 0.5000 - val_mean_average_precision: 0.4812
# Epoch 3/60
# 77/77 [==============================] - 42s 543ms/step - loss: -0.1341 - dice_metric: 0.5863 - jaccard_metric: 0.4843 - sensitivity_metric: 0.8525 - specificity_metric: 0.8525 - precision_metric: 0.5865 - recall_metric: 0.8525 - mean_average_precision: 0.3205 - val_loss: -0.0896 - val_dice_metric: 0.6291 - val_jaccard_metric: 0.5813 - val_sensitivity_metric: 0.6183 - val_specificity_metric: 0.6183 - val_precision_metric: 0.7249 - val_recall_metric: 0.6183 - val_mean_average_precision: 0.5111
# Epoch 4/60
# 77/77 [==============================] - 42s 545ms/step - loss: -0.1587 - dice_metric: 0.6433 - jaccard_metric: 0.5430 - sensitivity_metric: 0.9038 - specificity_metric: 0.9038 - precision_metric: 0.6169 - recall_metric: 0.9038 - mean_average_precision: 0.3786 - val_loss: -0.1333 - val_dice_metric: 0.7283 - val_jaccard_metric: 0.6516 - val_sensitivity_metric: 0.7958 - val_specificity_metric: 0.7958 - val_precision_metric: 0.7199 - val_recall_metric: 0.7958 - val_mean_average_precision: 0.5183
# Epoch 5/60
# 77/77 [==============================] - 41s 527ms/step - loss: -0.1960 - dice_metric: 0.7045 - jaccard_metric: 0.6071 - sensitivity_metric: 0.9302 - specificity_metric: 0.9302 - precision_metric: 0.6571 - recall_metric: 0.9302 - mean_average_precision: 0.4340 - val_loss: -0.1983 - val_dice_metric: 0.7678 - val_jaccard_metric: 0.6840 - val_sensitivity_metric: 0.8667 - val_specificity_metric: 0.8667 - val_precision_metric: 0.7363 - val_recall_metric: 0.8667 - val_mean_average_precision: 0.5352
# Epoch 6/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.2669 - dice_metric: 0.7636 - jaccard_metric: 0.6705 - sensitivity_metric: 0.9375 - specificity_metric: 0.9375 - precision_metric: 0.7061 - recall_metric: 0.9375 - mean_average_precision: 0.4910 - val_loss: -0.3144 - val_dice_metric: 0.7951 - val_jaccard_metric: 0.7102 - val_sensitivity_metric: 0.9132 - val_specificity_metric: 0.9132 - val_precision_metric: 0.7448 - val_recall_metric: 0.9132 - val_mean_average_precision: 0.5612
# Epoch 7/60
# 77/77 [==============================] - 41s 531ms/step - loss: -0.3878 - dice_metric: 0.8141 - jaccard_metric: 0.7273 - sensitivity_metric: 0.9291 - specificity_metric: 0.9291 - precision_metric: 0.7610 - recall_metric: 0.9291 - mean_average_precision: 0.5585 - val_loss: -0.4628 - val_dice_metric: 0.8324 - val_jaccard_metric: 0.7524 - val_sensitivity_metric: 0.9071 - val_specificity_metric: 0.9071 - val_precision_metric: 0.7944 - val_recall_metric: 0.9071 - val_mean_average_precision: 0.5970
# Epoch 8/60
# 77/77 [==============================] - 42s 544ms/step - loss: -0.5203 - dice_metric: 0.8472 - jaccard_metric: 0.7663 - sensitivity_metric: 0.9153 - specificity_metric: 0.9153 - precision_metric: 0.8082 - recall_metric: 0.9153 - mean_average_precision: 0.6090 - val_loss: -0.5909 - val_dice_metric: 0.8535 - val_jaccard_metric: 0.7763 - val_sensitivity_metric: 0.9159 - val_specificity_metric: 0.9159 - val_precision_metric: 0.8172 - val_recall_metric: 0.9159 - val_mean_average_precision: 0.6252
# Epoch 9/60
# 77/77 [==============================] - 41s 523ms/step - loss: -0.6155 - dice_metric: 0.8660 - jaccard_metric: 0.7893 - sensitivity_metric: 0.9079 - specificity_metric: 0.9079 - precision_metric: 0.8391 - recall_metric: 0.9079 - mean_average_precision: 0.6389 - val_loss: -0.6625 - val_dice_metric: 0.8670 - val_jaccard_metric: 0.7924 - val_sensitivity_metric: 0.9168 - val_specificity_metric: 0.9168 - val_precision_metric: 0.8350 - val_recall_metric: 0.9168 - val_mean_average_precision: 0.6389
# Epoch 10/60
# 77/77 [==============================] - 41s 525ms/step - loss: -0.6737 - dice_metric: 0.8768 - jaccard_metric: 0.8029 - sensitivity_metric: 0.9057 - specificity_metric: 0.9057 - precision_metric: 0.8571 - recall_metric: 0.9057 - mean_average_precision: 0.6603 - val_loss: -0.7097 - val_dice_metric: 0.8808 - val_jaccard_metric: 0.8098 - val_sensitivity_metric: 0.9123 - val_specificity_metric: 0.9123 - val_precision_metric: 0.8585 - val_recall_metric: 0.9123 - val_mean_average_precision: 0.6689
# Epoch 11/60
# 77/77 [==============================] - 41s 528ms/step - loss: -0.7099 - dice_metric: 0.8839 - jaccard_metric: 0.8123 - sensitivity_metric: 0.9064 - specificity_metric: 0.9064 - precision_metric: 0.8683 - recall_metric: 0.9064 - mean_average_precision: 0.6736 - val_loss: -0.7372 - val_dice_metric: 0.8883 - val_jaccard_metric: 0.8199 - val_sensitivity_metric: 0.9116 - val_specificity_metric: 0.9116 - val_precision_metric: 0.8723 - val_recall_metric: 0.9116 - val_mean_average_precision: 0.6828
# Epoch 12/60
# 77/77 [==============================] - 40s 517ms/step - loss: -0.7347 - dice_metric: 0.8896 - jaccard_metric: 0.8198 - sensitivity_metric: 0.9079 - specificity_metric: 0.9079 - precision_metric: 0.8767 - recall_metric: 0.9079 - mean_average_precision: 0.6852 - val_loss: -0.7551 - val_dice_metric: 0.8939 - val_jaccard_metric: 0.8273 - val_sensitivity_metric: 0.9058 - val_specificity_metric: 0.9058 - val_precision_metric: 0.8870 - val_recall_metric: 0.9058 - val_mean_average_precision: 0.6961
# Epoch 13/60
# 77/77 [==============================] - 41s 530ms/step - loss: -0.7524 - dice_metric: 0.8943 - jaccard_metric: 0.8262 - sensitivity_metric: 0.9097 - specificity_metric: 0.9097 - precision_metric: 0.8835 - recall_metric: 0.9097 - mean_average_precision: 0.6962 - val_loss: -0.7682 - val_dice_metric: 0.8980 - val_jaccard_metric: 0.8328 - val_sensitivity_metric: 0.9046 - val_specificity_metric: 0.9046 - val_precision_metric: 0.8955 - val_recall_metric: 0.9046 - val_mean_average_precision: 0.7081
# Epoch 14/60
# 77/77 [==============================] - 41s 523ms/step - loss: -0.7668 - dice_metric: 0.8988 - jaccard_metric: 0.8323 - sensitivity_metric: 0.9116 - specificity_metric: 0.9116 - precision_metric: 0.8899 - recall_metric: 0.9116 - mean_average_precision: 0.7077 - val_loss: -0.7808 - val_dice_metric: 0.9018 - val_jaccard_metric: 0.8383 - val_sensitivity_metric: 0.9172 - val_specificity_metric: 0.9172 - val_precision_metric: 0.8911 - val_recall_metric: 0.9172 - val_mean_average_precision: 0.7177
# Epoch 15/60
# 77/77 [==============================] - 42s 538ms/step - loss: -0.7790 - dice_metric: 0.9032 - jaccard_metric: 0.8385 - sensitivity_metric: 0.9139 - specificity_metric: 0.9139 - precision_metric: 0.8960 - recall_metric: 0.9139 - mean_average_precision: 0.7194 - val_loss: -0.7888 - val_dice_metric: 0.9036 - val_jaccard_metric: 0.8410 - val_sensitivity_metric: 0.9297 - val_specificity_metric: 0.9297 - val_precision_metric: 0.8840 - val_recall_metric: 0.9297 - val_mean_average_precision: 0.7247
# Epoch 16/60
# 77/77 [==============================] - 42s 539ms/step - loss: -0.7897 - dice_metric: 0.9074 - jaccard_metric: 0.8447 - sensitivity_metric: 0.9164 - specificity_metric: 0.9164 - precision_metric: 0.9017 - recall_metric: 0.9164 - mean_average_precision: 0.7315 - val_loss: -0.7955 - val_dice_metric: 0.9061 - val_jaccard_metric: 0.8443 - val_sensitivity_metric: 0.9344 - val_specificity_metric: 0.9344 - val_precision_metric: 0.8842 - val_recall_metric: 0.9344 - val_mean_average_precision: 0.7300
# Epoch 17/60
# 77/77 [==============================] - 41s 525ms/step - loss: -0.7992 - dice_metric: 0.9114 - jaccard_metric: 0.8505 - sensitivity_metric: 0.9189 - specificity_metric: 0.9189 - precision_metric: 0.9069 - recall_metric: 0.9189 - mean_average_precision: 0.7421 - val_loss: -0.8043 - val_dice_metric: 0.9102 - val_jaccard_metric: 0.8503 - val_sensitivity_metric: 0.9390 - val_specificity_metric: 0.9390 - val_precision_metric: 0.8878 - val_recall_metric: 0.9390 - val_mean_average_precision: 0.7417
# Epoch 18/60
# 77/77 [==============================] - 41s 535ms/step - loss: -0.8075 - dice_metric: 0.9151 - jaccard_metric: 0.8560 - sensitivity_metric: 0.9215 - specificity_metric: 0.9215 - precision_metric: 0.9116 - recall_metric: 0.9215 - mean_average_precision: 0.7517 - val_loss: -0.8150 - val_dice_metric: 0.9167 - val_jaccard_metric: 0.8598 - val_sensitivity_metric: 0.9371 - val_specificity_metric: 0.9371 - val_precision_metric: 0.9007 - val_recall_metric: 0.9371 - val_mean_average_precision: 0.7574
# Epoch 19/60
# 77/77 [==============================] - 42s 540ms/step - loss: -0.8153 - dice_metric: 0.9186 - jaccard_metric: 0.8612 - sensitivity_metric: 0.9240 - specificity_metric: 0.9240 - precision_metric: 0.9160 - recall_metric: 0.9240 - mean_average_precision: 0.7610 - val_loss: -0.8222 - val_dice_metric: 0.9204 - val_jaccard_metric: 0.8655 - val_sensitivity_metric: 0.9379 - val_specificity_metric: 0.9379 - val_precision_metric: 0.9066 - val_recall_metric: 0.9379 - val_mean_average_precision: 0.7684
# Epoch 20/60
# 77/77 [==============================] - 41s 524ms/step - loss: -0.8230 - dice_metric: 0.9221 - jaccard_metric: 0.8665 - sensitivity_metric: 0.9265 - specificity_metric: 0.9265 - precision_metric: 0.9203 - recall_metric: 0.9265 - mean_average_precision: 0.7710 - val_loss: -0.8289 - val_dice_metric: 0.9242 - val_jaccard_metric: 0.8712 - val_sensitivity_metric: 0.9383 - val_specificity_metric: 0.9383 - val_precision_metric: 0.9130 - val_recall_metric: 0.9383 - val_mean_average_precision: 0.7783
# Epoch 21/60
# 77/77 [==============================] - 42s 533ms/step - loss: -0.8302 - dice_metric: 0.9255 - jaccard_metric: 0.8716 - sensitivity_metric: 0.9290 - specificity_metric: 0.9290 - precision_metric: 0.9242 - recall_metric: 0.9290 - mean_average_precision: 0.7807 - val_loss: -0.8349 - val_dice_metric: 0.9270 - val_jaccard_metric: 0.8756 - val_sensitivity_metric: 0.9416 - val_specificity_metric: 0.9416 - val_precision_metric: 0.9155 - val_recall_metric: 0.9416 - val_mean_average_precision: 0.7852
# Epoch 22/60
# 77/77 [==============================] - 42s 534ms/step - loss: -0.8366 - dice_metric: 0.9285 - jaccard_metric: 0.8764 - sensitivity_metric: 0.9312 - specificity_metric: 0.9312 - precision_metric: 0.9279 - recall_metric: 0.9312 - mean_average_precision: 0.7895 - val_loss: -0.8399 - val_dice_metric: 0.9291 - val_jaccard_metric: 0.8789 - val_sensitivity_metric: 0.9439 - val_specificity_metric: 0.9439 - val_precision_metric: 0.9176 - val_recall_metric: 0.9439 - val_mean_average_precision: 0.7957
# Epoch 23/60
# 77/77 [==============================] - 42s 542ms/step - loss: -0.8426 - dice_metric: 0.9313 - jaccard_metric: 0.8807 - sensitivity_metric: 0.9332 - specificity_metric: 0.9332 - precision_metric: 0.9312 - recall_metric: 0.9332 - mean_average_precision: 0.7990 - val_loss: -0.8423 - val_dice_metric: 0.9295 - val_jaccard_metric: 0.8800 - val_sensitivity_metric: 0.9483 - val_specificity_metric: 0.9483 - val_precision_metric: 0.9152 - val_recall_metric: 0.9483 - val_mean_average_precision: 0.8009
# Epoch 24/60
# 77/77 [==============================] - 41s 522ms/step - loss: -0.8475 - dice_metric: 0.9335 - jaccard_metric: 0.8842 - sensitivity_metric: 0.9351 - specificity_metric: 0.9351 - precision_metric: 0.9338 - recall_metric: 0.9351 - mean_average_precision: 0.8054 - val_loss: -0.8443 - val_dice_metric: 0.9298 - val_jaccard_metric: 0.8803 - val_sensitivity_metric: 0.9526 - val_specificity_metric: 0.9526 - val_precision_metric: 0.9119 - val_recall_metric: 0.9526 - val_mean_average_precision: 0.8023
# Epoch 25/60
# 77/77 [==============================] - 41s 532ms/step - loss: -0.8517 - dice_metric: 0.9354 - jaccard_metric: 0.8871 - sensitivity_metric: 0.9366 - specificity_metric: 0.9366 - precision_metric: 0.9359 - recall_metric: 0.9366 - mean_average_precision: 0.8105 - val_loss: -0.8496 - val_dice_metric: 0.9325 - val_jaccard_metric: 0.8845 - val_sensitivity_metric: 0.9512 - val_specificity_metric: 0.9512 - val_precision_metric: 0.9178 - val_recall_metric: 0.9512 - val_mean_average_precision: 0.8060
# Epoch 26/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.8560 - dice_metric: 0.9373 - jaccard_metric: 0.8901 - sensitivity_metric: 0.9382 - specificity_metric: 0.9382 - precision_metric: 0.9381 - recall_metric: 0.9382 - mean_average_precision: 0.8162 - val_loss: -0.8513 - val_dice_metric: 0.9332 - val_jaccard_metric: 0.8854 - val_sensitivity_metric: 0.9528 - val_specificity_metric: 0.9528 - val_precision_metric: 0.9175 - val_recall_metric: 0.9528 - val_mean_average_precision: 0.8074
# Epoch 27/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.8600 - dice_metric: 0.9391 - jaccard_metric: 0.8929 - sensitivity_metric: 0.9398 - specificity_metric: 0.9398 - precision_metric: 0.9400 - recall_metric: 0.9398 - mean_average_precision: 0.8211 - val_loss: -0.8550 - val_dice_metric: 0.9351 - val_jaccard_metric: 0.8884 - val_sensitivity_metric: 0.9553 - val_specificity_metric: 0.9553 - val_precision_metric: 0.9190 - val_recall_metric: 0.9553 - val_mean_average_precision: 0.8109
# Epoch 28/60
# 77/77 [==============================] - 41s 524ms/step - loss: -0.8629 - dice_metric: 0.9403 - jaccard_metric: 0.8948 - sensitivity_metric: 0.9408 - specificity_metric: 0.9408 - precision_metric: 0.9414 - recall_metric: 0.9408 - mean_average_precision: 0.8250 - val_loss: -0.8588 - val_dice_metric: 0.9372 - val_jaccard_metric: 0.8917 - val_sensitivity_metric: 0.9559 - val_specificity_metric: 0.9559 - val_precision_metric: 0.9222 - val_recall_metric: 0.9559 - val_mean_average_precision: 0.8215
# Epoch 29/60
# 77/77 [==============================] - 40s 514ms/step - loss: -0.8660 - dice_metric: 0.9416 - jaccard_metric: 0.8969 - sensitivity_metric: 0.9419 - specificity_metric: 0.9419 - precision_metric: 0.9428 - recall_metric: 0.9419 - mean_average_precision: 0.8295 - val_loss: -0.8592 - val_dice_metric: 0.9369 - val_jaccard_metric: 0.8916 - val_sensitivity_metric: 0.9586 - val_specificity_metric: 0.9586 - val_precision_metric: 0.9201 - val_recall_metric: 0.9586 - val_mean_average_precision: 0.8204
# Epoch 30/60
# 77/77 [==============================] - 41s 521ms/step - loss: -0.8683 - dice_metric: 0.9424 - jaccard_metric: 0.8983 - sensitivity_metric: 0.9428 - specificity_metric: 0.9428 - precision_metric: 0.9437 - recall_metric: 0.9428 - mean_average_precision: 0.8322 - val_loss: -0.8612 - val_dice_metric: 0.9377 - val_jaccard_metric: 0.8927 - val_sensitivity_metric: 0.9605 - val_specificity_metric: 0.9605 - val_precision_metric: 0.9198 - val_recall_metric: 0.9605 - val_mean_average_precision: 0.8208
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 41s 521ms/step - loss: -0.8713 - dice_metric: 0.9439 - jaccard_metric: 0.9008 - sensitivity_metric: 0.9445 - specificity_metric: 0.9445 - precision_metric: 0.9449 - recall_metric: 0.9445 - mean_average_precision: 0.8365 - val_loss: -0.8710 - val_dice_metric: 0.9438 - val_jaccard_metric: 0.9022 - val_sensitivity_metric: 0.9488 - val_specificity_metric: 0.9488 - val_precision_metric: 0.9408 - val_recall_metric: 0.9488 - val_mean_average_precision: 0.8380
# Epoch 32/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.8732 - dice_metric: 0.9449 - jaccard_metric: 0.9024 - sensitivity_metric: 0.9452 - specificity_metric: 0.9452 - precision_metric: 0.9461 - recall_metric: 0.9452 - mean_average_precision: 0.8397 - val_loss: -0.8715 - val_dice_metric: 0.9441 - val_jaccard_metric: 0.9028 - val_sensitivity_metric: 0.9481 - val_specificity_metric: 0.9481 - val_precision_metric: 0.9422 - val_recall_metric: 0.9481 - val_mean_average_precision: 0.8386
# Epoch 33/60
# 77/77 [==============================] - 41s 521ms/step - loss: -0.8740 - dice_metric: 0.9454 - jaccard_metric: 0.9030 - sensitivity_metric: 0.9455 - specificity_metric: 0.9455 - precision_metric: 0.9466 - recall_metric: 0.9455 - mean_average_precision: 0.8407 - val_loss: -0.8718 - val_dice_metric: 0.9442 - val_jaccard_metric: 0.9030 - val_sensitivity_metric: 0.9482 - val_specificity_metric: 0.9482 - val_precision_metric: 0.9424 - val_recall_metric: 0.9482 - val_mean_average_precision: 0.8388
# Epoch 34/60
# 77/77 [==============================] - 41s 524ms/step - loss: -0.8746 - dice_metric: 0.9457 - jaccard_metric: 0.9035 - sensitivity_metric: 0.9457 - specificity_metric: 0.9457 - precision_metric: 0.9469 - recall_metric: 0.9457 - mean_average_precision: 0.8416 - val_loss: -0.8721 - val_dice_metric: 0.9444 - val_jaccard_metric: 0.9032 - val_sensitivity_metric: 0.9483 - val_specificity_metric: 0.9483 - val_precision_metric: 0.9425 - val_recall_metric: 0.9483 - val_mean_average_precision: 0.8394
# Epoch 35/60
# 77/77 [==============================] - 42s 548ms/step - loss: -0.8751 - dice_metric: 0.9459 - jaccard_metric: 0.9039 - sensitivity_metric: 0.9459 - specificity_metric: 0.9459 - precision_metric: 0.9472 - recall_metric: 0.9459 - mean_average_precision: 0.8423 - val_loss: -0.8724 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9033 - val_sensitivity_metric: 0.9484 - val_specificity_metric: 0.9484 - val_precision_metric: 0.9426 - val_recall_metric: 0.9484 - val_mean_average_precision: 0.8400
# Epoch 36/60
# 77/77 [==============================] - 41s 534ms/step - loss: -0.8756 - dice_metric: 0.9462 - jaccard_metric: 0.9043 - sensitivity_metric: 0.9461 - specificity_metric: 0.9461 - precision_metric: 0.9475 - recall_metric: 0.9461 - mean_average_precision: 0.8430 - val_loss: -0.8726 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9035 - val_sensitivity_metric: 0.9486 - val_specificity_metric: 0.9486 - val_precision_metric: 0.9426 - val_recall_metric: 0.9486 - val_mean_average_precision: 0.8402
# Epoch 37/60
# 77/77 [==============================] - 41s 535ms/step - loss: -0.8760 - dice_metric: 0.9464 - jaccard_metric: 0.9047 - sensitivity_metric: 0.9463 - specificity_metric: 0.9463 - precision_metric: 0.9478 - recall_metric: 0.9463 - mean_average_precision: 0.8439 - val_loss: -0.8729 - val_dice_metric: 0.9447 - val_jaccard_metric: 0.9037 - val_sensitivity_metric: 0.9487 - val_specificity_metric: 0.9487 - val_precision_metric: 0.9427 - val_recall_metric: 0.9487 - val_mean_average_precision: 0.8400
# Epoch 38/60
# 77/77 [==============================] - 42s 535ms/step - loss: -0.8765 - dice_metric: 0.9466 - jaccard_metric: 0.9050 - sensitivity_metric: 0.9465 - specificity_metric: 0.9465 - precision_metric: 0.9480 - recall_metric: 0.9465 - mean_average_precision: 0.8444 - val_loss: -0.8732 - val_dice_metric: 0.9448 - val_jaccard_metric: 0.9038 - val_sensitivity_metric: 0.9488 - val_specificity_metric: 0.9488 - val_precision_metric: 0.9428 - val_recall_metric: 0.9488 - val_mean_average_precision: 0.8406
# Epoch 39/60
# 77/77 [==============================] - 42s 534ms/step - loss: -0.8769 - dice_metric: 0.9468 - jaccard_metric: 0.9053 - sensitivity_metric: 0.9467 - specificity_metric: 0.9467 - precision_metric: 0.9482 - recall_metric: 0.9467 - mean_average_precision: 0.8450 - val_loss: -0.8734 - val_dice_metric: 0.9448 - val_jaccard_metric: 0.9040 - val_sensitivity_metric: 0.9490 - val_specificity_metric: 0.9490 - val_precision_metric: 0.9428 - val_recall_metric: 0.9490 - val_mean_average_precision: 0.8410
# Epoch 40/60
# 77/77 [==============================] - 41s 528ms/step - loss: -0.8773 - dice_metric: 0.9470 - jaccard_metric: 0.9056 - sensitivity_metric: 0.9469 - specificity_metric: 0.9469 - precision_metric: 0.9484 - recall_metric: 0.9469 - mean_average_precision: 0.8455 - val_loss: -0.8737 - val_dice_metric: 0.9449 - val_jaccard_metric: 0.9041 - val_sensitivity_metric: 0.9491 - val_specificity_metric: 0.9491 - val_precision_metric: 0.9428 - val_recall_metric: 0.9491 - val_mean_average_precision: 0.8411
# Epoch 41/60
# 77/77 [==============================] - 40s 521ms/step - loss: -0.8778 - dice_metric: 0.9472 - jaccard_metric: 0.9060 - sensitivity_metric: 0.9470 - specificity_metric: 0.9470 - precision_metric: 0.9486 - recall_metric: 0.9470 - mean_average_precision: 0.8463 - val_loss: -0.8739 - val_dice_metric: 0.9450 - val_jaccard_metric: 0.9043 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493 - val_precision_metric: 0.9429 - val_recall_metric: 0.9493 - val_mean_average_precision: 0.8411
# Epoch 42/60
# 77/77 [==============================] - 42s 546ms/step - loss: -0.8782 - dice_metric: 0.9474 - jaccard_metric: 0.9063 - sensitivity_metric: 0.9472 - specificity_metric: 0.9472 - precision_metric: 0.9488 - recall_metric: 0.9472 - mean_average_precision: 0.8465 - val_loss: -0.8742 - val_dice_metric: 0.9451 - val_jaccard_metric: 0.9045 - val_sensitivity_metric: 0.9494 - val_specificity_metric: 0.9494 - val_precision_metric: 0.9430 - val_recall_metric: 0.9494 - val_mean_average_precision: 0.8411
# Epoch 43/60
# 77/77 [==============================] - 40s 516ms/step - loss: -0.8786 - dice_metric: 0.9476 - jaccard_metric: 0.9066 - sensitivity_metric: 0.9474 - specificity_metric: 0.9474 - precision_metric: 0.9490 - recall_metric: 0.9474 - mean_average_precision: 0.8469 - val_loss: -0.8745 - val_dice_metric: 0.9453 - val_jaccard_metric: 0.9047 - val_sensitivity_metric: 0.9495 - val_specificity_metric: 0.9495 - val_precision_metric: 0.9431 - val_recall_metric: 0.9495 - val_mean_average_precision: 0.8415
# Epoch 44/60
# 77/77 [==============================] - 40s 517ms/step - loss: -0.8790 - dice_metric: 0.9478 - jaccard_metric: 0.9068 - sensitivity_metric: 0.9475 - specificity_metric: 0.9475 - precision_metric: 0.9492 - recall_metric: 0.9475 - mean_average_precision: 0.8475 - val_loss: -0.8747 - val_dice_metric: 0.9454 - val_jaccard_metric: 0.9048 - val_sensitivity_metric: 0.9497 - val_specificity_metric: 0.9497 - val_precision_metric: 0.9432 - val_recall_metric: 0.9497 - val_mean_average_precision: 0.8413
# Epoch 45/60
# 77/77 [==============================] - 41s 521ms/step - loss: -0.8794 - dice_metric: 0.9480 - jaccard_metric: 0.9071 - sensitivity_metric: 0.9477 - specificity_metric: 0.9477 - precision_metric: 0.9494 - recall_metric: 0.9477 - mean_average_precision: 0.8480 - val_loss: -0.8750 - val_dice_metric: 0.9454 - val_jaccard_metric: 0.9050 - val_sensitivity_metric: 0.9498 - val_specificity_metric: 0.9498 - val_precision_metric: 0.9432 - val_recall_metric: 0.9498 - val_mean_average_precision: 0.8417
# Epoch 46/60
# 77/77 [==============================] - 41s 521ms/step - loss: -0.8798 - dice_metric: 0.9481 - jaccard_metric: 0.9074 - sensitivity_metric: 0.9478 - specificity_metric: 0.9478 - precision_metric: 0.9496 - recall_metric: 0.9478 - mean_average_precision: 0.8485 - val_loss: -0.8753 - val_dice_metric: 0.9455 - val_jaccard_metric: 0.9051 - val_sensitivity_metric: 0.9499 - val_specificity_metric: 0.9499 - val_precision_metric: 0.9432 - val_recall_metric: 0.9499 - val_mean_average_precision: 0.8419
# Epoch 47/60
# 77/77 [==============================] - 40s 520ms/step - loss: -0.8802 - dice_metric: 0.9483 - jaccard_metric: 0.9077 - sensitivity_metric: 0.9480 - specificity_metric: 0.9480 - precision_metric: 0.9498 - recall_metric: 0.9480 - mean_average_precision: 0.8489 - val_loss: -0.8755 - val_dice_metric: 0.9456 - val_jaccard_metric: 0.9052 - val_sensitivity_metric: 0.9500 - val_specificity_metric: 0.9500 - val_precision_metric: 0.9434 - val_recall_metric: 0.9500 - val_mean_average_precision: 0.8419
# Epoch 48/60
# 77/77 [==============================] - 41s 530ms/step - loss: -0.8806 - dice_metric: 0.9485 - jaccard_metric: 0.9080 - sensitivity_metric: 0.9481 - specificity_metric: 0.9481 - precision_metric: 0.9500 - recall_metric: 0.9481 - mean_average_precision: 0.8495 - val_loss: -0.8758 - val_dice_metric: 0.9457 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9501 - val_specificity_metric: 0.9501 - val_precision_metric: 0.9434 - val_recall_metric: 0.9501 - val_mean_average_precision: 0.8421
# Epoch 49/60
# 77/77 [==============================] - 40s 519ms/step - loss: -0.8810 - dice_metric: 0.9487 - jaccard_metric: 0.9082 - sensitivity_metric: 0.9483 - specificity_metric: 0.9483 - precision_metric: 0.9501 - recall_metric: 0.9483 - mean_average_precision: 0.8499 - val_loss: -0.8761 - val_dice_metric: 0.9458 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9501 - val_specificity_metric: 0.9501 - val_precision_metric: 0.9436 - val_recall_metric: 0.9501 - val_mean_average_precision: 0.8423
# Epoch 50/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.8814 - dice_metric: 0.9488 - jaccard_metric: 0.9085 - sensitivity_metric: 0.9484 - specificity_metric: 0.9484 - precision_metric: 0.9503 - recall_metric: 0.9484 - mean_average_precision: 0.8505 - val_loss: -0.8763 - val_dice_metric: 0.9459 - val_jaccard_metric: 0.9057 - val_sensitivity_metric: 0.9503 - val_specificity_metric: 0.9503 - val_precision_metric: 0.9436 - val_recall_metric: 0.9503 - val_mean_average_precision: 0.8423
# Epoch 51/60
# 77/77 [==============================] - 40s 513ms/step - loss: -0.8818 - dice_metric: 0.9490 - jaccard_metric: 0.9088 - sensitivity_metric: 0.9486 - specificity_metric: 0.9486 - precision_metric: 0.9505 - recall_metric: 0.9486 - mean_average_precision: 0.8508 - val_loss: -0.8766 - val_dice_metric: 0.9460 - val_jaccard_metric: 0.9058 - val_sensitivity_metric: 0.9503 - val_specificity_metric: 0.9503 - val_precision_metric: 0.9437 - val_recall_metric: 0.9503 - val_mean_average_precision: 0.8425
# Epoch 52/60
# 77/77 [==============================] - 42s 534ms/step - loss: -0.8822 - dice_metric: 0.9491 - jaccard_metric: 0.9090 - sensitivity_metric: 0.9487 - specificity_metric: 0.9487 - precision_metric: 0.9507 - recall_metric: 0.9487 - mean_average_precision: 0.8514 - val_loss: -0.8768 - val_dice_metric: 0.9461 - val_jaccard_metric: 0.9060 - val_sensitivity_metric: 0.9505 - val_specificity_metric: 0.9505 - val_precision_metric: 0.9438 - val_recall_metric: 0.9505 - val_mean_average_precision: 0.8427
# Epoch 53/60
# 77/77 [==============================] - 41s 531ms/step - loss: -0.8826 - dice_metric: 0.9493 - jaccard_metric: 0.9093 - sensitivity_metric: 0.9489 - specificity_metric: 0.9489 - precision_metric: 0.9508 - recall_metric: 0.9489 - mean_average_precision: 0.8517 - val_loss: -0.8771 - val_dice_metric: 0.9461 - val_jaccard_metric: 0.9061 - val_sensitivity_metric: 0.9505 - val_specificity_metric: 0.9505 - val_precision_metric: 0.9439 - val_recall_metric: 0.9505 - val_mean_average_precision: 0.8427
# Epoch 54/60
# 77/77 [==============================] - 42s 538ms/step - loss: -0.8830 - dice_metric: 0.9495 - jaccard_metric: 0.9096 - sensitivity_metric: 0.9490 - specificity_metric: 0.9490 - precision_metric: 0.9510 - recall_metric: 0.9490 - mean_average_precision: 0.8521 - val_loss: -0.8774 - val_dice_metric: 0.9462 - val_jaccard_metric: 0.9063 - val_sensitivity_metric: 0.9506 - val_specificity_metric: 0.9506 - val_precision_metric: 0.9440 - val_recall_metric: 0.9506 - val_mean_average_precision: 0.8427
# Epoch 55/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.8834 - dice_metric: 0.9496 - jaccard_metric: 0.9098 - sensitivity_metric: 0.9492 - specificity_metric: 0.9492 - precision_metric: 0.9512 - recall_metric: 0.9492 - mean_average_precision: 0.8526 - val_loss: -0.8776 - val_dice_metric: 0.9463 - val_jaccard_metric: 0.9064 - val_sensitivity_metric: 0.9507 - val_specificity_metric: 0.9507 - val_precision_metric: 0.9441 - val_recall_metric: 0.9507 - val_mean_average_precision: 0.8429
# Epoch 56/60
# 77/77 [==============================] - 40s 520ms/step - loss: -0.8838 - dice_metric: 0.9498 - jaccard_metric: 0.9101 - sensitivity_metric: 0.9493 - specificity_metric: 0.9493 - precision_metric: 0.9513 - recall_metric: 0.9493 - mean_average_precision: 0.8529 - val_loss: -0.8779 - val_dice_metric: 0.9464 - val_jaccard_metric: 0.9065 - val_sensitivity_metric: 0.9508 - val_specificity_metric: 0.9508 - val_precision_metric: 0.9441 - val_recall_metric: 0.9508 - val_mean_average_precision: 0.8431
# Epoch 57/60
# 77/77 [==============================] - 41s 532ms/step - loss: -0.8842 - dice_metric: 0.9499 - jaccard_metric: 0.9103 - sensitivity_metric: 0.9494 - specificity_metric: 0.9494 - precision_metric: 0.9515 - recall_metric: 0.9494 - mean_average_precision: 0.8532 - val_loss: -0.8782 - val_dice_metric: 0.9465 - val_jaccard_metric: 0.9067 - val_sensitivity_metric: 0.9509 - val_specificity_metric: 0.9509 - val_precision_metric: 0.9441 - val_recall_metric: 0.9509 - val_mean_average_precision: 0.8435
# Epoch 58/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.8845 - dice_metric: 0.9501 - jaccard_metric: 0.9106 - sensitivity_metric: 0.9496 - specificity_metric: 0.9496 - precision_metric: 0.9517 - recall_metric: 0.9496 - mean_average_precision: 0.8536 - val_loss: -0.8784 - val_dice_metric: 0.9466 - val_jaccard_metric: 0.9068 - val_sensitivity_metric: 0.9509 - val_specificity_metric: 0.9509 - val_precision_metric: 0.9443 - val_recall_metric: 0.9509 - val_mean_average_precision: 0.8433
# Epoch 59/60
# 77/77 [==============================] - 40s 508ms/step - loss: -0.8849 - dice_metric: 0.9503 - jaccard_metric: 0.9108 - sensitivity_metric: 0.9497 - specificity_metric: 0.9497 - precision_metric: 0.9518 - recall_metric: 0.9497 - mean_average_precision: 0.8540 - val_loss: -0.8787 - val_dice_metric: 0.9466 - val_jaccard_metric: 0.9069 - val_sensitivity_metric: 0.9511 - val_specificity_metric: 0.9511 - val_precision_metric: 0.9443 - val_recall_metric: 0.9511 - val_mean_average_precision: 0.8435
# Epoch 60/60
# 77/77 [==============================] - 41s 535ms/step - loss: -0.8853 - dice_metric: 0.9504 - jaccard_metric: 0.9111 - sensitivity_metric: 0.9499 - specificity_metric: 0.9499 - precision_metric: 0.9520 - recall_metric: 0.9499 - mean_average_precision: 0.8545 - val_loss: -0.8789 - val_dice_metric: 0.9467 - val_jaccard_metric: 0.9071 - val_sensitivity_metric: 0.9511 - val_specificity_metric: 0.9511 - val_precision_metric: 0.9444 - val_recall_metric: 0.9511 - val_mean_average_precision: 0.8435

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.94639, std: 0.07204
# Jaccard Index mean: 0.90616, std: 0.11647
# Sensitivity mean: 0.94974, std: 0.07579
# Specificity mean: 0.94974, std: 0.07579
# Precision mean: 0.94402, std: 0.07168
# Recall mean: 0.94974, std: 0.07579
# mAP@50 mean: 0.99153, std: 0.06454
# mAP@50-95 mean: 0.84280, std: 0.10741
