# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  97%|███████████████████████████████████████▉ | 972M/998M [00:07<00:00, 100MB/s]
# 100%|█████████████████████████████████████████| 998M/998M [00:07<00:00, 136MB/s]

# %%
config = {"Seg_model":"RFFSkipsResUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import res_unet_rff_skips
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = res_unet_rff_skips(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 188s 1s/step - loss: -0.1128 - dice_metric: 0.2037 - jaccard_metric: 0.1209 - sensitivity_metric: 0.5561 - specificity_metric: 0.5561 - precision_metric: 0.5159 - recall_metric: 0.5561 - mean_average_precision: 1.8575e-04 - val_loss: -0.0766 - val_dice_metric: 0.3261 - val_jaccard_metric: 0.2241 - val_sensitivity_metric: 0.4869 - val_specificity_metric: 0.4869 - val_precision_metric: 0.4964 - val_recall_metric: 0.4869 - val_mean_average_precision: 0.0000e+00
# Epoch 2/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.1477 - dice_metric: 0.5772 - jaccard_metric: 0.4739 - sensitivity_metric: 0.8386 - specificity_metric: 0.8386 - precision_metric: 0.5963 - recall_metric: 0.8386 - mean_average_precision: 0.2865 - val_loss: -0.0761 - val_dice_metric: 0.4898 - val_jaccard_metric: 0.4794 - val_sensitivity_metric: 0.5002 - val_specificity_metric: 0.5002 - val_precision_metric: 0.5792 - val_recall_metric: 0.5002 - val_mean_average_precision: 0.4812
# Epoch 3/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.1619 - dice_metric: 0.7037 - jaccard_metric: 0.6077 - sensitivity_metric: 0.9214 - specificity_metric: 0.9214 - precision_metric: 0.6654 - recall_metric: 0.9214 - mean_average_precision: 0.4267 - val_loss: -0.0962 - val_dice_metric: 0.7037 - val_jaccard_metric: 0.6303 - val_sensitivity_metric: 0.6644 - val_specificity_metric: 0.6644 - val_precision_metric: 0.8064 - val_recall_metric: 0.6644 - val_mean_average_precision: 0.4965
# Epoch 4/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.1744 - dice_metric: 0.7074 - jaccard_metric: 0.6121 - sensitivity_metric: 0.9189 - specificity_metric: 0.9189 - precision_metric: 0.6781 - recall_metric: 0.9189 - mean_average_precision: 0.4241 - val_loss: -0.1504 - val_dice_metric: 0.7718 - val_jaccard_metric: 0.6921 - val_sensitivity_metric: 0.9004 - val_specificity_metric: 0.9004 - val_precision_metric: 0.7341 - val_recall_metric: 0.9004 - val_mean_average_precision: 0.5586
# Epoch 5/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.1955 - dice_metric: 0.6959 - jaccard_metric: 0.6027 - sensitivity_metric: 0.9038 - specificity_metric: 0.9038 - precision_metric: 0.6852 - recall_metric: 0.9038 - mean_average_precision: 0.4217 - val_loss: -0.1863 - val_dice_metric: 0.7034 - val_jaccard_metric: 0.6202 - val_sensitivity_metric: 0.9090 - val_specificity_metric: 0.9090 - val_precision_metric: 0.6908 - val_recall_metric: 0.9090 - val_mean_average_precision: 0.4797
# Epoch 6/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.2395 - dice_metric: 0.7430 - jaccard_metric: 0.6580 - sensitivity_metric: 0.9171 - specificity_metric: 0.9171 - precision_metric: 0.7255 - recall_metric: 0.9171 - mean_average_precision: 0.4985 - val_loss: -0.2597 - val_dice_metric: 0.8325 - val_jaccard_metric: 0.7660 - val_sensitivity_metric: 0.9184 - val_specificity_metric: 0.9184 - val_precision_metric: 0.8035 - val_recall_metric: 0.9184 - val_mean_average_precision: 0.6505
# Epoch 7/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.2841 - dice_metric: 0.8029 - jaccard_metric: 0.7272 - sensitivity_metric: 0.9398 - specificity_metric: 0.9398 - precision_metric: 0.7713 - recall_metric: 0.9398 - mean_average_precision: 0.5892 - val_loss: -0.2888 - val_dice_metric: 0.8294 - val_jaccard_metric: 0.7653 - val_sensitivity_metric: 0.9456 - val_specificity_metric: 0.9456 - val_precision_metric: 0.7969 - val_recall_metric: 0.9456 - val_mean_average_precision: 0.6599
# Epoch 8/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.3180 - dice_metric: 0.8240 - jaccard_metric: 0.7533 - sensitivity_metric: 0.9453 - specificity_metric: 0.9453 - precision_metric: 0.7921 - recall_metric: 0.9453 - mean_average_precision: 0.6276 - val_loss: -0.3142 - val_dice_metric: 0.8501 - val_jaccard_metric: 0.7914 - val_sensitivity_metric: 0.9458 - val_specificity_metric: 0.9458 - val_precision_metric: 0.8242 - val_recall_metric: 0.9458 - val_mean_average_precision: 0.6966
# Epoch 9/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.3495 - dice_metric: 0.8368 - jaccard_metric: 0.7695 - sensitivity_metric: 0.9480 - specificity_metric: 0.9480 - precision_metric: 0.8060 - recall_metric: 0.9480 - mean_average_precision: 0.6516 - val_loss: -0.3457 - val_dice_metric: 0.8613 - val_jaccard_metric: 0.8055 - val_sensitivity_metric: 0.9453 - val_specificity_metric: 0.9453 - val_precision_metric: 0.8382 - val_recall_metric: 0.9453 - val_mean_average_precision: 0.7214
# Epoch 10/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.3799 - dice_metric: 0.8463 - jaccard_metric: 0.7817 - sensitivity_metric: 0.9492 - specificity_metric: 0.9492 - precision_metric: 0.8172 - recall_metric: 0.9492 - mean_average_precision: 0.6710 - val_loss: -0.3807 - val_dice_metric: 0.8689 - val_jaccard_metric: 0.8144 - val_sensitivity_metric: 0.9464 - val_specificity_metric: 0.9464 - val_precision_metric: 0.8465 - val_recall_metric: 0.9464 - val_mean_average_precision: 0.7304
# Epoch 11/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.4091 - dice_metric: 0.8539 - jaccard_metric: 0.7915 - sensitivity_metric: 0.9494 - specificity_metric: 0.9494 - precision_metric: 0.8269 - recall_metric: 0.9494 - mean_average_precision: 0.6861 - val_loss: -0.4105 - val_dice_metric: 0.8737 - val_jaccard_metric: 0.8200 - val_sensitivity_metric: 0.9474 - val_specificity_metric: 0.9474 - val_precision_metric: 0.8522 - val_recall_metric: 0.9474 - val_mean_average_precision: 0.7363
# Epoch 12/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.4373 - dice_metric: 0.8610 - jaccard_metric: 0.8005 - sensitivity_metric: 0.9497 - specificity_metric: 0.9497 - precision_metric: 0.8357 - recall_metric: 0.9497 - mean_average_precision: 0.7008 - val_loss: -0.4358 - val_dice_metric: 0.8713 - val_jaccard_metric: 0.8178 - val_sensitivity_metric: 0.9523 - val_specificity_metric: 0.9523 - val_precision_metric: 0.8480 - val_recall_metric: 0.9523 - val_mean_average_precision: 0.7342
# Epoch 13/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.4646 - dice_metric: 0.8677 - jaccard_metric: 0.8090 - sensitivity_metric: 0.9499 - specificity_metric: 0.9499 - precision_metric: 0.8442 - recall_metric: 0.9499 - mean_average_precision: 0.7139 - val_loss: -0.4569 - val_dice_metric: 0.8694 - val_jaccard_metric: 0.8161 - val_sensitivity_metric: 0.9543 - val_specificity_metric: 0.9543 - val_precision_metric: 0.8456 - val_recall_metric: 0.9543 - val_mean_average_precision: 0.7314
# Epoch 14/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.4912 - dice_metric: 0.8743 - jaccard_metric: 0.8173 - sensitivity_metric: 0.9499 - specificity_metric: 0.9499 - precision_metric: 0.8524 - recall_metric: 0.9499 - mean_average_precision: 0.7261 - val_loss: -0.4838 - val_dice_metric: 0.8637 - val_jaccard_metric: 0.8103 - val_sensitivity_metric: 0.9546 - val_specificity_metric: 0.9546 - val_precision_metric: 0.8415 - val_recall_metric: 0.9546 - val_mean_average_precision: 0.7256
# Epoch 15/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5169 - dice_metric: 0.8809 - jaccard_metric: 0.8253 - sensitivity_metric: 0.9500 - specificity_metric: 0.9500 - precision_metric: 0.8602 - recall_metric: 0.9500 - mean_average_precision: 0.7366 - val_loss: -0.5043 - val_dice_metric: 0.8672 - val_jaccard_metric: 0.8140 - val_sensitivity_metric: 0.9566 - val_specificity_metric: 0.9566 - val_precision_metric: 0.8436 - val_recall_metric: 0.9566 - val_mean_average_precision: 0.7275
# Epoch 16/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.5417 - dice_metric: 0.8875 - jaccard_metric: 0.8331 - sensitivity_metric: 0.9500 - specificity_metric: 0.9500 - precision_metric: 0.8679 - recall_metric: 0.9500 - mean_average_precision: 0.7474 - val_loss: -0.5290 - val_dice_metric: 0.8751 - val_jaccard_metric: 0.8223 - val_sensitivity_metric: 0.9587 - val_specificity_metric: 0.9587 - val_precision_metric: 0.8494 - val_recall_metric: 0.9587 - val_mean_average_precision: 0.7352
# Epoch 17/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.5653 - dice_metric: 0.8933 - jaccard_metric: 0.8400 - sensitivity_metric: 0.9499 - specificity_metric: 0.9499 - precision_metric: 0.8748 - recall_metric: 0.9499 - mean_average_precision: 0.7562 - val_loss: -0.5497 - val_dice_metric: 0.8794 - val_jaccard_metric: 0.8265 - val_sensitivity_metric: 0.9608 - val_specificity_metric: 0.9608 - val_precision_metric: 0.8516 - val_recall_metric: 0.9608 - val_mean_average_precision: 0.7407
# Epoch 18/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.5880 - dice_metric: 0.8986 - jaccard_metric: 0.8462 - sensitivity_metric: 0.9497 - specificity_metric: 0.9497 - precision_metric: 0.8812 - recall_metric: 0.9497 - mean_average_precision: 0.7648 - val_loss: -0.5703 - val_dice_metric: 0.8891 - val_jaccard_metric: 0.8368 - val_sensitivity_metric: 0.9604 - val_specificity_metric: 0.9604 - val_precision_metric: 0.8615 - val_recall_metric: 0.9604 - val_mean_average_precision: 0.7523
# Epoch 19/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.6097 - dice_metric: 0.9038 - jaccard_metric: 0.8523 - sensitivity_metric: 0.9493 - specificity_metric: 0.9493 - precision_metric: 0.8876 - recall_metric: 0.9493 - mean_average_precision: 0.7724 - val_loss: -0.5854 - val_dice_metric: 0.8870 - val_jaccard_metric: 0.8326 - val_sensitivity_metric: 0.9623 - val_specificity_metric: 0.9623 - val_precision_metric: 0.8554 - val_recall_metric: 0.9623 - val_mean_average_precision: 0.7466
# Epoch 20/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.6303 - dice_metric: 0.9086 - jaccard_metric: 0.8578 - sensitivity_metric: 0.9489 - specificity_metric: 0.9489 - precision_metric: 0.8935 - recall_metric: 0.9489 - mean_average_precision: 0.7790 - val_loss: -0.6052 - val_dice_metric: 0.8927 - val_jaccard_metric: 0.8386 - val_sensitivity_metric: 0.9622 - val_specificity_metric: 0.9622 - val_precision_metric: 0.8613 - val_recall_metric: 0.9622 - val_mean_average_precision: 0.7531
# Epoch 21/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.6497 - dice_metric: 0.9134 - jaccard_metric: 0.8630 - sensitivity_metric: 0.9477 - specificity_metric: 0.9477 - precision_metric: 0.8995 - recall_metric: 0.9477 - mean_average_precision: 0.7844 - val_loss: -0.6238 - val_dice_metric: 0.8939 - val_jaccard_metric: 0.8398 - val_sensitivity_metric: 0.9638 - val_specificity_metric: 0.9638 - val_precision_metric: 0.8616 - val_recall_metric: 0.9638 - val_mean_average_precision: 0.7529
# Epoch 22/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.6685 - dice_metric: 0.9175 - jaccard_metric: 0.8677 - sensitivity_metric: 0.9467 - specificity_metric: 0.9467 - precision_metric: 0.9051 - recall_metric: 0.9467 - mean_average_precision: 0.7892 - val_loss: -0.6488 - val_dice_metric: 0.9094 - val_jaccard_metric: 0.8595 - val_sensitivity_metric: 0.9608 - val_specificity_metric: 0.9608 - val_precision_metric: 0.8846 - val_recall_metric: 0.9608 - val_mean_average_precision: 0.7781
# Epoch 23/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.6872 - dice_metric: 0.9216 - jaccard_metric: 0.8725 - sensitivity_metric: 0.9462 - specificity_metric: 0.9462 - precision_metric: 0.9108 - recall_metric: 0.9462 - mean_average_precision: 0.7939 - val_loss: -0.6737 - val_dice_metric: 0.9200 - val_jaccard_metric: 0.8726 - val_sensitivity_metric: 0.9574 - val_specificity_metric: 0.9574 - val_precision_metric: 0.9008 - val_recall_metric: 0.9574 - val_mean_average_precision: 0.7940
# Epoch 24/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.7055 - dice_metric: 0.9249 - jaccard_metric: 0.8765 - sensitivity_metric: 0.9457 - specificity_metric: 0.9457 - precision_metric: 0.9157 - recall_metric: 0.9457 - mean_average_precision: 0.7984 - val_loss: -0.6932 - val_dice_metric: 0.9262 - val_jaccard_metric: 0.8799 - val_sensitivity_metric: 0.9549 - val_specificity_metric: 0.9549 - val_precision_metric: 0.9108 - val_recall_metric: 0.9549 - val_mean_average_precision: 0.7979
# Epoch 25/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.7228 - dice_metric: 0.9277 - jaccard_metric: 0.8799 - sensitivity_metric: 0.9449 - specificity_metric: 0.9449 - precision_metric: 0.9202 - recall_metric: 0.9449 - mean_average_precision: 0.8023 - val_loss: -0.7095 - val_dice_metric: 0.9316 - val_jaccard_metric: 0.8864 - val_sensitivity_metric: 0.9530 - val_specificity_metric: 0.9530 - val_precision_metric: 0.9192 - val_recall_metric: 0.9530 - val_mean_average_precision: 0.8059
# Epoch 26/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.7390 - dice_metric: 0.9305 - jaccard_metric: 0.8835 - sensitivity_metric: 0.9447 - specificity_metric: 0.9447 - precision_metric: 0.9245 - recall_metric: 0.9447 - mean_average_precision: 0.8067 - val_loss: -0.7258 - val_dice_metric: 0.9321 - val_jaccard_metric: 0.8869 - val_sensitivity_metric: 0.9555 - val_specificity_metric: 0.9555 - val_precision_metric: 0.9176 - val_recall_metric: 0.9555 - val_mean_average_precision: 0.8085
# Epoch 27/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.7539 - dice_metric: 0.9329 - jaccard_metric: 0.8865 - sensitivity_metric: 0.9446 - specificity_metric: 0.9446 - precision_metric: 0.9280 - recall_metric: 0.9446 - mean_average_precision: 0.8112 - val_loss: -0.7411 - val_dice_metric: 0.9339 - val_jaccard_metric: 0.8892 - val_sensitivity_metric: 0.9547 - val_specificity_metric: 0.9547 - val_precision_metric: 0.9205 - val_recall_metric: 0.9547 - val_mean_average_precision: 0.8122
# Epoch 28/60
# 77/77 [==============================] - 104s 1s/step - loss: -0.7674 - dice_metric: 0.9347 - jaccard_metric: 0.8890 - sensitivity_metric: 0.9442 - specificity_metric: 0.9442 - precision_metric: 0.9312 - recall_metric: 0.9442 - mean_average_precision: 0.8148 - val_loss: -0.7561 - val_dice_metric: 0.9374 - val_jaccard_metric: 0.8941 - val_sensitivity_metric: 0.9517 - val_specificity_metric: 0.9517 - val_precision_metric: 0.9281 - val_recall_metric: 0.9517 - val_mean_average_precision: 0.8214
# Epoch 29/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.7798 - dice_metric: 0.9358 - jaccard_metric: 0.8903 - sensitivity_metric: 0.9434 - specificity_metric: 0.9434 - precision_metric: 0.9336 - recall_metric: 0.9434 - mean_average_precision: 0.8164 - val_loss: -0.7703 - val_dice_metric: 0.9393 - val_jaccard_metric: 0.8968 - val_sensitivity_metric: 0.9497 - val_specificity_metric: 0.9497 - val_precision_metric: 0.9331 - val_recall_metric: 0.9497 - val_mean_average_precision: 0.8275
# Epoch 30/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.7915 - dice_metric: 0.9360 - jaccard_metric: 0.8906 - sensitivity_metric: 0.9415 - specificity_metric: 0.9415 - precision_metric: 0.9359 - recall_metric: 0.9415 - mean_average_precision: 0.8176 - val_loss: -0.7943 - val_dice_metric: 0.9392 - val_jaccard_metric: 0.8967 - val_sensitivity_metric: 0.9519 - val_specificity_metric: 0.9519 - val_precision_metric: 0.9316 - val_recall_metric: 0.9519 - val_mean_average_precision: 0.8275
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.8016 - dice_metric: 0.9392 - jaccard_metric: 0.8951 - sensitivity_metric: 0.9432 - specificity_metric: 0.9432 - precision_metric: 0.9391 - recall_metric: 0.9432 - mean_average_precision: 0.8258 - val_loss: -0.8006 - val_dice_metric: 0.9443 - val_jaccard_metric: 0.9045 - val_sensitivity_metric: 0.9441 - val_specificity_metric: 0.9441 - val_precision_metric: 0.9478 - val_recall_metric: 0.9441 - val_mean_average_precision: 0.8424
# Epoch 32/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.8041 - dice_metric: 0.9403 - jaccard_metric: 0.8966 - sensitivity_metric: 0.9436 - specificity_metric: 0.9436 - precision_metric: 0.9404 - recall_metric: 0.9436 - mean_average_precision: 0.8281 - val_loss: -0.8030 - val_dice_metric: 0.9443 - val_jaccard_metric: 0.9045 - val_sensitivity_metric: 0.9462 - val_specificity_metric: 0.9462 - val_precision_metric: 0.9457 - val_recall_metric: 0.9462 - val_mean_average_precision: 0.8428
# Epoch 33/60
# 77/77 [==============================] - 104s 1s/step - loss: -0.8056 - dice_metric: 0.9407 - jaccard_metric: 0.8972 - sensitivity_metric: 0.9438 - specificity_metric: 0.9438 - precision_metric: 0.9409 - recall_metric: 0.9438 - mean_average_precision: 0.8292 - val_loss: -0.8047 - val_dice_metric: 0.9442 - val_jaccard_metric: 0.9044 - val_sensitivity_metric: 0.9472 - val_specificity_metric: 0.9472 - val_precision_metric: 0.9446 - val_recall_metric: 0.9472 - val_mean_average_precision: 0.8420
# Epoch 34/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.8069 - dice_metric: 0.9410 - jaccard_metric: 0.8976 - sensitivity_metric: 0.9439 - specificity_metric: 0.9439 - precision_metric: 0.9413 - recall_metric: 0.9439 - mean_average_precision: 0.8299 - val_loss: -0.8060 - val_dice_metric: 0.9442 - val_jaccard_metric: 0.9044 - val_sensitivity_metric: 0.9481 - val_specificity_metric: 0.9481 - val_precision_metric: 0.9437 - val_recall_metric: 0.9481 - val_mean_average_precision: 0.8432
# Epoch 35/60
# 77/77 [==============================] - 104s 1s/step - loss: -0.8082 - dice_metric: 0.9413 - jaccard_metric: 0.8980 - sensitivity_metric: 0.9441 - specificity_metric: 0.9441 - precision_metric: 0.9417 - recall_metric: 0.9441 - mean_average_precision: 0.8306 - val_loss: -0.8072 - val_dice_metric: 0.9442 - val_jaccard_metric: 0.9044 - val_sensitivity_metric: 0.9484 - val_specificity_metric: 0.9484 - val_precision_metric: 0.9434 - val_recall_metric: 0.9484 - val_mean_average_precision: 0.8432
# Epoch 36/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.8094 - dice_metric: 0.9415 - jaccard_metric: 0.8983 - sensitivity_metric: 0.9442 - specificity_metric: 0.9442 - precision_metric: 0.9420 - recall_metric: 0.9442 - mean_average_precision: 0.8315 - val_loss: -0.8084 - val_dice_metric: 0.9443 - val_jaccard_metric: 0.9045 - val_sensitivity_metric: 0.9488 - val_specificity_metric: 0.9488 - val_precision_metric: 0.9432 - val_recall_metric: 0.9488 - val_mean_average_precision: 0.8438
# Epoch 37/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.8106 - dice_metric: 0.9417 - jaccard_metric: 0.8987 - sensitivity_metric: 0.9443 - specificity_metric: 0.9443 - precision_metric: 0.9423 - recall_metric: 0.9443 - mean_average_precision: 0.8320 - val_loss: -0.8095 - val_dice_metric: 0.9444 - val_jaccard_metric: 0.9046 - val_sensitivity_metric: 0.9489 - val_specificity_metric: 0.9489 - val_precision_metric: 0.9432 - val_recall_metric: 0.9489 - val_mean_average_precision: 0.8442
# Epoch 38/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.8118 - dice_metric: 0.9420 - jaccard_metric: 0.8990 - sensitivity_metric: 0.9444 - specificity_metric: 0.9444 - precision_metric: 0.9426 - recall_metric: 0.9444 - mean_average_precision: 0.8324 - val_loss: -0.8106 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9048 - val_sensitivity_metric: 0.9490 - val_specificity_metric: 0.9490 - val_precision_metric: 0.9433 - val_recall_metric: 0.9490 - val_mean_average_precision: 0.8444
# Epoch 39/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.8129 - dice_metric: 0.9422 - jaccard_metric: 0.8993 - sensitivity_metric: 0.9445 - specificity_metric: 0.9445 - precision_metric: 0.9429 - recall_metric: 0.9445 - mean_average_precision: 0.8330 - val_loss: -0.8116 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9049 - val_sensitivity_metric: 0.9492 - val_specificity_metric: 0.9492 - val_precision_metric: 0.9433 - val_recall_metric: 0.9492 - val_mean_average_precision: 0.8446
# Epoch 40/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.8141 - dice_metric: 0.9424 - jaccard_metric: 0.8996 - sensitivity_metric: 0.9446 - specificity_metric: 0.9446 - precision_metric: 0.9431 - recall_metric: 0.9446 - mean_average_precision: 0.8335 - val_loss: -0.8127 - val_dice_metric: 0.9447 - val_jaccard_metric: 0.9051 - val_sensitivity_metric: 0.9492 - val_specificity_metric: 0.9492 - val_precision_metric: 0.9435 - val_recall_metric: 0.9492 - val_mean_average_precision: 0.8452
# Epoch 41/60
# 77/77 [==============================] - 107s 1s/step - loss: -0.8152 - dice_metric: 0.9426 - jaccard_metric: 0.8999 - sensitivity_metric: 0.9447 - specificity_metric: 0.9447 - precision_metric: 0.9434 - recall_metric: 0.9447 - mean_average_precision: 0.8340 - val_loss: -0.8138 - val_dice_metric: 0.9447 - val_jaccard_metric: 0.9052 - val_sensitivity_metric: 0.9492 - val_specificity_metric: 0.9492 - val_precision_metric: 0.9436 - val_recall_metric: 0.9492 - val_mean_average_precision: 0.8460
# Epoch 42/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.8164 - dice_metric: 0.9427 - jaccard_metric: 0.9001 - sensitivity_metric: 0.9448 - specificity_metric: 0.9448 - precision_metric: 0.9437 - recall_metric: 0.9448 - mean_average_precision: 0.8345 - val_loss: -0.8148 - val_dice_metric: 0.9448 - val_jaccard_metric: 0.9053 - val_sensitivity_metric: 0.9492 - val_specificity_metric: 0.9492 - val_precision_metric: 0.9437 - val_recall_metric: 0.9492 - val_mean_average_precision: 0.8464
# Epoch 43/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.8175 - dice_metric: 0.9429 - jaccard_metric: 0.9004 - sensitivity_metric: 0.9448 - specificity_metric: 0.9448 - precision_metric: 0.9439 - recall_metric: 0.9448 - mean_average_precision: 0.8352 - val_loss: -0.8159 - val_dice_metric: 0.9449 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493 - val_precision_metric: 0.9437 - val_recall_metric: 0.9493 - val_mean_average_precision: 0.8469
# Epoch 44/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.8186 - dice_metric: 0.9431 - jaccard_metric: 0.9006 - sensitivity_metric: 0.9449 - specificity_metric: 0.9449 - precision_metric: 0.9442 - recall_metric: 0.9449 - mean_average_precision: 0.8355 - val_loss: -0.8169 - val_dice_metric: 0.9450 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493 - val_precision_metric: 0.9438 - val_recall_metric: 0.9493 - val_mean_average_precision: 0.8469
# Epoch 45/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.8197 - dice_metric: 0.9433 - jaccard_metric: 0.9009 - sensitivity_metric: 0.9450 - specificity_metric: 0.9450 - precision_metric: 0.9444 - recall_metric: 0.9450 - mean_average_precision: 0.8360 - val_loss: -0.8179 - val_dice_metric: 0.9450 - val_jaccard_metric: 0.9056 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493 - val_precision_metric: 0.9440 - val_recall_metric: 0.9493 - val_mean_average_precision: 0.8473
# Epoch 46/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.8208 - dice_metric: 0.9434 - jaccard_metric: 0.9011 - sensitivity_metric: 0.9450 - specificity_metric: 0.9450 - precision_metric: 0.9447 - recall_metric: 0.9450 - mean_average_precision: 0.8367 - val_loss: -0.8189 - val_dice_metric: 0.9451 - val_jaccard_metric: 0.9057 - val_sensitivity_metric: 0.9494 - val_specificity_metric: 0.9494 - val_precision_metric: 0.9440 - val_recall_metric: 0.9494 - val_mean_average_precision: 0.8475
# Epoch 47/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.8219 - dice_metric: 0.9436 - jaccard_metric: 0.9014 - sensitivity_metric: 0.9451 - specificity_metric: 0.9451 - precision_metric: 0.9449 - recall_metric: 0.9451 - mean_average_precision: 0.8373 - val_loss: -0.8198 - val_dice_metric: 0.9451 - val_jaccard_metric: 0.9057 - val_sensitivity_metric: 0.9494 - val_specificity_metric: 0.9494 - val_precision_metric: 0.9439 - val_recall_metric: 0.9494 - val_mean_average_precision: 0.8471
# Epoch 48/60
# 77/77 [==============================] - 104s 1s/step - loss: -0.8229 - dice_metric: 0.9438 - jaccard_metric: 0.9016 - sensitivity_metric: 0.9452 - specificity_metric: 0.9452 - precision_metric: 0.9451 - recall_metric: 0.9452 - mean_average_precision: 0.8378 - val_loss: -0.8208 - val_dice_metric: 0.9452 - val_jaccard_metric: 0.9058 - val_sensitivity_metric: 0.9495 - val_specificity_metric: 0.9495 - val_precision_metric: 0.9440 - val_recall_metric: 0.9495 - val_mean_average_precision: 0.8473
# Epoch 49/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.8240 - dice_metric: 0.9439 - jaccard_metric: 0.9018 - sensitivity_metric: 0.9452 - specificity_metric: 0.9452 - precision_metric: 0.9454 - recall_metric: 0.9452 - mean_average_precision: 0.8382 - val_loss: -0.8218 - val_dice_metric: 0.9452 - val_jaccard_metric: 0.9059 - val_sensitivity_metric: 0.9495 - val_specificity_metric: 0.9495 - val_precision_metric: 0.9441 - val_recall_metric: 0.9495 - val_mean_average_precision: 0.8471
# Epoch 50/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.8250 - dice_metric: 0.9441 - jaccard_metric: 0.9021 - sensitivity_metric: 0.9453 - specificity_metric: 0.9453 - precision_metric: 0.9456 - recall_metric: 0.9453 - mean_average_precision: 0.8386 - val_loss: -0.8228 - val_dice_metric: 0.9453 - val_jaccard_metric: 0.9060 - val_sensitivity_metric: 0.9496 - val_specificity_metric: 0.9496 - val_precision_metric: 0.9441 - val_recall_metric: 0.9496 - val_mean_average_precision: 0.8475
# Epoch 51/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.8261 - dice_metric: 0.9442 - jaccard_metric: 0.9023 - sensitivity_metric: 0.9454 - specificity_metric: 0.9454 - precision_metric: 0.9458 - recall_metric: 0.9454 - mean_average_precision: 0.8390 - val_loss: -0.8237 - val_dice_metric: 0.9453 - val_jaccard_metric: 0.9060 - val_sensitivity_metric: 0.9496 - val_specificity_metric: 0.9496 - val_precision_metric: 0.9442 - val_recall_metric: 0.9496 - val_mean_average_precision: 0.8479
# Epoch 52/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.8271 - dice_metric: 0.9444 - jaccard_metric: 0.9025 - sensitivity_metric: 0.9454 - specificity_metric: 0.9454 - precision_metric: 0.9460 - recall_metric: 0.9454 - mean_average_precision: 0.8395 - val_loss: -0.8247 - val_dice_metric: 0.9454 - val_jaccard_metric: 0.9061 - val_sensitivity_metric: 0.9495 - val_specificity_metric: 0.9495 - val_precision_metric: 0.9443 - val_recall_metric: 0.9495 - val_mean_average_precision: 0.8477
# Epoch 53/60
# 77/77 [==============================] - 98s 1s/step - loss: -0.8281 - dice_metric: 0.9445 - jaccard_metric: 0.9027 - sensitivity_metric: 0.9455 - specificity_metric: 0.9455 - precision_metric: 0.9462 - recall_metric: 0.9455 - mean_average_precision: 0.8400 - val_loss: -0.8256 - val_dice_metric: 0.9454 - val_jaccard_metric: 0.9062 - val_sensitivity_metric: 0.9497 - val_specificity_metric: 0.9497 - val_precision_metric: 0.9443 - val_recall_metric: 0.9497 - val_mean_average_precision: 0.8477
# Epoch 54/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.8291 - dice_metric: 0.9447 - jaccard_metric: 0.9030 - sensitivity_metric: 0.9455 - specificity_metric: 0.9455 - precision_metric: 0.9464 - recall_metric: 0.9455 - mean_average_precision: 0.8404 - val_loss: -0.8265 - val_dice_metric: 0.9454 - val_jaccard_metric: 0.9062 - val_sensitivity_metric: 0.9497 - val_specificity_metric: 0.9497 - val_precision_metric: 0.9442 - val_recall_metric: 0.9497 - val_mean_average_precision: 0.8479
# Epoch 55/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.8302 - dice_metric: 0.9448 - jaccard_metric: 0.9032 - sensitivity_metric: 0.9456 - specificity_metric: 0.9456 - precision_metric: 0.9467 - recall_metric: 0.9456 - mean_average_precision: 0.8408 - val_loss: -0.8274 - val_dice_metric: 0.9455 - val_jaccard_metric: 0.9063 - val_sensitivity_metric: 0.9497 - val_specificity_metric: 0.9497 - val_precision_metric: 0.9443 - val_recall_metric: 0.9497 - val_mean_average_precision: 0.8483
# Epoch 56/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.8312 - dice_metric: 0.9450 - jaccard_metric: 0.9034 - sensitivity_metric: 0.9457 - specificity_metric: 0.9457 - precision_metric: 0.9469 - recall_metric: 0.9457 - mean_average_precision: 0.8412 - val_loss: -0.8282 - val_dice_metric: 0.9455 - val_jaccard_metric: 0.9063 - val_sensitivity_metric: 0.9497 - val_specificity_metric: 0.9497 - val_precision_metric: 0.9444 - val_recall_metric: 0.9497 - val_mean_average_precision: 0.8487
# Epoch 57/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.8321 - dice_metric: 0.9451 - jaccard_metric: 0.9036 - sensitivity_metric: 0.9457 - specificity_metric: 0.9457 - precision_metric: 0.9470 - recall_metric: 0.9457 - mean_average_precision: 0.8415 - val_loss: -0.8291 - val_dice_metric: 0.9455 - val_jaccard_metric: 0.9064 - val_sensitivity_metric: 0.9498 - val_specificity_metric: 0.9498 - val_precision_metric: 0.9444 - val_recall_metric: 0.9498 - val_mean_average_precision: 0.8485
# Epoch 58/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.8331 - dice_metric: 0.9452 - jaccard_metric: 0.9038 - sensitivity_metric: 0.9458 - specificity_metric: 0.9458 - precision_metric: 0.9473 - recall_metric: 0.9458 - mean_average_precision: 0.8418 - val_loss: -0.8300 - val_dice_metric: 0.9456 - val_jaccard_metric: 0.9065 - val_sensitivity_metric: 0.9498 - val_specificity_metric: 0.9498 - val_precision_metric: 0.9445 - val_recall_metric: 0.9498 - val_mean_average_precision: 0.8489
# Epoch 59/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.8341 - dice_metric: 0.9454 - jaccard_metric: 0.9040 - sensitivity_metric: 0.9458 - specificity_metric: 0.9458 - precision_metric: 0.9474 - recall_metric: 0.9458 - mean_average_precision: 0.8422 - val_loss: -0.8309 - val_dice_metric: 0.9456 - val_jaccard_metric: 0.9065 - val_sensitivity_metric: 0.9498 - val_specificity_metric: 0.9498 - val_precision_metric: 0.9446 - val_recall_metric: 0.9498 - val_mean_average_precision: 0.8491
# Epoch 60/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.8351 - dice_metric: 0.9455 - jaccard_metric: 0.9042 - sensitivity_metric: 0.9459 - specificity_metric: 0.9459 - precision_metric: 0.9476 - recall_metric: 0.9459 - mean_average_precision: 0.8426 - val_loss: -0.8318 - val_dice_metric: 0.9457 - val_jaccard_metric: 0.9066 - val_sensitivity_metric: 0.9498 - val_specificity_metric: 0.9498 - val_precision_metric: 0.9446 - val_recall_metric: 0.9498 - val_mean_average_precision: 0.8491

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.94442, std: 0.08240
# Jaccard Index mean: 0.90464, std: 0.12815
# Sensitivity mean: 0.94655, std: 0.08886
# Specificity mean: 0.94655, std: 0.08886
# Precision mean: 0.94446, std: 0.08213
# Recall mean: 0.94655, std: 0.08886
# mAP@50 mean: 0.98729, std: 0.07870
# mAP@50-95 mean: 0.83941, std: 0.12853
