# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|████████████████████████████████████████▋| 989M/998M [00:04<00:00, 287MB/s]
# 100%|█████████████████████████████████████████| 998M/998M [00:04<00:00, 237MB/s]

# %%
config = {"Seg_model":"FCNMobV2","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import fcn_mobilenetv2
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = fcn_mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 100s 908ms/step - loss: -0.2412 - dice_metric: 0.5227 - jaccard_metric: 0.4270 - sensitivity_metric: 0.7777 - specificity_metric: 0.7777 - val_loss: -0.1425 - val_dice_metric: 0.5095 - val_jaccard_metric: 0.4026 - val_sensitivity_metric: 0.8288 - val_specificity_metric: 0.8288
# Epoch 2/60
# 77/77 [==============================] - 64s 822ms/step - loss: -0.4984 - dice_metric: 0.6341 - jaccard_metric: 0.5727 - sensitivity_metric: 0.8107 - specificity_metric: 0.8107 - val_loss: -0.5064 - val_dice_metric: 0.9283 - val_jaccard_metric: 0.8802 - val_sensitivity_metric: 0.9055 - val_specificity_metric: 0.9055
# Epoch 3/60
# 77/77 [==============================] - 62s 803ms/step - loss: -0.5821 - dice_metric: 0.7086 - jaccard_metric: 0.6524 - sensitivity_metric: 0.8475 - specificity_metric: 0.8475 - val_loss: -0.7723 - val_dice_metric: 0.9451 - val_jaccard_metric: 0.9052 - val_sensitivity_metric: 0.9313 - val_specificity_metric: 0.9313
# Epoch 4/60
# 77/77 [==============================] - 65s 847ms/step - loss: -0.6272 - dice_metric: 0.7406 - jaccard_metric: 0.6870 - sensitivity_metric: 0.8611 - specificity_metric: 0.8611 - val_loss: -0.8530 - val_dice_metric: 0.9518 - val_jaccard_metric: 0.9156 - val_sensitivity_metric: 0.9422 - val_specificity_metric: 0.9422
# Epoch 5/60
# 77/77 [==============================] - 63s 813ms/step - loss: -0.6565 - dice_metric: 0.7647 - jaccard_metric: 0.7122 - sensitivity_metric: 0.8735 - specificity_metric: 0.8735 - val_loss: -0.8804 - val_dice_metric: 0.9556 - val_jaccard_metric: 0.9215 - val_sensitivity_metric: 0.9472 - val_specificity_metric: 0.9472
# Epoch 6/60
# 77/77 [==============================] - 66s 856ms/step - loss: -0.6817 - dice_metric: 0.7907 - jaccard_metric: 0.7389 - sensitivity_metric: 0.8870 - specificity_metric: 0.8870 - val_loss: -0.8894 - val_dice_metric: 0.9558 - val_jaccard_metric: 0.9219 - val_sensitivity_metric: 0.9432 - val_specificity_metric: 0.9432
# Epoch 7/60
# 77/77 [==============================] - 64s 831ms/step - loss: -0.7045 - dice_metric: 0.8107 - jaccard_metric: 0.7603 - sensitivity_metric: 0.8969 - specificity_metric: 0.8969 - val_loss: -0.8993 - val_dice_metric: 0.9585 - val_jaccard_metric: 0.9262 - val_sensitivity_metric: 0.9518 - val_specificity_metric: 0.9518
# Epoch 8/60
# 77/77 [==============================] - 61s 792ms/step - loss: -0.7218 - dice_metric: 0.8241 - jaccard_metric: 0.7748 - sensitivity_metric: 0.9034 - specificity_metric: 0.9034 - val_loss: -0.9058 - val_dice_metric: 0.9598 - val_jaccard_metric: 0.9284 - val_sensitivity_metric: 0.9600 - val_specificity_metric: 0.9600
# Epoch 9/60
# 77/77 [==============================] - 62s 801ms/step - loss: -0.7381 - dice_metric: 0.8389 - jaccard_metric: 0.7909 - sensitivity_metric: 0.9112 - specificity_metric: 0.9112 - val_loss: -0.9092 - val_dice_metric: 0.9604 - val_jaccard_metric: 0.9293 - val_sensitivity_metric: 0.9641 - val_specificity_metric: 0.9641
# Epoch 10/60
# 77/77 [==============================] - 65s 837ms/step - loss: -0.7525 - dice_metric: 0.8538 - jaccard_metric: 0.8065 - sensitivity_metric: 0.9196 - specificity_metric: 0.9196 - val_loss: -0.9123 - val_dice_metric: 0.9609 - val_jaccard_metric: 0.9301 - val_sensitivity_metric: 0.9634 - val_specificity_metric: 0.9634
# Epoch 11/60
# 77/77 [==============================] - 61s 795ms/step - loss: -0.7690 - dice_metric: 0.8661 - jaccard_metric: 0.8204 - sensitivity_metric: 0.9253 - specificity_metric: 0.9253 - val_loss: -0.9146 - val_dice_metric: 0.9611 - val_jaccard_metric: 0.9305 - val_sensitivity_metric: 0.9661 - val_specificity_metric: 0.9661
# Epoch 12/60
# 77/77 [==============================] - 63s 821ms/step - loss: -0.7816 - dice_metric: 0.8768 - jaccard_metric: 0.8321 - sensitivity_metric: 0.9310 - specificity_metric: 0.9310 - val_loss: -0.9167 - val_dice_metric: 0.9614 - val_jaccard_metric: 0.9311 - val_sensitivity_metric: 0.9646 - val_specificity_metric: 0.9646
# Epoch 13/60
# 77/77 [==============================] - 64s 833ms/step - loss: -0.7943 - dice_metric: 0.8850 - jaccard_metric: 0.8413 - sensitivity_metric: 0.9345 - specificity_metric: 0.9345 - val_loss: -0.9171 - val_dice_metric: 0.9617 - val_jaccard_metric: 0.9316 - val_sensitivity_metric: 0.9664 - val_specificity_metric: 0.9664
# Epoch 14/60
# 77/77 [==============================] - 62s 800ms/step - loss: -0.8057 - dice_metric: 0.8922 - jaccard_metric: 0.8497 - sensitivity_metric: 0.9380 - specificity_metric: 0.9380 - val_loss: -0.9183 - val_dice_metric: 0.9622 - val_jaccard_metric: 0.9323 - val_sensitivity_metric: 0.9629 - val_specificity_metric: 0.9629
# Epoch 15/60
# 77/77 [==============================] - 63s 821ms/step - loss: -0.8154 - dice_metric: 0.8988 - jaccard_metric: 0.8572 - sensitivity_metric: 0.9412 - specificity_metric: 0.9412 - val_loss: -0.9186 - val_dice_metric: 0.9623 - val_jaccard_metric: 0.9326 - val_sensitivity_metric: 0.9655 - val_specificity_metric: 0.9655
# Epoch 16/60
# 77/77 [==============================] - 63s 815ms/step - loss: -0.8235 - dice_metric: 0.9043 - jaccard_metric: 0.8635 - sensitivity_metric: 0.9440 - specificity_metric: 0.9440 - val_loss: -0.9196 - val_dice_metric: 0.9623 - val_jaccard_metric: 0.9324 - val_sensitivity_metric: 0.9663 - val_specificity_metric: 0.9663
# Epoch 17/60
# 77/77 [==============================] - 63s 812ms/step - loss: -0.8284 - dice_metric: 0.9099 - jaccard_metric: 0.8693 - sensitivity_metric: 0.9477 - specificity_metric: 0.9477 - val_loss: -0.9222 - val_dice_metric: 0.9631 - val_jaccard_metric: 0.9339 - val_sensitivity_metric: 0.9642 - val_specificity_metric: 0.9642
# Epoch 18/60
# 77/77 [==============================] - 64s 831ms/step - loss: -0.8364 - dice_metric: 0.9131 - jaccard_metric: 0.8735 - sensitivity_metric: 0.9486 - specificity_metric: 0.9486 - val_loss: -0.9213 - val_dice_metric: 0.9631 - val_jaccard_metric: 0.9338 - val_sensitivity_metric: 0.9640 - val_specificity_metric: 0.9640
# Epoch 19/60
# 77/77 [==============================] - 64s 828ms/step - loss: -0.8429 - dice_metric: 0.9183 - jaccard_metric: 0.8793 - sensitivity_metric: 0.9514 - specificity_metric: 0.9514 - val_loss: -0.9217 - val_dice_metric: 0.9627 - val_jaccard_metric: 0.9331 - val_sensitivity_metric: 0.9678 - val_specificity_metric: 0.9678
# Epoch 20/60
# 77/77 [==============================] - 66s 857ms/step - loss: -0.8481 - dice_metric: 0.9254 - jaccard_metric: 0.8871 - sensitivity_metric: 0.9561 - specificity_metric: 0.9561 - val_loss: -0.9225 - val_dice_metric: 0.9628 - val_jaccard_metric: 0.9333 - val_sensitivity_metric: 0.9675 - val_specificity_metric: 0.9675
# Epoch 21/60
# 77/77 [==============================] - 59s 767ms/step - loss: -0.8725 - dice_metric: 0.9497 - jaccard_metric: 0.9136 - sensitivity_metric: 0.9658 - specificity_metric: 0.9658 - val_loss: -0.9248 - val_dice_metric: 0.9622 - val_jaccard_metric: 0.9323 - val_sensitivity_metric: 0.9672 - val_specificity_metric: 0.9672
# Epoch 22/60
# 77/77 [==============================] - 62s 806ms/step - loss: -0.8946 - dice_metric: 0.9584 - jaccard_metric: 0.9247 - sensitivity_metric: 0.9657 - specificity_metric: 0.9657 - val_loss: -0.9260 - val_dice_metric: 0.9628 - val_jaccard_metric: 0.9333 - val_sensitivity_metric: 0.9632 - val_specificity_metric: 0.9632
# Epoch 23/60
# 77/77 [==============================] - 59s 756ms/step - loss: -0.9064 - dice_metric: 0.9611 - jaccard_metric: 0.9291 - sensitivity_metric: 0.9661 - specificity_metric: 0.9661 - val_loss: -0.9253 - val_dice_metric: 0.9629 - val_jaccard_metric: 0.9335 - val_sensitivity_metric: 0.9650 - val_specificity_metric: 0.9650
# Epoch 24/60
# 77/77 [==============================] - 61s 793ms/step - loss: -0.9129 - dice_metric: 0.9624 - jaccard_metric: 0.9312 - sensitivity_metric: 0.9661 - specificity_metric: 0.9661 - val_loss: -0.9243 - val_dice_metric: 0.9626 - val_jaccard_metric: 0.9331 - val_sensitivity_metric: 0.9695 - val_specificity_metric: 0.9695
# Epoch 25/60
# 77/77 [==============================] - 61s 791ms/step - loss: -0.9166 - dice_metric: 0.9629 - jaccard_metric: 0.9321 - sensitivity_metric: 0.9660 - specificity_metric: 0.9660 - val_loss: -0.9243 - val_dice_metric: 0.9629 - val_jaccard_metric: 0.9335 - val_sensitivity_metric: 0.9707 - val_specificity_metric: 0.9707
# Epoch 26/60
# 77/77 [==============================] - 63s 812ms/step - loss: -0.9194 - dice_metric: 0.9633 - jaccard_metric: 0.9327 - sensitivity_metric: 0.9659 - specificity_metric: 0.9659 - val_loss: -0.9242 - val_dice_metric: 0.9628 - val_jaccard_metric: 0.9334 - val_sensitivity_metric: 0.9719 - val_specificity_metric: 0.9719
# Epoch 27/60
# 77/77 [==============================] - 62s 796ms/step - loss: -0.9218 - dice_metric: 0.9638 - jaccard_metric: 0.9336 - sensitivity_metric: 0.9659 - specificity_metric: 0.9659 - val_loss: -0.9252 - val_dice_metric: 0.9632 - val_jaccard_metric: 0.9340 - val_sensitivity_metric: 0.9717 - val_specificity_metric: 0.9717
# Epoch 28/60
# 77/77 [==============================] - 61s 786ms/step - loss: -0.9236 - dice_metric: 0.9641 - jaccard_metric: 0.9341 - sensitivity_metric: 0.9659 - specificity_metric: 0.9659 - val_loss: -0.9249 - val_dice_metric: 0.9632 - val_jaccard_metric: 0.9340 - val_sensitivity_metric: 0.9713 - val_specificity_metric: 0.9713
# Epoch 29/60
# 77/77 [==============================] - 64s 822ms/step - loss: -0.9241 - dice_metric: 0.9639 - jaccard_metric: 0.9337 - sensitivity_metric: 0.9656 - specificity_metric: 0.9656 - val_loss: -0.9253 - val_dice_metric: 0.9631 - val_jaccard_metric: 0.9338 - val_sensitivity_metric: 0.9732 - val_specificity_metric: 0.9732
# Epoch 30/60
# 77/77 [==============================] - 62s 806ms/step - loss: -0.9253 - dice_metric: 0.9641 - jaccard_metric: 0.9341 - sensitivity_metric: 0.9657 - specificity_metric: 0.9657 - val_loss: -0.9215 - val_dice_metric: 0.9609 - val_jaccard_metric: 0.9301 - val_sensitivity_metric: 0.9776 - val_specificity_metric: 0.9776
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 61s 792ms/step - loss: -0.9281 - dice_metric: 0.9653 - jaccard_metric: 0.9362 - sensitivity_metric: 0.9678 - specificity_metric: 0.9678 - val_loss: -0.9288 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9375 - val_sensitivity_metric: 0.9663 - val_specificity_metric: 0.9663
# Epoch 32/60
# 77/77 [==============================] - 64s 831ms/step - loss: -0.9302 - dice_metric: 0.9664 - jaccard_metric: 0.9380 - sensitivity_metric: 0.9677 - specificity_metric: 0.9677 - val_loss: -0.9286 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9375 - val_sensitivity_metric: 0.9673 - val_specificity_metric: 0.9673
# Epoch 33/60
# 77/77 [==============================] - 62s 805ms/step - loss: -0.9309 - dice_metric: 0.9668 - jaccard_metric: 0.9387 - sensitivity_metric: 0.9680 - specificity_metric: 0.9680 - val_loss: -0.9285 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9676 - val_specificity_metric: 0.9676
# Epoch 34/60
# 77/77 [==============================] - 61s 787ms/step - loss: -0.9315 - dice_metric: 0.9671 - jaccard_metric: 0.9391 - sensitivity_metric: 0.9682 - specificity_metric: 0.9682 - val_loss: -0.9285 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9677 - val_specificity_metric: 0.9677
# Epoch 35/60
# 77/77 [==============================] - 61s 786ms/step - loss: -0.9320 - dice_metric: 0.9673 - jaccard_metric: 0.9395 - sensitivity_metric: 0.9684 - specificity_metric: 0.9684 - val_loss: -0.9285 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9678 - val_specificity_metric: 0.9678
# Epoch 36/60
# 77/77 [==============================] - 64s 829ms/step - loss: -0.9324 - dice_metric: 0.9675 - jaccard_metric: 0.9399 - sensitivity_metric: 0.9686 - specificity_metric: 0.9686 - val_loss: -0.9285 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9678 - val_specificity_metric: 0.9678
# Epoch 37/60
# 77/77 [==============================] - 61s 786ms/step - loss: -0.9328 - dice_metric: 0.9677 - jaccard_metric: 0.9402 - sensitivity_metric: 0.9688 - specificity_metric: 0.9688 - val_loss: -0.9286 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9679 - val_specificity_metric: 0.9679
# Epoch 38/60
# 77/77 [==============================] - 63s 810ms/step - loss: -0.9331 - dice_metric: 0.9679 - jaccard_metric: 0.9405 - sensitivity_metric: 0.9689 - specificity_metric: 0.9689 - val_loss: -0.9287 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9679 - val_specificity_metric: 0.9679
# Epoch 39/60
# 77/77 [==============================] - 65s 844ms/step - loss: -0.9335 - dice_metric: 0.9680 - jaccard_metric: 0.9408 - sensitivity_metric: 0.9690 - specificity_metric: 0.9690 - val_loss: -0.9287 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9680 - val_specificity_metric: 0.9680
# Epoch 40/60
# 77/77 [==============================] - 62s 800ms/step - loss: -0.9338 - dice_metric: 0.9682 - jaccard_metric: 0.9410 - sensitivity_metric: 0.9692 - specificity_metric: 0.9692 - val_loss: -0.9288 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9680 - val_specificity_metric: 0.9680
# Epoch 41/60
# 77/77 [==============================] - 62s 802ms/step - loss: -0.9341 - dice_metric: 0.9683 - jaccard_metric: 0.9413 - sensitivity_metric: 0.9693 - specificity_metric: 0.9693 - val_loss: -0.9289 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9681 - val_specificity_metric: 0.9681
# Epoch 42/60
# 77/77 [==============================] - 64s 826ms/step - loss: -0.9345 - dice_metric: 0.9685 - jaccard_metric: 0.9415 - sensitivity_metric: 0.9694 - specificity_metric: 0.9694 - val_loss: -0.9290 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9681 - val_specificity_metric: 0.9681
# Epoch 43/60
# 77/77 [==============================] - 64s 826ms/step - loss: -0.9348 - dice_metric: 0.9686 - jaccard_metric: 0.9417 - sensitivity_metric: 0.9695 - specificity_metric: 0.9695 - val_loss: -0.9290 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9681 - val_specificity_metric: 0.9681
# Epoch 44/60
# 77/77 [==============================] - 62s 806ms/step - loss: -0.9351 - dice_metric: 0.9687 - jaccard_metric: 0.9420 - sensitivity_metric: 0.9696 - specificity_metric: 0.9696 - val_loss: -0.9291 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9679 - val_specificity_metric: 0.9679
# Epoch 45/60
# 77/77 [==============================] - 64s 831ms/step - loss: -0.9353 - dice_metric: 0.9688 - jaccard_metric: 0.9422 - sensitivity_metric: 0.9697 - specificity_metric: 0.9697 - val_loss: -0.9292 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9679 - val_specificity_metric: 0.9679
# Epoch 46/60
# 77/77 [==============================] - 60s 781ms/step - loss: -0.9356 - dice_metric: 0.9689 - jaccard_metric: 0.9424 - sensitivity_metric: 0.9698 - specificity_metric: 0.9698 - val_loss: -0.9293 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9679 - val_specificity_metric: 0.9679
# Epoch 47/60
# 77/77 [==============================] - 63s 813ms/step - loss: -0.9359 - dice_metric: 0.9691 - jaccard_metric: 0.9426 - sensitivity_metric: 0.9699 - specificity_metric: 0.9699 - val_loss: -0.9293 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9680 - val_specificity_metric: 0.9680
# Epoch 48/60
# 77/77 [==============================] - 62s 803ms/step - loss: -0.9362 - dice_metric: 0.9692 - jaccard_metric: 0.9428 - sensitivity_metric: 0.9700 - specificity_metric: 0.9700 - val_loss: -0.9294 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9682 - val_specificity_metric: 0.9682
# Epoch 49/60
# 77/77 [==============================] - 63s 809ms/step - loss: -0.9365 - dice_metric: 0.9693 - jaccard_metric: 0.9429 - sensitivity_metric: 0.9701 - specificity_metric: 0.9701 - val_loss: -0.9294 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9682 - val_specificity_metric: 0.9682
# Epoch 50/60
# 77/77 [==============================] - 63s 810ms/step - loss: -0.9367 - dice_metric: 0.9694 - jaccard_metric: 0.9431 - sensitivity_metric: 0.9702 - specificity_metric: 0.9702 - val_loss: -0.9294 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9677 - val_specificity_metric: 0.9677
# Epoch 51/60
# 77/77 [==============================] - 62s 801ms/step - loss: -0.9369 - dice_metric: 0.9694 - jaccard_metric: 0.9432 - sensitivity_metric: 0.9702 - specificity_metric: 0.9702 - val_loss: -0.9295 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9667 - val_specificity_metric: 0.9667
# Epoch 52/60
# 77/77 [==============================] - 62s 799ms/step - loss: -0.9369 - dice_metric: 0.9693 - jaccard_metric: 0.9431 - sensitivity_metric: 0.9702 - specificity_metric: 0.9702 - val_loss: -0.9297 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9671 - val_specificity_metric: 0.9671
# Epoch 53/60
# 77/77 [==============================] - 64s 824ms/step - loss: -0.9372 - dice_metric: 0.9695 - jaccard_metric: 0.9433 - sensitivity_metric: 0.9703 - specificity_metric: 0.9703 - val_loss: -0.9298 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9681 - val_specificity_metric: 0.9681
# Epoch 54/60
# 77/77 [==============================] - 62s 805ms/step - loss: -0.9376 - dice_metric: 0.9696 - jaccard_metric: 0.9435 - sensitivity_metric: 0.9704 - specificity_metric: 0.9704 - val_loss: -0.9298 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9689 - val_specificity_metric: 0.9689
# Epoch 55/60
# 77/77 [==============================] - 59s 769ms/step - loss: -0.9379 - dice_metric: 0.9698 - jaccard_metric: 0.9438 - sensitivity_metric: 0.9705 - specificity_metric: 0.9705 - val_loss: -0.9298 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9376 - val_sensitivity_metric: 0.9689 - val_specificity_metric: 0.9689
# Epoch 56/60
# 77/77 [==============================] - 64s 831ms/step - loss: -0.9382 - dice_metric: 0.9699 - jaccard_metric: 0.9440 - sensitivity_metric: 0.9706 - specificity_metric: 0.9706 - val_loss: -0.9300 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9679 - val_specificity_metric: 0.9679
# Epoch 57/60
# 77/77 [==============================] - 63s 815ms/step - loss: -0.9384 - dice_metric: 0.9699 - jaccard_metric: 0.9441 - sensitivity_metric: 0.9707 - specificity_metric: 0.9707 - val_loss: -0.9300 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9672 - val_specificity_metric: 0.9672
# Epoch 58/60
# 77/77 [==============================] - 65s 839ms/step - loss: -0.9385 - dice_metric: 0.9700 - jaccard_metric: 0.9441 - sensitivity_metric: 0.9707 - specificity_metric: 0.9707 - val_loss: -0.9301 - val_dice_metric: 0.9654 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9677 - val_specificity_metric: 0.9677
# Epoch 59/60
# 77/77 [==============================] - 61s 793ms/step - loss: -0.9387 - dice_metric: 0.9700 - jaccard_metric: 0.9443 - sensitivity_metric: 0.9707 - specificity_metric: 0.9707 - val_loss: -0.9301 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9377 - val_sensitivity_metric: 0.9688 - val_specificity_metric: 0.9688
# Epoch 60/60
# 77/77 [==============================] - 63s 810ms/step - loss: -0.9390 - dice_metric: 0.9702 - jaccard_metric: 0.9445 - sensitivity_metric: 0.9708 - specificity_metric: 0.9708 - val_loss: -0.9300 - val_dice_metric: 0.9653 - val_jaccard_metric: 0.9375 - val_sensitivity_metric: 0.9696 - val_specificity_metric: 0.9696

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.96638, standard deviation: 0.04727
# Jaccard Index mean: 0.93864, standard deviation: 0.08112
# Sensitivity mean: 0.96893, standard deviation: 0.05127
# Specificity mean: 0.96893, standard deviation: 0.05127
