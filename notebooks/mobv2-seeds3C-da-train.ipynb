# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  98%|███████████████████████████████████████▎| 982M/0.98G [00:04<00:00, 195MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:04<00:00, 250MB/s]

# %%
config = {"Seg_model":"MobV2","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import mobilenetv2
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 109s 798ms/step - loss: -0.2874 - dice_metric: 0.3097 - jaccard_metric: 0.2888 - sensitivity_metric: 0.3013 - specificity_metric: 0.7621 - precision_metric: 0.3395 - recall_metric: 0.3013 - mean_average_precision: 0.2624 - val_loss: -0.3167 - val_dice_metric: 0.5380 - val_jaccard_metric: 0.5072 - val_sensitivity_metric: 0.3753 - val_specificity_metric: 0.7086 - val_precision_metric: 0.3992 - val_recall_metric: 0.3753 - val_mean_average_precision: 0.4746
# Epoch 2/60
# 77/77 [==============================] - 59s 758ms/step - loss: -0.4223 - dice_metric: 0.4818 - jaccard_metric: 0.4157 - sensitivity_metric: 0.5136 - specificity_metric: 0.8322 - precision_metric: 0.4758 - recall_metric: 0.5136 - mean_average_precision: 0.3164 - val_loss: -0.2813 - val_dice_metric: 0.4968 - val_jaccard_metric: 0.4843 - val_sensitivity_metric: 0.3400 - val_specificity_metric: 0.6732 - val_precision_metric: 0.4627 - val_recall_metric: 0.3400 - val_mean_average_precision: 0.4789
# Epoch 3/60
# 77/77 [==============================] - 58s 747ms/step - loss: -0.5469 - dice_metric: 0.6045 - jaccard_metric: 0.5213 - sensitivity_metric: 0.6323 - specificity_metric: 0.8777 - precision_metric: 0.5988 - recall_metric: 0.6323 - mean_average_precision: 0.3647 - val_loss: -0.2895 - val_dice_metric: 0.5011 - val_jaccard_metric: 0.4865 - val_sensitivity_metric: 0.3423 - val_specificity_metric: 0.6749 - val_precision_metric: 0.5167 - val_recall_metric: 0.3423 - val_mean_average_precision: 0.4788
# Epoch 4/60
# 77/77 [==============================] - 58s 752ms/step - loss: -0.6014 - dice_metric: 0.6552 - jaccard_metric: 0.5719 - sensitivity_metric: 0.6695 - specificity_metric: 0.8965 - precision_metric: 0.6573 - recall_metric: 0.6695 - mean_average_precision: 0.4060 - val_loss: -0.3251 - val_dice_metric: 0.5095 - val_jaccard_metric: 0.4813 - val_sensitivity_metric: 0.3621 - val_specificity_metric: 0.6926 - val_precision_metric: 0.6015 - val_recall_metric: 0.3621 - val_mean_average_precision: 0.4551
# Epoch 5/60
# 77/77 [==============================] - 59s 760ms/step - loss: -0.6332 - dice_metric: 0.6892 - jaccard_metric: 0.6075 - sensitivity_metric: 0.6922 - specificity_metric: 0.9071 - precision_metric: 0.6867 - recall_metric: 0.6922 - mean_average_precision: 0.4414 - val_loss: -0.3031 - val_dice_metric: 0.4881 - val_jaccard_metric: 0.4712 - val_sensitivity_metric: 0.3450 - val_specificity_metric: 0.6772 - val_precision_metric: 0.5671 - val_recall_metric: 0.3450 - val_mean_average_precision: 0.4607
# Epoch 6/60
# 77/77 [==============================] - 59s 763ms/step - loss: -0.6536 - dice_metric: 0.7110 - jaccard_metric: 0.6311 - sensitivity_metric: 0.7055 - specificity_metric: 0.9135 - precision_metric: 0.7069 - recall_metric: 0.7055 - mean_average_precision: 0.4682 - val_loss: -0.3265 - val_dice_metric: 0.5037 - val_jaccard_metric: 0.4780 - val_sensitivity_metric: 0.3580 - val_specificity_metric: 0.6886 - val_precision_metric: 0.6132 - val_recall_metric: 0.3580 - val_mean_average_precision: 0.4549
# Epoch 7/60
# 77/77 [==============================] - 58s 746ms/step - loss: -0.6664 - dice_metric: 0.7243 - jaccard_metric: 0.6459 - sensitivity_metric: 0.7138 - specificity_metric: 0.9175 - precision_metric: 0.7190 - recall_metric: 0.7138 - mean_average_precision: 0.4855 - val_loss: -0.3306 - val_dice_metric: 0.4824 - val_jaccard_metric: 0.4562 - val_sensitivity_metric: 0.3595 - val_specificity_metric: 0.6880 - val_precision_metric: 0.6538 - val_recall_metric: 0.3595 - val_mean_average_precision: 0.4332
# Epoch 8/60
# 77/77 [==============================] - 58s 747ms/step - loss: -0.6735 - dice_metric: 0.7326 - jaccard_metric: 0.6549 - sensitivity_metric: 0.7187 - specificity_metric: 0.9208 - precision_metric: 0.7256 - recall_metric: 0.7187 - mean_average_precision: 0.4959 - val_loss: -0.3600 - val_dice_metric: 0.5272 - val_jaccard_metric: 0.4908 - val_sensitivity_metric: 0.3755 - val_specificity_metric: 0.6992 - val_precision_metric: 0.7001 - val_recall_metric: 0.3755 - val_mean_average_precision: 0.4529
# Epoch 9/60
# 77/77 [==============================] - 59s 756ms/step - loss: -0.6832 - dice_metric: 0.7439 - jaccard_metric: 0.6675 - sensitivity_metric: 0.7254 - specificity_metric: 0.9236 - precision_metric: 0.7329 - recall_metric: 0.7254 - mean_average_precision: 0.5115 - val_loss: -0.3456 - val_dice_metric: 0.5168 - val_jaccard_metric: 0.4867 - val_sensitivity_metric: 0.3665 - val_specificity_metric: 0.6957 - val_precision_metric: 0.6491 - val_recall_metric: 0.3665 - val_mean_average_precision: 0.4576
# Epoch 10/60
# 77/77 [==============================] - 58s 749ms/step - loss: -0.6947 - dice_metric: 0.7493 - jaccard_metric: 0.6746 - sensitivity_metric: 0.7336 - specificity_metric: 0.9265 - precision_metric: 0.7436 - recall_metric: 0.7336 - mean_average_precision: 0.5234 - val_loss: -0.4016 - val_dice_metric: 0.5632 - val_jaccard_metric: 0.5140 - val_sensitivity_metric: 0.4024 - val_specificity_metric: 0.7223 - val_precision_metric: 0.7257 - val_recall_metric: 0.4024 - val_mean_average_precision: 0.4521
# Epoch 11/60
# 77/77 [==============================] - 58s 748ms/step - loss: -0.7015 - dice_metric: 0.7594 - jaccard_metric: 0.6858 - sensitivity_metric: 0.7385 - specificity_metric: 0.9287 - precision_metric: 0.7497 - recall_metric: 0.7385 - mean_average_precision: 0.5372 - val_loss: -0.3974 - val_dice_metric: 0.5444 - val_jaccard_metric: 0.4975 - val_sensitivity_metric: 0.3988 - val_specificity_metric: 0.7174 - val_precision_metric: 0.7317 - val_recall_metric: 0.3988 - val_mean_average_precision: 0.4391
# Epoch 12/60
# 77/77 [==============================] - 57s 730ms/step - loss: -0.7062 - dice_metric: 0.7639 - jaccard_metric: 0.6911 - sensitivity_metric: 0.7421 - specificity_metric: 0.9306 - precision_metric: 0.7529 - recall_metric: 0.7421 - mean_average_precision: 0.5449 - val_loss: -0.4123 - val_dice_metric: 0.4867 - val_jaccard_metric: 0.4339 - val_sensitivity_metric: 0.4062 - val_specificity_metric: 0.7204 - val_precision_metric: 0.7472 - val_recall_metric: 0.4062 - val_mean_average_precision: 0.3688
# Epoch 13/60
# 77/77 [==============================] - 58s 752ms/step - loss: -0.7093 - dice_metric: 0.7681 - jaccard_metric: 0.6957 - sensitivity_metric: 0.7445 - specificity_metric: 0.9320 - precision_metric: 0.7561 - recall_metric: 0.7445 - mean_average_precision: 0.5508 - val_loss: -0.4870 - val_dice_metric: 0.5610 - val_jaccard_metric: 0.4884 - val_sensitivity_metric: 0.4641 - val_specificity_metric: 0.7646 - val_precision_metric: 0.7527 - val_recall_metric: 0.4641 - val_mean_average_precision: 0.3701
# Epoch 14/60
# 77/77 [==============================] - 59s 755ms/step - loss: -0.7109 - dice_metric: 0.7689 - jaccard_metric: 0.6965 - sensitivity_metric: 0.7457 - specificity_metric: 0.9327 - precision_metric: 0.7576 - recall_metric: 0.7457 - mean_average_precision: 0.5515 - val_loss: -0.5604 - val_dice_metric: 0.6092 - val_jaccard_metric: 0.5269 - val_sensitivity_metric: 0.5348 - val_specificity_metric: 0.8151 - val_precision_metric: 0.7481 - val_recall_metric: 0.5348 - val_mean_average_precision: 0.3642
# Epoch 15/60
# 77/77 [==============================] - 58s 749ms/step - loss: -0.7144 - dice_metric: 0.7743 - jaccard_metric: 0.7029 - sensitivity_metric: 0.7476 - specificity_metric: 0.9338 - precision_metric: 0.7602 - recall_metric: 0.7476 - mean_average_precision: 0.5606 - val_loss: -0.5771 - val_dice_metric: 0.6864 - val_jaccard_metric: 0.6090 - val_sensitivity_metric: 0.5599 - val_specificity_metric: 0.8372 - val_precision_metric: 0.7381 - val_recall_metric: 0.5599 - val_mean_average_precision: 0.4549
# Epoch 16/60
# 77/77 [==============================] - 59s 757ms/step - loss: -0.7166 - dice_metric: 0.7689 - jaccard_metric: 0.6978 - sensitivity_metric: 0.7491 - specificity_metric: 0.9348 - precision_metric: 0.7620 - recall_metric: 0.7491 - mean_average_precision: 0.5569 - val_loss: -0.6009 - val_dice_metric: 0.7264 - val_jaccard_metric: 0.6493 - val_sensitivity_metric: 0.5923 - val_specificity_metric: 0.8606 - val_precision_metric: 0.7373 - val_recall_metric: 0.5923 - val_mean_average_precision: 0.4901
# Epoch 17/60
# 77/77 [==============================] - 59s 760ms/step - loss: -0.7210 - dice_metric: 0.7772 - jaccard_metric: 0.7069 - sensitivity_metric: 0.7518 - specificity_metric: 0.9354 - precision_metric: 0.7662 - recall_metric: 0.7518 - mean_average_precision: 0.5677 - val_loss: -0.6213 - val_dice_metric: 0.7400 - val_jaccard_metric: 0.6646 - val_sensitivity_metric: 0.6172 - val_specificity_metric: 0.8777 - val_precision_metric: 0.7304 - val_recall_metric: 0.6172 - val_mean_average_precision: 0.5049
# Epoch 18/60
# 77/77 [==============================] - 59s 754ms/step - loss: -0.7214 - dice_metric: 0.7824 - jaccard_metric: 0.7119 - sensitivity_metric: 0.7531 - specificity_metric: 0.9361 - precision_metric: 0.7658 - recall_metric: 0.7531 - mean_average_precision: 0.5721 - val_loss: -0.6364 - val_dice_metric: 0.7633 - val_jaccard_metric: 0.6918 - val_sensitivity_metric: 0.6505 - val_specificity_metric: 0.9054 - val_precision_metric: 0.7230 - val_recall_metric: 0.6505 - val_mean_average_precision: 0.5449
# Epoch 19/60
# 77/77 [==============================] - 59s 763ms/step - loss: -0.7219 - dice_metric: 0.7842 - jaccard_metric: 0.7136 - sensitivity_metric: 0.7530 - specificity_metric: 0.9361 - precision_metric: 0.7663 - recall_metric: 0.7530 - mean_average_precision: 0.5734 - val_loss: -0.6468 - val_dice_metric: 0.8199 - val_jaccard_metric: 0.7492 - val_sensitivity_metric: 0.6577 - val_specificity_metric: 0.9078 - val_precision_metric: 0.7294 - val_recall_metric: 0.6577 - val_mean_average_precision: 0.6047
# Epoch 20/60
# 77/77 [==============================] - 60s 769ms/step - loss: -0.7254 - dice_metric: 0.7887 - jaccard_metric: 0.7189 - sensitivity_metric: 0.7560 - specificity_metric: 0.9374 - precision_metric: 0.7679 - recall_metric: 0.7560 - mean_average_precision: 0.5809 - val_loss: -0.6578 - val_dice_metric: 0.7489 - val_jaccard_metric: 0.6764 - val_sensitivity_metric: 0.6532 - val_specificity_metric: 0.8964 - val_precision_metric: 0.7527 - val_recall_metric: 0.6532 - val_mean_average_precision: 0.5276
# Epoch 21/60
# 77/77 [==============================] - 58s 743ms/step - loss: -0.7324 - dice_metric: 0.7889 - jaccard_metric: 0.7210 - sensitivity_metric: 0.7599 - specificity_metric: 0.9388 - precision_metric: 0.7744 - recall_metric: 0.7599 - mean_average_precision: 0.5888 - val_loss: -0.6667 - val_dice_metric: 0.7040 - val_jaccard_metric: 0.6316 - val_sensitivity_metric: 0.6616 - val_specificity_metric: 0.9003 - val_precision_metric: 0.7563 - val_recall_metric: 0.6616 - val_mean_average_precision: 0.4810
# Epoch 22/60
# 77/77 [==============================] - 57s 739ms/step - loss: -0.7368 - dice_metric: 0.7952 - jaccard_metric: 0.7284 - sensitivity_metric: 0.7629 - specificity_metric: 0.9398 - precision_metric: 0.7785 - recall_metric: 0.7629 - mean_average_precision: 0.5996 - val_loss: -0.6690 - val_dice_metric: 0.7244 - val_jaccard_metric: 0.6534 - val_sensitivity_metric: 0.6672 - val_specificity_metric: 0.9052 - val_precision_metric: 0.7522 - val_recall_metric: 0.6672 - val_mean_average_precision: 0.5093
# Epoch 23/60
# 77/77 [==============================] - 60s 778ms/step - loss: -0.7406 - dice_metric: 0.7957 - jaccard_metric: 0.7297 - sensitivity_metric: 0.7657 - specificity_metric: 0.9408 - precision_metric: 0.7819 - recall_metric: 0.7657 - mean_average_precision: 0.6042 - val_loss: -0.6784 - val_dice_metric: 0.7105 - val_jaccard_metric: 0.6413 - val_sensitivity_metric: 0.6809 - val_specificity_metric: 0.9126 - val_precision_metric: 0.7519 - val_recall_metric: 0.6809 - val_mean_average_precision: 0.5022
# Epoch 24/60
# 77/77 [==============================] - 57s 737ms/step - loss: -0.7433 - dice_metric: 0.7927 - jaccard_metric: 0.7272 - sensitivity_metric: 0.7676 - specificity_metric: 0.9416 - precision_metric: 0.7842 - recall_metric: 0.7676 - mean_average_precision: 0.6032 - val_loss: -0.6756 - val_dice_metric: 0.7035 - val_jaccard_metric: 0.6326 - val_sensitivity_metric: 0.6706 - val_specificity_metric: 0.9065 - val_precision_metric: 0.7588 - val_recall_metric: 0.6706 - val_mean_average_precision: 0.4871
# Epoch 25/60
# 77/77 [==============================] - 59s 764ms/step - loss: -0.7458 - dice_metric: 0.7933 - jaccard_metric: 0.7283 - sensitivity_metric: 0.7692 - specificity_metric: 0.9422 - precision_metric: 0.7863 - recall_metric: 0.7692 - mean_average_precision: 0.6058 - val_loss: -0.6821 - val_dice_metric: 0.7199 - val_jaccard_metric: 0.6518 - val_sensitivity_metric: 0.6799 - val_specificity_metric: 0.9123 - val_precision_metric: 0.7591 - val_recall_metric: 0.6799 - val_mean_average_precision: 0.5139
# Epoch 26/60
# 77/77 [==============================] - 57s 739ms/step - loss: -0.7478 - dice_metric: 0.7950 - jaccard_metric: 0.7303 - sensitivity_metric: 0.7715 - specificity_metric: 0.9431 - precision_metric: 0.7872 - recall_metric: 0.7715 - mean_average_precision: 0.6090 - val_loss: -0.6848 - val_dice_metric: 0.7118 - val_jaccard_metric: 0.6430 - val_sensitivity_metric: 0.6854 - val_specificity_metric: 0.9146 - val_precision_metric: 0.7581 - val_recall_metric: 0.6854 - val_mean_average_precision: 0.5043
# Epoch 27/60
# 77/77 [==============================] - 58s 742ms/step - loss: -0.7494 - dice_metric: 0.7930 - jaccard_metric: 0.7285 - sensitivity_metric: 0.7726 - specificity_metric: 0.9436 - precision_metric: 0.7883 - recall_metric: 0.7726 - mean_average_precision: 0.6077 - val_loss: -0.6889 - val_dice_metric: 0.7151 - val_jaccard_metric: 0.6484 - val_sensitivity_metric: 0.6888 - val_specificity_metric: 0.9172 - val_precision_metric: 0.7607 - val_recall_metric: 0.6888 - val_mean_average_precision: 0.5147
# Epoch 28/60
# 77/77 [==============================] - 59s 756ms/step - loss: -0.7510 - dice_metric: 0.7933 - jaccard_metric: 0.7289 - sensitivity_metric: 0.7741 - specificity_metric: 0.9440 - precision_metric: 0.7892 - recall_metric: 0.7741 - mean_average_precision: 0.6091 - val_loss: -0.6809 - val_dice_metric: 0.7098 - val_jaccard_metric: 0.6406 - val_sensitivity_metric: 0.6714 - val_specificity_metric: 0.9055 - val_precision_metric: 0.7655 - val_recall_metric: 0.6714 - val_mean_average_precision: 0.4991
# Epoch 29/60
# 77/77 [==============================] - 59s 754ms/step - loss: -0.7521 - dice_metric: 0.7901 - jaccard_metric: 0.7258 - sensitivity_metric: 0.7750 - specificity_metric: 0.9444 - precision_metric: 0.7899 - recall_metric: 0.7750 - mean_average_precision: 0.6062 - val_loss: -0.6942 - val_dice_metric: 0.7233 - val_jaccard_metric: 0.6575 - val_sensitivity_metric: 0.6956 - val_specificity_metric: 0.9206 - val_precision_metric: 0.7605 - val_recall_metric: 0.6956 - val_mean_average_precision: 0.5232
# Epoch 30/60
# 77/77 [==============================] - 58s 739ms/step - loss: -0.7516 - dice_metric: 0.7916 - jaccard_metric: 0.7269 - sensitivity_metric: 0.7748 - specificity_metric: 0.9442 - precision_metric: 0.7894 - recall_metric: 0.7748 - mean_average_precision: 0.6060 - val_loss: -0.7035 - val_dice_metric: 0.7313 - val_jaccard_metric: 0.6699 - val_sensitivity_metric: 0.7341 - val_specificity_metric: 0.9476 - val_precision_metric: 0.7358 - val_recall_metric: 0.7341 - val_mean_average_precision: 0.5480
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 59s 758ms/step - loss: -0.7550 - dice_metric: 0.7909 - jaccard_metric: 0.7275 - sensitivity_metric: 0.7777 - specificity_metric: 0.9454 - precision_metric: 0.7921 - recall_metric: 0.7777 - mean_average_precision: 0.6105 - val_loss: -0.7058 - val_dice_metric: 0.7380 - val_jaccard_metric: 0.6775 - val_sensitivity_metric: 0.7192 - val_specificity_metric: 0.9402 - val_precision_metric: 0.7537 - val_recall_metric: 0.7192 - val_mean_average_precision: 0.5567
# Epoch 32/60
# 77/77 [==============================] - 59s 765ms/step - loss: -0.7581 - dice_metric: 0.7958 - jaccard_metric: 0.7332 - sensitivity_metric: 0.7799 - specificity_metric: 0.9462 - precision_metric: 0.7957 - recall_metric: 0.7799 - mean_average_precision: 0.6190 - val_loss: -0.7088 - val_dice_metric: 0.7472 - val_jaccard_metric: 0.6878 - val_sensitivity_metric: 0.7254 - val_specificity_metric: 0.9446 - val_precision_metric: 0.7522 - val_recall_metric: 0.7254 - val_mean_average_precision: 0.5688
# Epoch 33/60
# 77/77 [==============================] - 59s 756ms/step - loss: -0.7592 - dice_metric: 0.7960 - jaccard_metric: 0.7337 - sensitivity_metric: 0.7808 - specificity_metric: 0.9465 - precision_metric: 0.7968 - recall_metric: 0.7808 - mean_average_precision: 0.6200 - val_loss: -0.7104 - val_dice_metric: 0.7551 - val_jaccard_metric: 0.6966 - val_sensitivity_metric: 0.7293 - val_specificity_metric: 0.9472 - val_precision_metric: 0.7512 - val_recall_metric: 0.7293 - val_mean_average_precision: 0.5825
# Epoch 34/60
# 77/77 [==============================] - 59s 755ms/step - loss: -0.7601 - dice_metric: 0.7959 - jaccard_metric: 0.7339 - sensitivity_metric: 0.7814 - specificity_metric: 0.9465 - precision_metric: 0.7979 - recall_metric: 0.7814 - mean_average_precision: 0.6209 - val_loss: -0.7118 - val_dice_metric: 0.7591 - val_jaccard_metric: 0.7011 - val_sensitivity_metric: 0.7322 - val_specificity_metric: 0.9490 - val_precision_metric: 0.7508 - val_recall_metric: 0.7322 - val_mean_average_precision: 0.5920
# Epoch 35/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.7607 - dice_metric: 0.7968 - jaccard_metric: 0.7349 - sensitivity_metric: 0.7821 - specificity_metric: 0.9468 - precision_metric: 0.7984 - recall_metric: 0.7821 - mean_average_precision: 0.6226 - val_loss: -0.7132 - val_dice_metric: 0.7684 - val_jaccard_metric: 0.7108 - val_sensitivity_metric: 0.7348 - val_specificity_metric: 0.9504 - val_precision_metric: 0.7509 - val_recall_metric: 0.7348 - val_mean_average_precision: 0.6038
# Epoch 36/60
# 77/77 [==============================] - 59s 754ms/step - loss: -0.7613 - dice_metric: 0.7978 - jaccard_metric: 0.7360 - sensitivity_metric: 0.7824 - specificity_metric: 0.9468 - precision_metric: 0.7993 - recall_metric: 0.7824 - mean_average_precision: 0.6239 - val_loss: -0.7141 - val_dice_metric: 0.7730 - val_jaccard_metric: 0.7157 - val_sensitivity_metric: 0.7354 - val_specificity_metric: 0.9508 - val_precision_metric: 0.7518 - val_recall_metric: 0.7354 - val_mean_average_precision: 0.6084
# Epoch 37/60
# 77/77 [==============================] - 60s 767ms/step - loss: -0.7619 - dice_metric: 0.7981 - jaccard_metric: 0.7365 - sensitivity_metric: 0.7828 - specificity_metric: 0.9470 - precision_metric: 0.7998 - recall_metric: 0.7828 - mean_average_precision: 0.6251 - val_loss: -0.7152 - val_dice_metric: 0.7755 - val_jaccard_metric: 0.7188 - val_sensitivity_metric: 0.7388 - val_specificity_metric: 0.9530 - val_precision_metric: 0.7509 - val_recall_metric: 0.7388 - val_mean_average_precision: 0.6119
# Epoch 38/60
# 77/77 [==============================] - 58s 749ms/step - loss: -0.7623 - dice_metric: 0.7977 - jaccard_metric: 0.7362 - sensitivity_metric: 0.7833 - specificity_metric: 0.9472 - precision_metric: 0.8001 - recall_metric: 0.7833 - mean_average_precision: 0.6248 - val_loss: -0.7161 - val_dice_metric: 0.7790 - val_jaccard_metric: 0.7224 - val_sensitivity_metric: 0.7408 - val_specificity_metric: 0.9540 - val_precision_metric: 0.7506 - val_recall_metric: 0.7408 - val_mean_average_precision: 0.6173
# Epoch 39/60
# 77/77 [==============================] - 57s 739ms/step - loss: -0.7630 - dice_metric: 0.7993 - jaccard_metric: 0.7378 - sensitivity_metric: 0.7837 - specificity_metric: 0.9473 - precision_metric: 0.8008 - recall_metric: 0.7837 - mean_average_precision: 0.6270 - val_loss: -0.7166 - val_dice_metric: 0.7820 - val_jaccard_metric: 0.7258 - val_sensitivity_metric: 0.7422 - val_specificity_metric: 0.9552 - val_precision_metric: 0.7501 - val_recall_metric: 0.7422 - val_mean_average_precision: 0.6221
# Epoch 40/60
# 77/77 [==============================] - 59s 764ms/step - loss: -0.7632 - dice_metric: 0.7999 - jaccard_metric: 0.7385 - sensitivity_metric: 0.7838 - specificity_metric: 0.9473 - precision_metric: 0.8011 - recall_metric: 0.7838 - mean_average_precision: 0.6277 - val_loss: -0.7173 - val_dice_metric: 0.7785 - val_jaccard_metric: 0.7225 - val_sensitivity_metric: 0.7431 - val_specificity_metric: 0.9555 - val_precision_metric: 0.7500 - val_recall_metric: 0.7431 - val_mean_average_precision: 0.6194
# Epoch 41/60
# 77/77 [==============================] - 58s 751ms/step - loss: -0.7637 - dice_metric: 0.8000 - jaccard_metric: 0.7387 - sensitivity_metric: 0.7843 - specificity_metric: 0.9474 - precision_metric: 0.8016 - recall_metric: 0.7843 - mean_average_precision: 0.6285 - val_loss: -0.7179 - val_dice_metric: 0.7991 - val_jaccard_metric: 0.7434 - val_sensitivity_metric: 0.7457 - val_specificity_metric: 0.9573 - val_precision_metric: 0.7488 - val_recall_metric: 0.7457 - val_mean_average_precision: 0.6406
# Epoch 42/60
# 77/77 [==============================] - 57s 729ms/step - loss: -0.7641 - dice_metric: 0.7996 - jaccard_metric: 0.7384 - sensitivity_metric: 0.7846 - specificity_metric: 0.9476 - precision_metric: 0.8019 - recall_metric: 0.7846 - mean_average_precision: 0.6285 - val_loss: -0.7181 - val_dice_metric: 0.7992 - val_jaccard_metric: 0.7436 - val_sensitivity_metric: 0.7459 - val_specificity_metric: 0.9576 - val_precision_metric: 0.7489 - val_recall_metric: 0.7459 - val_mean_average_precision: 0.6403
# Epoch 43/60
# 77/77 [==============================] - 57s 738ms/step - loss: -0.7644 - dice_metric: 0.7992 - jaccard_metric: 0.7380 - sensitivity_metric: 0.7848 - specificity_metric: 0.9475 - precision_metric: 0.8025 - recall_metric: 0.7848 - mean_average_precision: 0.6279 - val_loss: -0.7186 - val_dice_metric: 0.7983 - val_jaccard_metric: 0.7428 - val_sensitivity_metric: 0.7456 - val_specificity_metric: 0.9573 - val_precision_metric: 0.7498 - val_recall_metric: 0.7456 - val_mean_average_precision: 0.6401
# Epoch 44/60
# 77/77 [==============================] - 59s 763ms/step - loss: -0.7648 - dice_metric: 0.8023 - jaccard_metric: 0.7413 - sensitivity_metric: 0.7852 - specificity_metric: 0.9477 - precision_metric: 0.8026 - recall_metric: 0.7852 - mean_average_precision: 0.6316 - val_loss: -0.7188 - val_dice_metric: 0.7927 - val_jaccard_metric: 0.7374 - val_sensitivity_metric: 0.7475 - val_specificity_metric: 0.9586 - val_precision_metric: 0.7483 - val_recall_metric: 0.7475 - val_mean_average_precision: 0.6347
# Epoch 45/60
# 77/77 [==============================] - 58s 751ms/step - loss: -0.7652 - dice_metric: 0.8012 - jaccard_metric: 0.7402 - sensitivity_metric: 0.7854 - specificity_metric: 0.9477 - precision_metric: 0.8030 - recall_metric: 0.7854 - mean_average_precision: 0.6307 - val_loss: -0.7189 - val_dice_metric: 0.8076 - val_jaccard_metric: 0.7522 - val_sensitivity_metric: 0.7487 - val_specificity_metric: 0.9596 - val_precision_metric: 0.7473 - val_recall_metric: 0.7487 - val_mean_average_precision: 0.6500
# Epoch 46/60
# 77/77 [==============================] - 57s 732ms/step - loss: -0.7655 - dice_metric: 0.8009 - jaccard_metric: 0.7400 - sensitivity_metric: 0.7859 - specificity_metric: 0.9478 - precision_metric: 0.8031 - recall_metric: 0.7859 - mean_average_precision: 0.6306 - val_loss: -0.7192 - val_dice_metric: 0.7999 - val_jaccard_metric: 0.7445 - val_sensitivity_metric: 0.7503 - val_specificity_metric: 0.9603 - val_precision_metric: 0.7459 - val_recall_metric: 0.7503 - val_mean_average_precision: 0.6420
# Epoch 47/60
# 77/77 [==============================] - 58s 745ms/step - loss: -0.7659 - dice_metric: 0.8004 - jaccard_metric: 0.7395 - sensitivity_metric: 0.7862 - specificity_metric: 0.9480 - precision_metric: 0.8035 - recall_metric: 0.7862 - mean_average_precision: 0.6299 - val_loss: -0.7199 - val_dice_metric: 0.8085 - val_jaccard_metric: 0.7533 - val_sensitivity_metric: 0.7503 - val_specificity_metric: 0.9601 - val_precision_metric: 0.7473 - val_recall_metric: 0.7503 - val_mean_average_precision: 0.6514
# Epoch 48/60
# 77/77 [==============================] - 58s 748ms/step - loss: -0.7663 - dice_metric: 0.8022 - jaccard_metric: 0.7414 - sensitivity_metric: 0.7863 - specificity_metric: 0.9480 - precision_metric: 0.8039 - recall_metric: 0.7863 - mean_average_precision: 0.6325 - val_loss: -0.7201 - val_dice_metric: 0.8111 - val_jaccard_metric: 0.7560 - val_sensitivity_metric: 0.7504 - val_specificity_metric: 0.9600 - val_precision_metric: 0.7474 - val_recall_metric: 0.7504 - val_mean_average_precision: 0.6540
# Epoch 49/60
# 77/77 [==============================] - 59s 755ms/step - loss: -0.7666 - dice_metric: 0.8028 - jaccard_metric: 0.7421 - sensitivity_metric: 0.7867 - specificity_metric: 0.9481 - precision_metric: 0.8042 - recall_metric: 0.7867 - mean_average_precision: 0.6339 - val_loss: -0.7202 - val_dice_metric: 0.8137 - val_jaccard_metric: 0.7585 - val_sensitivity_metric: 0.7516 - val_specificity_metric: 0.9609 - val_precision_metric: 0.7461 - val_recall_metric: 0.7516 - val_mean_average_precision: 0.6566
# Epoch 50/60
# 77/77 [==============================] - 59s 762ms/step - loss: -0.7669 - dice_metric: 0.8019 - jaccard_metric: 0.7412 - sensitivity_metric: 0.7871 - specificity_metric: 0.9482 - precision_metric: 0.8042 - recall_metric: 0.7871 - mean_average_precision: 0.6326 - val_loss: -0.7205 - val_dice_metric: 0.8114 - val_jaccard_metric: 0.7564 - val_sensitivity_metric: 0.7516 - val_specificity_metric: 0.9608 - val_precision_metric: 0.7467 - val_recall_metric: 0.7516 - val_mean_average_precision: 0.6550
# Epoch 51/60
# 77/77 [==============================] - 58s 750ms/step - loss: -0.7672 - dice_metric: 0.8039 - jaccard_metric: 0.7433 - sensitivity_metric: 0.7871 - specificity_metric: 0.9481 - precision_metric: 0.8048 - recall_metric: 0.7871 - mean_average_precision: 0.6352 - val_loss: -0.7201 - val_dice_metric: 0.8040 - val_jaccard_metric: 0.7489 - val_sensitivity_metric: 0.7533 - val_specificity_metric: 0.9623 - val_precision_metric: 0.7444 - val_recall_metric: 0.7533 - val_mean_average_precision: 0.6481
# Epoch 52/60
# 77/77 [==============================] - 60s 769ms/step - loss: -0.7675 - dice_metric: 0.8045 - jaccard_metric: 0.7440 - sensitivity_metric: 0.7876 - specificity_metric: 0.9484 - precision_metric: 0.8047 - recall_metric: 0.7876 - mean_average_precision: 0.6357 - val_loss: -0.7203 - val_dice_metric: 0.8187 - val_jaccard_metric: 0.7636 - val_sensitivity_metric: 0.7531 - val_specificity_metric: 0.9623 - val_precision_metric: 0.7446 - val_recall_metric: 0.7531 - val_mean_average_precision: 0.6621
# Epoch 53/60
# 77/77 [==============================] - 57s 731ms/step - loss: -0.7679 - dice_metric: 0.8027 - jaccard_metric: 0.7422 - sensitivity_metric: 0.7881 - specificity_metric: 0.9486 - precision_metric: 0.8049 - recall_metric: 0.7881 - mean_average_precision: 0.6342 - val_loss: -0.7206 - val_dice_metric: 0.8018 - val_jaccard_metric: 0.7469 - val_sensitivity_metric: 0.7526 - val_specificity_metric: 0.9617 - val_precision_metric: 0.7461 - val_recall_metric: 0.7526 - val_mean_average_precision: 0.6452
# Epoch 54/60
# 77/77 [==============================] - 59s 759ms/step - loss: -0.7680 - dice_metric: 0.8024 - jaccard_metric: 0.7420 - sensitivity_metric: 0.7881 - specificity_metric: 0.9487 - precision_metric: 0.8051 - recall_metric: 0.7881 - mean_average_precision: 0.6343 - val_loss: -0.7212 - val_dice_metric: 0.8051 - val_jaccard_metric: 0.7502 - val_sensitivity_metric: 0.7531 - val_specificity_metric: 0.9615 - val_precision_metric: 0.7465 - val_recall_metric: 0.7531 - val_mean_average_precision: 0.6490
# Epoch 55/60
# 77/77 [==============================] - 60s 767ms/step - loss: -0.7684 - dice_metric: 0.8039 - jaccard_metric: 0.7435 - sensitivity_metric: 0.7883 - specificity_metric: 0.9486 - precision_metric: 0.8055 - recall_metric: 0.7883 - mean_average_precision: 0.6364 - val_loss: -0.7211 - val_dice_metric: 0.8021 - val_jaccard_metric: 0.7472 - val_sensitivity_metric: 0.7528 - val_specificity_metric: 0.9614 - val_precision_metric: 0.7463 - val_recall_metric: 0.7528 - val_mean_average_precision: 0.6452
# Epoch 56/60
# 77/77 [==============================] - 59s 755ms/step - loss: -0.7687 - dice_metric: 0.8046 - jaccard_metric: 0.7444 - sensitivity_metric: 0.7886 - specificity_metric: 0.9487 - precision_metric: 0.8058 - recall_metric: 0.7886 - mean_average_precision: 0.6370 - val_loss: -0.7210 - val_dice_metric: 0.8115 - val_jaccard_metric: 0.7566 - val_sensitivity_metric: 0.7527 - val_specificity_metric: 0.9617 - val_precision_metric: 0.7461 - val_recall_metric: 0.7527 - val_mean_average_precision: 0.6552
# Epoch 57/60
# 77/77 [==============================] - 59s 763ms/step - loss: -0.7690 - dice_metric: 0.8043 - jaccard_metric: 0.7440 - sensitivity_metric: 0.7888 - specificity_metric: 0.9488 - precision_metric: 0.8060 - recall_metric: 0.7888 - mean_average_precision: 0.6371 - val_loss: -0.7214 - val_dice_metric: 0.8077 - val_jaccard_metric: 0.7528 - val_sensitivity_metric: 0.7534 - val_specificity_metric: 0.9618 - val_precision_metric: 0.7463 - val_recall_metric: 0.7534 - val_mean_average_precision: 0.6510
# Epoch 58/60
# 77/77 [==============================] - 59s 751ms/step - loss: -0.7691 - dice_metric: 0.8031 - jaccard_metric: 0.7429 - sensitivity_metric: 0.7890 - specificity_metric: 0.9489 - precision_metric: 0.8060 - recall_metric: 0.7890 - mean_average_precision: 0.6362 - val_loss: -0.7214 - val_dice_metric: 0.8105 - val_jaccard_metric: 0.7556 - val_sensitivity_metric: 0.7543 - val_specificity_metric: 0.9624 - val_precision_metric: 0.7451 - val_recall_metric: 0.7543 - val_mean_average_precision: 0.6530
# Epoch 59/60
# 77/77 [==============================] - 58s 751ms/step - loss: -0.7696 - dice_metric: 0.8044 - jaccard_metric: 0.7443 - sensitivity_metric: 0.7893 - specificity_metric: 0.9489 - precision_metric: 0.8064 - recall_metric: 0.7893 - mean_average_precision: 0.6379 - val_loss: -0.7216 - val_dice_metric: 0.8236 - val_jaccard_metric: 0.7688 - val_sensitivity_metric: 0.7541 - val_specificity_metric: 0.9623 - val_precision_metric: 0.7453 - val_recall_metric: 0.7541 - val_mean_average_precision: 0.6669
# Epoch 60/60
# 77/77 [==============================] - 59s 753ms/step - loss: -0.7698 - dice_metric: 0.8047 - jaccard_metric: 0.7446 - sensitivity_metric: 0.7896 - specificity_metric: 0.9491 - precision_metric: 0.8066 - recall_metric: 0.7896 - mean_average_precision: 0.6380 - val_loss: -0.7212 - val_dice_metric: 0.8152 - val_jaccard_metric: 0.7601 - val_sensitivity_metric: 0.7552 - val_specificity_metric: 0.9633 - val_precision_metric: 0.7432 - val_recall_metric: 0.7552 - val_mean_average_precision: 0.6572

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.82374, std: 0.27229
# Jaccard Index mean: 0.76559, std: 0.28816
# Sensitivity mean: 0.77379, std: 0.33788
# Specificity mean: 0.96243, std: 0.06862
# Precision mean: 0.76899, std: 0.32519
# Recall mean: 0.77379, std: 0.33788
# mAP@50 mean: 0.85876, std: 0.18106
# mAP@50-95 mean: 0.65565, std: 0.17462
