# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|███████████████████████████████████████▌| 989M/0.98G [00:07<00:00, 158MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:07<00:00, 141MB/s]

# %%
config = {"Seg_model":"RFFSkipsResUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import res_unet_rff_skips
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = res_unet_rff_skips(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 183s 1s/step - loss: -0.1727 - dice_metric: 0.0178 - jaccard_metric: 0.0102 - sensitivity_metric: 0.0518 - specificity_metric: 0.9538 - precision_metric: 0.0578 - recall_metric: 0.0518 - mean_average_precision: 0.0000e+00 - val_loss: -0.1869 - val_dice_metric: 0.1580 - val_jaccard_metric: 0.1580 - val_sensitivity_metric: 0.0000e+00 - val_specificity_metric: 1.0000 - val_precision_metric: 0.0000e+00 - val_recall_metric: 0.0000e+00 - val_mean_average_precision: 0.1580
# Epoch 2/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.1980 - dice_metric: 0.0515 - jaccard_metric: 0.0323 - sensitivity_metric: 0.0613 - specificity_metric: 0.9888 - precision_metric: 0.1149 - recall_metric: 0.0613 - mean_average_precision: 5.8795e-04 - val_loss: -0.1962 - val_dice_metric: 0.1580 - val_jaccard_metric: 0.1580 - val_sensitivity_metric: 0.0000e+00 - val_specificity_metric: 1.0000 - val_precision_metric: 0.0000e+00 - val_recall_metric: 0.0000e+00 - val_mean_average_precision: 0.1580
# Epoch 3/60
# 77/77 [==============================] - 104s 1s/step - loss: -0.2220 - dice_metric: 0.1411 - jaccard_metric: 0.1005 - sensitivity_metric: 0.2011 - specificity_metric: 0.9768 - precision_metric: 0.1705 - recall_metric: 0.2011 - mean_average_precision: 0.0183 - val_loss: -0.2038 - val_dice_metric: 0.1583 - val_jaccard_metric: 0.1581 - val_sensitivity_metric: 1.6519e-04 - val_specificity_metric: 1.0000 - val_precision_metric: 0.0320 - val_recall_metric: 1.6519e-04 - val_mean_average_precision: 0.1580
# Epoch 4/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.2405 - dice_metric: 0.1702 - jaccard_metric: 0.1263 - sensitivity_metric: 0.2602 - specificity_metric: 0.9745 - precision_metric: 0.2102 - recall_metric: 0.2602 - mean_average_precision: 0.0315 - val_loss: -0.2242 - val_dice_metric: 0.2042 - val_jaccard_metric: 0.1700 - val_sensitivity_metric: 0.0998 - val_specificity_metric: 0.9986 - val_precision_metric: 0.2342 - val_recall_metric: 0.0998 - val_mean_average_precision: 0.1055
# Epoch 5/60
# 77/77 [==============================] - 106s 1s/step - loss: -0.2571 - dice_metric: 0.1866 - jaccard_metric: 0.1407 - sensitivity_metric: 0.3080 - specificity_metric: 0.9702 - precision_metric: 0.1996 - recall_metric: 0.3080 - mean_average_precision: 0.0386 - val_loss: -0.2611 - val_dice_metric: 0.2333 - val_jaccard_metric: 0.1911 - val_sensitivity_metric: 0.2657 - val_specificity_metric: 0.9937 - val_precision_metric: 0.2045 - val_recall_metric: 0.2657 - val_mean_average_precision: 0.1010
# Epoch 6/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.2677 - dice_metric: 0.1936 - jaccard_metric: 0.1479 - sensitivity_metric: 0.3156 - specificity_metric: 0.9660 - precision_metric: 0.3100 - recall_metric: 0.3156 - mean_average_precision: 0.0450 - val_loss: -0.2644 - val_dice_metric: 0.1998 - val_jaccard_metric: 0.1555 - val_sensitivity_metric: 0.3229 - val_specificity_metric: 0.9656 - val_precision_metric: 0.1760 - val_recall_metric: 0.3229 - val_mean_average_precision: 0.0543
# Epoch 7/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.2784 - dice_metric: 0.2101 - jaccard_metric: 0.1642 - sensitivity_metric: 0.3225 - specificity_metric: 0.9589 - precision_metric: 0.4912 - recall_metric: 0.3225 - mean_average_precision: 0.0611 - val_loss: -0.2547 - val_dice_metric: 0.1811 - val_jaccard_metric: 0.1385 - val_sensitivity_metric: 0.3282 - val_specificity_metric: 0.9313 - val_precision_metric: 0.4758 - val_recall_metric: 0.3282 - val_mean_average_precision: 0.0449
# Epoch 8/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.2904 - dice_metric: 0.2361 - jaccard_metric: 0.1856 - sensitivity_metric: 0.3367 - specificity_metric: 0.9481 - precision_metric: 0.5184 - recall_metric: 0.3367 - mean_average_precision: 0.0795 - val_loss: -0.2738 - val_dice_metric: 0.2158 - val_jaccard_metric: 0.1719 - val_sensitivity_metric: 0.3329 - val_specificity_metric: 0.9247 - val_precision_metric: 0.5061 - val_recall_metric: 0.3329 - val_mean_average_precision: 0.0791
# Epoch 9/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.3040 - dice_metric: 0.4688 - jaccard_metric: 0.3901 - sensitivity_metric: 0.5367 - specificity_metric: 0.9113 - precision_metric: 0.5320 - recall_metric: 0.5367 - mean_average_precision: 0.2252 - val_loss: -0.2898 - val_dice_metric: 0.5055 - val_jaccard_metric: 0.4258 - val_sensitivity_metric: 0.5655 - val_specificity_metric: 0.8911 - val_precision_metric: 0.5351 - val_recall_metric: 0.5655 - val_mean_average_precision: 0.2559
# Epoch 10/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.3207 - dice_metric: 0.5122 - jaccard_metric: 0.4291 - sensitivity_metric: 0.5710 - specificity_metric: 0.8817 - precision_metric: 0.5446 - recall_metric: 0.5710 - mean_average_precision: 0.2494 - val_loss: -0.2919 - val_dice_metric: 0.4807 - val_jaccard_metric: 0.3894 - val_sensitivity_metric: 0.5416 - val_specificity_metric: 0.8613 - val_precision_metric: 0.5288 - val_recall_metric: 0.5416 - val_mean_average_precision: 0.1817
# Epoch 11/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.3383 - dice_metric: 0.5052 - jaccard_metric: 0.4176 - sensitivity_metric: 0.5564 - specificity_metric: 0.8608 - precision_metric: 0.5537 - recall_metric: 0.5564 - mean_average_precision: 0.2242 - val_loss: -0.3152 - val_dice_metric: 0.4867 - val_jaccard_metric: 0.3954 - val_sensitivity_metric: 0.5405 - val_specificity_metric: 0.8539 - val_precision_metric: 0.5396 - val_recall_metric: 0.5405 - val_mean_average_precision: 0.1883
# Epoch 12/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.3581 - dice_metric: 0.5011 - jaccard_metric: 0.4117 - sensitivity_metric: 0.5537 - specificity_metric: 0.8501 - precision_metric: 0.5604 - recall_metric: 0.5537 - mean_average_precision: 0.2131 - val_loss: -0.3430 - val_dice_metric: 0.4944 - val_jaccard_metric: 0.4036 - val_sensitivity_metric: 0.5418 - val_specificity_metric: 0.8498 - val_precision_metric: 0.5519 - val_recall_metric: 0.5418 - val_mean_average_precision: 0.1948
# Epoch 13/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.3764 - dice_metric: 0.5007 - jaccard_metric: 0.4106 - sensitivity_metric: 0.5551 - specificity_metric: 0.8453 - precision_metric: 0.5660 - recall_metric: 0.5551 - mean_average_precision: 0.2097 - val_loss: -0.3649 - val_dice_metric: 0.4946 - val_jaccard_metric: 0.4040 - val_sensitivity_metric: 0.5396 - val_specificity_metric: 0.8442 - val_precision_metric: 0.5591 - val_recall_metric: 0.5396 - val_mean_average_precision: 0.1984
# Epoch 14/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.3926 - dice_metric: 0.5021 - jaccard_metric: 0.4116 - sensitivity_metric: 0.5584 - specificity_metric: 0.8430 - precision_metric: 0.5709 - recall_metric: 0.5584 - mean_average_precision: 0.2092 - val_loss: -0.3736 - val_dice_metric: 0.4791 - val_jaccard_metric: 0.3855 - val_sensitivity_metric: 0.5297 - val_specificity_metric: 0.8277 - val_precision_metric: 0.5606 - val_recall_metric: 0.5297 - val_mean_average_precision: 0.1741
# Epoch 15/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.4065 - dice_metric: 0.5047 - jaccard_metric: 0.4134 - sensitivity_metric: 0.5662 - specificity_metric: 0.8433 - precision_metric: 0.5754 - recall_metric: 0.5662 - mean_average_precision: 0.2073 - val_loss: -0.3845 - val_dice_metric: 0.4781 - val_jaccard_metric: 0.3837 - val_sensitivity_metric: 0.5297 - val_specificity_metric: 0.8232 - val_precision_metric: 0.5668 - val_recall_metric: 0.5297 - val_mean_average_precision: 0.1688
# Epoch 16/60
# 77/77 [==============================] - 105s 1s/step - loss: -0.4188 - dice_metric: 0.5082 - jaccard_metric: 0.4168 - sensitivity_metric: 0.5749 - specificity_metric: 0.8447 - precision_metric: 0.5798 - recall_metric: 0.5749 - mean_average_precision: 0.2107 - val_loss: -0.4079 - val_dice_metric: 0.4963 - val_jaccard_metric: 0.4046 - val_sensitivity_metric: 0.5441 - val_specificity_metric: 0.8342 - val_precision_metric: 0.5791 - val_recall_metric: 0.5441 - val_mean_average_precision: 0.1951
# Epoch 17/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.4296 - dice_metric: 0.5121 - jaccard_metric: 0.4211 - sensitivity_metric: 0.5840 - specificity_metric: 0.8468 - precision_metric: 0.5839 - recall_metric: 0.5840 - mean_average_precision: 0.2166 - val_loss: -0.4312 - val_dice_metric: 0.5148 - val_jaccard_metric: 0.4271 - val_sensitivity_metric: 0.5618 - val_specificity_metric: 0.8497 - val_precision_metric: 0.5857 - val_recall_metric: 0.5618 - val_mean_average_precision: 0.2314
# Epoch 18/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.4392 - dice_metric: 0.5159 - jaccard_metric: 0.4252 - sensitivity_metric: 0.5944 - specificity_metric: 0.8494 - precision_metric: 0.5876 - recall_metric: 0.5944 - mean_average_precision: 0.2228 - val_loss: -0.4445 - val_dice_metric: 0.5219 - val_jaccard_metric: 0.4354 - val_sensitivity_metric: 0.5749 - val_specificity_metric: 0.8549 - val_precision_metric: 0.5893 - val_recall_metric: 0.5749 - val_mean_average_precision: 0.2433
# Epoch 19/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.4483 - dice_metric: 0.5195 - jaccard_metric: 0.4291 - sensitivity_metric: 0.6072 - specificity_metric: 0.8525 - precision_metric: 0.5908 - recall_metric: 0.6072 - mean_average_precision: 0.2290 - val_loss: -0.4541 - val_dice_metric: 0.5186 - val_jaccard_metric: 0.4312 - val_sensitivity_metric: 0.5877 - val_specificity_metric: 0.8591 - val_precision_metric: 0.5777 - val_recall_metric: 0.5877 - val_mean_average_precision: 0.2393
# Epoch 20/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.4572 - dice_metric: 0.5239 - jaccard_metric: 0.4339 - sensitivity_metric: 0.6185 - specificity_metric: 0.8556 - precision_metric: 0.5949 - recall_metric: 0.6185 - mean_average_precision: 0.2364 - val_loss: -0.4771 - val_dice_metric: 0.5436 - val_jaccard_metric: 0.4618 - val_sensitivity_metric: 0.6090 - val_specificity_metric: 0.8781 - val_precision_metric: 0.5909 - val_recall_metric: 0.6090 - val_mean_average_precision: 0.2918
# Epoch 21/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.4655 - dice_metric: 0.5287 - jaccard_metric: 0.4397 - sensitivity_metric: 0.6291 - specificity_metric: 0.8593 - precision_metric: 0.5986 - recall_metric: 0.6291 - mean_average_precision: 0.2461 - val_loss: -0.4857 - val_dice_metric: 0.5486 - val_jaccard_metric: 0.4679 - val_sensitivity_metric: 0.6131 - val_specificity_metric: 0.8823 - val_precision_metric: 0.5920 - val_recall_metric: 0.6131 - val_mean_average_precision: 0.2995
# Epoch 22/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.4725 - dice_metric: 0.5327 - jaccard_metric: 0.4443 - sensitivity_metric: 0.6376 - specificity_metric: 0.8630 - precision_metric: 0.6010 - recall_metric: 0.6376 - mean_average_precision: 0.2539 - val_loss: -0.4929 - val_dice_metric: 0.5545 - val_jaccard_metric: 0.4748 - val_sensitivity_metric: 0.6183 - val_specificity_metric: 0.8834 - val_precision_metric: 0.6001 - val_recall_metric: 0.6183 - val_mean_average_precision: 0.3113
# Epoch 23/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.4796 - dice_metric: 0.5373 - jaccard_metric: 0.4499 - sensitivity_metric: 0.6453 - specificity_metric: 0.8661 - precision_metric: 0.6039 - recall_metric: 0.6453 - mean_average_precision: 0.2634 - val_loss: -0.4972 - val_dice_metric: 0.5558 - val_jaccard_metric: 0.4749 - val_sensitivity_metric: 0.6233 - val_specificity_metric: 0.8799 - val_precision_metric: 0.6090 - val_recall_metric: 0.6233 - val_mean_average_precision: 0.3090
# Epoch 24/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.4864 - dice_metric: 0.5421 - jaccard_metric: 0.4557 - sensitivity_metric: 0.6528 - specificity_metric: 0.8694 - precision_metric: 0.6065 - recall_metric: 0.6528 - mean_average_precision: 0.2729 - val_loss: -0.5015 - val_dice_metric: 0.5566 - val_jaccard_metric: 0.4745 - val_sensitivity_metric: 0.6275 - val_specificity_metric: 0.8792 - val_precision_metric: 0.6118 - val_recall_metric: 0.6275 - val_mean_average_precision: 0.3066
# Epoch 25/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.4936 - dice_metric: 0.5486 - jaccard_metric: 0.4630 - sensitivity_metric: 0.6619 - specificity_metric: 0.8726 - precision_metric: 0.6111 - recall_metric: 0.6619 - mean_average_precision: 0.2838 - val_loss: -0.5044 - val_dice_metric: 0.5542 - val_jaccard_metric: 0.4713 - val_sensitivity_metric: 0.6284 - val_specificity_metric: 0.8783 - val_precision_metric: 0.6061 - val_recall_metric: 0.6284 - val_mean_average_precision: 0.3024
# Epoch 26/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.4987 - dice_metric: 0.5520 - jaccard_metric: 0.4668 - sensitivity_metric: 0.6644 - specificity_metric: 0.8756 - precision_metric: 0.6123 - recall_metric: 0.6644 - mean_average_precision: 0.2893 - val_loss: -0.4980 - val_dice_metric: 0.5410 - val_jaccard_metric: 0.4546 - val_sensitivity_metric: 0.6198 - val_specificity_metric: 0.8674 - val_precision_metric: 0.5961 - val_recall_metric: 0.6198 - val_mean_average_precision: 0.2717
# Epoch 27/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.5054 - dice_metric: 0.5574 - jaccard_metric: 0.4729 - sensitivity_metric: 0.6718 - specificity_metric: 0.8782 - precision_metric: 0.6160 - recall_metric: 0.6718 - mean_average_precision: 0.2989 - val_loss: -0.5066 - val_dice_metric: 0.5484 - val_jaccard_metric: 0.4637 - val_sensitivity_metric: 0.6245 - val_specificity_metric: 0.8747 - val_precision_metric: 0.5978 - val_recall_metric: 0.6245 - val_mean_average_precision: 0.2852
# Epoch 28/60
# 77/77 [==============================] - 103s 1s/step - loss: -0.5108 - dice_metric: 0.5615 - jaccard_metric: 0.4777 - sensitivity_metric: 0.6768 - specificity_metric: 0.8812 - precision_metric: 0.6179 - recall_metric: 0.6768 - mean_average_precision: 0.3063 - val_loss: -0.5100 - val_dice_metric: 0.5490 - val_jaccard_metric: 0.4643 - val_sensitivity_metric: 0.6292 - val_specificity_metric: 0.8767 - val_precision_metric: 0.5966 - val_recall_metric: 0.6292 - val_mean_average_precision: 0.2885
# Epoch 29/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.5163 - dice_metric: 0.5660 - jaccard_metric: 0.4829 - sensitivity_metric: 0.6820 - specificity_metric: 0.8839 - precision_metric: 0.6209 - recall_metric: 0.6820 - mean_average_precision: 0.3141 - val_loss: -0.5150 - val_dice_metric: 0.5541 - val_jaccard_metric: 0.4718 - val_sensitivity_metric: 0.6284 - val_specificity_metric: 0.8732 - val_precision_metric: 0.6125 - val_recall_metric: 0.6284 - val_mean_average_precision: 0.3000
# Epoch 30/60
# 77/77 [==============================] - 98s 1s/step - loss: -0.5218 - dice_metric: 0.5703 - jaccard_metric: 0.4878 - sensitivity_metric: 0.6860 - specificity_metric: 0.8866 - precision_metric: 0.6232 - recall_metric: 0.6860 - mean_average_precision: 0.3215 - val_loss: -0.5259 - val_dice_metric: 0.5648 - val_jaccard_metric: 0.4863 - val_sensitivity_metric: 0.6376 - val_specificity_metric: 0.8851 - val_precision_metric: 0.6136 - val_recall_metric: 0.6376 - val_mean_average_precision: 0.3289
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5271 - dice_metric: 0.5756 - jaccard_metric: 0.4941 - sensitivity_metric: 0.6938 - specificity_metric: 0.8887 - precision_metric: 0.6259 - recall_metric: 0.6938 - mean_average_precision: 0.3317 - val_loss: -0.5238 - val_dice_metric: 0.5660 - val_jaccard_metric: 0.4861 - val_sensitivity_metric: 0.6385 - val_specificity_metric: 0.8757 - val_precision_metric: 0.6331 - val_recall_metric: 0.6385 - val_mean_average_precision: 0.3171
# Epoch 32/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.5293 - dice_metric: 0.5784 - jaccard_metric: 0.4973 - sensitivity_metric: 0.6993 - specificity_metric: 0.8888 - precision_metric: 0.6295 - recall_metric: 0.6993 - mean_average_precision: 0.3356 - val_loss: -0.5226 - val_dice_metric: 0.5651 - val_jaccard_metric: 0.4848 - val_sensitivity_metric: 0.6366 - val_specificity_metric: 0.8742 - val_precision_metric: 0.6360 - val_recall_metric: 0.6366 - val_mean_average_precision: 0.3151
# Epoch 33/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.5303 - dice_metric: 0.5795 - jaccard_metric: 0.4986 - sensitivity_metric: 0.7008 - specificity_metric: 0.8889 - precision_metric: 0.6304 - recall_metric: 0.7008 - mean_average_precision: 0.3380 - val_loss: -0.5224 - val_dice_metric: 0.5645 - val_jaccard_metric: 0.4841 - val_sensitivity_metric: 0.6362 - val_specificity_metric: 0.8734 - val_precision_metric: 0.6362 - val_recall_metric: 0.6362 - val_mean_average_precision: 0.3142
# Epoch 34/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.5312 - dice_metric: 0.5805 - jaccard_metric: 0.4996 - sensitivity_metric: 0.7020 - specificity_metric: 0.8891 - precision_metric: 0.6312 - recall_metric: 0.7020 - mean_average_precision: 0.3394 - val_loss: -0.5229 - val_dice_metric: 0.5648 - val_jaccard_metric: 0.4845 - val_sensitivity_metric: 0.6368 - val_specificity_metric: 0.8735 - val_precision_metric: 0.6363 - val_recall_metric: 0.6368 - val_mean_average_precision: 0.3161
# Epoch 35/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.5320 - dice_metric: 0.5813 - jaccard_metric: 0.5006 - sensitivity_metric: 0.7031 - specificity_metric: 0.8892 - precision_metric: 0.6319 - recall_metric: 0.7031 - mean_average_precision: 0.3409 - val_loss: -0.5235 - val_dice_metric: 0.5651 - val_jaccard_metric: 0.4848 - val_sensitivity_metric: 0.6373 - val_specificity_metric: 0.8737 - val_precision_metric: 0.6361 - val_recall_metric: 0.6373 - val_mean_average_precision: 0.3167
# Epoch 36/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.5328 - dice_metric: 0.5820 - jaccard_metric: 0.5015 - sensitivity_metric: 0.7040 - specificity_metric: 0.8894 - precision_metric: 0.6325 - recall_metric: 0.7040 - mean_average_precision: 0.3420 - val_loss: -0.5240 - val_dice_metric: 0.5654 - val_jaccard_metric: 0.4852 - val_sensitivity_metric: 0.6379 - val_specificity_metric: 0.8739 - val_precision_metric: 0.6361 - val_recall_metric: 0.6379 - val_mean_average_precision: 0.3175
# Epoch 37/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.5336 - dice_metric: 0.5828 - jaccard_metric: 0.5024 - sensitivity_metric: 0.7050 - specificity_metric: 0.8897 - precision_metric: 0.6331 - recall_metric: 0.7050 - mean_average_precision: 0.3433 - val_loss: -0.5245 - val_dice_metric: 0.5657 - val_jaccard_metric: 0.4856 - val_sensitivity_metric: 0.6385 - val_specificity_metric: 0.8742 - val_precision_metric: 0.6361 - val_recall_metric: 0.6385 - val_mean_average_precision: 0.3180
# Epoch 38/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.5343 - dice_metric: 0.5835 - jaccard_metric: 0.5032 - sensitivity_metric: 0.7058 - specificity_metric: 0.8899 - precision_metric: 0.6337 - recall_metric: 0.7058 - mean_average_precision: 0.3447 - val_loss: -0.5249 - val_dice_metric: 0.5659 - val_jaccard_metric: 0.4859 - val_sensitivity_metric: 0.6387 - val_specificity_metric: 0.8742 - val_precision_metric: 0.6366 - val_recall_metric: 0.6387 - val_mean_average_precision: 0.3180
# Epoch 39/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.5351 - dice_metric: 0.5843 - jaccard_metric: 0.5041 - sensitivity_metric: 0.7067 - specificity_metric: 0.8902 - precision_metric: 0.6342 - recall_metric: 0.7067 - mean_average_precision: 0.3462 - val_loss: -0.5257 - val_dice_metric: 0.5666 - val_jaccard_metric: 0.4867 - val_sensitivity_metric: 0.6396 - val_specificity_metric: 0.8748 - val_precision_metric: 0.6366 - val_recall_metric: 0.6396 - val_mean_average_precision: 0.3205
# Epoch 40/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5358 - dice_metric: 0.5850 - jaccard_metric: 0.5050 - sensitivity_metric: 0.7076 - specificity_metric: 0.8905 - precision_metric: 0.6346 - recall_metric: 0.7076 - mean_average_precision: 0.3475 - val_loss: -0.5265 - val_dice_metric: 0.5673 - val_jaccard_metric: 0.4876 - val_sensitivity_metric: 0.6405 - val_specificity_metric: 0.8754 - val_precision_metric: 0.6367 - val_recall_metric: 0.6405 - val_mean_average_precision: 0.3224
# Epoch 41/60
# 77/77 [==============================] - 98s 1s/step - loss: -0.5365 - dice_metric: 0.5857 - jaccard_metric: 0.5058 - sensitivity_metric: 0.7083 - specificity_metric: 0.8908 - precision_metric: 0.6351 - recall_metric: 0.7083 - mean_average_precision: 0.3489 - val_loss: -0.5273 - val_dice_metric: 0.5679 - val_jaccard_metric: 0.4884 - val_sensitivity_metric: 0.6412 - val_specificity_metric: 0.8759 - val_precision_metric: 0.6367 - val_recall_metric: 0.6412 - val_mean_average_precision: 0.3237
# Epoch 42/60
# 77/77 [==============================] - 97s 1s/step - loss: -0.5372 - dice_metric: 0.5864 - jaccard_metric: 0.5065 - sensitivity_metric: 0.7091 - specificity_metric: 0.8910 - precision_metric: 0.6356 - recall_metric: 0.7091 - mean_average_precision: 0.3500 - val_loss: -0.5275 - val_dice_metric: 0.5680 - val_jaccard_metric: 0.4884 - val_sensitivity_metric: 0.6416 - val_specificity_metric: 0.8757 - val_precision_metric: 0.6367 - val_recall_metric: 0.6416 - val_mean_average_precision: 0.3239
# Epoch 43/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5379 - dice_metric: 0.5870 - jaccard_metric: 0.5073 - sensitivity_metric: 0.7097 - specificity_metric: 0.8912 - precision_metric: 0.6361 - recall_metric: 0.7097 - mean_average_precision: 0.3508 - val_loss: -0.5281 - val_dice_metric: 0.5682 - val_jaccard_metric: 0.4887 - val_sensitivity_metric: 0.6421 - val_specificity_metric: 0.8759 - val_precision_metric: 0.6367 - val_recall_metric: 0.6421 - val_mean_average_precision: 0.3247
# Epoch 44/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.5386 - dice_metric: 0.5877 - jaccard_metric: 0.5081 - sensitivity_metric: 0.7105 - specificity_metric: 0.8915 - precision_metric: 0.6366 - recall_metric: 0.7105 - mean_average_precision: 0.3519 - val_loss: -0.5287 - val_dice_metric: 0.5686 - val_jaccard_metric: 0.4892 - val_sensitivity_metric: 0.6425 - val_specificity_metric: 0.8762 - val_precision_metric: 0.6369 - val_recall_metric: 0.6425 - val_mean_average_precision: 0.3248
# Epoch 45/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.5393 - dice_metric: 0.5884 - jaccard_metric: 0.5089 - sensitivity_metric: 0.7112 - specificity_metric: 0.8917 - precision_metric: 0.6371 - recall_metric: 0.7112 - mean_average_precision: 0.3531 - val_loss: -0.5292 - val_dice_metric: 0.5689 - val_jaccard_metric: 0.4896 - val_sensitivity_metric: 0.6427 - val_specificity_metric: 0.8764 - val_precision_metric: 0.6372 - val_recall_metric: 0.6427 - val_mean_average_precision: 0.3254
# Epoch 46/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.5400 - dice_metric: 0.5891 - jaccard_metric: 0.5097 - sensitivity_metric: 0.7118 - specificity_metric: 0.8920 - precision_metric: 0.6376 - recall_metric: 0.7118 - mean_average_precision: 0.3541 - val_loss: -0.5294 - val_dice_metric: 0.5689 - val_jaccard_metric: 0.4896 - val_sensitivity_metric: 0.6429 - val_specificity_metric: 0.8763 - val_precision_metric: 0.6372 - val_recall_metric: 0.6429 - val_mean_average_precision: 0.3252
# Epoch 47/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5407 - dice_metric: 0.5897 - jaccard_metric: 0.5104 - sensitivity_metric: 0.7125 - specificity_metric: 0.8922 - precision_metric: 0.6381 - recall_metric: 0.7125 - mean_average_precision: 0.3550 - val_loss: -0.5302 - val_dice_metric: 0.5697 - val_jaccard_metric: 0.4905 - val_sensitivity_metric: 0.6438 - val_specificity_metric: 0.8768 - val_precision_metric: 0.6373 - val_recall_metric: 0.6438 - val_mean_average_precision: 0.3273
# Epoch 48/60
# 77/77 [==============================] - 95s 1s/step - loss: -0.5414 - dice_metric: 0.5904 - jaccard_metric: 0.5112 - sensitivity_metric: 0.7131 - specificity_metric: 0.8924 - precision_metric: 0.6386 - recall_metric: 0.7131 - mean_average_precision: 0.3564 - val_loss: -0.5308 - val_dice_metric: 0.5701 - val_jaccard_metric: 0.4910 - val_sensitivity_metric: 0.6444 - val_specificity_metric: 0.8771 - val_precision_metric: 0.6373 - val_recall_metric: 0.6444 - val_mean_average_precision: 0.3283
# Epoch 49/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.5421 - dice_metric: 0.5911 - jaccard_metric: 0.5121 - sensitivity_metric: 0.7138 - specificity_metric: 0.8927 - precision_metric: 0.6390 - recall_metric: 0.7138 - mean_average_precision: 0.3577 - val_loss: -0.5315 - val_dice_metric: 0.5707 - val_jaccard_metric: 0.4917 - val_sensitivity_metric: 0.6451 - val_specificity_metric: 0.8776 - val_precision_metric: 0.6376 - val_recall_metric: 0.6451 - val_mean_average_precision: 0.3287
# Epoch 50/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5428 - dice_metric: 0.5918 - jaccard_metric: 0.5129 - sensitivity_metric: 0.7144 - specificity_metric: 0.8929 - precision_metric: 0.6396 - recall_metric: 0.7144 - mean_average_precision: 0.3588 - val_loss: -0.5323 - val_dice_metric: 0.5714 - val_jaccard_metric: 0.4926 - val_sensitivity_metric: 0.6458 - val_specificity_metric: 0.8781 - val_precision_metric: 0.6378 - val_recall_metric: 0.6458 - val_mean_average_precision: 0.3303
# Epoch 51/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.5435 - dice_metric: 0.5925 - jaccard_metric: 0.5137 - sensitivity_metric: 0.7151 - specificity_metric: 0.8932 - precision_metric: 0.6401 - recall_metric: 0.7151 - mean_average_precision: 0.3600 - val_loss: -0.5326 - val_dice_metric: 0.5716 - val_jaccard_metric: 0.4929 - val_sensitivity_metric: 0.6459 - val_specificity_metric: 0.8781 - val_precision_metric: 0.6381 - val_recall_metric: 0.6459 - val_mean_average_precision: 0.3299
# Epoch 52/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5442 - dice_metric: 0.5933 - jaccard_metric: 0.5145 - sensitivity_metric: 0.7157 - specificity_metric: 0.8935 - precision_metric: 0.6406 - recall_metric: 0.7157 - mean_average_precision: 0.3612 - val_loss: -0.5332 - val_dice_metric: 0.5722 - val_jaccard_metric: 0.4936 - val_sensitivity_metric: 0.6461 - val_specificity_metric: 0.8785 - val_precision_metric: 0.6386 - val_recall_metric: 0.6461 - val_mean_average_precision: 0.3317
# Epoch 53/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.5450 - dice_metric: 0.5940 - jaccard_metric: 0.5154 - sensitivity_metric: 0.7163 - specificity_metric: 0.8937 - precision_metric: 0.6411 - recall_metric: 0.7163 - mean_average_precision: 0.3624 - val_loss: -0.5337 - val_dice_metric: 0.5727 - val_jaccard_metric: 0.4941 - val_sensitivity_metric: 0.6461 - val_specificity_metric: 0.8787 - val_precision_metric: 0.6390 - val_recall_metric: 0.6461 - val_mean_average_precision: 0.3330
# Epoch 54/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.5457 - dice_metric: 0.5948 - jaccard_metric: 0.5162 - sensitivity_metric: 0.7169 - specificity_metric: 0.8939 - precision_metric: 0.6417 - recall_metric: 0.7169 - mean_average_precision: 0.3633 - val_loss: -0.5341 - val_dice_metric: 0.5729 - val_jaccard_metric: 0.4943 - val_sensitivity_metric: 0.6463 - val_specificity_metric: 0.8788 - val_precision_metric: 0.6394 - val_recall_metric: 0.6463 - val_mean_average_precision: 0.3322
# Epoch 55/60
# 77/77 [==============================] - 102s 1s/step - loss: -0.5464 - dice_metric: 0.5955 - jaccard_metric: 0.5171 - sensitivity_metric: 0.7175 - specificity_metric: 0.8942 - precision_metric: 0.6422 - recall_metric: 0.7175 - mean_average_precision: 0.3645 - val_loss: -0.5343 - val_dice_metric: 0.5730 - val_jaccard_metric: 0.4945 - val_sensitivity_metric: 0.6465 - val_specificity_metric: 0.8786 - val_precision_metric: 0.6397 - val_recall_metric: 0.6465 - val_mean_average_precision: 0.3329
# Epoch 56/60
# 77/77 [==============================] - 98s 1s/step - loss: -0.5471 - dice_metric: 0.5963 - jaccard_metric: 0.5179 - sensitivity_metric: 0.7182 - specificity_metric: 0.8945 - precision_metric: 0.6428 - recall_metric: 0.7182 - mean_average_precision: 0.3658 - val_loss: -0.5349 - val_dice_metric: 0.5735 - val_jaccard_metric: 0.4950 - val_sensitivity_metric: 0.6469 - val_specificity_metric: 0.8789 - val_precision_metric: 0.6398 - val_recall_metric: 0.6469 - val_mean_average_precision: 0.3338
# Epoch 57/60
# 77/77 [==============================] - 96s 1s/step - loss: -0.5478 - dice_metric: 0.5971 - jaccard_metric: 0.5188 - sensitivity_metric: 0.7187 - specificity_metric: 0.8947 - precision_metric: 0.6433 - recall_metric: 0.7187 - mean_average_precision: 0.3669 - val_loss: -0.5354 - val_dice_metric: 0.5740 - val_jaccard_metric: 0.4955 - val_sensitivity_metric: 0.6476 - val_specificity_metric: 0.8791 - val_precision_metric: 0.6402 - val_recall_metric: 0.6476 - val_mean_average_precision: 0.3338
# Epoch 58/60
# 77/77 [==============================] - 101s 1s/step - loss: -0.5485 - dice_metric: 0.5978 - jaccard_metric: 0.5196 - sensitivity_metric: 0.7193 - specificity_metric: 0.8949 - precision_metric: 0.6439 - recall_metric: 0.7193 - mean_average_precision: 0.3680 - val_loss: -0.5358 - val_dice_metric: 0.5742 - val_jaccard_metric: 0.4957 - val_sensitivity_metric: 0.6480 - val_specificity_metric: 0.8790 - val_precision_metric: 0.6406 - val_recall_metric: 0.6480 - val_mean_average_precision: 0.3345
# Epoch 59/60
# 77/77 [==============================] - 100s 1s/step - loss: -0.5492 - dice_metric: 0.5986 - jaccard_metric: 0.5204 - sensitivity_metric: 0.7198 - specificity_metric: 0.8951 - precision_metric: 0.6445 - recall_metric: 0.7198 - mean_average_precision: 0.3691 - val_loss: -0.5360 - val_dice_metric: 0.5743 - val_jaccard_metric: 0.4959 - val_sensitivity_metric: 0.6478 - val_specificity_metric: 0.8789 - val_precision_metric: 0.6411 - val_recall_metric: 0.6478 - val_mean_average_precision: 0.3349
# Epoch 60/60
# 77/77 [==============================] - 99s 1s/step - loss: -0.5499 - dice_metric: 0.5993 - jaccard_metric: 0.5213 - sensitivity_metric: 0.7203 - specificity_metric: 0.8952 - precision_metric: 0.6451 - recall_metric: 0.7203 - mean_average_precision: 0.3701 - val_loss: -0.5365 - val_dice_metric: 0.5748 - val_jaccard_metric: 0.4964 - val_sensitivity_metric: 0.6480 - val_specificity_metric: 0.8790 - val_precision_metric: 0.6414 - val_recall_metric: 0.6480 - val_mean_average_precision: 0.3357

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.57550, std: 0.37221
# Jaccard Index mean: 0.49319, std: 0.34566
# Sensitivity mean: 0.65981, std: 0.32190
# Specificity mean: 0.87884, std: 0.19295
# Precision mean: 0.63798, std: 0.42472
# Recall mean: 0.65981, std: 0.32190
# mAP@50 mean: 0.57062, std: 0.18967
# mAP@50-95 mean: 0.32175, std: 0.16344
