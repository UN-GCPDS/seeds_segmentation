# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|███████████████████████████████████████▊| 997M/0.98G [00:07<00:00, 209MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:07<00:00, 144MB/s]

# %%
config = {"Seg_model":"RFFSkipsFCN","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import fcn_rff_skips
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP

@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = fcn_rff_skips(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 74s 620ms/step - loss: -0.2031 - dice_metric: 0.0582 - jaccard_metric: 0.0408 - sensitivity_metric: 0.0272 - specificity_metric: 0.9769 - precision_metric: 0.2684 - recall_metric: 0.0272 - mean_average_precision: 0.0156 - val_loss: -0.1987 - val_dice_metric: 0.1580 - val_jaccard_metric: 0.1580 - val_sensitivity_metric: 0.0000e+00 - val_specificity_metric: 1.0000 - val_precision_metric: 0.0000e+00 - val_recall_metric: 0.0000e+00 - val_mean_average_precision: 0.1580
# Epoch 2/60
# 77/77 [==============================] - 40s 518ms/step - loss: -0.2796 - dice_metric: 0.2618 - jaccard_metric: 0.2168 - sensitivity_metric: 0.2263 - specificity_metric: 0.8398 - precision_metric: 0.3300 - recall_metric: 0.2263 - mean_average_precision: 0.1221 - val_loss: -0.2557 - val_dice_metric: 0.2605 - val_jaccard_metric: 0.2136 - val_sensitivity_metric: 0.2201 - val_specificity_metric: 0.7649 - val_precision_metric: 0.3219 - val_recall_metric: 0.2201 - val_mean_average_precision: 0.1075
# Epoch 3/60
# 77/77 [==============================] - 40s 512ms/step - loss: -0.3726 - dice_metric: 0.3203 - jaccard_metric: 0.3077 - sensitivity_metric: 0.3130 - specificity_metric: 0.8552 - precision_metric: 0.3606 - recall_metric: 0.3130 - mean_average_precision: 0.2988 - val_loss: -0.3267 - val_dice_metric: 0.4798 - val_jaccard_metric: 0.4691 - val_sensitivity_metric: 0.3244 - val_specificity_metric: 0.6704 - val_precision_metric: 0.3193 - val_recall_metric: 0.3244 - val_mean_average_precision: 0.4635
# Epoch 4/60
# 77/77 [==============================] - 41s 524ms/step - loss: -0.4279 - dice_metric: 0.3341 - jaccard_metric: 0.3281 - sensitivity_metric: 0.3267 - specificity_metric: 0.8775 - precision_metric: 0.4695 - recall_metric: 0.3267 - mean_average_precision: 0.3343 - val_loss: -0.3689 - val_dice_metric: 0.4842 - val_jaccard_metric: 0.4774 - val_sensitivity_metric: 0.3300 - val_specificity_metric: 0.7204 - val_precision_metric: 0.3226 - val_recall_metric: 0.3300 - val_mean_average_precision: 0.4827
# Epoch 5/60
# 77/77 [==============================] - 43s 554ms/step - loss: -0.4622 - dice_metric: 0.3397 - jaccard_metric: 0.3304 - sensitivity_metric: 0.3338 - specificity_metric: 0.9005 - precision_metric: 0.5625 - recall_metric: 0.3338 - mean_average_precision: 0.3327 - val_loss: -0.4272 - val_dice_metric: 0.4534 - val_jaccard_metric: 0.4495 - val_sensitivity_metric: 0.3307 - val_specificity_metric: 0.8545 - val_precision_metric: 0.3656 - val_recall_metric: 0.3307 - val_mean_average_precision: 0.4564
# Epoch 6/60
# 77/77 [==============================] - 41s 527ms/step - loss: -0.4897 - dice_metric: 0.4147 - jaccard_metric: 0.3777 - sensitivity_metric: 0.3845 - specificity_metric: 0.9164 - precision_metric: 0.6065 - recall_metric: 0.3845 - mean_average_precision: 0.3327 - val_loss: -0.4751 - val_dice_metric: 0.4075 - val_jaccard_metric: 0.3819 - val_sensitivity_metric: 0.3655 - val_specificity_metric: 0.9179 - val_precision_metric: 0.5977 - val_recall_metric: 0.3655 - val_mean_average_precision: 0.3534
# Epoch 7/60
# 77/77 [==============================] - 42s 544ms/step - loss: -0.5147 - dice_metric: 0.5074 - jaccard_metric: 0.4523 - sensitivity_metric: 0.4732 - specificity_metric: 0.9254 - precision_metric: 0.6099 - recall_metric: 0.4732 - mean_average_precision: 0.3452 - val_loss: -0.5129 - val_dice_metric: 0.5287 - val_jaccard_metric: 0.4746 - val_sensitivity_metric: 0.4964 - val_specificity_metric: 0.9398 - val_precision_metric: 0.6161 - val_recall_metric: 0.4964 - val_mean_average_precision: 0.3640
# Epoch 8/60
# 77/77 [==============================] - 42s 537ms/step - loss: -0.5372 - dice_metric: 0.5518 - jaccard_metric: 0.4956 - sensitivity_metric: 0.5359 - specificity_metric: 0.9295 - precision_metric: 0.6092 - recall_metric: 0.5359 - mean_average_precision: 0.3794 - val_loss: -0.5414 - val_dice_metric: 0.5692 - val_jaccard_metric: 0.5175 - val_sensitivity_metric: 0.5687 - val_specificity_metric: 0.9485 - val_precision_metric: 0.6042 - val_recall_metric: 0.5687 - val_mean_average_precision: 0.4137
# Epoch 9/60
# 77/77 [==============================] - 41s 530ms/step - loss: -0.5564 - dice_metric: 0.5688 - jaccard_metric: 0.5136 - sensitivity_metric: 0.5662 - specificity_metric: 0.9304 - precision_metric: 0.6108 - recall_metric: 0.5662 - mean_average_precision: 0.4015 - val_loss: -0.5590 - val_dice_metric: 0.5794 - val_jaccard_metric: 0.5291 - val_sensitivity_metric: 0.5958 - val_specificity_metric: 0.9519 - val_precision_metric: 0.5979 - val_recall_metric: 0.5958 - val_mean_average_precision: 0.4294
# Epoch 10/60
# 77/77 [==============================] - 41s 531ms/step - loss: -0.5710 - dice_metric: 0.5781 - jaccard_metric: 0.5237 - sensitivity_metric: 0.5813 - specificity_metric: 0.9297 - precision_metric: 0.6129 - recall_metric: 0.5813 - mean_average_precision: 0.4150 - val_loss: -0.5727 - val_dice_metric: 0.5849 - val_jaccard_metric: 0.5355 - val_sensitivity_metric: 0.6035 - val_specificity_metric: 0.9494 - val_precision_metric: 0.5994 - val_recall_metric: 0.6035 - val_mean_average_precision: 0.4411
# Epoch 11/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.5825 - dice_metric: 0.5851 - jaccard_metric: 0.5314 - sensitivity_metric: 0.5901 - specificity_metric: 0.9289 - precision_metric: 0.6160 - recall_metric: 0.5901 - mean_average_precision: 0.4258 - val_loss: -0.5834 - val_dice_metric: 0.5900 - val_jaccard_metric: 0.5415 - val_sensitivity_metric: 0.6094 - val_specificity_metric: 0.9487 - val_precision_metric: 0.6004 - val_recall_metric: 0.6094 - val_mean_average_precision: 0.4498
# Epoch 12/60
# 77/77 [==============================] - 42s 542ms/step - loss: -0.5915 - dice_metric: 0.5905 - jaccard_metric: 0.5373 - sensitivity_metric: 0.5962 - specificity_metric: 0.9285 - precision_metric: 0.6189 - recall_metric: 0.5962 - mean_average_precision: 0.4347 - val_loss: -0.5907 - val_dice_metric: 0.5922 - val_jaccard_metric: 0.5441 - val_sensitivity_metric: 0.6166 - val_specificity_metric: 0.9531 - val_precision_metric: 0.5991 - val_recall_metric: 0.6166 - val_mean_average_precision: 0.4520
# Epoch 13/60
# 77/77 [==============================] - 42s 539ms/step - loss: -0.5993 - dice_metric: 0.5957 - jaccard_metric: 0.5431 - sensitivity_metric: 0.6012 - specificity_metric: 0.9286 - precision_metric: 0.6228 - recall_metric: 0.6012 - mean_average_precision: 0.4432 - val_loss: -0.5957 - val_dice_metric: 0.5950 - val_jaccard_metric: 0.5474 - val_sensitivity_metric: 0.6232 - val_specificity_metric: 0.9568 - val_precision_metric: 0.5976 - val_recall_metric: 0.6232 - val_mean_average_precision: 0.4577
# Epoch 14/60
# 77/77 [==============================] - 43s 551ms/step - loss: -0.6057 - dice_metric: 0.6005 - jaccard_metric: 0.5482 - sensitivity_metric: 0.6059 - specificity_metric: 0.9292 - precision_metric: 0.6269 - recall_metric: 0.6059 - mean_average_precision: 0.4507 - val_loss: -0.6044 - val_dice_metric: 0.6014 - val_jaccard_metric: 0.5547 - val_sensitivity_metric: 0.6141 - val_specificity_metric: 0.9468 - val_precision_metric: 0.6162 - val_recall_metric: 0.6141 - val_mean_average_precision: 0.4704
# Epoch 15/60
# 77/77 [==============================] - 41s 533ms/step - loss: -0.6120 - dice_metric: 0.6056 - jaccard_metric: 0.5539 - sensitivity_metric: 0.6101 - specificity_metric: 0.9298 - precision_metric: 0.6324 - recall_metric: 0.6101 - mean_average_precision: 0.4600 - val_loss: -0.6102 - val_dice_metric: 0.6051 - val_jaccard_metric: 0.5597 - val_sensitivity_metric: 0.6157 - val_specificity_metric: 0.9474 - val_precision_metric: 0.6227 - val_recall_metric: 0.6157 - val_mean_average_precision: 0.4767
# Epoch 16/60
# 77/77 [==============================] - 41s 530ms/step - loss: -0.6184 - dice_metric: 0.6112 - jaccard_metric: 0.5601 - sensitivity_metric: 0.6144 - specificity_metric: 0.9304 - precision_metric: 0.6395 - recall_metric: 0.6144 - mean_average_precision: 0.4699 - val_loss: -0.6151 - val_dice_metric: 0.6094 - val_jaccard_metric: 0.5644 - val_sensitivity_metric: 0.6268 - val_specificity_metric: 0.9514 - val_precision_metric: 0.6223 - val_recall_metric: 0.6268 - val_mean_average_precision: 0.4851
# Epoch 17/60
# 77/77 [==============================] - 42s 537ms/step - loss: -0.6236 - dice_metric: 0.6166 - jaccard_metric: 0.5658 - sensitivity_metric: 0.6186 - specificity_metric: 0.9310 - precision_metric: 0.6463 - recall_metric: 0.6186 - mean_average_precision: 0.4782 - val_loss: -0.6182 - val_dice_metric: 0.6124 - val_jaccard_metric: 0.5675 - val_sensitivity_metric: 0.6285 - val_specificity_metric: 0.9532 - val_precision_metric: 0.6269 - val_recall_metric: 0.6285 - val_mean_average_precision: 0.4888
# Epoch 18/60
# 77/77 [==============================] - 43s 548ms/step - loss: -0.6287 - dice_metric: 0.6224 - jaccard_metric: 0.5713 - sensitivity_metric: 0.6233 - specificity_metric: 0.9317 - precision_metric: 0.6539 - recall_metric: 0.6233 - mean_average_precision: 0.4855 - val_loss: -0.6226 - val_dice_metric: 0.6175 - val_jaccard_metric: 0.5725 - val_sensitivity_metric: 0.6334 - val_specificity_metric: 0.9533 - val_precision_metric: 0.6334 - val_recall_metric: 0.6334 - val_mean_average_precision: 0.4955
# Epoch 19/60
# 77/77 [==============================] - 42s 539ms/step - loss: -0.6337 - dice_metric: 0.6292 - jaccard_metric: 0.5771 - sensitivity_metric: 0.6290 - specificity_metric: 0.9327 - precision_metric: 0.6622 - recall_metric: 0.6290 - mean_average_precision: 0.4917 - val_loss: -0.6233 - val_dice_metric: 0.6193 - val_jaccard_metric: 0.5727 - val_sensitivity_metric: 0.6422 - val_specificity_metric: 0.9582 - val_precision_metric: 0.6297 - val_recall_metric: 0.6422 - val_mean_average_precision: 0.4938
# Epoch 20/60
# 77/77 [==============================] - 40s 517ms/step - loss: -0.6371 - dice_metric: 0.6361 - jaccard_metric: 0.5817 - sensitivity_metric: 0.6355 - specificity_metric: 0.9342 - precision_metric: 0.6693 - recall_metric: 0.6355 - mean_average_precision: 0.4939 - val_loss: -0.6272 - val_dice_metric: 0.6269 - val_jaccard_metric: 0.5779 - val_sensitivity_metric: 0.6459 - val_specificity_metric: 0.9574 - val_precision_metric: 0.6385 - val_recall_metric: 0.6459 - val_mean_average_precision: 0.4959
# Epoch 21/60
# 77/77 [==============================] - 42s 542ms/step - loss: -0.6397 - dice_metric: 0.6444 - jaccard_metric: 0.5865 - sensitivity_metric: 0.6455 - specificity_metric: 0.9372 - precision_metric: 0.6735 - recall_metric: 0.6455 - mean_average_precision: 0.4936 - val_loss: -0.6369 - val_dice_metric: 0.6451 - val_jaccard_metric: 0.5937 - val_sensitivity_metric: 0.6499 - val_specificity_metric: 0.9525 - val_precision_metric: 0.6649 - val_recall_metric: 0.6499 - val_mean_average_precision: 0.5135
# Epoch 22/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.6502 - dice_metric: 0.6660 - jaccard_metric: 0.6033 - sensitivity_metric: 0.6693 - specificity_metric: 0.9417 - precision_metric: 0.6885 - recall_metric: 0.6693 - mean_average_precision: 0.5043 - val_loss: -0.6357 - val_dice_metric: 0.6509 - val_jaccard_metric: 0.5949 - val_sensitivity_metric: 0.6747 - val_specificity_metric: 0.9654 - val_precision_metric: 0.6489 - val_recall_metric: 0.6747 - val_mean_average_precision: 0.5036
# Epoch 23/60
# 77/77 [==============================] - 42s 542ms/step - loss: -0.6595 - dice_metric: 0.6839 - jaccard_metric: 0.6177 - sensitivity_metric: 0.6964 - specificity_metric: 0.9468 - precision_metric: 0.6969 - recall_metric: 0.6964 - mean_average_precision: 0.5103 - val_loss: -0.6354 - val_dice_metric: 0.6541 - val_jaccard_metric: 0.5952 - val_sensitivity_metric: 0.6869 - val_specificity_metric: 0.9679 - val_precision_metric: 0.6431 - val_recall_metric: 0.6869 - val_mean_average_precision: 0.4935
# Epoch 24/60
# 77/77 [==============================] - 40s 520ms/step - loss: -0.6648 - dice_metric: 0.6915 - jaccard_metric: 0.6237 - sensitivity_metric: 0.7134 - specificity_metric: 0.9500 - precision_metric: 0.6981 - recall_metric: 0.7134 - mean_average_precision: 0.5108 - val_loss: -0.6501 - val_dice_metric: 0.6748 - val_jaccard_metric: 0.6158 - val_sensitivity_metric: 0.7018 - val_specificity_metric: 0.9661 - val_precision_metric: 0.6662 - val_recall_metric: 0.7018 - val_mean_average_precision: 0.5174
# Epoch 25/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.6706 - dice_metric: 0.6975 - jaccard_metric: 0.6293 - sensitivity_metric: 0.7239 - specificity_metric: 0.9517 - precision_metric: 0.7009 - recall_metric: 0.7239 - mean_average_precision: 0.5148 - val_loss: -0.6624 - val_dice_metric: 0.6904 - val_jaccard_metric: 0.6318 - val_sensitivity_metric: 0.7186 - val_specificity_metric: 0.9669 - val_precision_metric: 0.6820 - val_recall_metric: 0.7186 - val_mean_average_precision: 0.5314
# Epoch 26/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.6802 - dice_metric: 0.7076 - jaccard_metric: 0.6395 - sensitivity_metric: 0.7357 - specificity_metric: 0.9529 - precision_metric: 0.7081 - recall_metric: 0.7357 - mean_average_precision: 0.5240 - val_loss: -0.6592 - val_dice_metric: 0.6861 - val_jaccard_metric: 0.6259 - val_sensitivity_metric: 0.7235 - val_specificity_metric: 0.9711 - val_precision_metric: 0.6688 - val_recall_metric: 0.7235 - val_mean_average_precision: 0.5201
# Epoch 27/60
# 77/77 [==============================] - 40s 512ms/step - loss: -0.6885 - dice_metric: 0.7160 - jaccard_metric: 0.6481 - sensitivity_metric: 0.7445 - specificity_metric: 0.9536 - precision_metric: 0.7149 - recall_metric: 0.7445 - mean_average_precision: 0.5317 - val_loss: -0.6610 - val_dice_metric: 0.6878 - val_jaccard_metric: 0.6269 - val_sensitivity_metric: 0.7267 - val_specificity_metric: 0.9721 - val_precision_metric: 0.6693 - val_recall_metric: 0.7267 - val_mean_average_precision: 0.5169
# Epoch 28/60
# 77/77 [==============================] - 41s 532ms/step - loss: -0.6947 - dice_metric: 0.7221 - jaccard_metric: 0.6541 - sensitivity_metric: 0.7488 - specificity_metric: 0.9537 - precision_metric: 0.7207 - recall_metric: 0.7488 - mean_average_precision: 0.5367 - val_loss: -0.6635 - val_dice_metric: 0.6903 - val_jaccard_metric: 0.6297 - val_sensitivity_metric: 0.7271 - val_specificity_metric: 0.9721 - val_precision_metric: 0.6735 - val_recall_metric: 0.7271 - val_mean_average_precision: 0.5206
# Epoch 29/60
# 77/77 [==============================] - 42s 542ms/step - loss: -0.6996 - dice_metric: 0.7268 - jaccard_metric: 0.6587 - sensitivity_metric: 0.7509 - specificity_metric: 0.9534 - precision_metric: 0.7260 - recall_metric: 0.7509 - mean_average_precision: 0.5392 - val_loss: -0.6736 - val_dice_metric: 0.7002 - val_jaccard_metric: 0.6404 - val_sensitivity_metric: 0.7278 - val_specificity_metric: 0.9699 - val_precision_metric: 0.6899 - val_recall_metric: 0.7278 - val_mean_average_precision: 0.5322
# Epoch 30/60
# 77/77 [==============================] - 42s 539ms/step - loss: -0.7042 - dice_metric: 0.7312 - jaccard_metric: 0.6630 - sensitivity_metric: 0.7516 - specificity_metric: 0.9530 - precision_metric: 0.7316 - recall_metric: 0.7516 - mean_average_precision: 0.5417 - val_loss: -0.6821 - val_dice_metric: 0.7077 - val_jaccard_metric: 0.6485 - val_sensitivity_metric: 0.7279 - val_specificity_metric: 0.9677 - val_precision_metric: 0.7028 - val_recall_metric: 0.7279 - val_mean_average_precision: 0.5405
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 41s 535ms/step - loss: -0.7105 - dice_metric: 0.7375 - jaccard_metric: 0.6702 - sensitivity_metric: 0.7557 - specificity_metric: 0.9539 - precision_metric: 0.7374 - recall_metric: 0.7557 - mean_average_precision: 0.5508 - val_loss: -0.6919 - val_dice_metric: 0.7160 - val_jaccard_metric: 0.6590 - val_sensitivity_metric: 0.7279 - val_specificity_metric: 0.9648 - val_precision_metric: 0.7182 - val_recall_metric: 0.7279 - val_mean_average_precision: 0.5550
# Epoch 32/60
# 77/77 [==============================] - 41s 531ms/step - loss: -0.7134 - dice_metric: 0.7409 - jaccard_metric: 0.6740 - sensitivity_metric: 0.7577 - specificity_metric: 0.9538 - precision_metric: 0.7416 - recall_metric: 0.7577 - mean_average_precision: 0.5555 - val_loss: -0.6927 - val_dice_metric: 0.7169 - val_jaccard_metric: 0.6600 - val_sensitivity_metric: 0.7273 - val_specificity_metric: 0.9644 - val_precision_metric: 0.7204 - val_recall_metric: 0.7273 - val_mean_average_precision: 0.5566
# Epoch 33/60
# 77/77 [==============================] - 41s 534ms/step - loss: -0.7147 - dice_metric: 0.7425 - jaccard_metric: 0.6757 - sensitivity_metric: 0.7586 - specificity_metric: 0.9538 - precision_metric: 0.7434 - recall_metric: 0.7586 - mean_average_precision: 0.5573 - val_loss: -0.6933 - val_dice_metric: 0.7176 - val_jaccard_metric: 0.6608 - val_sensitivity_metric: 0.7279 - val_specificity_metric: 0.9645 - val_precision_metric: 0.7212 - val_recall_metric: 0.7279 - val_mean_average_precision: 0.5569
# Epoch 34/60
# 77/77 [==============================] - 41s 525ms/step - loss: -0.7157 - dice_metric: 0.7437 - jaccard_metric: 0.6771 - sensitivity_metric: 0.7592 - specificity_metric: 0.9538 - precision_metric: 0.7449 - recall_metric: 0.7592 - mean_average_precision: 0.5587 - val_loss: -0.6939 - val_dice_metric: 0.7182 - val_jaccard_metric: 0.6615 - val_sensitivity_metric: 0.7284 - val_specificity_metric: 0.9646 - val_precision_metric: 0.7218 - val_recall_metric: 0.7284 - val_mean_average_precision: 0.5576
# Epoch 35/60
# 77/77 [==============================] - 41s 530ms/step - loss: -0.7167 - dice_metric: 0.7448 - jaccard_metric: 0.6783 - sensitivity_metric: 0.7597 - specificity_metric: 0.9537 - precision_metric: 0.7464 - recall_metric: 0.7597 - mean_average_precision: 0.5597 - val_loss: -0.6944 - val_dice_metric: 0.7188 - val_jaccard_metric: 0.6621 - val_sensitivity_metric: 0.7288 - val_specificity_metric: 0.9646 - val_precision_metric: 0.7224 - val_recall_metric: 0.7288 - val_mean_average_precision: 0.5581
# Epoch 36/60
# 77/77 [==============================] - 41s 528ms/step - loss: -0.7176 - dice_metric: 0.7458 - jaccard_metric: 0.6794 - sensitivity_metric: 0.7601 - specificity_metric: 0.9537 - precision_metric: 0.7477 - recall_metric: 0.7601 - mean_average_precision: 0.5607 - val_loss: -0.6950 - val_dice_metric: 0.7194 - val_jaccard_metric: 0.6627 - val_sensitivity_metric: 0.7291 - val_specificity_metric: 0.9646 - val_precision_metric: 0.7231 - val_recall_metric: 0.7291 - val_mean_average_precision: 0.5584
# Epoch 37/60
# 77/77 [==============================] - 41s 535ms/step - loss: -0.7185 - dice_metric: 0.7468 - jaccard_metric: 0.6804 - sensitivity_metric: 0.7605 - specificity_metric: 0.9537 - precision_metric: 0.7490 - recall_metric: 0.7605 - mean_average_precision: 0.5618 - val_loss: -0.6955 - val_dice_metric: 0.7199 - val_jaccard_metric: 0.6633 - val_sensitivity_metric: 0.7293 - val_specificity_metric: 0.9646 - val_precision_metric: 0.7238 - val_recall_metric: 0.7293 - val_mean_average_precision: 0.5588
# Epoch 38/60
# 77/77 [==============================] - 41s 527ms/step - loss: -0.7193 - dice_metric: 0.7477 - jaccard_metric: 0.6814 - sensitivity_metric: 0.7609 - specificity_metric: 0.9536 - precision_metric: 0.7503 - recall_metric: 0.7609 - mean_average_precision: 0.5627 - val_loss: -0.6960 - val_dice_metric: 0.7204 - val_jaccard_metric: 0.6638 - val_sensitivity_metric: 0.7295 - val_specificity_metric: 0.9646 - val_precision_metric: 0.7245 - val_recall_metric: 0.7295 - val_mean_average_precision: 0.5593
# Epoch 39/60
# 77/77 [==============================] - 40s 519ms/step - loss: -0.7202 - dice_metric: 0.7486 - jaccard_metric: 0.6824 - sensitivity_metric: 0.7612 - specificity_metric: 0.9536 - precision_metric: 0.7515 - recall_metric: 0.7612 - mean_average_precision: 0.5636 - val_loss: -0.6965 - val_dice_metric: 0.7209 - val_jaccard_metric: 0.6644 - val_sensitivity_metric: 0.7297 - val_specificity_metric: 0.9645 - val_precision_metric: 0.7252 - val_recall_metric: 0.7297 - val_mean_average_precision: 0.5597
# Epoch 40/60
# 77/77 [==============================] - 40s 518ms/step - loss: -0.7210 - dice_metric: 0.7495 - jaccard_metric: 0.6834 - sensitivity_metric: 0.7615 - specificity_metric: 0.9535 - precision_metric: 0.7527 - recall_metric: 0.7615 - mean_average_precision: 0.5646 - val_loss: -0.6969 - val_dice_metric: 0.7213 - val_jaccard_metric: 0.6648 - val_sensitivity_metric: 0.7298 - val_specificity_metric: 0.9645 - val_precision_metric: 0.7259 - val_recall_metric: 0.7298 - val_mean_average_precision: 0.5601
# Epoch 41/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.7218 - dice_metric: 0.7504 - jaccard_metric: 0.6843 - sensitivity_metric: 0.7618 - specificity_metric: 0.9535 - precision_metric: 0.7540 - recall_metric: 0.7618 - mean_average_precision: 0.5657 - val_loss: -0.6974 - val_dice_metric: 0.7217 - val_jaccard_metric: 0.6653 - val_sensitivity_metric: 0.7300 - val_specificity_metric: 0.9645 - val_precision_metric: 0.7264 - val_recall_metric: 0.7300 - val_mean_average_precision: 0.5609
# Epoch 42/60
# 77/77 [==============================] - 41s 534ms/step - loss: -0.7227 - dice_metric: 0.7512 - jaccard_metric: 0.6853 - sensitivity_metric: 0.7621 - specificity_metric: 0.9534 - precision_metric: 0.7552 - recall_metric: 0.7621 - mean_average_precision: 0.5667 - val_loss: -0.6979 - val_dice_metric: 0.7222 - val_jaccard_metric: 0.6658 - val_sensitivity_metric: 0.7303 - val_specificity_metric: 0.9645 - val_precision_metric: 0.7270 - val_recall_metric: 0.7303 - val_mean_average_precision: 0.5615
# Epoch 43/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.7235 - dice_metric: 0.7520 - jaccard_metric: 0.6862 - sensitivity_metric: 0.7623 - specificity_metric: 0.9533 - precision_metric: 0.7564 - recall_metric: 0.7623 - mean_average_precision: 0.5676 - val_loss: -0.6984 - val_dice_metric: 0.7226 - val_jaccard_metric: 0.6662 - val_sensitivity_metric: 0.7304 - val_specificity_metric: 0.9645 - val_precision_metric: 0.7276 - val_recall_metric: 0.7304 - val_mean_average_precision: 0.5619
# Epoch 44/60
# 77/77 [==============================] - 42s 545ms/step - loss: -0.7243 - dice_metric: 0.7528 - jaccard_metric: 0.6871 - sensitivity_metric: 0.7626 - specificity_metric: 0.9533 - precision_metric: 0.7576 - recall_metric: 0.7626 - mean_average_precision: 0.5686 - val_loss: -0.6989 - val_dice_metric: 0.7229 - val_jaccard_metric: 0.6666 - val_sensitivity_metric: 0.7305 - val_specificity_metric: 0.9644 - val_precision_metric: 0.7282 - val_recall_metric: 0.7305 - val_mean_average_precision: 0.5622
# Epoch 45/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.7251 - dice_metric: 0.7536 - jaccard_metric: 0.6880 - sensitivity_metric: 0.7628 - specificity_metric: 0.9532 - precision_metric: 0.7588 - recall_metric: 0.7628 - mean_average_precision: 0.5693 - val_loss: -0.6994 - val_dice_metric: 0.7233 - val_jaccard_metric: 0.6670 - val_sensitivity_metric: 0.7307 - val_specificity_metric: 0.9644 - val_precision_metric: 0.7287 - val_recall_metric: 0.7307 - val_mean_average_precision: 0.5631
# Epoch 46/60
# 77/77 [==============================] - 42s 541ms/step - loss: -0.7259 - dice_metric: 0.7544 - jaccard_metric: 0.6888 - sensitivity_metric: 0.7630 - specificity_metric: 0.9531 - precision_metric: 0.7600 - recall_metric: 0.7630 - mean_average_precision: 0.5703 - val_loss: -0.6999 - val_dice_metric: 0.7237 - val_jaccard_metric: 0.6674 - val_sensitivity_metric: 0.7307 - val_specificity_metric: 0.9643 - val_precision_metric: 0.7294 - val_recall_metric: 0.7307 - val_mean_average_precision: 0.5635
# Epoch 47/60
# 77/77 [==============================] - 41s 529ms/step - loss: -0.7267 - dice_metric: 0.7552 - jaccard_metric: 0.6897 - sensitivity_metric: 0.7633 - specificity_metric: 0.9531 - precision_metric: 0.7612 - recall_metric: 0.7633 - mean_average_precision: 0.5713 - val_loss: -0.7004 - val_dice_metric: 0.7241 - val_jaccard_metric: 0.6679 - val_sensitivity_metric: 0.7309 - val_specificity_metric: 0.9643 - val_precision_metric: 0.7300 - val_recall_metric: 0.7309 - val_mean_average_precision: 0.5641
# Epoch 48/60
# 77/77 [==============================] - 42s 537ms/step - loss: -0.7276 - dice_metric: 0.7559 - jaccard_metric: 0.6906 - sensitivity_metric: 0.7635 - specificity_metric: 0.9530 - precision_metric: 0.7623 - recall_metric: 0.7635 - mean_average_precision: 0.5721 - val_loss: -0.7009 - val_dice_metric: 0.7244 - val_jaccard_metric: 0.6683 - val_sensitivity_metric: 0.7310 - val_specificity_metric: 0.9642 - val_precision_metric: 0.7307 - val_recall_metric: 0.7310 - val_mean_average_precision: 0.5646
# Epoch 49/60
# 77/77 [==============================] - 41s 536ms/step - loss: -0.7284 - dice_metric: 0.7567 - jaccard_metric: 0.6914 - sensitivity_metric: 0.7637 - specificity_metric: 0.9529 - precision_metric: 0.7635 - recall_metric: 0.7637 - mean_average_precision: 0.5730 - val_loss: -0.7014 - val_dice_metric: 0.7248 - val_jaccard_metric: 0.6687 - val_sensitivity_metric: 0.7312 - val_specificity_metric: 0.9642 - val_precision_metric: 0.7312 - val_recall_metric: 0.7312 - val_mean_average_precision: 0.5651
# Epoch 50/60
# 77/77 [==============================] - 40s 513ms/step - loss: -0.7292 - dice_metric: 0.7574 - jaccard_metric: 0.6922 - sensitivity_metric: 0.7640 - specificity_metric: 0.9529 - precision_metric: 0.7647 - recall_metric: 0.7640 - mean_average_precision: 0.5740 - val_loss: -0.7019 - val_dice_metric: 0.7252 - val_jaccard_metric: 0.6691 - val_sensitivity_metric: 0.7315 - val_specificity_metric: 0.9642 - val_precision_metric: 0.7317 - val_recall_metric: 0.7315 - val_mean_average_precision: 0.5659
# Epoch 51/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.7300 - dice_metric: 0.7581 - jaccard_metric: 0.6931 - sensitivity_metric: 0.7642 - specificity_metric: 0.9528 - precision_metric: 0.7658 - recall_metric: 0.7642 - mean_average_precision: 0.5749 - val_loss: -0.7024 - val_dice_metric: 0.7255 - val_jaccard_metric: 0.6695 - val_sensitivity_metric: 0.7316 - val_specificity_metric: 0.9641 - val_precision_metric: 0.7323 - val_recall_metric: 0.7316 - val_mean_average_precision: 0.5658
# Epoch 52/60
# 77/77 [==============================] - 41s 528ms/step - loss: -0.7308 - dice_metric: 0.7589 - jaccard_metric: 0.6939 - sensitivity_metric: 0.7644 - specificity_metric: 0.9527 - precision_metric: 0.7670 - recall_metric: 0.7644 - mean_average_precision: 0.5760 - val_loss: -0.7029 - val_dice_metric: 0.7259 - val_jaccard_metric: 0.6699 - val_sensitivity_metric: 0.7319 - val_specificity_metric: 0.9642 - val_precision_metric: 0.7327 - val_recall_metric: 0.7319 - val_mean_average_precision: 0.5663
# Epoch 53/60
# 77/77 [==============================] - 41s 526ms/step - loss: -0.7316 - dice_metric: 0.7596 - jaccard_metric: 0.6947 - sensitivity_metric: 0.7646 - specificity_metric: 0.9527 - precision_metric: 0.7681 - recall_metric: 0.7646 - mean_average_precision: 0.5770 - val_loss: -0.7034 - val_dice_metric: 0.7262 - val_jaccard_metric: 0.6702 - val_sensitivity_metric: 0.7320 - val_specificity_metric: 0.9641 - val_precision_metric: 0.7333 - val_recall_metric: 0.7320 - val_mean_average_precision: 0.5666
# Epoch 54/60
# 77/77 [==============================] - 42s 540ms/step - loss: -0.7325 - dice_metric: 0.7603 - jaccard_metric: 0.6955 - sensitivity_metric: 0.7649 - specificity_metric: 0.9526 - precision_metric: 0.7693 - recall_metric: 0.7649 - mean_average_precision: 0.5778 - val_loss: -0.7039 - val_dice_metric: 0.7265 - val_jaccard_metric: 0.6706 - val_sensitivity_metric: 0.7322 - val_specificity_metric: 0.9641 - val_precision_metric: 0.7338 - val_recall_metric: 0.7322 - val_mean_average_precision: 0.5671
# Epoch 55/60
# 77/77 [==============================] - 42s 544ms/step - loss: -0.7333 - dice_metric: 0.7610 - jaccard_metric: 0.6963 - sensitivity_metric: 0.7651 - specificity_metric: 0.9525 - precision_metric: 0.7704 - recall_metric: 0.7651 - mean_average_precision: 0.5788 - val_loss: -0.7044 - val_dice_metric: 0.7268 - val_jaccard_metric: 0.6709 - val_sensitivity_metric: 0.7322 - val_specificity_metric: 0.9640 - val_precision_metric: 0.7344 - val_recall_metric: 0.7322 - val_mean_average_precision: 0.5671
# Epoch 56/60
# 77/77 [==============================] - 41s 530ms/step - loss: -0.7341 - dice_metric: 0.7616 - jaccard_metric: 0.6970 - sensitivity_metric: 0.7653 - specificity_metric: 0.9524 - precision_metric: 0.7716 - recall_metric: 0.7653 - mean_average_precision: 0.5798 - val_loss: -0.7049 - val_dice_metric: 0.7272 - val_jaccard_metric: 0.6713 - val_sensitivity_metric: 0.7323 - val_specificity_metric: 0.9639 - val_precision_metric: 0.7350 - val_recall_metric: 0.7323 - val_mean_average_precision: 0.5669
# Epoch 57/60
# 77/77 [==============================] - 40s 516ms/step - loss: -0.7349 - dice_metric: 0.7623 - jaccard_metric: 0.6978 - sensitivity_metric: 0.7656 - specificity_metric: 0.9524 - precision_metric: 0.7727 - recall_metric: 0.7656 - mean_average_precision: 0.5807 - val_loss: -0.7054 - val_dice_metric: 0.7274 - val_jaccard_metric: 0.6716 - val_sensitivity_metric: 0.7325 - val_specificity_metric: 0.9639 - val_precision_metric: 0.7354 - val_recall_metric: 0.7325 - val_mean_average_precision: 0.5675
# Epoch 58/60
# 77/77 [==============================] - 42s 543ms/step - loss: -0.7358 - dice_metric: 0.7630 - jaccard_metric: 0.6986 - sensitivity_metric: 0.7658 - specificity_metric: 0.9523 - precision_metric: 0.7738 - recall_metric: 0.7658 - mean_average_precision: 0.5815 - val_loss: -0.7059 - val_dice_metric: 0.7278 - val_jaccard_metric: 0.6720 - val_sensitivity_metric: 0.7327 - val_specificity_metric: 0.9639 - val_precision_metric: 0.7359 - val_recall_metric: 0.7327 - val_mean_average_precision: 0.5676
# Epoch 59/60
# 77/77 [==============================] - 41s 528ms/step - loss: -0.7366 - dice_metric: 0.7636 - jaccard_metric: 0.6993 - sensitivity_metric: 0.7660 - specificity_metric: 0.9522 - precision_metric: 0.7748 - recall_metric: 0.7660 - mean_average_precision: 0.5824 - val_loss: -0.7064 - val_dice_metric: 0.7280 - val_jaccard_metric: 0.6722 - val_sensitivity_metric: 0.7327 - val_specificity_metric: 0.9638 - val_precision_metric: 0.7364 - val_recall_metric: 0.7327 - val_mean_average_precision: 0.5669
# Epoch 60/60
# 77/77 [==============================] - 41s 535ms/step - loss: -0.7374 - dice_metric: 0.7643 - jaccard_metric: 0.7000 - sensitivity_metric: 0.7662 - specificity_metric: 0.9521 - precision_metric: 0.7759 - recall_metric: 0.7662 - mean_average_precision: 0.5831 - val_loss: -0.7069 - val_dice_metric: 0.7283 - val_jaccard_metric: 0.6725 - val_sensitivity_metric: 0.7329 - val_specificity_metric: 0.9638 - val_precision_metric: 0.7369 - val_recall_metric: 0.7329 - val_mean_average_precision: 0.5684

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.75203, std: 0.33044
# Jaccard Index mean: 0.69097, std: 0.33945
# Sensitivity mean: 0.75843, std: 0.33689
# Specificity mean: 0.96198, std: 0.08109
# Precision mean: 0.76057, std: 0.32831
# Recall mean: 0.75843, std: 0.33689
# mAP@50 mean: 0.73729, std: 0.15557
# mAP@50-95 mean: 0.57599, std: 0.11812
