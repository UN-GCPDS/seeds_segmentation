# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
# 100%|██████████████████████████████████████▉| 0.98G/0.98G [00:09<00:00, 136MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:09<00:00, 113MB/s]

# %%
config = {"Seg_model":"UNetMobV2","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_mobilenetv2
from seeds_segmentation.losses import DiceCoefficient

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = unet_mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 89s 917ms/step - loss: -0.3187 - dice_metric: 0.3811 - jaccard_metric: 0.3085 - sensitivity_metric: 0.3642 - specificity_metric: 0.8527 - val_loss: -0.3929 - val_dice_metric: 0.4098 - val_jaccard_metric: 0.3721 - val_sensitivity_metric: 0.3845 - val_specificity_metric: 0.7724
# Epoch 2/60
# 77/77 [==============================] - 65s 840ms/step - loss: -0.5048 - dice_metric: 0.5623 - jaccard_metric: 0.5042 - sensitivity_metric: 0.5521 - specificity_metric: 0.8969 - val_loss: -0.4920 - val_dice_metric: 0.5222 - val_jaccard_metric: 0.4675 - val_sensitivity_metric: 0.4547 - val_specificity_metric: 0.8030
# Epoch 3/60
# 77/77 [==============================] - 65s 836ms/step - loss: -0.5655 - dice_metric: 0.5924 - jaccard_metric: 0.5446 - sensitivity_metric: 0.5865 - specificity_metric: 0.9026 - val_loss: -0.5557 - val_dice_metric: 0.6617 - val_jaccard_metric: 0.6087 - val_sensitivity_metric: 0.5325 - val_specificity_metric: 0.8641
# Epoch 4/60
# 77/77 [==============================] - 65s 842ms/step - loss: -0.5873 - dice_metric: 0.6042 - jaccard_metric: 0.5597 - sensitivity_metric: 0.6007 - specificity_metric: 0.9097 - val_loss: -0.5956 - val_dice_metric: 0.6076 - val_jaccard_metric: 0.5654 - val_sensitivity_metric: 0.5900 - val_specificity_metric: 0.9157
# Epoch 5/60
# 77/77 [==============================] - 64s 830ms/step - loss: -0.6128 - dice_metric: 0.6302 - jaccard_metric: 0.5736 - sensitivity_metric: 0.6225 - specificity_metric: 0.9203 - val_loss: -0.6261 - val_dice_metric: 0.6518 - val_jaccard_metric: 0.6065 - val_sensitivity_metric: 0.6229 - val_specificity_metric: 0.9258
# Epoch 6/60
# 77/77 [==============================] - 66s 853ms/step - loss: -0.6490 - dice_metric: 0.6703 - jaccard_metric: 0.6038 - sensitivity_metric: 0.6567 - specificity_metric: 0.9255 - val_loss: -0.6500 - val_dice_metric: 0.7643 - val_jaccard_metric: 0.7169 - val_sensitivity_metric: 0.6531 - val_specificity_metric: 0.9415
# Epoch 7/60
# 77/77 [==============================] - 65s 834ms/step - loss: -0.6792 - dice_metric: 0.7011 - jaccard_metric: 0.6322 - sensitivity_metric: 0.6902 - specificity_metric: 0.9336 - val_loss: -0.6817 - val_dice_metric: 0.7658 - val_jaccard_metric: 0.7131 - val_sensitivity_metric: 0.6808 - val_specificity_metric: 0.9475
# Epoch 8/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.6968 - dice_metric: 0.7146 - jaccard_metric: 0.6459 - sensitivity_metric: 0.7070 - specificity_metric: 0.9378 - val_loss: -0.7061 - val_dice_metric: 0.7712 - val_jaccard_metric: 0.7169 - val_sensitivity_metric: 0.7064 - val_specificity_metric: 0.9542
# Epoch 9/60
# 77/77 [==============================] - 67s 864ms/step - loss: -0.7082 - dice_metric: 0.7239 - jaccard_metric: 0.6557 - sensitivity_metric: 0.7178 - specificity_metric: 0.9408 - val_loss: -0.7221 - val_dice_metric: 0.7804 - val_jaccard_metric: 0.7274 - val_sensitivity_metric: 0.7249 - val_specificity_metric: 0.9602
# Epoch 10/60
# 77/77 [==============================] - 65s 841ms/step - loss: -0.7162 - dice_metric: 0.7307 - jaccard_metric: 0.6629 - sensitivity_metric: 0.7250 - specificity_metric: 0.9427 - val_loss: -0.7337 - val_dice_metric: 0.7565 - val_jaccard_metric: 0.7040 - val_sensitivity_metric: 0.7332 - val_specificity_metric: 0.9588
# Epoch 11/60
# 77/77 [==============================] - 67s 865ms/step - loss: -0.7231 - dice_metric: 0.7361 - jaccard_metric: 0.6688 - sensitivity_metric: 0.7311 - specificity_metric: 0.9442 - val_loss: -0.7387 - val_dice_metric: 0.7694 - val_jaccard_metric: 0.7183 - val_sensitivity_metric: 0.7426 - val_specificity_metric: 0.9645
# Epoch 12/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.7283 - dice_metric: 0.7407 - jaccard_metric: 0.6740 - sensitivity_metric: 0.7361 - specificity_metric: 0.9455 - val_loss: -0.7432 - val_dice_metric: 0.7603 - val_jaccard_metric: 0.7097 - val_sensitivity_metric: 0.7491 - val_specificity_metric: 0.9670
# Epoch 13/60
# 77/77 [==============================] - 64s 832ms/step - loss: -0.7332 - dice_metric: 0.7450 - jaccard_metric: 0.6786 - sensitivity_metric: 0.7403 - specificity_metric: 0.9465 - val_loss: -0.7474 - val_dice_metric: 0.7621 - val_jaccard_metric: 0.7127 - val_sensitivity_metric: 0.7523 - val_specificity_metric: 0.9669
# Epoch 14/60
# 77/77 [==============================] - 64s 828ms/step - loss: -0.7370 - dice_metric: 0.7489 - jaccard_metric: 0.6829 - sensitivity_metric: 0.7437 - specificity_metric: 0.9473 - val_loss: -0.7489 - val_dice_metric: 0.7614 - val_jaccard_metric: 0.7123 - val_sensitivity_metric: 0.7531 - val_specificity_metric: 0.9682
# Epoch 15/60
# 77/77 [==============================] - 63s 818ms/step - loss: -0.7405 - dice_metric: 0.7505 - jaccard_metric: 0.6849 - sensitivity_metric: 0.7469 - specificity_metric: 0.9480 - val_loss: -0.7511 - val_dice_metric: 0.7584 - val_jaccard_metric: 0.7098 - val_sensitivity_metric: 0.7548 - val_specificity_metric: 0.9680
# Epoch 16/60
# 77/77 [==============================] - 66s 853ms/step - loss: -0.7431 - dice_metric: 0.7526 - jaccard_metric: 0.6873 - sensitivity_metric: 0.7492 - specificity_metric: 0.9485 - val_loss: -0.7520 - val_dice_metric: 0.7571 - val_jaccard_metric: 0.7090 - val_sensitivity_metric: 0.7566 - val_specificity_metric: 0.9691
# Epoch 17/60
# 77/77 [==============================] - 67s 859ms/step - loss: -0.7460 - dice_metric: 0.7565 - jaccard_metric: 0.6916 - sensitivity_metric: 0.7518 - specificity_metric: 0.9493 - val_loss: -0.7534 - val_dice_metric: 0.7599 - val_jaccard_metric: 0.7121 - val_sensitivity_metric: 0.7581 - val_specificity_metric: 0.9695
# Epoch 18/60
# 77/77 [==============================] - 68s 872ms/step - loss: -0.7484 - dice_metric: 0.7572 - jaccard_metric: 0.6925 - sensitivity_metric: 0.7540 - specificity_metric: 0.9497 - val_loss: -0.7536 - val_dice_metric: 0.7581 - val_jaccard_metric: 0.7104 - val_sensitivity_metric: 0.7593 - val_specificity_metric: 0.9707
# Epoch 19/60
# 77/77 [==============================] - 64s 830ms/step - loss: -0.7507 - dice_metric: 0.7613 - jaccard_metric: 0.6969 - sensitivity_metric: 0.7564 - specificity_metric: 0.9503 - val_loss: -0.7548 - val_dice_metric: 0.7598 - val_jaccard_metric: 0.7123 - val_sensitivity_metric: 0.7631 - val_specificity_metric: 0.9723
# Epoch 20/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.7524 - dice_metric: 0.7609 - jaccard_metric: 0.6968 - sensitivity_metric: 0.7575 - specificity_metric: 0.9505 - val_loss: -0.7564 - val_dice_metric: 0.7715 - val_jaccard_metric: 0.7251 - val_sensitivity_metric: 0.7629 - val_specificity_metric: 0.9713
# Epoch 21/60
# 77/77 [==============================] - 66s 857ms/step - loss: -0.7538 - dice_metric: 0.7622 - jaccard_metric: 0.6982 - sensitivity_metric: 0.7592 - specificity_metric: 0.9510 - val_loss: -0.7565 - val_dice_metric: 0.7610 - val_jaccard_metric: 0.7141 - val_sensitivity_metric: 0.7625 - val_specificity_metric: 0.9720
# Epoch 22/60
# 77/77 [==============================] - 65s 843ms/step - loss: -0.7561 - dice_metric: 0.7644 - jaccard_metric: 0.7007 - sensitivity_metric: 0.7613 - specificity_metric: 0.9513 - val_loss: -0.7567 - val_dice_metric: 0.7903 - val_jaccard_metric: 0.7441 - val_sensitivity_metric: 0.7620 - val_specificity_metric: 0.9722
# Epoch 23/60
# 77/77 [==============================] - 61s 791ms/step - loss: -0.7582 - dice_metric: 0.7654 - jaccard_metric: 0.7018 - sensitivity_metric: 0.7628 - specificity_metric: 0.9516 - val_loss: -0.7572 - val_dice_metric: 0.7602 - val_jaccard_metric: 0.7137 - val_sensitivity_metric: 0.7632 - val_specificity_metric: 0.9732
# Epoch 24/60
# 77/77 [==============================] - 65s 836ms/step - loss: -0.7597 - dice_metric: 0.7689 - jaccard_metric: 0.7055 - sensitivity_metric: 0.7645 - specificity_metric: 0.9519 - val_loss: -0.7580 - val_dice_metric: 0.7886 - val_jaccard_metric: 0.7425 - val_sensitivity_metric: 0.7638 - val_specificity_metric: 0.9729
# Epoch 25/60
# 77/77 [==============================] - 65s 838ms/step - loss: -0.7614 - dice_metric: 0.7681 - jaccard_metric: 0.7049 - sensitivity_metric: 0.7658 - specificity_metric: 0.9522 - val_loss: -0.7584 - val_dice_metric: 0.7840 - val_jaccard_metric: 0.7376 - val_sensitivity_metric: 0.7641 - val_specificity_metric: 0.9737
# Epoch 26/60
# 77/77 [==============================] - 67s 865ms/step - loss: -0.7634 - dice_metric: 0.7707 - jaccard_metric: 0.7078 - sensitivity_metric: 0.7674 - specificity_metric: 0.9525 - val_loss: -0.7590 - val_dice_metric: 0.7650 - val_jaccard_metric: 0.7187 - val_sensitivity_metric: 0.7636 - val_specificity_metric: 0.9731
# Epoch 27/60
# 77/77 [==============================] - 66s 849ms/step - loss: -0.7653 - dice_metric: 0.7729 - jaccard_metric: 0.7104 - sensitivity_metric: 0.7693 - specificity_metric: 0.9527 - val_loss: -0.7604 - val_dice_metric: 0.7724 - val_jaccard_metric: 0.7268 - val_sensitivity_metric: 0.7654 - val_specificity_metric: 0.9739
# Epoch 28/60
# 77/77 [==============================] - 64s 820ms/step - loss: -0.7672 - dice_metric: 0.7753 - jaccard_metric: 0.7131 - sensitivity_metric: 0.7707 - specificity_metric: 0.9530 - val_loss: -0.7616 - val_dice_metric: 0.7781 - val_jaccard_metric: 0.7329 - val_sensitivity_metric: 0.7668 - val_specificity_metric: 0.9735
# Epoch 29/60
# 77/77 [==============================] - 66s 851ms/step - loss: -0.7680 - dice_metric: 0.7756 - jaccard_metric: 0.7133 - sensitivity_metric: 0.7715 - specificity_metric: 0.9531 - val_loss: -0.7608 - val_dice_metric: 0.7835 - val_jaccard_metric: 0.7382 - val_sensitivity_metric: 0.7673 - val_specificity_metric: 0.9743
# Epoch 30/60
# 77/77 [==============================] - 64s 827ms/step - loss: -0.7691 - dice_metric: 0.7772 - jaccard_metric: 0.7151 - sensitivity_metric: 0.7726 - specificity_metric: 0.9533 - val_loss: -0.7624 - val_dice_metric: 0.7772 - val_jaccard_metric: 0.7317 - val_sensitivity_metric: 0.7664 - val_specificity_metric: 0.9732
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 66s 846ms/step - loss: -0.7720 - dice_metric: 0.7790 - jaccard_metric: 0.7175 - sensitivity_metric: 0.7754 - specificity_metric: 0.9540 - val_loss: -0.7631 - val_dice_metric: 0.7994 - val_jaccard_metric: 0.7546 - val_sensitivity_metric: 0.7678 - val_specificity_metric: 0.9730
# Epoch 32/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.7745 - dice_metric: 0.7824 - jaccard_metric: 0.7213 - sensitivity_metric: 0.7770 - specificity_metric: 0.9539 - val_loss: -0.7631 - val_dice_metric: 0.8072 - val_jaccard_metric: 0.7626 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9738
# Epoch 33/60
# 77/77 [==============================] - 67s 860ms/step - loss: -0.7751 - dice_metric: 0.7811 - jaccard_metric: 0.7201 - sensitivity_metric: 0.7776 - specificity_metric: 0.9540 - val_loss: -0.7633 - val_dice_metric: 0.7983 - val_jaccard_metric: 0.7537 - val_sensitivity_metric: 0.7684 - val_specificity_metric: 0.9735
# Epoch 34/60
# 77/77 [==============================] - 69s 889ms/step - loss: -0.7754 - dice_metric: 0.7827 - jaccard_metric: 0.7219 - sensitivity_metric: 0.7778 - specificity_metric: 0.9540 - val_loss: -0.7633 - val_dice_metric: 0.8115 - val_jaccard_metric: 0.7671 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9734
# Epoch 35/60
# 77/77 [==============================] - 66s 847ms/step - loss: -0.7756 - dice_metric: 0.7821 - jaccard_metric: 0.7213 - sensitivity_metric: 0.7779 - specificity_metric: 0.9540 - val_loss: -0.7634 - val_dice_metric: 0.8025 - val_jaccard_metric: 0.7580 - val_sensitivity_metric: 0.7684 - val_specificity_metric: 0.9735
# Epoch 36/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.7762 - dice_metric: 0.7827 - jaccard_metric: 0.7219 - sensitivity_metric: 0.7786 - specificity_metric: 0.9541 - val_loss: -0.7633 - val_dice_metric: 0.7984 - val_jaccard_metric: 0.7539 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9735
# Epoch 37/60
# 77/77 [==============================] - 65s 834ms/step - loss: -0.7764 - dice_metric: 0.7838 - jaccard_metric: 0.7231 - sensitivity_metric: 0.7788 - specificity_metric: 0.9542 - val_loss: -0.7634 - val_dice_metric: 0.8026 - val_jaccard_metric: 0.7581 - val_sensitivity_metric: 0.7686 - val_specificity_metric: 0.9735
# Epoch 38/60
# 77/77 [==============================] - 64s 832ms/step - loss: -0.7766 - dice_metric: 0.7837 - jaccard_metric: 0.7229 - sensitivity_metric: 0.7788 - specificity_metric: 0.9542 - val_loss: -0.7635 - val_dice_metric: 0.7934 - val_jaccard_metric: 0.7490 - val_sensitivity_metric: 0.7682 - val_specificity_metric: 0.9733
# Epoch 39/60
# 77/77 [==============================] - 66s 859ms/step - loss: -0.7770 - dice_metric: 0.7839 - jaccard_metric: 0.7233 - sensitivity_metric: 0.7792 - specificity_metric: 0.9542 - val_loss: -0.7634 - val_dice_metric: 0.8102 - val_jaccard_metric: 0.7658 - val_sensitivity_metric: 0.7685 - val_specificity_metric: 0.9736
# Epoch 40/60
# 77/77 [==============================] - 67s 866ms/step - loss: -0.7772 - dice_metric: 0.7846 - jaccard_metric: 0.7241 - sensitivity_metric: 0.7793 - specificity_metric: 0.9543 - val_loss: -0.7633 - val_dice_metric: 0.8011 - val_jaccard_metric: 0.7566 - val_sensitivity_metric: 0.7684 - val_specificity_metric: 0.9735
# Epoch 41/60
# 77/77 [==============================] - 65s 839ms/step - loss: -0.7775 - dice_metric: 0.7838 - jaccard_metric: 0.7232 - sensitivity_metric: 0.7796 - specificity_metric: 0.9543 - val_loss: -0.7633 - val_dice_metric: 0.8075 - val_jaccard_metric: 0.7631 - val_sensitivity_metric: 0.7683 - val_specificity_metric: 0.9735
# Epoch 42/60
# 77/77 [==============================] - 64s 826ms/step - loss: -0.7775 - dice_metric: 0.7852 - jaccard_metric: 0.7246 - sensitivity_metric: 0.7796 - specificity_metric: 0.9543 - val_loss: -0.7633 - val_dice_metric: 0.8115 - val_jaccard_metric: 0.7672 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9737
# Epoch 43/60
# 77/77 [==============================] - 64s 819ms/step - loss: -0.7778 - dice_metric: 0.7857 - jaccard_metric: 0.7253 - sensitivity_metric: 0.7799 - specificity_metric: 0.9544 - val_loss: -0.7634 - val_dice_metric: 0.7987 - val_jaccard_metric: 0.7542 - val_sensitivity_metric: 0.7686 - val_specificity_metric: 0.9736
# Epoch 44/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.7782 - dice_metric: 0.7856 - jaccard_metric: 0.7252 - sensitivity_metric: 0.7803 - specificity_metric: 0.9544 - val_loss: -0.7635 - val_dice_metric: 0.7974 - val_jaccard_metric: 0.7530 - val_sensitivity_metric: 0.7684 - val_specificity_metric: 0.9734
# Epoch 45/60
# 77/77 [==============================] - 66s 852ms/step - loss: -0.7782 - dice_metric: 0.7856 - jaccard_metric: 0.7252 - sensitivity_metric: 0.7802 - specificity_metric: 0.9544 - val_loss: -0.7633 - val_dice_metric: 0.8062 - val_jaccard_metric: 0.7618 - val_sensitivity_metric: 0.7680 - val_specificity_metric: 0.9735
# Epoch 46/60
# 77/77 [==============================] - 65s 838ms/step - loss: -0.7786 - dice_metric: 0.7865 - jaccard_metric: 0.7262 - sensitivity_metric: 0.7807 - specificity_metric: 0.9545 - val_loss: -0.7635 - val_dice_metric: 0.8116 - val_jaccard_metric: 0.7671 - val_sensitivity_metric: 0.7681 - val_specificity_metric: 0.9734
# Epoch 47/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.7787 - dice_metric: 0.7876 - jaccard_metric: 0.7272 - sensitivity_metric: 0.7806 - specificity_metric: 0.9544 - val_loss: -0.7633 - val_dice_metric: 0.8099 - val_jaccard_metric: 0.7654 - val_sensitivity_metric: 0.7681 - val_specificity_metric: 0.9736
# Epoch 48/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.7788 - dice_metric: 0.7860 - jaccard_metric: 0.7257 - sensitivity_metric: 0.7807 - specificity_metric: 0.9545 - val_loss: -0.7633 - val_dice_metric: 0.8087 - val_jaccard_metric: 0.7642 - val_sensitivity_metric: 0.7684 - val_specificity_metric: 0.9737
# Epoch 49/60
# 77/77 [==============================] - 67s 861ms/step - loss: -0.7790 - dice_metric: 0.7864 - jaccard_metric: 0.7261 - sensitivity_metric: 0.7812 - specificity_metric: 0.9546 - val_loss: -0.7633 - val_dice_metric: 0.8088 - val_jaccard_metric: 0.7644 - val_sensitivity_metric: 0.7686 - val_specificity_metric: 0.9737
# Epoch 50/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.7793 - dice_metric: 0.7874 - jaccard_metric: 0.7271 - sensitivity_metric: 0.7812 - specificity_metric: 0.9546 - val_loss: -0.7634 - val_dice_metric: 0.8141 - val_jaccard_metric: 0.7697 - val_sensitivity_metric: 0.7689 - val_specificity_metric: 0.9739
# Epoch 51/60
# 77/77 [==============================] - 67s 870ms/step - loss: -0.7798 - dice_metric: 0.7894 - jaccard_metric: 0.7293 - sensitivity_metric: 0.7815 - specificity_metric: 0.9546 - val_loss: -0.7634 - val_dice_metric: 0.8156 - val_jaccard_metric: 0.7712 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9737
# Epoch 52/60
# 77/77 [==============================] - 67s 862ms/step - loss: -0.7798 - dice_metric: 0.7881 - jaccard_metric: 0.7280 - sensitivity_metric: 0.7817 - specificity_metric: 0.9546 - val_loss: -0.7635 - val_dice_metric: 0.8104 - val_jaccard_metric: 0.7661 - val_sensitivity_metric: 0.7687 - val_specificity_metric: 0.9738
# Epoch 53/60
# 77/77 [==============================] - 66s 857ms/step - loss: -0.7800 - dice_metric: 0.7877 - jaccard_metric: 0.7276 - sensitivity_metric: 0.7817 - specificity_metric: 0.9545 - val_loss: -0.7636 - val_dice_metric: 0.8131 - val_jaccard_metric: 0.7688 - val_sensitivity_metric: 0.7686 - val_specificity_metric: 0.9736
# Epoch 54/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.7802 - dice_metric: 0.7880 - jaccard_metric: 0.7280 - sensitivity_metric: 0.7820 - specificity_metric: 0.9547 - val_loss: -0.7634 - val_dice_metric: 0.8141 - val_jaccard_metric: 0.7698 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9741
# Epoch 55/60
# 77/77 [==============================] - 66s 852ms/step - loss: -0.7804 - dice_metric: 0.7879 - jaccard_metric: 0.7279 - sensitivity_metric: 0.7821 - specificity_metric: 0.9547 - val_loss: -0.7637 - val_dice_metric: 0.8157 - val_jaccard_metric: 0.7715 - val_sensitivity_metric: 0.7692 - val_specificity_metric: 0.9739
# Epoch 56/60
# 77/77 [==============================] - 65s 837ms/step - loss: -0.7807 - dice_metric: 0.7896 - jaccard_metric: 0.7296 - sensitivity_metric: 0.7826 - specificity_metric: 0.9548 - val_loss: -0.7635 - val_dice_metric: 0.8179 - val_jaccard_metric: 0.7737 - val_sensitivity_metric: 0.7687 - val_specificity_metric: 0.9740
# Epoch 57/60
# 77/77 [==============================] - 66s 849ms/step - loss: -0.7808 - dice_metric: 0.7903 - jaccard_metric: 0.7303 - sensitivity_metric: 0.7826 - specificity_metric: 0.9547 - val_loss: -0.7636 - val_dice_metric: 0.8144 - val_jaccard_metric: 0.7701 - val_sensitivity_metric: 0.7693 - val_specificity_metric: 0.9740
# Epoch 58/60
# 77/77 [==============================] - 66s 854ms/step - loss: -0.7810 - dice_metric: 0.7895 - jaccard_metric: 0.7296 - sensitivity_metric: 0.7827 - specificity_metric: 0.9548 - val_loss: -0.7638 - val_dice_metric: 0.8147 - val_jaccard_metric: 0.7705 - val_sensitivity_metric: 0.7693 - val_specificity_metric: 0.9740
# Epoch 59/60
# 77/77 [==============================] - 63s 819ms/step - loss: -0.7812 - dice_metric: 0.7895 - jaccard_metric: 0.7296 - sensitivity_metric: 0.7828 - specificity_metric: 0.9549 - val_loss: -0.7637 - val_dice_metric: 0.8186 - val_jaccard_metric: 0.7745 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9736
# Epoch 60/60
# 77/77 [==============================] - 66s 848ms/step - loss: -0.7815 - dice_metric: 0.7903 - jaccard_metric: 0.7304 - sensitivity_metric: 0.7831 - specificity_metric: 0.9548 - val_loss: -0.7638 - val_dice_metric: 0.8145 - val_jaccard_metric: 0.7703 - val_sensitivity_metric: 0.7688 - val_specificity_metric: 0.9736

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.84108, standard deviation: 0.27680
# Jaccard Index mean: 0.79313, standard deviation: 0.28733
# Sensitivity mean: 0.79925, standard deviation: 0.32994
# Specificity mean: 0.97315, standard deviation: 0.05217
