# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|████████████████████████████████████████▍| 983M/998M [00:06<00:00, 139MB/s]
# 100%|█████████████████████████████████████████| 998M/998M [00:06<00:00, 156MB/s]

# %%
config = {"Seg_model":"UNetMobV2","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_mobilenetv2
from seeds_segmentation.losses import DiceCoefficient

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = unet_mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 90s 924ms/step - loss: -0.2042 - dice_metric: 0.5437 - jaccard_metric: 0.4426 - sensitivity_metric: 0.7529 - specificity_metric: 0.7529 - val_loss: -0.2997 - val_dice_metric: 0.8283 - val_jaccard_metric: 0.7444 - val_sensitivity_metric: 0.7880 - val_specificity_metric: 0.7880
# Epoch 2/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.6200 - dice_metric: 0.8944 - jaccard_metric: 0.8289 - sensitivity_metric: 0.9126 - specificity_metric: 0.9126 - val_loss: -0.5808 - val_dice_metric: 0.8228 - val_jaccard_metric: 0.7421 - val_sensitivity_metric: 0.7582 - val_specificity_metric: 0.7582
# Epoch 3/60
# 77/77 [==============================] - 71s 918ms/step - loss: -0.7822 - dice_metric: 0.9187 - jaccard_metric: 0.8631 - sensitivity_metric: 0.9176 - specificity_metric: 0.9176 - val_loss: -0.7545 - val_dice_metric: 0.8983 - val_jaccard_metric: 0.8341 - val_sensitivity_metric: 0.8495 - val_specificity_metric: 0.8495
# Epoch 4/60
# 77/77 [==============================] - 71s 923ms/step - loss: -0.8233 - dice_metric: 0.9269 - jaccard_metric: 0.8752 - sensitivity_metric: 0.9242 - specificity_metric: 0.9242 - val_loss: -0.8410 - val_dice_metric: 0.9347 - val_jaccard_metric: 0.8878 - val_sensitivity_metric: 0.9104 - val_specificity_metric: 0.9104
# Epoch 5/60
# 77/77 [==============================] - 70s 912ms/step - loss: -0.8435 - dice_metric: 0.9321 - jaccard_metric: 0.8830 - sensitivity_metric: 0.9292 - specificity_metric: 0.9292 - val_loss: -0.8723 - val_dice_metric: 0.9462 - val_jaccard_metric: 0.9061 - val_sensitivity_metric: 0.9363 - val_specificity_metric: 0.9363
# Epoch 6/60
# 77/77 [==============================] - 71s 912ms/step - loss: -0.8563 - dice_metric: 0.9358 - jaccard_metric: 0.8887 - sensitivity_metric: 0.9329 - specificity_metric: 0.9329 - val_loss: -0.8861 - val_dice_metric: 0.9505 - val_jaccard_metric: 0.9132 - val_sensitivity_metric: 0.9473 - val_specificity_metric: 0.9473
# Epoch 7/60
# 77/77 [==============================] - 72s 934ms/step - loss: -0.8649 - dice_metric: 0.9385 - jaccard_metric: 0.8928 - sensitivity_metric: 0.9355 - specificity_metric: 0.9355 - val_loss: -0.8941 - val_dice_metric: 0.9527 - val_jaccard_metric: 0.9167 - val_sensitivity_metric: 0.9531 - val_specificity_metric: 0.9531
# Epoch 8/60
# 77/77 [==============================] - 70s 907ms/step - loss: -0.8713 - dice_metric: 0.9405 - jaccard_metric: 0.8959 - sensitivity_metric: 0.9377 - specificity_metric: 0.9377 - val_loss: -0.8993 - val_dice_metric: 0.9542 - val_jaccard_metric: 0.9192 - val_sensitivity_metric: 0.9565 - val_specificity_metric: 0.9565
# Epoch 9/60
# 77/77 [==============================] - 66s 853ms/step - loss: -0.8764 - dice_metric: 0.9421 - jaccard_metric: 0.8986 - sensitivity_metric: 0.9395 - specificity_metric: 0.9395 - val_loss: -0.9037 - val_dice_metric: 0.9555 - val_jaccard_metric: 0.9213 - val_sensitivity_metric: 0.9570 - val_specificity_metric: 0.9570
# Epoch 10/60
# 77/77 [==============================] - 69s 894ms/step - loss: -0.8805 - dice_metric: 0.9436 - jaccard_metric: 0.9008 - sensitivity_metric: 0.9410 - specificity_metric: 0.9410 - val_loss: -0.9066 - val_dice_metric: 0.9563 - val_jaccard_metric: 0.9226 - val_sensitivity_metric: 0.9594 - val_specificity_metric: 0.9594
# Epoch 11/60
# 77/77 [==============================] - 70s 900ms/step - loss: -0.8840 - dice_metric: 0.9448 - jaccard_metric: 0.9027 - sensitivity_metric: 0.9423 - specificity_metric: 0.9423 - val_loss: -0.9087 - val_dice_metric: 0.9567 - val_jaccard_metric: 0.9234 - val_sensitivity_metric: 0.9625 - val_specificity_metric: 0.9625
# Epoch 12/60
# 77/77 [==============================] - 71s 921ms/step - loss: -0.8868 - dice_metric: 0.9458 - jaccard_metric: 0.9043 - sensitivity_metric: 0.9434 - specificity_metric: 0.9434 - val_loss: -0.9104 - val_dice_metric: 0.9572 - val_jaccard_metric: 0.9241 - val_sensitivity_metric: 0.9632 - val_specificity_metric: 0.9632
# Epoch 13/60
# 77/77 [==============================] - 71s 922ms/step - loss: -0.8894 - dice_metric: 0.9467 - jaccard_metric: 0.9058 - sensitivity_metric: 0.9443 - specificity_metric: 0.9443 - val_loss: -0.9119 - val_dice_metric: 0.9575 - val_jaccard_metric: 0.9247 - val_sensitivity_metric: 0.9642 - val_specificity_metric: 0.9642
# Epoch 14/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.8916 - dice_metric: 0.9476 - jaccard_metric: 0.9070 - sensitivity_metric: 0.9453 - specificity_metric: 0.9453 - val_loss: -0.9136 - val_dice_metric: 0.9581 - val_jaccard_metric: 0.9256 - val_sensitivity_metric: 0.9647 - val_specificity_metric: 0.9647
# Epoch 15/60
# 77/77 [==============================] - 75s 967ms/step - loss: -0.8935 - dice_metric: 0.9483 - jaccard_metric: 0.9082 - sensitivity_metric: 0.9461 - specificity_metric: 0.9461 - val_loss: -0.9150 - val_dice_metric: 0.9586 - val_jaccard_metric: 0.9264 - val_sensitivity_metric: 0.9649 - val_specificity_metric: 0.9649
# Epoch 16/60
# 77/77 [==============================] - 68s 885ms/step - loss: -0.8954 - dice_metric: 0.9490 - jaccard_metric: 0.9094 - sensitivity_metric: 0.9469 - specificity_metric: 0.9469 - val_loss: -0.9157 - val_dice_metric: 0.9587 - val_jaccard_metric: 0.9267 - val_sensitivity_metric: 0.9652 - val_specificity_metric: 0.9652
# Epoch 17/60
# 77/77 [==============================] - 72s 928ms/step - loss: -0.8969 - dice_metric: 0.9496 - jaccard_metric: 0.9103 - sensitivity_metric: 0.9475 - specificity_metric: 0.9475 - val_loss: -0.9162 - val_dice_metric: 0.9588 - val_jaccard_metric: 0.9268 - val_sensitivity_metric: 0.9663 - val_specificity_metric: 0.9663
# Epoch 18/60
# 77/77 [==============================] - 69s 887ms/step - loss: -0.8984 - dice_metric: 0.9502 - jaccard_metric: 0.9113 - sensitivity_metric: 0.9481 - specificity_metric: 0.9481 - val_loss: -0.9180 - val_dice_metric: 0.9596 - val_jaccard_metric: 0.9281 - val_sensitivity_metric: 0.9657 - val_specificity_metric: 0.9657
# Epoch 19/60
# 77/77 [==============================] - 70s 904ms/step - loss: -0.8998 - dice_metric: 0.9508 - jaccard_metric: 0.9121 - sensitivity_metric: 0.9486 - specificity_metric: 0.9486 - val_loss: -0.9189 - val_dice_metric: 0.9599 - val_jaccard_metric: 0.9286 - val_sensitivity_metric: 0.9659 - val_specificity_metric: 0.9659
# Epoch 20/60
# 77/77 [==============================] - 73s 951ms/step - loss: -0.9011 - dice_metric: 0.9513 - jaccard_metric: 0.9130 - sensitivity_metric: 0.9492 - specificity_metric: 0.9492 - val_loss: -0.9194 - val_dice_metric: 0.9599 - val_jaccard_metric: 0.9287 - val_sensitivity_metric: 0.9665 - val_specificity_metric: 0.9665
# Epoch 21/60
# 77/77 [==============================] - 66s 859ms/step - loss: -0.9024 - dice_metric: 0.9519 - jaccard_metric: 0.9139 - sensitivity_metric: 0.9499 - specificity_metric: 0.9499 - val_loss: -0.9198 - val_dice_metric: 0.9601 - val_jaccard_metric: 0.9290 - val_sensitivity_metric: 0.9674 - val_specificity_metric: 0.9674
# Epoch 22/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.9034 - dice_metric: 0.9523 - jaccard_metric: 0.9146 - sensitivity_metric: 0.9504 - specificity_metric: 0.9504 - val_loss: -0.9201 - val_dice_metric: 0.9602 - val_jaccard_metric: 0.9291 - val_sensitivity_metric: 0.9677 - val_specificity_metric: 0.9677
# Epoch 23/60
# 77/77 [==============================] - 73s 941ms/step - loss: -0.9045 - dice_metric: 0.9527 - jaccard_metric: 0.9153 - sensitivity_metric: 0.9508 - specificity_metric: 0.9508 - val_loss: -0.9198 - val_dice_metric: 0.9599 - val_jaccard_metric: 0.9287 - val_sensitivity_metric: 0.9694 - val_specificity_metric: 0.9694
# Epoch 24/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.9055 - dice_metric: 0.9532 - jaccard_metric: 0.9160 - sensitivity_metric: 0.9513 - specificity_metric: 0.9513 - val_loss: -0.9208 - val_dice_metric: 0.9604 - val_jaccard_metric: 0.9295 - val_sensitivity_metric: 0.9686 - val_specificity_metric: 0.9686
# Epoch 25/60
# 77/77 [==============================] - 69s 895ms/step - loss: -0.9065 - dice_metric: 0.9536 - jaccard_metric: 0.9166 - sensitivity_metric: 0.9517 - specificity_metric: 0.9517 - val_loss: -0.9212 - val_dice_metric: 0.9605 - val_jaccard_metric: 0.9296 - val_sensitivity_metric: 0.9688 - val_specificity_metric: 0.9688
# Epoch 26/60
# 77/77 [==============================] - 71s 919ms/step - loss: -0.9074 - dice_metric: 0.9540 - jaccard_metric: 0.9173 - sensitivity_metric: 0.9521 - specificity_metric: 0.9521 - val_loss: -0.9220 - val_dice_metric: 0.9607 - val_jaccard_metric: 0.9301 - val_sensitivity_metric: 0.9688 - val_specificity_metric: 0.9688
# Epoch 27/60
# 77/77 [==============================] - 66s 861ms/step - loss: -0.9084 - dice_metric: 0.9544 - jaccard_metric: 0.9180 - sensitivity_metric: 0.9525 - specificity_metric: 0.9525 - val_loss: -0.9228 - val_dice_metric: 0.9612 - val_jaccard_metric: 0.9307 - val_sensitivity_metric: 0.9686 - val_specificity_metric: 0.9686
# Epoch 28/60
# 77/77 [==============================] - 69s 893ms/step - loss: -0.9092 - dice_metric: 0.9547 - jaccard_metric: 0.9185 - sensitivity_metric: 0.9529 - specificity_metric: 0.9529 - val_loss: -0.9230 - val_dice_metric: 0.9611 - val_jaccard_metric: 0.9307 - val_sensitivity_metric: 0.9688 - val_specificity_metric: 0.9688
# Epoch 29/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.9099 - dice_metric: 0.9550 - jaccard_metric: 0.9190 - sensitivity_metric: 0.9532 - specificity_metric: 0.9532 - val_loss: -0.9216 - val_dice_metric: 0.9603 - val_jaccard_metric: 0.9294 - val_sensitivity_metric: 0.9713 - val_specificity_metric: 0.9713
# Epoch 30/60
# 77/77 [==============================] - 72s 938ms/step - loss: -0.9107 - dice_metric: 0.9554 - jaccard_metric: 0.9195 - sensitivity_metric: 0.9536 - specificity_metric: 0.9536 - val_loss: -0.9232 - val_dice_metric: 0.9612 - val_jaccard_metric: 0.9309 - val_sensitivity_metric: 0.9703 - val_specificity_metric: 0.9703
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.9122 - dice_metric: 0.9561 - jaccard_metric: 0.9207 - sensitivity_metric: 0.9543 - specificity_metric: 0.9543 - val_loss: -0.9260 - val_dice_metric: 0.9627 - val_jaccard_metric: 0.9333 - val_sensitivity_metric: 0.9677 - val_specificity_metric: 0.9677
# Epoch 32/60
# 77/77 [==============================] - 71s 925ms/step - loss: -0.9130 - dice_metric: 0.9565 - jaccard_metric: 0.9214 - sensitivity_metric: 0.9548 - specificity_metric: 0.9548 - val_loss: -0.9264 - val_dice_metric: 0.9629 - val_jaccard_metric: 0.9336 - val_sensitivity_metric: 0.9672 - val_specificity_metric: 0.9672
# Epoch 33/60
# 77/77 [==============================] - 72s 929ms/step - loss: -0.9132 - dice_metric: 0.9566 - jaccard_metric: 0.9216 - sensitivity_metric: 0.9549 - specificity_metric: 0.9549 - val_loss: -0.9265 - val_dice_metric: 0.9630 - val_jaccard_metric: 0.9337 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 34/60
# 77/77 [==============================] - 70s 899ms/step - loss: -0.9134 - dice_metric: 0.9567 - jaccard_metric: 0.9217 - sensitivity_metric: 0.9549 - specificity_metric: 0.9549 - val_loss: -0.9267 - val_dice_metric: 0.9630 - val_jaccard_metric: 0.9339 - val_sensitivity_metric: 0.9667 - val_specificity_metric: 0.9667
# Epoch 35/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.9134 - dice_metric: 0.9567 - jaccard_metric: 0.9217 - sensitivity_metric: 0.9551 - specificity_metric: 0.9551 - val_loss: -0.9267 - val_dice_metric: 0.9630 - val_jaccard_metric: 0.9338 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 36/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.9137 - dice_metric: 0.9568 - jaccard_metric: 0.9219 - sensitivity_metric: 0.9551 - specificity_metric: 0.9551 - val_loss: -0.9267 - val_dice_metric: 0.9631 - val_jaccard_metric: 0.9339 - val_sensitivity_metric: 0.9668 - val_specificity_metric: 0.9668
# Epoch 37/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.9138 - dice_metric: 0.9569 - jaccard_metric: 0.9220 - sensitivity_metric: 0.9552 - specificity_metric: 0.9552 - val_loss: -0.9268 - val_dice_metric: 0.9631 - val_jaccard_metric: 0.9340 - val_sensitivity_metric: 0.9667 - val_specificity_metric: 0.9667
# Epoch 38/60
# 77/77 [==============================] - 69s 895ms/step - loss: -0.9139 - dice_metric: 0.9569 - jaccard_metric: 0.9221 - sensitivity_metric: 0.9552 - specificity_metric: 0.9552 - val_loss: -0.9269 - val_dice_metric: 0.9631 - val_jaccard_metric: 0.9340 - val_sensitivity_metric: 0.9666 - val_specificity_metric: 0.9666
# Epoch 39/60
# 77/77 [==============================] - 70s 905ms/step - loss: -0.9141 - dice_metric: 0.9570 - jaccard_metric: 0.9222 - sensitivity_metric: 0.9553 - specificity_metric: 0.9553 - val_loss: -0.9269 - val_dice_metric: 0.9632 - val_jaccard_metric: 0.9341 - val_sensitivity_metric: 0.9666 - val_specificity_metric: 0.9666
# Epoch 40/60
# 77/77 [==============================] - 72s 937ms/step - loss: -0.9141 - dice_metric: 0.9570 - jaccard_metric: 0.9222 - sensitivity_metric: 0.9554 - specificity_metric: 0.9554 - val_loss: -0.9270 - val_dice_metric: 0.9632 - val_jaccard_metric: 0.9341 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 41/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.9143 - dice_metric: 0.9571 - jaccard_metric: 0.9224 - sensitivity_metric: 0.9554 - specificity_metric: 0.9554 - val_loss: -0.9270 - val_dice_metric: 0.9632 - val_jaccard_metric: 0.9341 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 42/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.9144 - dice_metric: 0.9572 - jaccard_metric: 0.9225 - sensitivity_metric: 0.9556 - specificity_metric: 0.9556 - val_loss: -0.9271 - val_dice_metric: 0.9632 - val_jaccard_metric: 0.9341 - val_sensitivity_metric: 0.9668 - val_specificity_metric: 0.9668
# Epoch 43/60
# 77/77 [==============================] - 67s 870ms/step - loss: -0.9144 - dice_metric: 0.9572 - jaccard_metric: 0.9225 - sensitivity_metric: 0.9555 - specificity_metric: 0.9555 - val_loss: -0.9271 - val_dice_metric: 0.9632 - val_jaccard_metric: 0.9341 - val_sensitivity_metric: 0.9668 - val_specificity_metric: 0.9668
# Epoch 44/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.9147 - dice_metric: 0.9573 - jaccard_metric: 0.9227 - sensitivity_metric: 0.9557 - specificity_metric: 0.9557 - val_loss: -0.9272 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9342 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 45/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.9147 - dice_metric: 0.9573 - jaccard_metric: 0.9227 - sensitivity_metric: 0.9557 - specificity_metric: 0.9557 - val_loss: -0.9272 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9342 - val_sensitivity_metric: 0.9668 - val_specificity_metric: 0.9668
# Epoch 46/60
# 77/77 [==============================] - 70s 911ms/step - loss: -0.9149 - dice_metric: 0.9574 - jaccard_metric: 0.9228 - sensitivity_metric: 0.9558 - specificity_metric: 0.9558 - val_loss: -0.9273 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9342 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 47/60
# 77/77 [==============================] - 69s 899ms/step - loss: -0.9150 - dice_metric: 0.9574 - jaccard_metric: 0.9229 - sensitivity_metric: 0.9558 - specificity_metric: 0.9558 - val_loss: -0.9273 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9342 - val_sensitivity_metric: 0.9671 - val_specificity_metric: 0.9671
# Epoch 48/60
# 77/77 [==============================] - 71s 925ms/step - loss: -0.9150 - dice_metric: 0.9574 - jaccard_metric: 0.9229 - sensitivity_metric: 0.9558 - specificity_metric: 0.9558 - val_loss: -0.9274 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9343 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 49/60
# 77/77 [==============================] - 71s 919ms/step - loss: -0.9152 - dice_metric: 0.9575 - jaccard_metric: 0.9230 - sensitivity_metric: 0.9559 - specificity_metric: 0.9559 - val_loss: -0.9274 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9343 - val_sensitivity_metric: 0.9668 - val_specificity_metric: 0.9668
# Epoch 50/60
# 77/77 [==============================] - 68s 883ms/step - loss: -0.9153 - dice_metric: 0.9575 - jaccard_metric: 0.9231 - sensitivity_metric: 0.9559 - specificity_metric: 0.9559 - val_loss: -0.9274 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9343 - val_sensitivity_metric: 0.9672 - val_specificity_metric: 0.9672
# Epoch 51/60
# 77/77 [==============================] - 71s 915ms/step - loss: -0.9154 - dice_metric: 0.9576 - jaccard_metric: 0.9232 - sensitivity_metric: 0.9560 - specificity_metric: 0.9560 - val_loss: -0.9274 - val_dice_metric: 0.9633 - val_jaccard_metric: 0.9344 - val_sensitivity_metric: 0.9672 - val_specificity_metric: 0.9672
# Epoch 52/60
# 77/77 [==============================] - 67s 872ms/step - loss: -0.9156 - dice_metric: 0.9577 - jaccard_metric: 0.9233 - sensitivity_metric: 0.9561 - specificity_metric: 0.9561 - val_loss: -0.9276 - val_dice_metric: 0.9634 - val_jaccard_metric: 0.9345 - val_sensitivity_metric: 0.9667 - val_specificity_metric: 0.9667
# Epoch 53/60
# 77/77 [==============================] - 74s 954ms/step - loss: -0.9157 - dice_metric: 0.9578 - jaccard_metric: 0.9234 - sensitivity_metric: 0.9562 - specificity_metric: 0.9562 - val_loss: -0.9276 - val_dice_metric: 0.9634 - val_jaccard_metric: 0.9345 - val_sensitivity_metric: 0.9670 - val_specificity_metric: 0.9670
# Epoch 54/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.9157 - dice_metric: 0.9578 - jaccard_metric: 0.9234 - sensitivity_metric: 0.9561 - specificity_metric: 0.9561 - val_loss: -0.9276 - val_dice_metric: 0.9634 - val_jaccard_metric: 0.9345 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 55/60
# 77/77 [==============================] - 70s 909ms/step - loss: -0.9158 - dice_metric: 0.9578 - jaccard_metric: 0.9235 - sensitivity_metric: 0.9562 - specificity_metric: 0.9562 - val_loss: -0.9277 - val_dice_metric: 0.9634 - val_jaccard_metric: 0.9345 - val_sensitivity_metric: 0.9672 - val_specificity_metric: 0.9672
# Epoch 56/60
# 77/77 [==============================] - 67s 863ms/step - loss: -0.9159 - dice_metric: 0.9578 - jaccard_metric: 0.9236 - sensitivity_metric: 0.9562 - specificity_metric: 0.9562 - val_loss: -0.9278 - val_dice_metric: 0.9635 - val_jaccard_metric: 0.9346 - val_sensitivity_metric: 0.9669 - val_specificity_metric: 0.9669
# Epoch 57/60
# 77/77 [==============================] - 73s 941ms/step - loss: -0.9160 - dice_metric: 0.9579 - jaccard_metric: 0.9236 - sensitivity_metric: 0.9564 - specificity_metric: 0.9564 - val_loss: -0.9277 - val_dice_metric: 0.9634 - val_jaccard_metric: 0.9345 - val_sensitivity_metric: 0.9673 - val_specificity_metric: 0.9673
# Epoch 58/60
# 77/77 [==============================] - 71s 924ms/step - loss: -0.9162 - dice_metric: 0.9580 - jaccard_metric: 0.9238 - sensitivity_metric: 0.9564 - specificity_metric: 0.9564 - val_loss: -0.9278 - val_dice_metric: 0.9635 - val_jaccard_metric: 0.9346 - val_sensitivity_metric: 0.9670 - val_specificity_metric: 0.9670
# Epoch 59/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.9163 - dice_metric: 0.9580 - jaccard_metric: 0.9238 - sensitivity_metric: 0.9564 - specificity_metric: 0.9564 - val_loss: -0.9279 - val_dice_metric: 0.9635 - val_jaccard_metric: 0.9346 - val_sensitivity_metric: 0.9668 - val_specificity_metric: 0.9668
# Epoch 60/60
# 77/77 [==============================] - 68s 883ms/step - loss: -0.9164 - dice_metric: 0.9580 - jaccard_metric: 0.9239 - sensitivity_metric: 0.9565 - specificity_metric: 0.9565 - val_loss: -0.9278 - val_dice_metric: 0.9634 - val_jaccard_metric: 0.9345 - val_sensitivity_metric: 0.9674 - val_specificity_metric: 0.9674

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.96440, standard deviation: 0.05023
# Jaccard Index mean: 0.93539, standard deviation: 0.08546
# Sensitivity mean: 0.96709, standard deviation: 0.05349
# Specificity mean: 0.96709, standard deviation: 0.05349
