# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 3 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/1
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  98%|███████████████████████████████████████▏| 980M/0.98G [00:08<00:00, 200MB/s]
# 100%|███████████████████████████████████████| 0.98G/0.98G [00:08<00:00, 129MB/s]

# %%
config = {"Seg_model":"RFFSkipsUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458
# Original masks path, class 2: ./datasets/Seeds/Train/masks/class_2/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231
# Original masks path, class 2: ./datasets/Seeds/Valid/masks/class_2/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118
# Original masks path, class 2: ./datasets/Seeds/Test/masks/class_2/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_rff_skips
from seeds_segmentation.losses import DiceCoefficient

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = unet_rff_skips(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])

### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 119s 1s/step - loss: -0.2727 - dice_metric: 0.3042 - jaccard_metric: 0.2314 - sensitivity_metric: 0.4617 - specificity_metric: 0.8517 - precision_metric: 0.3938 - recall_metric: 0.4617 - mean_average_precision: 0.0976 - val_loss: -0.2687 - val_dice_metric: 0.4825 - val_jaccard_metric: 0.4742 - val_sensitivity_metric: 0.3299 - val_specificity_metric: 0.6667 - val_precision_metric: 0.3193 - val_recall_metric: 0.3299 - val_mean_average_precision: 0.4753
# Epoch 2/60
# 77/77 [==============================] - 69s 885ms/step - loss: -0.3582 - dice_metric: 0.4273 - jaccard_metric: 0.3583 - sensitivity_metric: 0.5745 - specificity_metric: 0.8946 - precision_metric: 0.4569 - recall_metric: 0.5745 - mean_average_precision: 0.2265 - val_loss: -0.3039 - val_dice_metric: 0.3246 - val_jaccard_metric: 0.3163 - val_sensitivity_metric: 0.3301 - val_specificity_metric: 0.6650 - val_precision_metric: 0.3194 - val_recall_metric: 0.3301 - val_mean_average_precision: 0.3175
# Epoch 3/60
# 77/77 [==============================] - 69s 893ms/step - loss: -0.3829 - dice_metric: 0.4581 - jaccard_metric: 0.3928 - sensitivity_metric: 0.5955 - specificity_metric: 0.9050 - precision_metric: 0.4829 - recall_metric: 0.5955 - mean_average_precision: 0.2705 - val_loss: -0.3284 - val_dice_metric: 0.3406 - val_jaccard_metric: 0.3258 - val_sensitivity_metric: 0.3440 - val_specificity_metric: 0.6908 - val_precision_metric: 0.4402 - val_recall_metric: 0.3440 - val_mean_average_precision: 0.3192
# Epoch 4/60
# 77/77 [==============================] - 70s 899ms/step - loss: -0.3985 - dice_metric: 0.4733 - jaccard_metric: 0.4103 - sensitivity_metric: 0.6056 - specificity_metric: 0.9094 - precision_metric: 0.4977 - recall_metric: 0.6056 - mean_average_precision: 0.2953 - val_loss: -0.4447 - val_dice_metric: 0.4805 - val_jaccard_metric: 0.4230 - val_sensitivity_metric: 0.4968 - val_specificity_metric: 0.8727 - val_precision_metric: 0.5666 - val_recall_metric: 0.4968 - val_mean_average_precision: 0.3234
# Epoch 5/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.4116 - dice_metric: 0.4857 - jaccard_metric: 0.4242 - sensitivity_metric: 0.6135 - specificity_metric: 0.9129 - precision_metric: 0.5092 - recall_metric: 0.6135 - mean_average_precision: 0.3129 - val_loss: -0.4740 - val_dice_metric: 0.5012 - val_jaccard_metric: 0.4439 - val_sensitivity_metric: 0.5806 - val_specificity_metric: 0.9230 - val_precision_metric: 0.5500 - val_recall_metric: 0.5806 - val_mean_average_precision: 0.3470
# Epoch 6/60
# 77/77 [==============================] - 71s 914ms/step - loss: -0.4239 - dice_metric: 0.4962 - jaccard_metric: 0.4352 - sensitivity_metric: 0.6186 - specificity_metric: 0.9154 - precision_metric: 0.5192 - recall_metric: 0.6186 - mean_average_precision: 0.3264 - val_loss: -0.4683 - val_dice_metric: 0.4908 - val_jaccard_metric: 0.4359 - val_sensitivity_metric: 0.5893 - val_specificity_metric: 0.9143 - val_precision_metric: 0.5300 - val_recall_metric: 0.5893 - val_mean_average_precision: 0.3445
# Epoch 7/60
# 77/77 [==============================] - 71s 920ms/step - loss: -0.4348 - dice_metric: 0.5048 - jaccard_metric: 0.4442 - sensitivity_metric: 0.6238 - specificity_metric: 0.9179 - precision_metric: 0.5265 - recall_metric: 0.6238 - mean_average_precision: 0.3385 - val_loss: -0.4762 - val_dice_metric: 0.4975 - val_jaccard_metric: 0.4445 - val_sensitivity_metric: 0.5954 - val_specificity_metric: 0.9156 - val_precision_metric: 0.5303 - val_recall_metric: 0.5954 - val_mean_average_precision: 0.3571
# Epoch 8/60
# 77/77 [==============================] - 71s 922ms/step - loss: -0.4457 - dice_metric: 0.5139 - jaccard_metric: 0.4534 - sensitivity_metric: 0.6286 - specificity_metric: 0.9211 - precision_metric: 0.5345 - recall_metric: 0.6286 - mean_average_precision: 0.3500 - val_loss: -0.4692 - val_dice_metric: 0.4890 - val_jaccard_metric: 0.4340 - val_sensitivity_metric: 0.5754 - val_specificity_metric: 0.9103 - val_precision_metric: 0.5216 - val_recall_metric: 0.5754 - val_mean_average_precision: 0.3436
# Epoch 9/60
# 77/77 [==============================] - 74s 956ms/step - loss: -0.4565 - dice_metric: 0.5232 - jaccard_metric: 0.4622 - sensitivity_metric: 0.6369 - specificity_metric: 0.9238 - precision_metric: 0.5423 - recall_metric: 0.6369 - mean_average_precision: 0.3605 - val_loss: -0.4584 - val_dice_metric: 0.4767 - val_jaccard_metric: 0.4196 - val_sensitivity_metric: 0.5751 - val_specificity_metric: 0.9046 - val_precision_metric: 0.5125 - val_recall_metric: 0.5751 - val_mean_average_precision: 0.3291
# Epoch 10/60
# 77/77 [==============================] - 71s 911ms/step - loss: -0.4680 - dice_metric: 0.5335 - jaccard_metric: 0.4715 - sensitivity_metric: 0.6491 - specificity_metric: 0.9264 - precision_metric: 0.5513 - recall_metric: 0.6491 - mean_average_precision: 0.3715 - val_loss: -0.4759 - val_dice_metric: 0.4992 - val_jaccard_metric: 0.4447 - val_sensitivity_metric: 0.5840 - val_specificity_metric: 0.9093 - val_precision_metric: 0.5386 - val_recall_metric: 0.5840 - val_mean_average_precision: 0.3660
# Epoch 11/60
# 77/77 [==============================] - 71s 910ms/step - loss: -0.4799 - dice_metric: 0.5442 - jaccard_metric: 0.4813 - sensitivity_metric: 0.6627 - specificity_metric: 0.9293 - precision_metric: 0.5605 - recall_metric: 0.6627 - mean_average_precision: 0.3828 - val_loss: -0.4770 - val_dice_metric: 0.4978 - val_jaccard_metric: 0.4446 - val_sensitivity_metric: 0.5853 - val_specificity_metric: 0.9059 - val_precision_metric: 0.5438 - val_recall_metric: 0.5853 - val_mean_average_precision: 0.3674
# Epoch 12/60
# 77/77 [==============================] - 72s 931ms/step - loss: -0.4911 - dice_metric: 0.5542 - jaccard_metric: 0.4907 - sensitivity_metric: 0.6735 - specificity_metric: 0.9312 - precision_metric: 0.5692 - recall_metric: 0.6735 - mean_average_precision: 0.3930 - val_loss: -0.4940 - val_dice_metric: 0.5133 - val_jaccard_metric: 0.4594 - val_sensitivity_metric: 0.6002 - val_specificity_metric: 0.9126 - val_precision_metric: 0.5525 - val_recall_metric: 0.6002 - val_mean_average_precision: 0.3802
# Epoch 13/60
# 77/77 [==============================] - 73s 947ms/step - loss: -0.5014 - dice_metric: 0.5630 - jaccard_metric: 0.4987 - sensitivity_metric: 0.6826 - specificity_metric: 0.9331 - precision_metric: 0.5766 - recall_metric: 0.6826 - mean_average_precision: 0.3998 - val_loss: -0.5057 - val_dice_metric: 0.5249 - val_jaccard_metric: 0.4707 - val_sensitivity_metric: 0.6072 - val_specificity_metric: 0.9162 - val_precision_metric: 0.5622 - val_recall_metric: 0.6072 - val_mean_average_precision: 0.3917
# Epoch 14/60
# 77/77 [==============================] - 69s 887ms/step - loss: -0.5112 - dice_metric: 0.5701 - jaccard_metric: 0.5050 - sensitivity_metric: 0.6887 - specificity_metric: 0.9341 - precision_metric: 0.5833 - recall_metric: 0.6887 - mean_average_precision: 0.4048 - val_loss: -0.5155 - val_dice_metric: 0.5353 - val_jaccard_metric: 0.4803 - val_sensitivity_metric: 0.6208 - val_specificity_metric: 0.9199 - val_precision_metric: 0.5667 - val_recall_metric: 0.6208 - val_mean_average_precision: 0.3979
# Epoch 15/60
# 77/77 [==============================] - 70s 900ms/step - loss: -0.5208 - dice_metric: 0.5779 - jaccard_metric: 0.5123 - sensitivity_metric: 0.6964 - specificity_metric: 0.9357 - precision_metric: 0.5898 - recall_metric: 0.6964 - mean_average_precision: 0.4104 - val_loss: -0.5191 - val_dice_metric: 0.5385 - val_jaccard_metric: 0.4807 - val_sensitivity_metric: 0.6281 - val_specificity_metric: 0.9192 - val_precision_metric: 0.5731 - val_recall_metric: 0.6281 - val_mean_average_precision: 0.3921
# Epoch 16/60
# 77/77 [==============================] - 73s 940ms/step - loss: -0.5292 - dice_metric: 0.5843 - jaccard_metric: 0.5182 - sensitivity_metric: 0.7011 - specificity_metric: 0.9368 - precision_metric: 0.5949 - recall_metric: 0.7011 - mean_average_precision: 0.4146 - val_loss: -0.5305 - val_dice_metric: 0.5490 - val_jaccard_metric: 0.4918 - val_sensitivity_metric: 0.6449 - val_specificity_metric: 0.9195 - val_precision_metric: 0.5881 - val_recall_metric: 0.6449 - val_mean_average_precision: 0.4039
# Epoch 17/60
# 77/77 [==============================] - 69s 887ms/step - loss: -0.5378 - dice_metric: 0.5909 - jaccard_metric: 0.5242 - sensitivity_metric: 0.7066 - specificity_metric: 0.9379 - precision_metric: 0.6003 - recall_metric: 0.7066 - mean_average_precision: 0.4183 - val_loss: -0.5443 - val_dice_metric: 0.5639 - val_jaccard_metric: 0.5061 - val_sensitivity_metric: 0.6552 - val_specificity_metric: 0.9282 - val_precision_metric: 0.5974 - val_recall_metric: 0.6552 - val_mean_average_precision: 0.4122
# Epoch 18/60
# 77/77 [==============================] - 72s 938ms/step - loss: -0.5472 - dice_metric: 0.5986 - jaccard_metric: 0.5318 - sensitivity_metric: 0.7132 - specificity_metric: 0.9392 - precision_metric: 0.6066 - recall_metric: 0.7132 - mean_average_precision: 0.4247 - val_loss: -0.5503 - val_dice_metric: 0.5716 - val_jaccard_metric: 0.5135 - val_sensitivity_metric: 0.6687 - val_specificity_metric: 0.9307 - val_precision_metric: 0.6019 - val_recall_metric: 0.6687 - val_mean_average_precision: 0.4176
# Epoch 19/60
# 77/77 [==============================] - 72s 933ms/step - loss: -0.5565 - dice_metric: 0.6066 - jaccard_metric: 0.5397 - sensitivity_metric: 0.7203 - specificity_metric: 0.9400 - precision_metric: 0.6131 - recall_metric: 0.7203 - mean_average_precision: 0.4311 - val_loss: -0.5537 - val_dice_metric: 0.5723 - val_jaccard_metric: 0.5146 - val_sensitivity_metric: 0.6612 - val_specificity_metric: 0.9304 - val_precision_metric: 0.6027 - val_recall_metric: 0.6612 - val_mean_average_precision: 0.4166
# Epoch 20/60
# 77/77 [==============================] - 70s 908ms/step - loss: -0.5642 - dice_metric: 0.6128 - jaccard_metric: 0.5457 - sensitivity_metric: 0.7228 - specificity_metric: 0.9403 - precision_metric: 0.6182 - recall_metric: 0.7228 - mean_average_precision: 0.4346 - val_loss: -0.5623 - val_dice_metric: 0.5818 - val_jaccard_metric: 0.5231 - val_sensitivity_metric: 0.6700 - val_specificity_metric: 0.9347 - val_precision_metric: 0.6044 - val_recall_metric: 0.6700 - val_mean_average_precision: 0.4208
# Epoch 21/60
# 77/77 [==============================] - 70s 902ms/step - loss: -0.5703 - dice_metric: 0.6170 - jaccard_metric: 0.5495 - sensitivity_metric: 0.7227 - specificity_metric: 0.9401 - precision_metric: 0.6222 - recall_metric: 0.7227 - mean_average_precision: 0.4361 - val_loss: -0.5588 - val_dice_metric: 0.5776 - val_jaccard_metric: 0.5197 - val_sensitivity_metric: 0.6678 - val_specificity_metric: 0.9329 - val_precision_metric: 0.5987 - val_recall_metric: 0.6678 - val_mean_average_precision: 0.4184
# Epoch 22/60
# 77/77 [==============================] - 72s 934ms/step - loss: -0.5777 - dice_metric: 0.6240 - jaccard_metric: 0.5560 - sensitivity_metric: 0.7277 - specificity_metric: 0.9405 - precision_metric: 0.6274 - recall_metric: 0.7277 - mean_average_precision: 0.4401 - val_loss: -0.5737 - val_dice_metric: 0.5915 - val_jaccard_metric: 0.5326 - val_sensitivity_metric: 0.6859 - val_specificity_metric: 0.9373 - val_precision_metric: 0.6059 - val_recall_metric: 0.6859 - val_mean_average_precision: 0.4250
# Epoch 23/60
# 77/77 [==============================] - 70s 904ms/step - loss: -0.5846 - dice_metric: 0.6286 - jaccard_metric: 0.5609 - sensitivity_metric: 0.7282 - specificity_metric: 0.9404 - precision_metric: 0.6316 - recall_metric: 0.7282 - mean_average_precision: 0.4443 - val_loss: -0.5708 - val_dice_metric: 0.5872 - val_jaccard_metric: 0.5280 - val_sensitivity_metric: 0.6857 - val_specificity_metric: 0.9304 - val_precision_metric: 0.6125 - val_recall_metric: 0.6857 - val_mean_average_precision: 0.4237
# Epoch 24/60
# 77/77 [==============================] - 70s 906ms/step - loss: -0.5927 - dice_metric: 0.6378 - jaccard_metric: 0.5700 - sensitivity_metric: 0.7363 - specificity_metric: 0.9434 - precision_metric: 0.6369 - recall_metric: 0.7363 - mean_average_precision: 0.4530 - val_loss: -0.5985 - val_dice_metric: 0.6228 - val_jaccard_metric: 0.5668 - val_sensitivity_metric: 0.6988 - val_specificity_metric: 0.9414 - val_precision_metric: 0.6344 - val_recall_metric: 0.6988 - val_mean_average_precision: 0.4724
# Epoch 25/60
# 77/77 [==============================] - 72s 926ms/step - loss: -0.5996 - dice_metric: 0.6427 - jaccard_metric: 0.5747 - sensitivity_metric: 0.7383 - specificity_metric: 0.9440 - precision_metric: 0.6412 - recall_metric: 0.7383 - mean_average_precision: 0.4566 - val_loss: -0.5993 - val_dice_metric: 0.6223 - val_jaccard_metric: 0.5668 - val_sensitivity_metric: 0.6937 - val_specificity_metric: 0.9412 - val_precision_metric: 0.6338 - val_recall_metric: 0.6937 - val_mean_average_precision: 0.4741
# Epoch 26/60
# 77/77 [==============================] - 70s 908ms/step - loss: -0.6069 - dice_metric: 0.6474 - jaccard_metric: 0.5796 - sensitivity_metric: 0.7414 - specificity_metric: 0.9442 - precision_metric: 0.6453 - recall_metric: 0.7414 - mean_average_precision: 0.4607 - val_loss: -0.6123 - val_dice_metric: 0.6362 - val_jaccard_metric: 0.5799 - val_sensitivity_metric: 0.7106 - val_specificity_metric: 0.9474 - val_precision_metric: 0.6455 - val_recall_metric: 0.7106 - val_mean_average_precision: 0.4840
# Epoch 27/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.6142 - dice_metric: 0.6532 - jaccard_metric: 0.5857 - sensitivity_metric: 0.7462 - specificity_metric: 0.9445 - precision_metric: 0.6501 - recall_metric: 0.7462 - mean_average_precision: 0.4672 - val_loss: -0.6144 - val_dice_metric: 0.6370 - val_jaccard_metric: 0.5809 - val_sensitivity_metric: 0.7095 - val_specificity_metric: 0.9480 - val_precision_metric: 0.6429 - val_recall_metric: 0.7095 - val_mean_average_precision: 0.4829
# Epoch 28/60
# 77/77 [==============================] - 71s 918ms/step - loss: -0.6207 - dice_metric: 0.6581 - jaccard_metric: 0.5906 - sensitivity_metric: 0.7495 - specificity_metric: 0.9454 - precision_metric: 0.6541 - recall_metric: 0.7495 - mean_average_precision: 0.4719 - val_loss: -0.6199 - val_dice_metric: 0.6411 - val_jaccard_metric: 0.5850 - val_sensitivity_metric: 0.7150 - val_specificity_metric: 0.9486 - val_precision_metric: 0.6459 - val_recall_metric: 0.7150 - val_mean_average_precision: 0.4862
# Epoch 29/60
# 77/77 [==============================] - 72s 927ms/step - loss: -0.6267 - dice_metric: 0.6622 - jaccard_metric: 0.5949 - sensitivity_metric: 0.7525 - specificity_metric: 0.9460 - precision_metric: 0.6574 - recall_metric: 0.7525 - mean_average_precision: 0.4765 - val_loss: -0.6179 - val_dice_metric: 0.6374 - val_jaccard_metric: 0.5808 - val_sensitivity_metric: 0.7146 - val_specificity_metric: 0.9485 - val_precision_metric: 0.6399 - val_recall_metric: 0.7146 - val_mean_average_precision: 0.4824
# Epoch 30/60
# 77/77 [==============================] - 71s 919ms/step - loss: -0.6312 - dice_metric: 0.6648 - jaccard_metric: 0.5975 - sensitivity_metric: 0.7536 - specificity_metric: 0.9464 - precision_metric: 0.6595 - recall_metric: 0.7536 - mean_average_precision: 0.4783 - val_loss: -0.6214 - val_dice_metric: 0.6409 - val_jaccard_metric: 0.5838 - val_sensitivity_metric: 0.7177 - val_specificity_metric: 0.9486 - val_precision_metric: 0.6458 - val_recall_metric: 0.7177 - val_mean_average_precision: 0.4837
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 69s 897ms/step - loss: -0.6369 - dice_metric: 0.6697 - jaccard_metric: 0.6030 - sensitivity_metric: 0.7576 - specificity_metric: 0.9470 - precision_metric: 0.6636 - recall_metric: 0.7576 - mean_average_precision: 0.4850 - val_loss: -0.6223 - val_dice_metric: 0.6463 - val_jaccard_metric: 0.5896 - val_sensitivity_metric: 0.7159 - val_specificity_metric: 0.9466 - val_precision_metric: 0.6557 - val_recall_metric: 0.7159 - val_mean_average_precision: 0.4891
# Epoch 32/60
# 77/77 [==============================] - 72s 921ms/step - loss: -0.6397 - dice_metric: 0.6732 - jaccard_metric: 0.6067 - sensitivity_metric: 0.7615 - specificity_metric: 0.9477 - precision_metric: 0.6662 - recall_metric: 0.7615 - mean_average_precision: 0.4884 - val_loss: -0.6210 - val_dice_metric: 0.6470 - val_jaccard_metric: 0.5903 - val_sensitivity_metric: 0.7168 - val_specificity_metric: 0.9468 - val_precision_metric: 0.6560 - val_recall_metric: 0.7168 - val_mean_average_precision: 0.4889
# Epoch 33/60
# 77/77 [==============================] - 72s 927ms/step - loss: -0.6413 - dice_metric: 0.6749 - jaccard_metric: 0.6085 - sensitivity_metric: 0.7629 - specificity_metric: 0.9478 - precision_metric: 0.6678 - recall_metric: 0.7629 - mean_average_precision: 0.4902 - val_loss: -0.6201 - val_dice_metric: 0.6470 - val_jaccard_metric: 0.5904 - val_sensitivity_metric: 0.7171 - val_specificity_metric: 0.9468 - val_precision_metric: 0.6559 - val_recall_metric: 0.7171 - val_mean_average_precision: 0.4901
# Epoch 34/60
# 77/77 [==============================] - 71s 917ms/step - loss: -0.6423 - dice_metric: 0.6758 - jaccard_metric: 0.6095 - sensitivity_metric: 0.7637 - specificity_metric: 0.9478 - precision_metric: 0.6687 - recall_metric: 0.7637 - mean_average_precision: 0.4913 - val_loss: -0.6196 - val_dice_metric: 0.6468 - val_jaccard_metric: 0.5903 - val_sensitivity_metric: 0.7172 - val_specificity_metric: 0.9465 - val_precision_metric: 0.6560 - val_recall_metric: 0.7172 - val_mean_average_precision: 0.4905
# Epoch 35/60
# 77/77 [==============================] - 70s 903ms/step - loss: -0.6433 - dice_metric: 0.6765 - jaccard_metric: 0.6103 - sensitivity_metric: 0.7644 - specificity_metric: 0.9477 - precision_metric: 0.6695 - recall_metric: 0.7644 - mean_average_precision: 0.4922 - val_loss: -0.6198 - val_dice_metric: 0.6469 - val_jaccard_metric: 0.5905 - val_sensitivity_metric: 0.7174 - val_specificity_metric: 0.9465 - val_precision_metric: 0.6562 - val_recall_metric: 0.7174 - val_mean_average_precision: 0.4902
# Epoch 36/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.6442 - dice_metric: 0.6771 - jaccard_metric: 0.6110 - sensitivity_metric: 0.7650 - specificity_metric: 0.9477 - precision_metric: 0.6701 - recall_metric: 0.7650 - mean_average_precision: 0.4931 - val_loss: -0.6200 - val_dice_metric: 0.6469 - val_jaccard_metric: 0.5905 - val_sensitivity_metric: 0.7175 - val_specificity_metric: 0.9464 - val_precision_metric: 0.6561 - val_recall_metric: 0.7175 - val_mean_average_precision: 0.4905
# Epoch 37/60
# 77/77 [==============================] - 71s 920ms/step - loss: -0.6450 - dice_metric: 0.6777 - jaccard_metric: 0.6117 - sensitivity_metric: 0.7655 - specificity_metric: 0.9477 - precision_metric: 0.6707 - recall_metric: 0.7655 - mean_average_precision: 0.4937 - val_loss: -0.6203 - val_dice_metric: 0.6471 - val_jaccard_metric: 0.5907 - val_sensitivity_metric: 0.7178 - val_specificity_metric: 0.9464 - val_precision_metric: 0.6562 - val_recall_metric: 0.7178 - val_mean_average_precision: 0.4913
# Epoch 38/60
# 77/77 [==============================] - 71s 924ms/step - loss: -0.6458 - dice_metric: 0.6783 - jaccard_metric: 0.6123 - sensitivity_metric: 0.7660 - specificity_metric: 0.9477 - precision_metric: 0.6713 - recall_metric: 0.7660 - mean_average_precision: 0.4944 - val_loss: -0.6208 - val_dice_metric: 0.6473 - val_jaccard_metric: 0.5910 - val_sensitivity_metric: 0.7178 - val_specificity_metric: 0.9465 - val_precision_metric: 0.6561 - val_recall_metric: 0.7178 - val_mean_average_precision: 0.4920
# Epoch 39/60
# 77/77 [==============================] - 71s 918ms/step - loss: -0.6465 - dice_metric: 0.6789 - jaccard_metric: 0.6129 - sensitivity_metric: 0.7666 - specificity_metric: 0.9478 - precision_metric: 0.6717 - recall_metric: 0.7666 - mean_average_precision: 0.4951 - val_loss: -0.6211 - val_dice_metric: 0.6474 - val_jaccard_metric: 0.5910 - val_sensitivity_metric: 0.7183 - val_specificity_metric: 0.9464 - val_precision_metric: 0.6563 - val_recall_metric: 0.7183 - val_mean_average_precision: 0.4918
# Epoch 40/60
# 77/77 [==============================] - 71s 911ms/step - loss: -0.6472 - dice_metric: 0.6793 - jaccard_metric: 0.6134 - sensitivity_metric: 0.7670 - specificity_metric: 0.9478 - precision_metric: 0.6722 - recall_metric: 0.7670 - mean_average_precision: 0.4957 - val_loss: -0.6219 - val_dice_metric: 0.6478 - val_jaccard_metric: 0.5915 - val_sensitivity_metric: 0.7189 - val_specificity_metric: 0.9467 - val_precision_metric: 0.6564 - val_recall_metric: 0.7189 - val_mean_average_precision: 0.4909
# Epoch 41/60
# 77/77 [==============================] - 69s 888ms/step - loss: -0.6479 - dice_metric: 0.6798 - jaccard_metric: 0.6139 - sensitivity_metric: 0.7675 - specificity_metric: 0.9478 - precision_metric: 0.6727 - recall_metric: 0.7675 - mean_average_precision: 0.4964 - val_loss: -0.6221 - val_dice_metric: 0.6478 - val_jaccard_metric: 0.5915 - val_sensitivity_metric: 0.7189 - val_specificity_metric: 0.9466 - val_precision_metric: 0.6565 - val_recall_metric: 0.7189 - val_mean_average_precision: 0.4915
# Epoch 42/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.6486 - dice_metric: 0.6802 - jaccard_metric: 0.6144 - sensitivity_metric: 0.7678 - specificity_metric: 0.9478 - precision_metric: 0.6731 - recall_metric: 0.7678 - mean_average_precision: 0.4968 - val_loss: -0.6227 - val_dice_metric: 0.6480 - val_jaccard_metric: 0.5918 - val_sensitivity_metric: 0.7193 - val_specificity_metric: 0.9467 - val_precision_metric: 0.6564 - val_recall_metric: 0.7193 - val_mean_average_precision: 0.4917
# Epoch 43/60
# 77/77 [==============================] - 72s 925ms/step - loss: -0.6493 - dice_metric: 0.6807 - jaccard_metric: 0.6149 - sensitivity_metric: 0.7682 - specificity_metric: 0.9478 - precision_metric: 0.6735 - recall_metric: 0.7682 - mean_average_precision: 0.4973 - val_loss: -0.6230 - val_dice_metric: 0.6481 - val_jaccard_metric: 0.5918 - val_sensitivity_metric: 0.7195 - val_specificity_metric: 0.9467 - val_precision_metric: 0.6565 - val_recall_metric: 0.7195 - val_mean_average_precision: 0.4918
# Epoch 44/60
# 77/77 [==============================] - 73s 941ms/step - loss: -0.6499 - dice_metric: 0.6811 - jaccard_metric: 0.6154 - sensitivity_metric: 0.7687 - specificity_metric: 0.9478 - precision_metric: 0.6739 - recall_metric: 0.7687 - mean_average_precision: 0.4978 - val_loss: -0.6236 - val_dice_metric: 0.6484 - val_jaccard_metric: 0.5921 - val_sensitivity_metric: 0.7196 - val_specificity_metric: 0.9468 - val_precision_metric: 0.6567 - val_recall_metric: 0.7196 - val_mean_average_precision: 0.4921
# Epoch 45/60
# 77/77 [==============================] - 72s 925ms/step - loss: -0.6506 - dice_metric: 0.6815 - jaccard_metric: 0.6158 - sensitivity_metric: 0.7691 - specificity_metric: 0.9478 - precision_metric: 0.6743 - recall_metric: 0.7691 - mean_average_precision: 0.4983 - val_loss: -0.6240 - val_dice_metric: 0.6485 - val_jaccard_metric: 0.5923 - val_sensitivity_metric: 0.7197 - val_specificity_metric: 0.9469 - val_precision_metric: 0.6569 - val_recall_metric: 0.7197 - val_mean_average_precision: 0.4921
# Epoch 46/60
# 77/77 [==============================] - 73s 938ms/step - loss: -0.6512 - dice_metric: 0.6820 - jaccard_metric: 0.6163 - sensitivity_metric: 0.7695 - specificity_metric: 0.9478 - precision_metric: 0.6747 - recall_metric: 0.7695 - mean_average_precision: 0.4986 - val_loss: -0.6245 - val_dice_metric: 0.6489 - val_jaccard_metric: 0.5926 - val_sensitivity_metric: 0.7199 - val_specificity_metric: 0.9471 - val_precision_metric: 0.6571 - val_recall_metric: 0.7199 - val_mean_average_precision: 0.4923
# Epoch 47/60
# 77/77 [==============================] - 71s 917ms/step - loss: -0.6519 - dice_metric: 0.6824 - jaccard_metric: 0.6167 - sensitivity_metric: 0.7699 - specificity_metric: 0.9479 - precision_metric: 0.6751 - recall_metric: 0.7699 - mean_average_precision: 0.4993 - val_loss: -0.6250 - val_dice_metric: 0.6491 - val_jaccard_metric: 0.5929 - val_sensitivity_metric: 0.7199 - val_specificity_metric: 0.9471 - val_precision_metric: 0.6571 - val_recall_metric: 0.7199 - val_mean_average_precision: 0.4927
# Epoch 48/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.6525 - dice_metric: 0.6829 - jaccard_metric: 0.6172 - sensitivity_metric: 0.7704 - specificity_metric: 0.9479 - precision_metric: 0.6755 - recall_metric: 0.7704 - mean_average_precision: 0.4997 - val_loss: -0.6251 - val_dice_metric: 0.6489 - val_jaccard_metric: 0.5927 - val_sensitivity_metric: 0.7197 - val_specificity_metric: 0.9469 - val_precision_metric: 0.6573 - val_recall_metric: 0.7197 - val_mean_average_precision: 0.4928
# Epoch 49/60
# 77/77 [==============================] - 69s 889ms/step - loss: -0.6532 - dice_metric: 0.6833 - jaccard_metric: 0.6177 - sensitivity_metric: 0.7708 - specificity_metric: 0.9480 - precision_metric: 0.6759 - recall_metric: 0.7708 - mean_average_precision: 0.5003 - val_loss: -0.6255 - val_dice_metric: 0.6492 - val_jaccard_metric: 0.5930 - val_sensitivity_metric: 0.7202 - val_specificity_metric: 0.9471 - val_precision_metric: 0.6572 - val_recall_metric: 0.7202 - val_mean_average_precision: 0.4928
# Epoch 50/60
# 77/77 [==============================] - 70s 898ms/step - loss: -0.6538 - dice_metric: 0.6837 - jaccard_metric: 0.6181 - sensitivity_metric: 0.7713 - specificity_metric: 0.9480 - precision_metric: 0.6762 - recall_metric: 0.7713 - mean_average_precision: 0.5007 - val_loss: -0.6260 - val_dice_metric: 0.6494 - val_jaccard_metric: 0.5933 - val_sensitivity_metric: 0.7203 - val_specificity_metric: 0.9472 - val_precision_metric: 0.6575 - val_recall_metric: 0.7203 - val_mean_average_precision: 0.4935
# Epoch 51/60
# 77/77 [==============================] - 71s 915ms/step - loss: -0.6545 - dice_metric: 0.6842 - jaccard_metric: 0.6186 - sensitivity_metric: 0.7717 - specificity_metric: 0.9480 - precision_metric: 0.6767 - recall_metric: 0.7717 - mean_average_precision: 0.5013 - val_loss: -0.6262 - val_dice_metric: 0.6495 - val_jaccard_metric: 0.5933 - val_sensitivity_metric: 0.7205 - val_specificity_metric: 0.9471 - val_precision_metric: 0.6574 - val_recall_metric: 0.7205 - val_mean_average_precision: 0.4932
# Epoch 52/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.6551 - dice_metric: 0.6845 - jaccard_metric: 0.6190 - sensitivity_metric: 0.7720 - specificity_metric: 0.9480 - precision_metric: 0.6770 - recall_metric: 0.7720 - mean_average_precision: 0.5014 - val_loss: -0.6269 - val_dice_metric: 0.6500 - val_jaccard_metric: 0.5939 - val_sensitivity_metric: 0.7210 - val_specificity_metric: 0.9473 - val_precision_metric: 0.6578 - val_recall_metric: 0.7210 - val_mean_average_precision: 0.4936
# Epoch 53/60
# 77/77 [==============================] - 71s 922ms/step - loss: -0.6558 - dice_metric: 0.6850 - jaccard_metric: 0.6194 - sensitivity_metric: 0.7725 - specificity_metric: 0.9481 - precision_metric: 0.6774 - recall_metric: 0.7725 - mean_average_precision: 0.5021 - val_loss: -0.6271 - val_dice_metric: 0.6500 - val_jaccard_metric: 0.5939 - val_sensitivity_metric: 0.7211 - val_specificity_metric: 0.9472 - val_precision_metric: 0.6578 - val_recall_metric: 0.7211 - val_mean_average_precision: 0.4940
# Epoch 54/60
# 77/77 [==============================] - 71s 921ms/step - loss: -0.6564 - dice_metric: 0.6854 - jaccard_metric: 0.6199 - sensitivity_metric: 0.7730 - specificity_metric: 0.9481 - precision_metric: 0.6778 - recall_metric: 0.7730 - mean_average_precision: 0.5025 - val_loss: -0.6275 - val_dice_metric: 0.6502 - val_jaccard_metric: 0.5941 - val_sensitivity_metric: 0.7214 - val_specificity_metric: 0.9473 - val_precision_metric: 0.6579 - val_recall_metric: 0.7214 - val_mean_average_precision: 0.4939
# Epoch 55/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.6570 - dice_metric: 0.6858 - jaccard_metric: 0.6203 - sensitivity_metric: 0.7732 - specificity_metric: 0.9481 - precision_metric: 0.6781 - recall_metric: 0.7732 - mean_average_precision: 0.5030 - val_loss: -0.6279 - val_dice_metric: 0.6504 - val_jaccard_metric: 0.5943 - val_sensitivity_metric: 0.7212 - val_specificity_metric: 0.9473 - val_precision_metric: 0.6581 - val_recall_metric: 0.7212 - val_mean_average_precision: 0.4943
# Epoch 56/60
# 77/77 [==============================] - 72s 931ms/step - loss: -0.6576 - dice_metric: 0.6862 - jaccard_metric: 0.6207 - sensitivity_metric: 0.7737 - specificity_metric: 0.9482 - precision_metric: 0.6785 - recall_metric: 0.7737 - mean_average_precision: 0.5035 - val_loss: -0.6285 - val_dice_metric: 0.6506 - val_jaccard_metric: 0.5945 - val_sensitivity_metric: 0.7214 - val_specificity_metric: 0.9474 - val_precision_metric: 0.6583 - val_recall_metric: 0.7214 - val_mean_average_precision: 0.4943
# Epoch 57/60
# 77/77 [==============================] - 71s 919ms/step - loss: -0.6583 - dice_metric: 0.6867 - jaccard_metric: 0.6212 - sensitivity_metric: 0.7741 - specificity_metric: 0.9482 - precision_metric: 0.6789 - recall_metric: 0.7741 - mean_average_precision: 0.5039 - val_loss: -0.6287 - val_dice_metric: 0.6507 - val_jaccard_metric: 0.5947 - val_sensitivity_metric: 0.7215 - val_specificity_metric: 0.9473 - val_precision_metric: 0.6584 - val_recall_metric: 0.7215 - val_mean_average_precision: 0.4945
# Epoch 58/60
# 77/77 [==============================] - 74s 956ms/step - loss: -0.6589 - dice_metric: 0.6871 - jaccard_metric: 0.6217 - sensitivity_metric: 0.7745 - specificity_metric: 0.9483 - precision_metric: 0.6792 - recall_metric: 0.7745 - mean_average_precision: 0.5046 - val_loss: -0.6290 - val_dice_metric: 0.6508 - val_jaccard_metric: 0.5947 - val_sensitivity_metric: 0.7218 - val_specificity_metric: 0.9473 - val_precision_metric: 0.6585 - val_recall_metric: 0.7218 - val_mean_average_precision: 0.4947
# Epoch 59/60
# 77/77 [==============================] - 72s 922ms/step - loss: -0.6595 - dice_metric: 0.6875 - jaccard_metric: 0.6220 - sensitivity_metric: 0.7748 - specificity_metric: 0.9483 - precision_metric: 0.6796 - recall_metric: 0.7748 - mean_average_precision: 0.5049 - val_loss: -0.6294 - val_dice_metric: 0.6510 - val_jaccard_metric: 0.5949 - val_sensitivity_metric: 0.7218 - val_specificity_metric: 0.9475 - val_precision_metric: 0.6586 - val_recall_metric: 0.7218 - val_mean_average_precision: 0.4949
# Epoch 60/60
# 77/77 [==============================] - 74s 957ms/step - loss: -0.6601 - dice_metric: 0.6879 - jaccard_metric: 0.6225 - sensitivity_metric: 0.7752 - specificity_metric: 0.9483 - precision_metric: 0.6799 - recall_metric: 0.7752 - mean_average_precision: 0.5054 - val_loss: -0.6300 - val_dice_metric: 0.6514 - val_jaccard_metric: 0.5953 - val_sensitivity_metric: 0.7220 - val_specificity_metric: 0.9476 - val_precision_metric: 0.6589 - val_recall_metric: 0.7220 - val_mean_average_precision: 0.4953

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 3)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.66067, std: 0.37625
# Jaccard Index mean: 0.59921, std: 0.38232
# Sensitivity mean: 0.74496, std: 0.34325
# Specificity mean: 0.94740, std: 0.13637
# Precision mean: 0.66698, std: 0.39341
# Recall mean: 0.74496, std: 0.34325
# mAP@50 mean: 0.59887, std: 0.26239
# mAP@50-95 mean: 0.48842, std: 0.22001
