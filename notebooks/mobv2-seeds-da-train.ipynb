# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|███████████████████████████████████████▌| 986M/998M [00:08<00:00, 90.8MB/s]
# 100%|█████████████████████████████████████████| 998M/998M [00:08<00:00, 121MB/s]

# %%
config = {"Seg_model":"MobV2","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import mobilenetv2
from seeds_segmentation.losses import DiceCoefficient 

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP
    
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = mobilenetv2(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 110s 798ms/step - loss: -0.2488 - dice_metric: 0.5789 - jaccard_metric: 0.4838 - sensitivity_metric: 0.7661 - specificity_metric: 0.7661 - precision_metric: 0.6137 - recall_metric: 0.7661 - mean_average_precision: 0.3240 - val_loss: 0.0326 - val_dice_metric: 0.5064 - val_jaccard_metric: 0.4888 - val_sensitivity_metric: 0.5091 - val_specificity_metric: 0.5091 - val_precision_metric: 0.6585 - val_recall_metric: 0.5091 - val_mean_average_precision: 0.4816
# Epoch 2/60
# 77/77 [==============================] - 57s 731ms/step - loss: -0.5396 - dice_metric: 0.7931 - jaccard_metric: 0.7065 - sensitivity_metric: 0.8361 - specificity_metric: 0.8361 - precision_metric: 0.7719 - recall_metric: 0.8361 - mean_average_precision: 0.5400 - val_loss: 4.8622e-04 - val_dice_metric: 0.5210 - val_jaccard_metric: 0.4973 - val_sensitivity_metric: 0.5172 - val_specificity_metric: 0.5172 - val_precision_metric: 0.8167 - val_recall_metric: 0.5172 - val_mean_average_precision: 0.4820
# Epoch 3/60
# 77/77 [==============================] - 56s 720ms/step - loss: -0.6655 - dice_metric: 0.8582 - jaccard_metric: 0.7815 - sensitivity_metric: 0.8755 - specificity_metric: 0.8755 - precision_metric: 0.8495 - recall_metric: 0.8755 - mean_average_precision: 0.6298 - val_loss: 0.0402 - val_dice_metric: 0.4987 - val_jaccard_metric: 0.4843 - val_sensitivity_metric: 0.5048 - val_specificity_metric: 0.5048 - val_precision_metric: 0.6690 - val_recall_metric: 0.5048 - val_mean_average_precision: 0.4812
# Epoch 4/60
# 77/77 [==============================] - 57s 741ms/step - loss: -0.7196 - dice_metric: 0.8849 - jaccard_metric: 0.8153 - sensitivity_metric: 0.8939 - specificity_metric: 0.8939 - precision_metric: 0.8810 - recall_metric: 0.8939 - mean_average_precision: 0.6821 - val_loss: 0.0355 - val_dice_metric: 0.4999 - val_jaccard_metric: 0.4850 - val_sensitivity_metric: 0.5055 - val_specificity_metric: 0.5055 - val_precision_metric: 0.6813 - val_recall_metric: 0.5055 - val_mean_average_precision: 0.4812
# Epoch 5/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.7476 - dice_metric: 0.8981 - jaccard_metric: 0.8330 - sensitivity_metric: 0.9041 - specificity_metric: 0.9041 - precision_metric: 0.8964 - recall_metric: 0.9041 - mean_average_precision: 0.7118 - val_loss: 0.0183 - val_dice_metric: 0.5077 - val_jaccard_metric: 0.4894 - val_sensitivity_metric: 0.5097 - val_specificity_metric: 0.5097 - val_precision_metric: 0.7493 - val_recall_metric: 0.5097 - val_mean_average_precision: 0.4814
# Epoch 6/60
# 77/77 [==============================] - 58s 742ms/step - loss: -0.7621 - dice_metric: 0.9046 - jaccard_metric: 0.8418 - sensitivity_metric: 0.9098 - specificity_metric: 0.9098 - precision_metric: 0.9046 - recall_metric: 0.9098 - mean_average_precision: 0.7269 - val_loss: -0.0198 - val_dice_metric: 0.5258 - val_jaccard_metric: 0.5000 - val_sensitivity_metric: 0.5198 - val_specificity_metric: 0.5198 - val_precision_metric: 0.8176 - val_recall_metric: 0.5198 - val_mean_average_precision: 0.4822
# Epoch 7/60
# 77/77 [==============================] - 57s 739ms/step - loss: -0.7720 - dice_metric: 0.9089 - jaccard_metric: 0.8477 - sensitivity_metric: 0.9149 - specificity_metric: 0.9149 - precision_metric: 0.9085 - recall_metric: 0.9149 - mean_average_precision: 0.7376 - val_loss: -0.0405 - val_dice_metric: 0.5358 - val_jaccard_metric: 0.5056 - val_sensitivity_metric: 0.5252 - val_specificity_metric: 0.5252 - val_precision_metric: 0.8762 - val_recall_metric: 0.5252 - val_mean_average_precision: 0.4826
# Epoch 8/60
# 77/77 [==============================] - 58s 744ms/step - loss: -0.7860 - dice_metric: 0.9154 - jaccard_metric: 0.8571 - sensitivity_metric: 0.9188 - specificity_metric: 0.9188 - precision_metric: 0.9158 - recall_metric: 0.9188 - mean_average_precision: 0.7551 - val_loss: -0.1015 - val_dice_metric: 0.5662 - val_jaccard_metric: 0.5249 - val_sensitivity_metric: 0.5439 - val_specificity_metric: 0.5439 - val_precision_metric: 0.8939 - val_recall_metric: 0.5439 - val_mean_average_precision: 0.4857
# Epoch 9/60
# 77/77 [==============================] - 57s 738ms/step - loss: -0.7970 - dice_metric: 0.9204 - jaccard_metric: 0.8644 - sensitivity_metric: 0.9221 - specificity_metric: 0.9221 - precision_metric: 0.9213 - recall_metric: 0.9221 - mean_average_precision: 0.7675 - val_loss: -0.1372 - val_dice_metric: 0.5834 - val_jaccard_metric: 0.5365 - val_sensitivity_metric: 0.5550 - val_specificity_metric: 0.5550 - val_precision_metric: 0.9126 - val_recall_metric: 0.5550 - val_mean_average_precision: 0.4893
# Epoch 10/60
# 77/77 [==============================] - 56s 719ms/step - loss: -0.8050 - dice_metric: 0.9239 - jaccard_metric: 0.8695 - sensitivity_metric: 0.9248 - specificity_metric: 0.9248 - precision_metric: 0.9251 - recall_metric: 0.9248 - mean_average_precision: 0.7771 - val_loss: -0.2277 - val_dice_metric: 0.6274 - val_jaccard_metric: 0.5669 - val_sensitivity_metric: 0.5844 - val_specificity_metric: 0.5844 - val_precision_metric: 0.9475 - val_recall_metric: 0.5844 - val_mean_average_precision: 0.4920
# Epoch 11/60
# 77/77 [==============================] - 58s 744ms/step - loss: -0.8111 - dice_metric: 0.9264 - jaccard_metric: 0.8732 - sensitivity_metric: 0.9273 - specificity_metric: 0.9273 - precision_metric: 0.9276 - recall_metric: 0.9273 - mean_average_precision: 0.7847 - val_loss: -0.3163 - val_dice_metric: 0.6711 - val_jaccard_metric: 0.6006 - val_sensitivity_metric: 0.6174 - val_specificity_metric: 0.6174 - val_precision_metric: 0.9525 - val_recall_metric: 0.6174 - val_mean_average_precision: 0.4939
# Epoch 12/60
# 77/77 [==============================] - 57s 729ms/step - loss: -0.8159 - dice_metric: 0.9284 - jaccard_metric: 0.8762 - sensitivity_metric: 0.9292 - specificity_metric: 0.9292 - precision_metric: 0.9295 - recall_metric: 0.9292 - mean_average_precision: 0.7899 - val_loss: -0.3729 - val_dice_metric: 0.6993 - val_jaccard_metric: 0.6233 - val_sensitivity_metric: 0.6396 - val_specificity_metric: 0.6396 - val_precision_metric: 0.9544 - val_recall_metric: 0.6396 - val_mean_average_precision: 0.4945
# Epoch 13/60
# 77/77 [==============================] - 57s 740ms/step - loss: -0.8199 - dice_metric: 0.9300 - jaccard_metric: 0.8785 - sensitivity_metric: 0.9307 - specificity_metric: 0.9307 - precision_metric: 0.9310 - recall_metric: 0.9307 - mean_average_precision: 0.7939 - val_loss: -0.4616 - val_dice_metric: 0.7435 - val_jaccard_metric: 0.6610 - val_sensitivity_metric: 0.6771 - val_specificity_metric: 0.6771 - val_precision_metric: 0.9568 - val_recall_metric: 0.6771 - val_mean_average_precision: 0.5088
# Epoch 14/60
# 77/77 [==============================] - 57s 729ms/step - loss: -0.8227 - dice_metric: 0.9309 - jaccard_metric: 0.8799 - sensitivity_metric: 0.9318 - specificity_metric: 0.9318 - precision_metric: 0.9320 - recall_metric: 0.9318 - mean_average_precision: 0.7962 - val_loss: -0.5033 - val_dice_metric: 0.7651 - val_jaccard_metric: 0.6803 - val_sensitivity_metric: 0.6964 - val_specificity_metric: 0.6964 - val_precision_metric: 0.9605 - val_recall_metric: 0.6964 - val_mean_average_precision: 0.5188
# Epoch 15/60
# 77/77 [==============================] - 57s 734ms/step - loss: -0.8229 - dice_metric: 0.9306 - jaccard_metric: 0.8793 - sensitivity_metric: 0.9321 - specificity_metric: 0.9321 - precision_metric: 0.9312 - recall_metric: 0.9321 - mean_average_precision: 0.7954 - val_loss: -0.5394 - val_dice_metric: 0.7833 - val_jaccard_metric: 0.6981 - val_sensitivity_metric: 0.7138 - val_specificity_metric: 0.7138 - val_precision_metric: 0.9633 - val_recall_metric: 0.7138 - val_mean_average_precision: 0.5340
# Epoch 16/60
# 77/77 [==============================] - 57s 732ms/step - loss: -0.8198 - dice_metric: 0.9285 - jaccard_metric: 0.8763 - sensitivity_metric: 0.9317 - specificity_metric: 0.9317 - precision_metric: 0.9293 - recall_metric: 0.9317 - mean_average_precision: 0.7896 - val_loss: -0.7152 - val_dice_metric: 0.8734 - val_jaccard_metric: 0.7998 - val_sensitivity_metric: 0.8260 - val_specificity_metric: 0.8260 - val_precision_metric: 0.9501 - val_recall_metric: 0.8260 - val_mean_average_precision: 0.6495
# Epoch 17/60
# 77/77 [==============================] - 58s 741ms/step - loss: -0.8228 - dice_metric: 0.9298 - jaccard_metric: 0.8782 - sensitivity_metric: 0.9317 - specificity_metric: 0.9317 - precision_metric: 0.9317 - recall_metric: 0.9317 - mean_average_precision: 0.7929 - val_loss: -0.7646 - val_dice_metric: 0.8989 - val_jaccard_metric: 0.8338 - val_sensitivity_metric: 0.8761 - val_specificity_metric: 0.8761 - val_precision_metric: 0.9337 - val_recall_metric: 0.8761 - val_mean_average_precision: 0.7099
# Epoch 18/60
# 77/77 [==============================] - 57s 742ms/step - loss: -0.8234 - dice_metric: 0.9297 - jaccard_metric: 0.8780 - sensitivity_metric: 0.9328 - specificity_metric: 0.9328 - precision_metric: 0.9305 - recall_metric: 0.9328 - mean_average_precision: 0.7932 - val_loss: -0.7654 - val_dice_metric: 0.8991 - val_jaccard_metric: 0.8343 - val_sensitivity_metric: 0.8720 - val_specificity_metric: 0.8720 - val_precision_metric: 0.9398 - val_recall_metric: 0.8720 - val_mean_average_precision: 0.7097
# Epoch 19/60
# 77/77 [==============================] - 56s 727ms/step - loss: -0.8299 - dice_metric: 0.9328 - jaccard_metric: 0.8826 - sensitivity_metric: 0.9343 - specificity_metric: 0.9343 - precision_metric: 0.9341 - recall_metric: 0.9343 - mean_average_precision: 0.8014 - val_loss: -0.7832 - val_dice_metric: 0.9076 - val_jaccard_metric: 0.8471 - val_sensitivity_metric: 0.8907 - val_specificity_metric: 0.8907 - val_precision_metric: 0.9336 - val_recall_metric: 0.8907 - val_mean_average_precision: 0.7381
# Epoch 20/60
# 77/77 [==============================] - 57s 736ms/step - loss: -0.8304 - dice_metric: 0.9328 - jaccard_metric: 0.8825 - sensitivity_metric: 0.9348 - specificity_metric: 0.9348 - precision_metric: 0.9338 - recall_metric: 0.9348 - mean_average_precision: 0.8018 - val_loss: -0.7823 - val_dice_metric: 0.9069 - val_jaccard_metric: 0.8460 - val_sensitivity_metric: 0.8864 - val_specificity_metric: 0.8864 - val_precision_metric: 0.9369 - val_recall_metric: 0.8864 - val_mean_average_precision: 0.7312
# Epoch 21/60
# 77/77 [==============================] - 56s 725ms/step - loss: -0.8318 - dice_metric: 0.9331 - jaccard_metric: 0.8831 - sensitivity_metric: 0.9358 - specificity_metric: 0.9358 - precision_metric: 0.9331 - recall_metric: 0.9358 - mean_average_precision: 0.8024 - val_loss: -0.7771 - val_dice_metric: 0.9042 - val_jaccard_metric: 0.8419 - val_sensitivity_metric: 0.8744 - val_specificity_metric: 0.8744 - val_precision_metric: 0.9465 - val_recall_metric: 0.8744 - val_mean_average_precision: 0.7236
# Epoch 22/60
# 77/77 [==============================] - 56s 720ms/step - loss: -0.8385 - dice_metric: 0.9363 - jaccard_metric: 0.8880 - sensitivity_metric: 0.9374 - specificity_metric: 0.9374 - precision_metric: 0.9368 - recall_metric: 0.9374 - mean_average_precision: 0.8119 - val_loss: -0.7954 - val_dice_metric: 0.9133 - val_jaccard_metric: 0.8549 - val_sensitivity_metric: 0.8937 - val_specificity_metric: 0.8937 - val_precision_metric: 0.9405 - val_recall_metric: 0.8937 - val_mean_average_precision: 0.7509
# Epoch 23/60
# 77/77 [==============================] - 56s 714ms/step - loss: -0.8408 - dice_metric: 0.9372 - jaccard_metric: 0.8894 - sensitivity_metric: 0.9382 - specificity_metric: 0.9382 - precision_metric: 0.9378 - recall_metric: 0.9382 - mean_average_precision: 0.8148 - val_loss: -0.8108 - val_dice_metric: 0.9207 - val_jaccard_metric: 0.8660 - val_sensitivity_metric: 0.9088 - val_specificity_metric: 0.9088 - val_precision_metric: 0.9379 - val_recall_metric: 0.9088 - val_mean_average_precision: 0.7678
# Epoch 24/60
# 77/77 [==============================] - 56s 723ms/step - loss: -0.8431 - dice_metric: 0.9381 - jaccard_metric: 0.8908 - sensitivity_metric: 0.9394 - specificity_metric: 0.9394 - precision_metric: 0.9387 - recall_metric: 0.9394 - mean_average_precision: 0.8180 - val_loss: -0.8112 - val_dice_metric: 0.9208 - val_jaccard_metric: 0.8662 - val_sensitivity_metric: 0.9079 - val_specificity_metric: 0.9079 - val_precision_metric: 0.9394 - val_recall_metric: 0.9079 - val_mean_average_precision: 0.7684
# Epoch 25/60
# 77/77 [==============================] - 58s 741ms/step - loss: -0.8450 - dice_metric: 0.9388 - jaccard_metric: 0.8919 - sensitivity_metric: 0.9402 - specificity_metric: 0.9402 - precision_metric: 0.9394 - recall_metric: 0.9402 - mean_average_precision: 0.8199 - val_loss: -0.8173 - val_dice_metric: 0.9236 - val_jaccard_metric: 0.8704 - val_sensitivity_metric: 0.9122 - val_specificity_metric: 0.9122 - val_precision_metric: 0.9401 - val_recall_metric: 0.9122 - val_mean_average_precision: 0.7748
# Epoch 26/60
# 77/77 [==============================] - 56s 719ms/step - loss: -0.8451 - dice_metric: 0.9387 - jaccard_metric: 0.8916 - sensitivity_metric: 0.9401 - specificity_metric: 0.9401 - precision_metric: 0.9394 - recall_metric: 0.9401 - mean_average_precision: 0.8194 - val_loss: -0.8228 - val_dice_metric: 0.9264 - val_jaccard_metric: 0.8747 - val_sensitivity_metric: 0.9143 - val_specificity_metric: 0.9143 - val_precision_metric: 0.9431 - val_recall_metric: 0.9143 - val_mean_average_precision: 0.7860
# Epoch 27/60
# 77/77 [==============================] - 58s 755ms/step - loss: -0.8435 - dice_metric: 0.9376 - jaccard_metric: 0.8899 - sensitivity_metric: 0.9400 - specificity_metric: 0.9400 - precision_metric: 0.9378 - recall_metric: 0.9400 - mean_average_precision: 0.8158 - val_loss: -0.8157 - val_dice_metric: 0.9226 - val_jaccard_metric: 0.8685 - val_sensitivity_metric: 0.9046 - val_specificity_metric: 0.9046 - val_precision_metric: 0.9460 - val_recall_metric: 0.9046 - val_mean_average_precision: 0.7751
# Epoch 28/60
# 77/77 [==============================] - 56s 718ms/step - loss: -0.8396 - dice_metric: 0.9353 - jaccard_metric: 0.8863 - sensitivity_metric: 0.9385 - specificity_metric: 0.9385 - precision_metric: 0.9350 - recall_metric: 0.9385 - mean_average_precision: 0.8083 - val_loss: -0.8258 - val_dice_metric: 0.9276 - val_jaccard_metric: 0.8763 - val_sensitivity_metric: 0.9272 - val_specificity_metric: 0.9272 - val_precision_metric: 0.9315 - val_recall_metric: 0.9272 - val_mean_average_precision: 0.7874
# Epoch 29/60
# 77/77 [==============================] - 57s 736ms/step - loss: -0.8419 - dice_metric: 0.9363 - jaccard_metric: 0.8878 - sensitivity_metric: 0.9384 - specificity_metric: 0.9384 - precision_metric: 0.9363 - recall_metric: 0.9384 - mean_average_precision: 0.8113 - val_loss: -0.8206 - val_dice_metric: 0.9247 - val_jaccard_metric: 0.8716 - val_sensitivity_metric: 0.9307 - val_specificity_metric: 0.9307 - val_precision_metric: 0.9220 - val_recall_metric: 0.9307 - val_mean_average_precision: 0.7777
# Epoch 30/60
# 77/77 [==============================] - 56s 724ms/step - loss: -0.8437 - dice_metric: 0.9370 - jaccard_metric: 0.8889 - sensitivity_metric: 0.9395 - specificity_metric: 0.9395 - precision_metric: 0.9368 - recall_metric: 0.9395 - mean_average_precision: 0.8138 - val_loss: -0.8301 - val_dice_metric: 0.9293 - val_jaccard_metric: 0.8789 - val_sensitivity_metric: 0.9379 - val_specificity_metric: 0.9379 - val_precision_metric: 0.9236 - val_recall_metric: 0.9379 - val_mean_average_precision: 0.7917
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 56s 722ms/step - loss: -0.8539 - dice_metric: 0.9423 - jaccard_metric: 0.8974 - sensitivity_metric: 0.9441 - specificity_metric: 0.9441 - precision_metric: 0.9418 - recall_metric: 0.9441 - mean_average_precision: 0.8312 - val_loss: -0.8398 - val_dice_metric: 0.9344 - val_jaccard_metric: 0.8871 - val_sensitivity_metric: 0.9232 - val_specificity_metric: 0.9232 - val_precision_metric: 0.9489 - val_recall_metric: 0.9232 - val_mean_average_precision: 0.8140
# Epoch 32/60
# 77/77 [==============================] - 56s 729ms/step - loss: -0.8580 - dice_metric: 0.9444 - jaccard_metric: 0.9008 - sensitivity_metric: 0.9452 - specificity_metric: 0.9452 - precision_metric: 0.9447 - recall_metric: 0.9452 - mean_average_precision: 0.8379 - val_loss: -0.8428 - val_dice_metric: 0.9360 - val_jaccard_metric: 0.8895 - val_sensitivity_metric: 0.9258 - val_specificity_metric: 0.9258 - val_precision_metric: 0.9491 - val_recall_metric: 0.9258 - val_mean_average_precision: 0.8179
# Epoch 33/60
# 77/77 [==============================] - 57s 729ms/step - loss: -0.8589 - dice_metric: 0.9448 - jaccard_metric: 0.9015 - sensitivity_metric: 0.9456 - specificity_metric: 0.9456 - precision_metric: 0.9452 - recall_metric: 0.9456 - mean_average_precision: 0.8393 - val_loss: -0.8451 - val_dice_metric: 0.9372 - val_jaccard_metric: 0.8914 - val_sensitivity_metric: 0.9280 - val_specificity_metric: 0.9280 - val_precision_metric: 0.9490 - val_recall_metric: 0.9280 - val_mean_average_precision: 0.8205
# Epoch 34/60
# 77/77 [==============================] - 57s 739ms/step - loss: -0.8598 - dice_metric: 0.9453 - jaccard_metric: 0.9022 - sensitivity_metric: 0.9459 - specificity_metric: 0.9459 - precision_metric: 0.9456 - recall_metric: 0.9459 - mean_average_precision: 0.8404 - val_loss: -0.8473 - val_dice_metric: 0.9382 - val_jaccard_metric: 0.8930 - val_sensitivity_metric: 0.9305 - val_specificity_metric: 0.9305 - val_precision_metric: 0.9484 - val_recall_metric: 0.9305 - val_mean_average_precision: 0.8230
# Epoch 35/60
# 77/77 [==============================] - 56s 727ms/step - loss: -0.8605 - dice_metric: 0.9456 - jaccard_metric: 0.9027 - sensitivity_metric: 0.9462 - specificity_metric: 0.9462 - precision_metric: 0.9460 - recall_metric: 0.9462 - mean_average_precision: 0.8416 - val_loss: -0.8489 - val_dice_metric: 0.9391 - val_jaccard_metric: 0.8944 - val_sensitivity_metric: 0.9332 - val_specificity_metric: 0.9332 - val_precision_metric: 0.9473 - val_recall_metric: 0.9332 - val_mean_average_precision: 0.8256
# Epoch 36/60
# 77/77 [==============================] - 57s 730ms/step - loss: -0.8612 - dice_metric: 0.9459 - jaccard_metric: 0.9032 - sensitivity_metric: 0.9464 - specificity_metric: 0.9464 - precision_metric: 0.9464 - recall_metric: 0.9464 - mean_average_precision: 0.8422 - val_loss: -0.8501 - val_dice_metric: 0.9396 - val_jaccard_metric: 0.8952 - val_sensitivity_metric: 0.9338 - val_specificity_metric: 0.9338 - val_precision_metric: 0.9477 - val_recall_metric: 0.9338 - val_mean_average_precision: 0.8262
# Epoch 37/60
# 77/77 [==============================] - 57s 730ms/step - loss: -0.8616 - dice_metric: 0.9461 - jaccard_metric: 0.9034 - sensitivity_metric: 0.9466 - specificity_metric: 0.9466 - precision_metric: 0.9465 - recall_metric: 0.9466 - mean_average_precision: 0.8426 - val_loss: -0.8518 - val_dice_metric: 0.9405 - val_jaccard_metric: 0.8966 - val_sensitivity_metric: 0.9367 - val_specificity_metric: 0.9367 - val_precision_metric: 0.9464 - val_recall_metric: 0.9367 - val_mean_average_precision: 0.8287
# Epoch 38/60
# 77/77 [==============================] - 57s 741ms/step - loss: -0.8620 - dice_metric: 0.9463 - jaccard_metric: 0.9038 - sensitivity_metric: 0.9466 - specificity_metric: 0.9466 - precision_metric: 0.9469 - recall_metric: 0.9466 - mean_average_precision: 0.8430 - val_loss: -0.8527 - val_dice_metric: 0.9409 - val_jaccard_metric: 0.8973 - val_sensitivity_metric: 0.9381 - val_specificity_metric: 0.9381 - val_precision_metric: 0.9458 - val_recall_metric: 0.9381 - val_mean_average_precision: 0.8297
# Epoch 39/60
# 77/77 [==============================] - 59s 754ms/step - loss: -0.8626 - dice_metric: 0.9465 - jaccard_metric: 0.9042 - sensitivity_metric: 0.9470 - specificity_metric: 0.9470 - precision_metric: 0.9470 - recall_metric: 0.9470 - mean_average_precision: 0.8438 - val_loss: -0.8534 - val_dice_metric: 0.9413 - val_jaccard_metric: 0.8979 - val_sensitivity_metric: 0.9389 - val_specificity_metric: 0.9389 - val_precision_metric: 0.9457 - val_recall_metric: 0.9389 - val_mean_average_precision: 0.8311
# Epoch 40/60
# 77/77 [==============================] - 58s 741ms/step - loss: -0.8629 - dice_metric: 0.9466 - jaccard_metric: 0.9044 - sensitivity_metric: 0.9471 - specificity_metric: 0.9471 - precision_metric: 0.9472 - recall_metric: 0.9471 - mean_average_precision: 0.8439 - val_loss: -0.8543 - val_dice_metric: 0.9417 - val_jaccard_metric: 0.8985 - val_sensitivity_metric: 0.9408 - val_specificity_metric: 0.9408 - val_precision_metric: 0.9444 - val_recall_metric: 0.9408 - val_mean_average_precision: 0.8319
# Epoch 41/60
# 77/77 [==============================] - 56s 723ms/step - loss: -0.8634 - dice_metric: 0.9469 - jaccard_metric: 0.9047 - sensitivity_metric: 0.9473 - specificity_metric: 0.9473 - precision_metric: 0.9473 - recall_metric: 0.9473 - mean_average_precision: 0.8450 - val_loss: -0.8550 - val_dice_metric: 0.9420 - val_jaccard_metric: 0.8990 - val_sensitivity_metric: 0.9418 - val_specificity_metric: 0.9418 - val_precision_metric: 0.9440 - val_recall_metric: 0.9418 - val_mean_average_precision: 0.8331
# Epoch 42/60
# 77/77 [==============================] - 57s 730ms/step - loss: -0.8637 - dice_metric: 0.9470 - jaccard_metric: 0.9049 - sensitivity_metric: 0.9474 - specificity_metric: 0.9474 - precision_metric: 0.9475 - recall_metric: 0.9474 - mean_average_precision: 0.8452 - val_loss: -0.8557 - val_dice_metric: 0.9424 - val_jaccard_metric: 0.8995 - val_sensitivity_metric: 0.9430 - val_specificity_metric: 0.9430 - val_precision_metric: 0.9435 - val_recall_metric: 0.9430 - val_mean_average_precision: 0.8340
# Epoch 43/60
# 77/77 [==============================] - 56s 728ms/step - loss: -0.8640 - dice_metric: 0.9471 - jaccard_metric: 0.9051 - sensitivity_metric: 0.9477 - specificity_metric: 0.9477 - precision_metric: 0.9475 - recall_metric: 0.9477 - mean_average_precision: 0.8456 - val_loss: -0.8559 - val_dice_metric: 0.9423 - val_jaccard_metric: 0.8995 - val_sensitivity_metric: 0.9439 - val_specificity_metric: 0.9439 - val_precision_metric: 0.9425 - val_recall_metric: 0.9439 - val_mean_average_precision: 0.8340
# Epoch 44/60
# 77/77 [==============================] - 58s 746ms/step - loss: -0.8645 - dice_metric: 0.9473 - jaccard_metric: 0.9054 - sensitivity_metric: 0.9477 - specificity_metric: 0.9477 - precision_metric: 0.9479 - recall_metric: 0.9477 - mean_average_precision: 0.8459 - val_loss: -0.8562 - val_dice_metric: 0.9425 - val_jaccard_metric: 0.8998 - val_sensitivity_metric: 0.9435 - val_specificity_metric: 0.9435 - val_precision_metric: 0.9433 - val_recall_metric: 0.9435 - val_mean_average_precision: 0.8348
# Epoch 45/60
# 77/77 [==============================] - 57s 732ms/step - loss: -0.8648 - dice_metric: 0.9474 - jaccard_metric: 0.9057 - sensitivity_metric: 0.9479 - specificity_metric: 0.9479 - precision_metric: 0.9479 - recall_metric: 0.9479 - mean_average_precision: 0.8462 - val_loss: -0.8566 - val_dice_metric: 0.9427 - val_jaccard_metric: 0.9001 - val_sensitivity_metric: 0.9456 - val_specificity_metric: 0.9456 - val_precision_metric: 0.9416 - val_recall_metric: 0.9456 - val_mean_average_precision: 0.8352
# Epoch 46/60
# 77/77 [==============================] - 57s 731ms/step - loss: -0.8651 - dice_metric: 0.9476 - jaccard_metric: 0.9059 - sensitivity_metric: 0.9480 - specificity_metric: 0.9480 - precision_metric: 0.9481 - recall_metric: 0.9480 - mean_average_precision: 0.8470 - val_loss: -0.8570 - val_dice_metric: 0.9428 - val_jaccard_metric: 0.9003 - val_sensitivity_metric: 0.9456 - val_specificity_metric: 0.9456 - val_precision_metric: 0.9418 - val_recall_metric: 0.9456 - val_mean_average_precision: 0.8352
# Epoch 47/60
# 77/77 [==============================] - 56s 725ms/step - loss: -0.8656 - dice_metric: 0.9478 - jaccard_metric: 0.9062 - sensitivity_metric: 0.9482 - specificity_metric: 0.9482 - precision_metric: 0.9482 - recall_metric: 0.9482 - mean_average_precision: 0.8474 - val_loss: -0.8572 - val_dice_metric: 0.9430 - val_jaccard_metric: 0.9005 - val_sensitivity_metric: 0.9469 - val_specificity_metric: 0.9469 - val_precision_metric: 0.9409 - val_recall_metric: 0.9469 - val_mean_average_precision: 0.8360
# Epoch 48/60
# 77/77 [==============================] - 56s 717ms/step - loss: -0.8658 - dice_metric: 0.9479 - jaccard_metric: 0.9063 - sensitivity_metric: 0.9482 - specificity_metric: 0.9482 - precision_metric: 0.9484 - recall_metric: 0.9482 - mean_average_precision: 0.8477 - val_loss: -0.8575 - val_dice_metric: 0.9431 - val_jaccard_metric: 0.9006 - val_sensitivity_metric: 0.9474 - val_specificity_metric: 0.9474 - val_precision_metric: 0.9405 - val_recall_metric: 0.9474 - val_mean_average_precision: 0.8360
# Epoch 49/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.8662 - dice_metric: 0.9480 - jaccard_metric: 0.9066 - sensitivity_metric: 0.9482 - specificity_metric: 0.9482 - precision_metric: 0.9487 - recall_metric: 0.9482 - mean_average_precision: 0.8482 - val_loss: -0.8577 - val_dice_metric: 0.9432 - val_jaccard_metric: 0.9008 - val_sensitivity_metric: 0.9478 - val_specificity_metric: 0.9478 - val_precision_metric: 0.9403 - val_recall_metric: 0.9478 - val_mean_average_precision: 0.8362
# Epoch 50/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.8665 - dice_metric: 0.9482 - jaccard_metric: 0.9068 - sensitivity_metric: 0.9485 - specificity_metric: 0.9485 - precision_metric: 0.9487 - recall_metric: 0.9485 - mean_average_precision: 0.8485 - val_loss: -0.8577 - val_dice_metric: 0.9431 - val_jaccard_metric: 0.9006 - val_sensitivity_metric: 0.9483 - val_specificity_metric: 0.9483 - val_precision_metric: 0.9397 - val_recall_metric: 0.9483 - val_mean_average_precision: 0.8370
# Epoch 51/60
# 77/77 [==============================] - 56s 717ms/step - loss: -0.8669 - dice_metric: 0.9483 - jaccard_metric: 0.9070 - sensitivity_metric: 0.9487 - specificity_metric: 0.9487 - precision_metric: 0.9488 - recall_metric: 0.9487 - mean_average_precision: 0.8491 - val_loss: -0.8582 - val_dice_metric: 0.9433 - val_jaccard_metric: 0.9010 - val_sensitivity_metric: 0.9483 - val_specificity_metric: 0.9483 - val_precision_metric: 0.9401 - val_recall_metric: 0.9483 - val_mean_average_precision: 0.8376
# Epoch 52/60
# 77/77 [==============================] - 60s 770ms/step - loss: -0.8671 - dice_metric: 0.9484 - jaccard_metric: 0.9072 - sensitivity_metric: 0.9487 - specificity_metric: 0.9487 - precision_metric: 0.9490 - recall_metric: 0.9487 - mean_average_precision: 0.8493 - val_loss: -0.8582 - val_dice_metric: 0.9433 - val_jaccard_metric: 0.9010 - val_sensitivity_metric: 0.9483 - val_specificity_metric: 0.9483 - val_precision_metric: 0.9401 - val_recall_metric: 0.9483 - val_mean_average_precision: 0.8378
# Epoch 53/60
# 77/77 [==============================] - 57s 740ms/step - loss: -0.8675 - dice_metric: 0.9485 - jaccard_metric: 0.9074 - sensitivity_metric: 0.9488 - specificity_metric: 0.9488 - precision_metric: 0.9490 - recall_metric: 0.9488 - mean_average_precision: 0.8495 - val_loss: -0.8584 - val_dice_metric: 0.9434 - val_jaccard_metric: 0.9011 - val_sensitivity_metric: 0.9489 - val_specificity_metric: 0.9489 - val_precision_metric: 0.9397 - val_recall_metric: 0.9489 - val_mean_average_precision: 0.8374
# Epoch 54/60
# 77/77 [==============================] - 59s 756ms/step - loss: -0.8679 - dice_metric: 0.9487 - jaccard_metric: 0.9076 - sensitivity_metric: 0.9490 - specificity_metric: 0.9490 - precision_metric: 0.9492 - recall_metric: 0.9490 - mean_average_precision: 0.8503 - val_loss: -0.8586 - val_dice_metric: 0.9435 - val_jaccard_metric: 0.9012 - val_sensitivity_metric: 0.9487 - val_specificity_metric: 0.9487 - val_precision_metric: 0.9400 - val_recall_metric: 0.9487 - val_mean_average_precision: 0.8376
# Epoch 55/60
# 77/77 [==============================] - 58s 741ms/step - loss: -0.8681 - dice_metric: 0.9487 - jaccard_metric: 0.9077 - sensitivity_metric: 0.9490 - specificity_metric: 0.9490 - precision_metric: 0.9493 - recall_metric: 0.9490 - mean_average_precision: 0.8502 - val_loss: -0.8588 - val_dice_metric: 0.9434 - val_jaccard_metric: 0.9012 - val_sensitivity_metric: 0.9495 - val_specificity_metric: 0.9495 - val_precision_metric: 0.9393 - val_recall_metric: 0.9495 - val_mean_average_precision: 0.8376
# Epoch 56/60
# 77/77 [==============================] - 56s 722ms/step - loss: -0.8684 - dice_metric: 0.9489 - jaccard_metric: 0.9080 - sensitivity_metric: 0.9491 - specificity_metric: 0.9491 - precision_metric: 0.9494 - recall_metric: 0.9491 - mean_average_precision: 0.8508 - val_loss: -0.8588 - val_dice_metric: 0.9435 - val_jaccard_metric: 0.9012 - val_sensitivity_metric: 0.9501 - val_specificity_metric: 0.9501 - val_precision_metric: 0.9387 - val_recall_metric: 0.9501 - val_mean_average_precision: 0.8378
# Epoch 57/60
# 77/77 [==============================] - 57s 733ms/step - loss: -0.8687 - dice_metric: 0.9490 - jaccard_metric: 0.9081 - sensitivity_metric: 0.9493 - specificity_metric: 0.9493 - precision_metric: 0.9495 - recall_metric: 0.9493 - mean_average_precision: 0.8510 - val_loss: -0.8587 - val_dice_metric: 0.9433 - val_jaccard_metric: 0.9010 - val_sensitivity_metric: 0.9499 - val_specificity_metric: 0.9499 - val_precision_metric: 0.9386 - val_recall_metric: 0.9499 - val_mean_average_precision: 0.8380
# Epoch 58/60
# 77/77 [==============================] - 56s 724ms/step - loss: -0.8689 - dice_metric: 0.9491 - jaccard_metric: 0.9083 - sensitivity_metric: 0.9493 - specificity_metric: 0.9493 - precision_metric: 0.9496 - recall_metric: 0.9493 - mean_average_precision: 0.8512 - val_loss: -0.8589 - val_dice_metric: 0.9435 - val_jaccard_metric: 0.9013 - val_sensitivity_metric: 0.9501 - val_specificity_metric: 0.9501 - val_precision_metric: 0.9388 - val_recall_metric: 0.9501 - val_mean_average_precision: 0.8386
# Epoch 59/60
# 77/77 [==============================] - 57s 735ms/step - loss: -0.8693 - dice_metric: 0.9492 - jaccard_metric: 0.9085 - sensitivity_metric: 0.9496 - specificity_metric: 0.9496 - precision_metric: 0.9497 - recall_metric: 0.9496 - mean_average_precision: 0.8519 - val_loss: -0.8590 - val_dice_metric: 0.9435 - val_jaccard_metric: 0.9013 - val_sensitivity_metric: 0.9500 - val_specificity_metric: 0.9500 - val_precision_metric: 0.9389 - val_recall_metric: 0.9500 - val_mean_average_precision: 0.8390
# Epoch 60/60
# 77/77 [==============================] - 57s 729ms/step - loss: -0.8695 - dice_metric: 0.9493 - jaccard_metric: 0.9086 - sensitivity_metric: 0.9496 - specificity_metric: 0.9496 - precision_metric: 0.9497 - recall_metric: 0.9496 - mean_average_precision: 0.8518 - val_loss: -0.8594 - val_dice_metric: 0.9436 - val_jaccard_metric: 0.9015 - val_sensitivity_metric: 0.9502 - val_specificity_metric: 0.9502 - val_precision_metric: 0.9390 - val_recall_metric: 0.9502 - val_mean_average_precision: 0.8392

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.94514, std: 0.06868
# Jaccard Index mean: 0.90328, std: 0.11262
# Sensitivity mean: 0.95115, std: 0.06816
# Specificity mean: 0.95115, std: 0.06816
# Precision mean: 0.94017, std: 0.07297
# Recall mean: 0.95115, std: 0.06816
# mAP@50 mean: 0.99153, std: 0.06454
# mAP@50-95 mean: 0.84195, std: 0.09850
