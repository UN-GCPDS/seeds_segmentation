# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  98%|████████████████████████████████████████ | 975M/998M [00:05<00:00, 199MB/s]
# 100%|█████████████████████████████████████████| 998M/998M [00:05<00:00, 196MB/s]

# %%
config = {"Seg_model":"VGG16","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"SeedsDA","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import vgg16
from seeds_segmentation.losses import DiceCoefficient

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def precision_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=axis)
    
    precision = true_positives / (true_positives + false_positives + smooth)

    if return_mean:
        return tf.reduce_mean(precision)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if precision.shape[1] > 1:
            return tf.transpose(precision, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(precision, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def recall_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)

    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    false_negatives = tf.reduce_sum(y_true * (1 - y_pred), axis=axis)
    
    recall = true_positives / (true_positives + false_negatives + smooth)

    if return_mean:
        return tf.reduce_mean(recall)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if recall.shape[1] > 1:
            return tf.transpose(recall, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(recall, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def mean_average_precision(y_true, y_pred, axis=(1, 2), smooth=1e-7, thresholds=None, return_mean=True):
    if thresholds is None:
        thresholds = tf.linspace(0.5, 0.95, 10)
    
    iou = jaccard_metric(y_true, y_pred, axis=axis, smooth=smooth, return_mean=False)  # (batch, classes)

    # Expandimos dimensiones para broadcasting
    thresholds = tf.reshape(thresholds, (-1, 1, 1))  # (T, 1, 1)
    iou = tf.expand_dims(iou, axis=0)               # (1, batch, classes)
    
    # Comparar IoU con umbrales en paralelo usando broadcasting
    aps = tf.reduce_mean(tf.cast(iou > thresholds, tf.float32), axis=1)  # (T, classes)
    
    mAP = tf.reduce_mean(aps, axis=0)  # Promedio de umbrales (classes,)

    return tf.reduce_mean(mAP) if return_mean else mAP

@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = vgg16(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric, precision_metric, recall_metric, mean_average_precision])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 84s 867ms/step - loss: -0.1698 - dice_metric: 0.5421 - jaccard_metric: 0.4489 - sensitivity_metric: 0.7320 - specificity_metric: 0.7320 - precision_metric: 0.5779 - recall_metric: 0.7320 - mean_average_precision: 0.2953 - val_loss: -0.3310 - val_dice_metric: 0.6688 - val_jaccard_metric: 0.5866 - val_sensitivity_metric: 0.7984 - val_specificity_metric: 0.7984 - val_precision_metric: 0.6470 - val_recall_metric: 0.7984 - val_mean_average_precision: 0.4641
# Epoch 2/60
# 77/77 [==============================] - 64s 822ms/step - loss: -0.3101 - dice_metric: 0.6540 - jaccard_metric: 0.5679 - sensitivity_metric: 0.7679 - specificity_metric: 0.7679 - precision_metric: 0.6358 - recall_metric: 0.7679 - mean_average_precision: 0.4406 - val_loss: -0.4117 - val_dice_metric: 0.7129 - val_jaccard_metric: 0.6328 - val_sensitivity_metric: 0.8086 - val_specificity_metric: 0.8086 - val_precision_metric: 0.6869 - val_recall_metric: 0.8086 - val_mean_average_precision: 0.5145
# Epoch 3/60
# 77/77 [==============================] - 64s 825ms/step - loss: -0.3613 - dice_metric: 0.6835 - jaccard_metric: 0.5979 - sensitivity_metric: 0.7740 - specificity_metric: 0.7740 - precision_metric: 0.6595 - recall_metric: 0.7740 - mean_average_precision: 0.4688 - val_loss: -0.4607 - val_dice_metric: 0.7388 - val_jaccard_metric: 0.6592 - val_sensitivity_metric: 0.8291 - val_specificity_metric: 0.8291 - val_precision_metric: 0.7084 - val_recall_metric: 0.8291 - val_mean_average_precision: 0.5367
# Epoch 4/60
# 77/77 [==============================] - 69s 895ms/step - loss: -0.3984 - dice_metric: 0.7042 - jaccard_metric: 0.6186 - sensitivity_metric: 0.7830 - specificity_metric: 0.7830 - precision_metric: 0.6781 - recall_metric: 0.7830 - mean_average_precision: 0.4838 - val_loss: -0.4927 - val_dice_metric: 0.7552 - val_jaccard_metric: 0.6755 - val_sensitivity_metric: 0.8583 - val_specificity_metric: 0.8583 - val_precision_metric: 0.7161 - val_recall_metric: 0.8583 - val_mean_average_precision: 0.5491
# Epoch 5/60
# 77/77 [==============================] - 67s 870ms/step - loss: -0.4336 - dice_metric: 0.7241 - jaccard_metric: 0.6386 - sensitivity_metric: 0.7912 - specificity_metric: 0.7912 - precision_metric: 0.6972 - recall_metric: 0.7912 - mean_average_precision: 0.4996 - val_loss: -0.5437 - val_dice_metric: 0.7841 - val_jaccard_metric: 0.7053 - val_sensitivity_metric: 0.8476 - val_specificity_metric: 0.8476 - val_precision_metric: 0.7552 - val_recall_metric: 0.8476 - val_mean_average_precision: 0.5727
# Epoch 6/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.4610 - dice_metric: 0.7393 - jaccard_metric: 0.6542 - sensitivity_metric: 0.7977 - specificity_metric: 0.7977 - precision_metric: 0.7166 - recall_metric: 0.7977 - mean_average_precision: 0.5098 - val_loss: -0.5861 - val_dice_metric: 0.8093 - val_jaccard_metric: 0.7320 - val_sensitivity_metric: 0.8434 - val_specificity_metric: 0.8434 - val_precision_metric: 0.7880 - val_recall_metric: 0.8434 - val_mean_average_precision: 0.5864
# Epoch 7/60
# 77/77 [==============================] - 67s 861ms/step - loss: -0.4912 - dice_metric: 0.7561 - jaccard_metric: 0.6716 - sensitivity_metric: 0.8032 - specificity_metric: 0.8032 - precision_metric: 0.7339 - recall_metric: 0.8032 - mean_average_precision: 0.5217 - val_loss: -0.6131 - val_dice_metric: 0.8241 - val_jaccard_metric: 0.7490 - val_sensitivity_metric: 0.8393 - val_specificity_metric: 0.8393 - val_precision_metric: 0.8146 - val_recall_metric: 0.8393 - val_mean_average_precision: 0.6030
# Epoch 8/60
# 77/77 [==============================] - 67s 866ms/step - loss: -0.5081 - dice_metric: 0.7650 - jaccard_metric: 0.6811 - sensitivity_metric: 0.8101 - specificity_metric: 0.8101 - precision_metric: 0.7447 - recall_metric: 0.8101 - mean_average_precision: 0.5318 - val_loss: -0.6286 - val_dice_metric: 0.8304 - val_jaccard_metric: 0.7547 - val_sensitivity_metric: 0.8828 - val_specificity_metric: 0.8828 - val_precision_metric: 0.7986 - val_recall_metric: 0.8828 - val_mean_average_precision: 0.6079
# Epoch 9/60
# 77/77 [==============================] - 70s 898ms/step - loss: -0.5281 - dice_metric: 0.7757 - jaccard_metric: 0.6927 - sensitivity_metric: 0.8155 - specificity_metric: 0.8155 - precision_metric: 0.7555 - recall_metric: 0.8155 - mean_average_precision: 0.5430 - val_loss: -0.6458 - val_dice_metric: 0.8386 - val_jaccard_metric: 0.7639 - val_sensitivity_metric: 0.8934 - val_specificity_metric: 0.8934 - val_precision_metric: 0.8048 - val_recall_metric: 0.8934 - val_mean_average_precision: 0.6191
# Epoch 10/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.5441 - dice_metric: 0.7842 - jaccard_metric: 0.7018 - sensitivity_metric: 0.8210 - specificity_metric: 0.8210 - precision_metric: 0.7646 - recall_metric: 0.8210 - mean_average_precision: 0.5533 - val_loss: -0.6587 - val_dice_metric: 0.8449 - val_jaccard_metric: 0.7713 - val_sensitivity_metric: 0.8995 - val_specificity_metric: 0.8995 - val_precision_metric: 0.8111 - val_recall_metric: 0.8995 - val_mean_average_precision: 0.6283
# Epoch 11/60
# 77/77 [==============================] - 69s 897ms/step - loss: -0.5576 - dice_metric: 0.7913 - jaccard_metric: 0.7096 - sensitivity_metric: 0.8252 - specificity_metric: 0.8252 - precision_metric: 0.7725 - recall_metric: 0.8252 - mean_average_precision: 0.5615 - val_loss: -0.6778 - val_dice_metric: 0.8555 - val_jaccard_metric: 0.7838 - val_sensitivity_metric: 0.9013 - val_specificity_metric: 0.9013 - val_precision_metric: 0.8251 - val_recall_metric: 0.9013 - val_mean_average_precision: 0.6441
# Epoch 12/60
# 77/77 [==============================] - 68s 880ms/step - loss: -0.5689 - dice_metric: 0.7972 - jaccard_metric: 0.7162 - sensitivity_metric: 0.8294 - specificity_metric: 0.8294 - precision_metric: 0.7795 - recall_metric: 0.8294 - mean_average_precision: 0.5681 - val_loss: -0.6896 - val_dice_metric: 0.8618 - val_jaccard_metric: 0.7916 - val_sensitivity_metric: 0.9046 - val_specificity_metric: 0.9046 - val_precision_metric: 0.8328 - val_recall_metric: 0.9046 - val_mean_average_precision: 0.6544
# Epoch 13/60
# 77/77 [==============================] - 65s 841ms/step - loss: -0.5801 - dice_metric: 0.8030 - jaccard_metric: 0.7229 - sensitivity_metric: 0.8325 - specificity_metric: 0.8325 - precision_metric: 0.7865 - recall_metric: 0.8325 - mean_average_precision: 0.5761 - val_loss: -0.6913 - val_dice_metric: 0.8620 - val_jaccard_metric: 0.7912 - val_sensitivity_metric: 0.9145 - val_specificity_metric: 0.9145 - val_precision_metric: 0.8272 - val_recall_metric: 0.9145 - val_mean_average_precision: 0.6536
# Epoch 14/60
# 77/77 [==============================] - 70s 902ms/step - loss: -0.5902 - dice_metric: 0.8082 - jaccard_metric: 0.7287 - sensitivity_metric: 0.8369 - specificity_metric: 0.8369 - precision_metric: 0.7920 - recall_metric: 0.8369 - mean_average_precision: 0.5823 - val_loss: -0.7129 - val_dice_metric: 0.8733 - val_jaccard_metric: 0.8065 - val_sensitivity_metric: 0.9110 - val_specificity_metric: 0.9110 - val_precision_metric: 0.8467 - val_recall_metric: 0.9110 - val_mean_average_precision: 0.6808
# Epoch 15/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.5978 - dice_metric: 0.8121 - jaccard_metric: 0.7332 - sensitivity_metric: 0.8395 - specificity_metric: 0.8395 - precision_metric: 0.7969 - recall_metric: 0.8395 - mean_average_precision: 0.5874 - val_loss: -0.7154 - val_dice_metric: 0.8746 - val_jaccard_metric: 0.8081 - val_sensitivity_metric: 0.9040 - val_specificity_metric: 0.9040 - val_precision_metric: 0.8539 - val_recall_metric: 0.9040 - val_mean_average_precision: 0.6824
# Epoch 16/60
# 77/77 [==============================] - 71s 920ms/step - loss: -0.6057 - dice_metric: 0.8162 - jaccard_metric: 0.7377 - sensitivity_metric: 0.8419 - specificity_metric: 0.8419 - precision_metric: 0.8016 - recall_metric: 0.8419 - mean_average_precision: 0.5922 - val_loss: -0.7252 - val_dice_metric: 0.8788 - val_jaccard_metric: 0.8136 - val_sensitivity_metric: 0.9147 - val_specificity_metric: 0.9147 - val_precision_metric: 0.8532 - val_recall_metric: 0.9147 - val_mean_average_precision: 0.6904
# Epoch 17/60
# 77/77 [==============================] - 66s 856ms/step - loss: -0.6123 - dice_metric: 0.8196 - jaccard_metric: 0.7416 - sensitivity_metric: 0.8437 - specificity_metric: 0.8437 - precision_metric: 0.8059 - recall_metric: 0.8437 - mean_average_precision: 0.5970 - val_loss: -0.7275 - val_dice_metric: 0.8801 - val_jaccard_metric: 0.8146 - val_sensitivity_metric: 0.9173 - val_specificity_metric: 0.9173 - val_precision_metric: 0.8533 - val_recall_metric: 0.9173 - val_mean_average_precision: 0.6900
# Epoch 18/60
# 77/77 [==============================] - 69s 887ms/step - loss: -0.6172 - dice_metric: 0.8220 - jaccard_metric: 0.7443 - sensitivity_metric: 0.8461 - specificity_metric: 0.8461 - precision_metric: 0.8090 - recall_metric: 0.8461 - mean_average_precision: 0.6001 - val_loss: -0.7354 - val_dice_metric: 0.8841 - val_jaccard_metric: 0.8201 - val_sensitivity_metric: 0.9176 - val_specificity_metric: 0.9176 - val_precision_metric: 0.8593 - val_recall_metric: 0.9176 - val_mean_average_precision: 0.6992
# Epoch 19/60
# 77/77 [==============================] - 68s 880ms/step - loss: -0.6236 - dice_metric: 0.8253 - jaccard_metric: 0.7479 - sensitivity_metric: 0.8479 - specificity_metric: 0.8479 - precision_metric: 0.8127 - recall_metric: 0.8479 - mean_average_precision: 0.6039 - val_loss: -0.7393 - val_dice_metric: 0.8860 - val_jaccard_metric: 0.8225 - val_sensitivity_metric: 0.9128 - val_specificity_metric: 0.9128 - val_precision_metric: 0.8656 - val_recall_metric: 0.9128 - val_mean_average_precision: 0.7021
# Epoch 20/60
# 77/77 [==============================] - 65s 838ms/step - loss: -0.6278 - dice_metric: 0.8275 - jaccard_metric: 0.7504 - sensitivity_metric: 0.8492 - specificity_metric: 0.8492 - precision_metric: 0.8152 - recall_metric: 0.8492 - mean_average_precision: 0.6055 - val_loss: -0.7497 - val_dice_metric: 0.8915 - val_jaccard_metric: 0.8304 - val_sensitivity_metric: 0.9052 - val_specificity_metric: 0.9052 - val_precision_metric: 0.8814 - val_recall_metric: 0.9052 - val_mean_average_precision: 0.7199
# Epoch 21/60
# 77/77 [==============================] - 65s 843ms/step - loss: -0.6356 - dice_metric: 0.8315 - jaccard_metric: 0.7551 - sensitivity_metric: 0.8510 - specificity_metric: 0.8510 - precision_metric: 0.8200 - recall_metric: 0.8510 - mean_average_precision: 0.6114 - val_loss: -0.7511 - val_dice_metric: 0.8918 - val_jaccard_metric: 0.8304 - val_sensitivity_metric: 0.9159 - val_specificity_metric: 0.9159 - val_precision_metric: 0.8734 - val_recall_metric: 0.9159 - val_mean_average_precision: 0.7168
# Epoch 22/60
# 77/77 [==============================] - 64s 829ms/step - loss: -0.6395 - dice_metric: 0.8334 - jaccard_metric: 0.7573 - sensitivity_metric: 0.8528 - specificity_metric: 0.8528 - precision_metric: 0.8223 - recall_metric: 0.8528 - mean_average_precision: 0.6132 - val_loss: -0.7498 - val_dice_metric: 0.8905 - val_jaccard_metric: 0.8282 - val_sensitivity_metric: 0.9228 - val_specificity_metric: 0.9228 - val_precision_metric: 0.8664 - val_recall_metric: 0.9228 - val_mean_average_precision: 0.7137
# Epoch 23/60
# 77/77 [==============================] - 70s 910ms/step - loss: -0.6438 - dice_metric: 0.8357 - jaccard_metric: 0.7598 - sensitivity_metric: 0.8543 - specificity_metric: 0.8543 - precision_metric: 0.8251 - recall_metric: 0.8543 - mean_average_precision: 0.6166 - val_loss: -0.7568 - val_dice_metric: 0.8942 - val_jaccard_metric: 0.8335 - val_sensitivity_metric: 0.9190 - val_specificity_metric: 0.9190 - val_precision_metric: 0.8756 - val_recall_metric: 0.9190 - val_mean_average_precision: 0.7213
# Epoch 24/60
# 77/77 [==============================] - 68s 880ms/step - loss: -0.6477 - dice_metric: 0.8377 - jaccard_metric: 0.7621 - sensitivity_metric: 0.8559 - specificity_metric: 0.8559 - precision_metric: 0.8273 - recall_metric: 0.8559 - mean_average_precision: 0.6191 - val_loss: -0.7615 - val_dice_metric: 0.8972 - val_jaccard_metric: 0.8375 - val_sensitivity_metric: 0.9144 - val_specificity_metric: 0.9144 - val_precision_metric: 0.8839 - val_recall_metric: 0.9144 - val_mean_average_precision: 0.7278
# Epoch 25/60
# 77/77 [==============================] - 67s 871ms/step - loss: -0.6518 - dice_metric: 0.8397 - jaccard_metric: 0.7645 - sensitivity_metric: 0.8569 - specificity_metric: 0.8569 - precision_metric: 0.8296 - recall_metric: 0.8569 - mean_average_precision: 0.6222 - val_loss: -0.7643 - val_dice_metric: 0.8983 - val_jaccard_metric: 0.8392 - val_sensitivity_metric: 0.9085 - val_specificity_metric: 0.9085 - val_precision_metric: 0.8912 - val_recall_metric: 0.9085 - val_mean_average_precision: 0.7313
# Epoch 26/60
# 77/77 [==============================] - 69s 896ms/step - loss: -0.6544 - dice_metric: 0.8410 - jaccard_metric: 0.7659 - sensitivity_metric: 0.8577 - specificity_metric: 0.8577 - precision_metric: 0.8312 - recall_metric: 0.8577 - mean_average_precision: 0.6238 - val_loss: -0.7611 - val_dice_metric: 0.8962 - val_jaccard_metric: 0.8358 - val_sensitivity_metric: 0.9213 - val_specificity_metric: 0.9213 - val_precision_metric: 0.8767 - val_recall_metric: 0.9213 - val_mean_average_precision: 0.7260
# Epoch 27/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.6593 - dice_metric: 0.8435 - jaccard_metric: 0.7689 - sensitivity_metric: 0.8594 - specificity_metric: 0.8594 - precision_metric: 0.8343 - recall_metric: 0.8594 - mean_average_precision: 0.6277 - val_loss: -0.7671 - val_dice_metric: 0.8995 - val_jaccard_metric: 0.8405 - val_sensitivity_metric: 0.9143 - val_specificity_metric: 0.9143 - val_precision_metric: 0.8882 - val_recall_metric: 0.9143 - val_mean_average_precision: 0.7337
# Epoch 28/60
# 77/77 [==============================] - 66s 850ms/step - loss: -0.6616 - dice_metric: 0.8446 - jaccard_metric: 0.7701 - sensitivity_metric: 0.8604 - specificity_metric: 0.8604 - precision_metric: 0.8353 - recall_metric: 0.8604 - mean_average_precision: 0.6290 - val_loss: -0.7694 - val_dice_metric: 0.9010 - val_jaccard_metric: 0.8425 - val_sensitivity_metric: 0.9138 - val_specificity_metric: 0.9138 - val_precision_metric: 0.8914 - val_recall_metric: 0.9138 - val_mean_average_precision: 0.7356
# Epoch 29/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.6650 - dice_metric: 0.8464 - jaccard_metric: 0.7721 - sensitivity_metric: 0.8619 - specificity_metric: 0.8619 - precision_metric: 0.8374 - recall_metric: 0.8619 - mean_average_precision: 0.6314 - val_loss: -0.7726 - val_dice_metric: 0.9025 - val_jaccard_metric: 0.8449 - val_sensitivity_metric: 0.9112 - val_specificity_metric: 0.9112 - val_precision_metric: 0.8969 - val_recall_metric: 0.9112 - val_mean_average_precision: 0.7404
# Epoch 30/60
# 77/77 [==============================] - 71s 921ms/step - loss: -0.6682 - dice_metric: 0.8480 - jaccard_metric: 0.7740 - sensitivity_metric: 0.8630 - specificity_metric: 0.8630 - precision_metric: 0.8394 - recall_metric: 0.8630 - mean_average_precision: 0.6339 - val_loss: -0.7743 - val_dice_metric: 0.9032 - val_jaccard_metric: 0.8457 - val_sensitivity_metric: 0.9143 - val_specificity_metric: 0.9143 - val_precision_metric: 0.8953 - val_recall_metric: 0.9143 - val_mean_average_precision: 0.7439
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.6757 - dice_metric: 0.8521 - jaccard_metric: 0.7790 - sensitivity_metric: 0.8649 - specificity_metric: 0.8649 - precision_metric: 0.8443 - recall_metric: 0.8649 - mean_average_precision: 0.6409 - val_loss: -0.7778 - val_dice_metric: 0.9049 - val_jaccard_metric: 0.8478 - val_sensitivity_metric: 0.9228 - val_specificity_metric: 0.9228 - val_precision_metric: 0.8910 - val_recall_metric: 0.9228 - val_mean_average_precision: 0.7436
# Epoch 32/60
# 77/77 [==============================] - 70s 906ms/step - loss: -0.6781 - dice_metric: 0.8533 - jaccard_metric: 0.7804 - sensitivity_metric: 0.8662 - specificity_metric: 0.8662 - precision_metric: 0.8452 - recall_metric: 0.8662 - mean_average_precision: 0.6431 - val_loss: -0.7786 - val_dice_metric: 0.9052 - val_jaccard_metric: 0.8484 - val_sensitivity_metric: 0.9222 - val_specificity_metric: 0.9222 - val_precision_metric: 0.8920 - val_recall_metric: 0.9222 - val_mean_average_precision: 0.7448
# Epoch 33/60
# 77/77 [==============================] - 69s 885ms/step - loss: -0.6789 - dice_metric: 0.8537 - jaccard_metric: 0.7809 - sensitivity_metric: 0.8663 - specificity_metric: 0.8663 - precision_metric: 0.8459 - recall_metric: 0.8663 - mean_average_precision: 0.6438 - val_loss: -0.7791 - val_dice_metric: 0.9053 - val_jaccard_metric: 0.8486 - val_sensitivity_metric: 0.9222 - val_specificity_metric: 0.9222 - val_precision_metric: 0.8923 - val_recall_metric: 0.9222 - val_mean_average_precision: 0.7448
# Epoch 34/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.6793 - dice_metric: 0.8539 - jaccard_metric: 0.7812 - sensitivity_metric: 0.8667 - specificity_metric: 0.8667 - precision_metric: 0.8460 - recall_metric: 0.8667 - mean_average_precision: 0.6442 - val_loss: -0.7800 - val_dice_metric: 0.9059 - val_jaccard_metric: 0.8494 - val_sensitivity_metric: 0.9214 - val_specificity_metric: 0.9214 - val_precision_metric: 0.8940 - val_recall_metric: 0.9214 - val_mean_average_precision: 0.7484
# Epoch 35/60
# 77/77 [==============================] - 66s 847ms/step - loss: -0.6798 - dice_metric: 0.8542 - jaccard_metric: 0.7816 - sensitivity_metric: 0.8669 - specificity_metric: 0.8669 - precision_metric: 0.8464 - recall_metric: 0.8669 - mean_average_precision: 0.6444 - val_loss: -0.7801 - val_dice_metric: 0.9058 - val_jaccard_metric: 0.8494 - val_sensitivity_metric: 0.9220 - val_specificity_metric: 0.9220 - val_precision_metric: 0.8935 - val_recall_metric: 0.9220 - val_mean_average_precision: 0.7486
# Epoch 36/60
# 77/77 [==============================] - 66s 849ms/step - loss: -0.6804 - dice_metric: 0.8544 - jaccard_metric: 0.7818 - sensitivity_metric: 0.8674 - specificity_metric: 0.8674 - precision_metric: 0.8464 - recall_metric: 0.8674 - mean_average_precision: 0.6441 - val_loss: -0.7797 - val_dice_metric: 0.9056 - val_jaccard_metric: 0.8489 - val_sensitivity_metric: 0.9238 - val_specificity_metric: 0.9238 - val_precision_metric: 0.8915 - val_recall_metric: 0.9238 - val_mean_average_precision: 0.7472
# Epoch 37/60
# 77/77 [==============================] - 65s 844ms/step - loss: -0.6806 - dice_metric: 0.8546 - jaccard_metric: 0.7819 - sensitivity_metric: 0.8670 - specificity_metric: 0.8670 - precision_metric: 0.8471 - recall_metric: 0.8670 - mean_average_precision: 0.6451 - val_loss: -0.7804 - val_dice_metric: 0.9059 - val_jaccard_metric: 0.8495 - val_sensitivity_metric: 0.9224 - val_specificity_metric: 0.9224 - val_precision_metric: 0.8933 - val_recall_metric: 0.9224 - val_mean_average_precision: 0.7469
# Epoch 38/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.6815 - dice_metric: 0.8550 - jaccard_metric: 0.7824 - sensitivity_metric: 0.8676 - specificity_metric: 0.8676 - precision_metric: 0.8472 - recall_metric: 0.8676 - mean_average_precision: 0.6452 - val_loss: -0.7802 - val_dice_metric: 0.9058 - val_jaccard_metric: 0.8492 - val_sensitivity_metric: 0.9239 - val_specificity_metric: 0.9239 - val_precision_metric: 0.8918 - val_recall_metric: 0.9239 - val_mean_average_precision: 0.7474
# Epoch 39/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.6819 - dice_metric: 0.8552 - jaccard_metric: 0.7826 - sensitivity_metric: 0.8674 - specificity_metric: 0.8674 - precision_metric: 0.8478 - recall_metric: 0.8674 - mean_average_precision: 0.6460 - val_loss: -0.7801 - val_dice_metric: 0.9057 - val_jaccard_metric: 0.8490 - val_sensitivity_metric: 0.9243 - val_specificity_metric: 0.9243 - val_precision_metric: 0.8912 - val_recall_metric: 0.9243 - val_mean_average_precision: 0.7464
# Epoch 40/60
# 77/77 [==============================] - 67s 870ms/step - loss: -0.6825 - dice_metric: 0.8555 - jaccard_metric: 0.7830 - sensitivity_metric: 0.8681 - specificity_metric: 0.8681 - precision_metric: 0.8477 - recall_metric: 0.8681 - mean_average_precision: 0.6458 - val_loss: -0.7807 - val_dice_metric: 0.9061 - val_jaccard_metric: 0.8496 - val_sensitivity_metric: 0.9241 - val_specificity_metric: 0.9241 - val_precision_metric: 0.8921 - val_recall_metric: 0.9241 - val_mean_average_precision: 0.7486
# Epoch 41/60
# 77/77 [==============================] - 66s 854ms/step - loss: -0.6829 - dice_metric: 0.8557 - jaccard_metric: 0.7833 - sensitivity_metric: 0.8681 - specificity_metric: 0.8681 - precision_metric: 0.8481 - recall_metric: 0.8681 - mean_average_precision: 0.6461 - val_loss: -0.7813 - val_dice_metric: 0.9064 - val_jaccard_metric: 0.8502 - val_sensitivity_metric: 0.9230 - val_specificity_metric: 0.9230 - val_precision_metric: 0.8938 - val_recall_metric: 0.9230 - val_mean_average_precision: 0.7504
# Epoch 42/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.6828 - dice_metric: 0.8556 - jaccard_metric: 0.7832 - sensitivity_metric: 0.8684 - specificity_metric: 0.8684 - precision_metric: 0.8478 - recall_metric: 0.8684 - mean_average_precision: 0.6463 - val_loss: -0.7811 - val_dice_metric: 0.9062 - val_jaccard_metric: 0.8498 - val_sensitivity_metric: 0.9240 - val_specificity_metric: 0.9240 - val_precision_metric: 0.8925 - val_recall_metric: 0.9240 - val_mean_average_precision: 0.7490
# Epoch 43/60
# 77/77 [==============================] - 69s 888ms/step - loss: -0.6837 - dice_metric: 0.8561 - jaccard_metric: 0.7837 - sensitivity_metric: 0.8683 - specificity_metric: 0.8683 - precision_metric: 0.8487 - recall_metric: 0.8683 - mean_average_precision: 0.6473 - val_loss: -0.7815 - val_dice_metric: 0.9064 - val_jaccard_metric: 0.8500 - val_sensitivity_metric: 0.9239 - val_specificity_metric: 0.9239 - val_precision_metric: 0.8928 - val_recall_metric: 0.9239 - val_mean_average_precision: 0.7506
# Epoch 44/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.6842 - dice_metric: 0.8564 - jaccard_metric: 0.7840 - sensitivity_metric: 0.8685 - specificity_metric: 0.8685 - precision_metric: 0.8490 - recall_metric: 0.8685 - mean_average_precision: 0.6475 - val_loss: -0.7815 - val_dice_metric: 0.9064 - val_jaccard_metric: 0.8501 - val_sensitivity_metric: 0.9245 - val_specificity_metric: 0.9245 - val_precision_metric: 0.8925 - val_recall_metric: 0.9245 - val_mean_average_precision: 0.7504
# Epoch 45/60
# 77/77 [==============================] - 66s 853ms/step - loss: -0.6844 - dice_metric: 0.8565 - jaccard_metric: 0.7841 - sensitivity_metric: 0.8689 - specificity_metric: 0.8689 - precision_metric: 0.8489 - recall_metric: 0.8689 - mean_average_precision: 0.6472 - val_loss: -0.7812 - val_dice_metric: 0.9063 - val_jaccard_metric: 0.8498 - val_sensitivity_metric: 0.9258 - val_specificity_metric: 0.9258 - val_precision_metric: 0.8910 - val_recall_metric: 0.9258 - val_mean_average_precision: 0.7496
# Epoch 46/60
# 77/77 [==============================] - 67s 863ms/step - loss: -0.6851 - dice_metric: 0.8568 - jaccard_metric: 0.7846 - sensitivity_metric: 0.8688 - specificity_metric: 0.8688 - precision_metric: 0.8495 - recall_metric: 0.8688 - mean_average_precision: 0.6481 - val_loss: -0.7827 - val_dice_metric: 0.9071 - val_jaccard_metric: 0.8511 - val_sensitivity_metric: 0.9241 - val_specificity_metric: 0.9241 - val_precision_metric: 0.8940 - val_recall_metric: 0.9241 - val_mean_average_precision: 0.7520
# Epoch 47/60
# 77/77 [==============================] - 66s 848ms/step - loss: -0.6856 - dice_metric: 0.8571 - jaccard_metric: 0.7849 - sensitivity_metric: 0.8692 - specificity_metric: 0.8692 - precision_metric: 0.8497 - recall_metric: 0.8692 - mean_average_precision: 0.6484 - val_loss: -0.7826 - val_dice_metric: 0.9070 - val_jaccard_metric: 0.8509 - val_sensitivity_metric: 0.9243 - val_specificity_metric: 0.9243 - val_precision_metric: 0.8935 - val_recall_metric: 0.9243 - val_mean_average_precision: 0.7520
# Epoch 48/60
# 77/77 [==============================] - 69s 887ms/step - loss: -0.6860 - dice_metric: 0.8572 - jaccard_metric: 0.7851 - sensitivity_metric: 0.8691 - specificity_metric: 0.8691 - precision_metric: 0.8500 - recall_metric: 0.8691 - mean_average_precision: 0.6489 - val_loss: -0.7829 - val_dice_metric: 0.9071 - val_jaccard_metric: 0.8511 - val_sensitivity_metric: 0.9245 - val_specificity_metric: 0.9245 - val_precision_metric: 0.8937 - val_recall_metric: 0.9245 - val_mean_average_precision: 0.7533
# Epoch 49/60
# 77/77 [==============================] - 69s 896ms/step - loss: -0.6865 - dice_metric: 0.8575 - jaccard_metric: 0.7854 - sensitivity_metric: 0.8695 - specificity_metric: 0.8695 - precision_metric: 0.8501 - recall_metric: 0.8695 - mean_average_precision: 0.6494 - val_loss: -0.7826 - val_dice_metric: 0.9069 - val_jaccard_metric: 0.8507 - val_sensitivity_metric: 0.9257 - val_specificity_metric: 0.9257 - val_precision_metric: 0.8923 - val_recall_metric: 0.9257 - val_mean_average_precision: 0.7512
# Epoch 50/60
# 77/77 [==============================] - 71s 912ms/step - loss: -0.6868 - dice_metric: 0.8576 - jaccard_metric: 0.7855 - sensitivity_metric: 0.8695 - specificity_metric: 0.8695 - precision_metric: 0.8503 - recall_metric: 0.8695 - mean_average_precision: 0.6491 - val_loss: -0.7838 - val_dice_metric: 0.9075 - val_jaccard_metric: 0.8516 - val_sensitivity_metric: 0.9240 - val_specificity_metric: 0.9240 - val_precision_metric: 0.8948 - val_recall_metric: 0.9240 - val_mean_average_precision: 0.7529
# Epoch 51/60
# 77/77 [==============================] - 68s 882ms/step - loss: -0.6873 - dice_metric: 0.8579 - jaccard_metric: 0.7858 - sensitivity_metric: 0.8697 - specificity_metric: 0.8697 - precision_metric: 0.8506 - recall_metric: 0.8697 - mean_average_precision: 0.6496 - val_loss: -0.7839 - val_dice_metric: 0.9075 - val_jaccard_metric: 0.8516 - val_sensitivity_metric: 0.9250 - val_specificity_metric: 0.9250 - val_precision_metric: 0.8939 - val_recall_metric: 0.9250 - val_mean_average_precision: 0.7531
# Epoch 52/60
# 77/77 [==============================] - 66s 852ms/step - loss: -0.6875 - dice_metric: 0.8580 - jaccard_metric: 0.7859 - sensitivity_metric: 0.8700 - specificity_metric: 0.8700 - precision_metric: 0.8506 - recall_metric: 0.8700 - mean_average_precision: 0.6497 - val_loss: -0.7839 - val_dice_metric: 0.9077 - val_jaccard_metric: 0.8517 - val_sensitivity_metric: 0.9253 - val_specificity_metric: 0.9253 - val_precision_metric: 0.8939 - val_recall_metric: 0.9253 - val_mean_average_precision: 0.7539
# Epoch 53/60
# 77/77 [==============================] - 70s 907ms/step - loss: -0.6882 - dice_metric: 0.8584 - jaccard_metric: 0.7864 - sensitivity_metric: 0.8700 - specificity_metric: 0.8700 - precision_metric: 0.8513 - recall_metric: 0.8700 - mean_average_precision: 0.6501 - val_loss: -0.7824 - val_dice_metric: 0.9067 - val_jaccard_metric: 0.8503 - val_sensitivity_metric: 0.9277 - val_specificity_metric: 0.9277 - val_precision_metric: 0.8903 - val_recall_metric: 0.9277 - val_mean_average_precision: 0.7512
# Epoch 54/60
# 77/77 [==============================] - 67s 859ms/step - loss: -0.6887 - dice_metric: 0.8585 - jaccard_metric: 0.7865 - sensitivity_metric: 0.8704 - specificity_metric: 0.8704 - precision_metric: 0.8513 - recall_metric: 0.8704 - mean_average_precision: 0.6503 - val_loss: -0.7840 - val_dice_metric: 0.9076 - val_jaccard_metric: 0.8516 - val_sensitivity_metric: 0.9263 - val_specificity_metric: 0.9263 - val_precision_metric: 0.8929 - val_recall_metric: 0.9263 - val_mean_average_precision: 0.7529
# Epoch 55/60
# 77/77 [==============================] - 68s 883ms/step - loss: -0.6891 - dice_metric: 0.8588 - jaccard_metric: 0.7869 - sensitivity_metric: 0.8706 - specificity_metric: 0.8706 - precision_metric: 0.8515 - recall_metric: 0.8706 - mean_average_precision: 0.6512 - val_loss: -0.7840 - val_dice_metric: 0.9075 - val_jaccard_metric: 0.8515 - val_sensitivity_metric: 0.9265 - val_specificity_metric: 0.9265 - val_precision_metric: 0.8927 - val_recall_metric: 0.9265 - val_mean_average_precision: 0.7525
# Epoch 56/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.6895 - dice_metric: 0.8589 - jaccard_metric: 0.7871 - sensitivity_metric: 0.8706 - specificity_metric: 0.8706 - precision_metric: 0.8518 - recall_metric: 0.8706 - mean_average_precision: 0.6512 - val_loss: -0.7847 - val_dice_metric: 0.9079 - val_jaccard_metric: 0.8521 - val_sensitivity_metric: 0.9254 - val_specificity_metric: 0.9254 - val_precision_metric: 0.8943 - val_recall_metric: 0.9254 - val_mean_average_precision: 0.7539
# Epoch 57/60
# 77/77 [==============================] - 70s 901ms/step - loss: -0.6900 - dice_metric: 0.8592 - jaccard_metric: 0.7874 - sensitivity_metric: 0.8704 - specificity_metric: 0.8704 - precision_metric: 0.8522 - recall_metric: 0.8704 - mean_average_precision: 0.6521 - val_loss: -0.7839 - val_dice_metric: 0.9075 - val_jaccard_metric: 0.8514 - val_sensitivity_metric: 0.9278 - val_specificity_metric: 0.9278 - val_precision_metric: 0.8916 - val_recall_metric: 0.9278 - val_mean_average_precision: 0.7525
# Epoch 58/60
# 77/77 [==============================] - 67s 867ms/step - loss: -0.6905 - dice_metric: 0.8594 - jaccard_metric: 0.7877 - sensitivity_metric: 0.8714 - specificity_metric: 0.8714 - precision_metric: 0.8521 - recall_metric: 0.8714 - mean_average_precision: 0.6517 - val_loss: -0.7859 - val_dice_metric: 0.9086 - val_jaccard_metric: 0.8530 - val_sensitivity_metric: 0.9252 - val_specificity_metric: 0.9252 - val_precision_metric: 0.8956 - val_recall_metric: 0.9252 - val_mean_average_precision: 0.7561
# Epoch 59/60
# 77/77 [==============================] - 70s 898ms/step - loss: -0.6911 - dice_metric: 0.8597 - jaccard_metric: 0.7880 - sensitivity_metric: 0.8710 - specificity_metric: 0.8710 - precision_metric: 0.8528 - recall_metric: 0.8710 - mean_average_precision: 0.6526 - val_loss: -0.7846 - val_dice_metric: 0.9078 - val_jaccard_metric: 0.8518 - val_sensitivity_metric: 0.9276 - val_specificity_metric: 0.9276 - val_precision_metric: 0.8922 - val_recall_metric: 0.9276 - val_mean_average_precision: 0.7510
# Epoch 60/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.6914 - dice_metric: 0.8599 - jaccard_metric: 0.7881 - sensitivity_metric: 0.8714 - specificity_metric: 0.8714 - precision_metric: 0.8528 - recall_metric: 0.8714 - mean_average_precision: 0.6527 - val_loss: -0.7852 - val_dice_metric: 0.9081 - val_jaccard_metric: 0.8523 - val_sensitivity_metric: 0.9272 - val_specificity_metric: 0.9272 - val_precision_metric: 0.8932 - val_recall_metric: 0.9272 - val_mean_average_precision: 0.7527

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
import os
import numpy as np
import gc
import tensorflow as tf

def performance_measures(model, dataset, config, save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Inicializar listas para almacenar los resultados de las métricas
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []
        precision_results = []
        recall_results = []
        mAP50_results = []
        mAP50_95_results = []

        # Procesar cada batch en el dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generar predicciones del modelo
            y_pred = model(images, training=False)
            y_pred_class = y_pred[..., :config['Number of classes']]

            # Calcular métricas
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            precision_batch = precision_metric(masks, y_pred_class, return_mean=False)
            recall_batch = recall_metric(masks, y_pred_class, return_mean=False)
            mAP50_batch = mean_average_precision(masks, y_pred_class, thresholds=[0.5], return_mean=False)
            mAP50_95_batch = mean_average_precision(masks, y_pred_class, thresholds=tf.linspace(0.5, 0.95, 10), return_mean=False)

            # Almacenar resultados en listas
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())
            precision_results.append(precision_batch.numpy().flatten())
            recall_results.append(recall_batch.numpy().flatten())
            mAP50_results.append(mAP50_batch.numpy().flatten())
            mAP50_95_results.append(mAP50_95_batch.numpy().flatten())

            # Liberar memoria de variables innecesarias
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch
            del precision_batch, recall_batch, mAP50_batch, mAP50_95_batch, images, masks

        # Convertir listas de batches a arrays de NumPy
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)
        precision_results = np.concatenate(precision_results)
        recall_results = np.concatenate(recall_results)
        mAP50_results = np.concatenate(mAP50_results)
        mAP50_95_results = np.concatenate(mAP50_95_results)

        # Imprimir resumen de métricas
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, std: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, std: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, std: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, std: {np.std(specificity_results):.5f}")
        print(f"Precision mean: {np.mean(precision_results):.5f}, std: {np.std(precision_results):.5f}")
        print(f"Recall mean: {np.mean(recall_results):.5f}, std: {np.std(recall_results):.5f}")
        print(f"mAP@50 mean: {np.mean(mAP50_results):.5f}, std: {np.std(mAP50_results):.5f}")
        print(f"mAP@50-95 mean: {np.mean(mAP50_95_results):.5f}, std: {np.std(mAP50_95_results):.5f}")

        # Guardar resultados en archivos si se solicita
        if save_results:
            if not os.path.exists('./results'):
                os.makedirs('./results')

            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)
            np.save(f"{filename_base}_Precision.npy", precision_results)
            np.save(f"{filename_base}_Recall.npy", recall_results)
            np.save(f"{filename_base}_mAP50.npy", mAP50_results)
            np.save(f"{filename_base}_mAP50_95.npy", mAP50_95_results)

        # Liberar memoria
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        del precision_results, recall_results, mAP50_results, mAP50_95_results

        return [
            f"{filename_base}_DICE.npy",
            f"{filename_base}_Jaccard.npy",
            f"{filename_base}_Sensitivity.npy",
            f"{filename_base}_Specificity.npy",
            f"{filename_base}_Precision.npy",
            f"{filename_base}_Recall.npy",
            f"{filename_base}_mAP50.npy",
            f"{filename_base}_mAP50_95.npy"
        ]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.90330, std: 0.12448
# Jaccard Index mean: 0.84424, std: 0.18266
# Sensitivity mean: 0.92208, std: 0.10949
# Specificity mean: 0.92208, std: 0.10949
# Precision mean: 0.88786, std: 0.14131
# Recall mean: 0.92208, std: 0.10949
# mAP@50 mean: 0.94915, std: 0.15112
# mAP@50-95 mean: 0.73263, std: 0.15285
