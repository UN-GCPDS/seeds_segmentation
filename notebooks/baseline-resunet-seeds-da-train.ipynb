# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de semillas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Puede ser 3 para tres clases; 0-Fondo, 1-Semilla germinada, 2-Semilla no germinada, o 2 para dos clases; 0-Fondo, 1-Semilla

# %%
# Download histology dataset
classes_ = {3:1, 2:2}
# !kaggle datasets download lucasiturriago/seeds/{classes_[classes]}

os.makedirs('./datasets/Seeds', exist_ok=True)
with zipfile.ZipFile('./seeds.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Seeds')
# !rm -rf ./seeds.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/lucasiturriago/seeds/versions/2
# License(s): CC-BY-SA-4.0
# Downloading seeds.zip to /kaggle/working
#  99%|████████████████████████████████████████▋| 989M/998M [00:03<00:00, 289MB/s]
# 100%|█████████████████████████████████████████| 998M/998M [00:03<00:00, 301MB/s]

# %%
config = {"Seg_model":"ResUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Seeds","Dir of dataset":"./datasets/Seeds","Batch size":32,"Epochs":60,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Train/images/*.png
# Number of images files found: 2458
# Original masks path, class 0: ./datasets/Seeds/Train/masks/class_0/*.png
# Number of masks found: 2458
# Original masks path, class 1: ./datasets/Seeds/Train/masks/class_1/*.png
# Number of masks found: 2458

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Valid/images/*.png
# Number of images files found: 231
# Original masks path, class 0: ./datasets/Seeds/Valid/masks/class_0/*.png
# Number of masks found: 231
# Original masks path, class 1: ./datasets/Seeds/Valid/masks/class_1/*.png
# Number of masks found: 231

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Seeds/Test/images/*.png
# Number of images files found: 118
# Original masks path, class 0: ./datasets/Seeds/Test/masks/class_0/*.png
# Number of masks found: 118
# Original masks path, class 1: ./datasets/Seeds/Test/masks/class_1/*.png
# Number of masks found: 118

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
pip install git+https://github.com/UN-GCPDS/seeds_segmentation.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for seeds_segmentation (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
from seeds_segmentation import unet_baseline, fcn_baseline, segnet_baseline, res_unet_baseline
from seeds_segmentation.losses import DiceCoefficient 
from seeds_segmentation.metrics import DiceCoefficientMetric, Jaccard, Sensitivity, Specificity

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

# %%
with strategy.scope():
    model = res_unet_baseline(input_shape=config['Input size'], out_channels=config['Number of classes'], out_ActFunction=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}")

lr_scheduler = CustomLearningRateScheduler(1e-5, 30)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/60
# 77/77 [==============================] - 137s 951ms/step - loss: -0.1125 - dice_metric: 0.4345 - jaccard_metric: 0.3304 - sensitivity_metric: 0.6156 - specificity_metric: 0.6157 - val_loss: -0.0774 - val_dice_metric: 0.5234 - val_jaccard_metric: 0.4934 - val_sensitivity_metric: 0.5203 - val_specificity_metric: 0.5203
# Epoch 2/60
# 77/77 [==============================] - 67s 864ms/step - loss: -0.1856 - dice_metric: 0.5800 - jaccard_metric: 0.4783 - sensitivity_metric: 0.7614 - specificity_metric: 0.7614 - val_loss: -0.0792 - val_dice_metric: 0.5403 - val_jaccard_metric: 0.5132 - val_sensitivity_metric: 0.5330 - val_specificity_metric: 0.5330
# Epoch 3/60
# 77/77 [==============================] - 67s 868ms/step - loss: -0.2822 - dice_metric: 0.7084 - jaccard_metric: 0.6176 - sensitivity_metric: 0.8437 - specificity_metric: 0.8437 - val_loss: -0.2078 - val_dice_metric: 0.7645 - val_jaccard_metric: 0.6903 - val_sensitivity_metric: 0.7747 - val_specificity_metric: 0.7747
# Epoch 4/60
# 77/77 [==============================] - 66s 849ms/step - loss: -0.3979 - dice_metric: 0.7408 - jaccard_metric: 0.6609 - sensitivity_metric: 0.8744 - specificity_metric: 0.8744 - val_loss: -0.3563 - val_dice_metric: 0.7973 - val_jaccard_metric: 0.7242 - val_sensitivity_metric: 0.8546 - val_specificity_metric: 0.8546
# Epoch 5/60
# 77/77 [==============================] - 70s 896ms/step - loss: -0.4680 - dice_metric: 0.7530 - jaccard_metric: 0.6792 - sensitivity_metric: 0.8776 - specificity_metric: 0.8776 - val_loss: -0.4340 - val_dice_metric: 0.7730 - val_jaccard_metric: 0.6948 - val_sensitivity_metric: 0.8848 - val_specificity_metric: 0.8848
# Epoch 6/60
# 77/77 [==============================] - 69s 889ms/step - loss: -0.5161 - dice_metric: 0.7828 - jaccard_metric: 0.7129 - sensitivity_metric: 0.8905 - specificity_metric: 0.8905 - val_loss: -0.5030 - val_dice_metric: 0.7972 - val_jaccard_metric: 0.7209 - val_sensitivity_metric: 0.9190 - val_specificity_metric: 0.9190
# Epoch 7/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.5647 - dice_metric: 0.8421 - jaccard_metric: 0.7788 - sensitivity_metric: 0.9193 - specificity_metric: 0.9193 - val_loss: -0.5662 - val_dice_metric: 0.8375 - val_jaccard_metric: 0.7753 - val_sensitivity_metric: 0.9314 - val_specificity_metric: 0.9314
# Epoch 8/60
# 77/77 [==============================] - 70s 906ms/step - loss: -0.6115 - dice_metric: 0.8743 - jaccard_metric: 0.8181 - sensitivity_metric: 0.9305 - specificity_metric: 0.9305 - val_loss: -0.6069 - val_dice_metric: 0.8710 - val_jaccard_metric: 0.8163 - val_sensitivity_metric: 0.9482 - val_specificity_metric: 0.9482
# Epoch 9/60
# 77/77 [==============================] - 69s 885ms/step - loss: -0.6507 - dice_metric: 0.9004 - jaccard_metric: 0.8473 - sensitivity_metric: 0.9358 - specificity_metric: 0.9358 - val_loss: -0.6450 - val_dice_metric: 0.8981 - val_jaccard_metric: 0.8439 - val_sensitivity_metric: 0.9523 - val_specificity_metric: 0.9523
# Epoch 10/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.6845 - dice_metric: 0.9139 - jaccard_metric: 0.8613 - sensitivity_metric: 0.9350 - specificity_metric: 0.9350 - val_loss: -0.6769 - val_dice_metric: 0.9129 - val_jaccard_metric: 0.8614 - val_sensitivity_metric: 0.9493 - val_specificity_metric: 0.9493
# Epoch 11/60
# 77/77 [==============================] - 69s 893ms/step - loss: -0.7123 - dice_metric: 0.9197 - jaccard_metric: 0.8682 - sensitivity_metric: 0.9343 - specificity_metric: 0.9343 - val_loss: -0.7041 - val_dice_metric: 0.9220 - val_jaccard_metric: 0.8733 - val_sensitivity_metric: 0.9467 - val_specificity_metric: 0.9467
# Epoch 12/60
# 77/77 [==============================] - 70s 898ms/step - loss: -0.7354 - dice_metric: 0.9235 - jaccard_metric: 0.8731 - sensitivity_metric: 0.9338 - specificity_metric: 0.9338 - val_loss: -0.7270 - val_dice_metric: 0.9260 - val_jaccard_metric: 0.8789 - val_sensitivity_metric: 0.9447 - val_specificity_metric: 0.9447
# Epoch 13/60
# 77/77 [==============================] - 70s 907ms/step - loss: -0.7545 - dice_metric: 0.9262 - jaccard_metric: 0.8768 - sensitivity_metric: 0.9334 - specificity_metric: 0.9334 - val_loss: -0.7476 - val_dice_metric: 0.9295 - val_jaccard_metric: 0.8835 - val_sensitivity_metric: 0.9432 - val_specificity_metric: 0.9432
# Epoch 14/60
# 77/77 [==============================] - 67s 859ms/step - loss: -0.7707 - dice_metric: 0.9284 - jaccard_metric: 0.8798 - sensitivity_metric: 0.9332 - specificity_metric: 0.9332 - val_loss: -0.7647 - val_dice_metric: 0.9315 - val_jaccard_metric: 0.8862 - val_sensitivity_metric: 0.9419 - val_specificity_metric: 0.9419
# Epoch 15/60
# 77/77 [==============================] - 71s 914ms/step - loss: -0.7846 - dice_metric: 0.9303 - jaccard_metric: 0.8824 - sensitivity_metric: 0.9331 - specificity_metric: 0.9331 - val_loss: -0.7790 - val_dice_metric: 0.9331 - val_jaccard_metric: 0.8883 - val_sensitivity_metric: 0.9418 - val_specificity_metric: 0.9418
# Epoch 16/60
# 77/77 [==============================] - 70s 900ms/step - loss: -0.7965 - dice_metric: 0.9318 - jaccard_metric: 0.8846 - sensitivity_metric: 0.9331 - specificity_metric: 0.9331 - val_loss: -0.7923 - val_dice_metric: 0.9344 - val_jaccard_metric: 0.8901 - val_sensitivity_metric: 0.9432 - val_specificity_metric: 0.9432
# Epoch 17/60
# 77/77 [==============================] - 68s 869ms/step - loss: -0.8065 - dice_metric: 0.9330 - jaccard_metric: 0.8863 - sensitivity_metric: 0.9332 - specificity_metric: 0.9332 - val_loss: -0.8021 - val_dice_metric: 0.9347 - val_jaccard_metric: 0.8907 - val_sensitivity_metric: 0.9441 - val_specificity_metric: 0.9441
# Epoch 18/60
# 77/77 [==============================] - 70s 894ms/step - loss: -0.8150 - dice_metric: 0.9339 - jaccard_metric: 0.8877 - sensitivity_metric: 0.9331 - specificity_metric: 0.9331 - val_loss: -0.8096 - val_dice_metric: 0.9339 - val_jaccard_metric: 0.8898 - val_sensitivity_metric: 0.9464 - val_specificity_metric: 0.9464
# Epoch 19/60
# 77/77 [==============================] - 69s 885ms/step - loss: -0.8226 - dice_metric: 0.9348 - jaccard_metric: 0.8890 - sensitivity_metric: 0.9331 - specificity_metric: 0.9331 - val_loss: -0.8214 - val_dice_metric: 0.9379 - val_jaccard_metric: 0.8951 - val_sensitivity_metric: 0.9419 - val_specificity_metric: 0.9419
# Epoch 20/60
# 77/77 [==============================] - 69s 886ms/step - loss: -0.8292 - dice_metric: 0.9356 - jaccard_metric: 0.8901 - sensitivity_metric: 0.9330 - specificity_metric: 0.9330 - val_loss: -0.8280 - val_dice_metric: 0.9376 - val_jaccard_metric: 0.8946 - val_sensitivity_metric: 0.9442 - val_specificity_metric: 0.9442
# Epoch 21/60
# 77/77 [==============================] - 67s 864ms/step - loss: -0.8357 - dice_metric: 0.9366 - jaccard_metric: 0.8917 - sensitivity_metric: 0.9335 - specificity_metric: 0.9335 - val_loss: -0.8331 - val_dice_metric: 0.9371 - val_jaccard_metric: 0.8939 - val_sensitivity_metric: 0.9470 - val_specificity_metric: 0.9470
# Epoch 22/60
# 77/77 [==============================] - 69s 888ms/step - loss: -0.8405 - dice_metric: 0.9370 - jaccard_metric: 0.8923 - sensitivity_metric: 0.9337 - specificity_metric: 0.9337 - val_loss: -0.8403 - val_dice_metric: 0.9390 - val_jaccard_metric: 0.8971 - val_sensitivity_metric: 0.9435 - val_specificity_metric: 0.9435
# Epoch 23/60
# 77/77 [==============================] - 68s 880ms/step - loss: -0.8455 - dice_metric: 0.9379 - jaccard_metric: 0.8935 - sensitivity_metric: 0.9339 - specificity_metric: 0.9339 - val_loss: -0.8456 - val_dice_metric: 0.9396 - val_jaccard_metric: 0.8978 - val_sensitivity_metric: 0.9445 - val_specificity_metric: 0.9445
# Epoch 24/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.8500 - dice_metric: 0.9387 - jaccard_metric: 0.8947 - sensitivity_metric: 0.9343 - specificity_metric: 0.9343 - val_loss: -0.8485 - val_dice_metric: 0.9393 - val_jaccard_metric: 0.8973 - val_sensitivity_metric: 0.9449 - val_specificity_metric: 0.9449
# Epoch 25/60
# 77/77 [==============================] - 67s 869ms/step - loss: -0.8533 - dice_metric: 0.9390 - jaccard_metric: 0.8952 - sensitivity_metric: 0.9343 - specificity_metric: 0.9343 - val_loss: -0.8505 - val_dice_metric: 0.9391 - val_jaccard_metric: 0.8968 - val_sensitivity_metric: 0.9444 - val_specificity_metric: 0.9444
# Epoch 26/60
# 77/77 [==============================] - 67s 861ms/step - loss: -0.8568 - dice_metric: 0.9396 - jaccard_metric: 0.8960 - sensitivity_metric: 0.9346 - specificity_metric: 0.9346 - val_loss: -0.8534 - val_dice_metric: 0.9395 - val_jaccard_metric: 0.8974 - val_sensitivity_metric: 0.9441 - val_specificity_metric: 0.9441
# Epoch 27/60
# 77/77 [==============================] - 68s 876ms/step - loss: -0.8584 - dice_metric: 0.9392 - jaccard_metric: 0.8955 - sensitivity_metric: 0.9344 - specificity_metric: 0.9344 - val_loss: -0.8574 - val_dice_metric: 0.9407 - val_jaccard_metric: 0.8995 - val_sensitivity_metric: 0.9396 - val_specificity_metric: 0.9396
# Epoch 28/60
# 77/77 [==============================] - 68s 881ms/step - loss: -0.8616 - dice_metric: 0.9400 - jaccard_metric: 0.8967 - sensitivity_metric: 0.9348 - specificity_metric: 0.9348 - val_loss: -0.8619 - val_dice_metric: 0.9418 - val_jaccard_metric: 0.9011 - val_sensitivity_metric: 0.9401 - val_specificity_metric: 0.9401
# Epoch 29/60
# 77/77 [==============================] - 69s 883ms/step - loss: -0.8644 - dice_metric: 0.9406 - jaccard_metric: 0.8976 - sensitivity_metric: 0.9351 - specificity_metric: 0.9351 - val_loss: -0.8628 - val_dice_metric: 0.9410 - val_jaccard_metric: 0.8997 - val_sensitivity_metric: 0.9403 - val_specificity_metric: 0.9403
# Epoch 30/60
# 77/77 [==============================] - 69s 888ms/step - loss: -0.8652 - dice_metric: 0.9402 - jaccard_metric: 0.8970 - sensitivity_metric: 0.9349 - specificity_metric: 0.9349 - val_loss: -0.8669 - val_dice_metric: 0.9425 - val_jaccard_metric: 0.9021 - val_sensitivity_metric: 0.9407 - val_specificity_metric: 0.9407
# Learning rate changed to 1e-05 at epoch 30
# Epoch 31/60
# 77/77 [==============================] - 68s 879ms/step - loss: -0.8689 - dice_metric: 0.9417 - jaccard_metric: 0.8993 - sensitivity_metric: 0.9359 - specificity_metric: 0.9359 - val_loss: -0.8707 - val_dice_metric: 0.9442 - val_jaccard_metric: 0.9049 - val_sensitivity_metric: 0.9420 - val_specificity_metric: 0.9420
# Epoch 32/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.8708 - dice_metric: 0.9427 - jaccard_metric: 0.9007 - sensitivity_metric: 0.9367 - specificity_metric: 0.9367 - val_loss: -0.8711 - val_dice_metric: 0.9443 - val_jaccard_metric: 0.9051 - val_sensitivity_metric: 0.9422 - val_specificity_metric: 0.9422
# Epoch 33/60
# 77/77 [==============================] - 69s 886ms/step - loss: -0.8716 - dice_metric: 0.9430 - jaccard_metric: 0.9012 - sensitivity_metric: 0.9369 - specificity_metric: 0.9369 - val_loss: -0.8715 - val_dice_metric: 0.9444 - val_jaccard_metric: 0.9051 - val_sensitivity_metric: 0.9422 - val_specificity_metric: 0.9422
# Epoch 34/60
# 77/77 [==============================] - 71s 909ms/step - loss: -0.8721 - dice_metric: 0.9432 - jaccard_metric: 0.9015 - sensitivity_metric: 0.9371 - specificity_metric: 0.9371 - val_loss: -0.8717 - val_dice_metric: 0.9444 - val_jaccard_metric: 0.9052 - val_sensitivity_metric: 0.9422 - val_specificity_metric: 0.9422
# Epoch 35/60
# 77/77 [==============================] - 70s 906ms/step - loss: -0.8726 - dice_metric: 0.9434 - jaccard_metric: 0.9018 - sensitivity_metric: 0.9373 - specificity_metric: 0.9373 - val_loss: -0.8719 - val_dice_metric: 0.9444 - val_jaccard_metric: 0.9052 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 36/60
# 77/77 [==============================] - 69s 890ms/step - loss: -0.8731 - dice_metric: 0.9436 - jaccard_metric: 0.9021 - sensitivity_metric: 0.9374 - specificity_metric: 0.9374 - val_loss: -0.8722 - val_dice_metric: 0.9444 - val_jaccard_metric: 0.9052 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 37/60
# 77/77 [==============================] - 70s 898ms/step - loss: -0.8735 - dice_metric: 0.9438 - jaccard_metric: 0.9023 - sensitivity_metric: 0.9375 - specificity_metric: 0.9375 - val_loss: -0.8724 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9053 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 38/60
# 77/77 [==============================] - 68s 874ms/step - loss: -0.8739 - dice_metric: 0.9439 - jaccard_metric: 0.9025 - sensitivity_metric: 0.9376 - specificity_metric: 0.9376 - val_loss: -0.8726 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9053 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 39/60
# 77/77 [==============================] - 70s 908ms/step - loss: -0.8743 - dice_metric: 0.9440 - jaccard_metric: 0.9027 - sensitivity_metric: 0.9377 - specificity_metric: 0.9377 - val_loss: -0.8728 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9053 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 40/60
# 77/77 [==============================] - 70s 898ms/step - loss: -0.8747 - dice_metric: 0.9442 - jaccard_metric: 0.9029 - sensitivity_metric: 0.9378 - specificity_metric: 0.9378 - val_loss: -0.8730 - val_dice_metric: 0.9445 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 41/60
# 77/77 [==============================] - 67s 858ms/step - loss: -0.8751 - dice_metric: 0.9443 - jaccard_metric: 0.9031 - sensitivity_metric: 0.9379 - specificity_metric: 0.9379 - val_loss: -0.8732 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 42/60
# 77/77 [==============================] - 68s 875ms/step - loss: -0.8755 - dice_metric: 0.9444 - jaccard_metric: 0.9033 - sensitivity_metric: 0.9380 - specificity_metric: 0.9380 - val_loss: -0.8735 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 43/60
# 77/77 [==============================] - 69s 887ms/step - loss: -0.8759 - dice_metric: 0.9445 - jaccard_metric: 0.9034 - sensitivity_metric: 0.9381 - specificity_metric: 0.9381 - val_loss: -0.8737 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9422 - val_specificity_metric: 0.9422
# Epoch 44/60
# 77/77 [==============================] - 71s 914ms/step - loss: -0.8763 - dice_metric: 0.9447 - jaccard_metric: 0.9036 - sensitivity_metric: 0.9382 - specificity_metric: 0.9382 - val_loss: -0.8739 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 45/60
# 77/77 [==============================] - 69s 891ms/step - loss: -0.8766 - dice_metric: 0.9448 - jaccard_metric: 0.9038 - sensitivity_metric: 0.9383 - specificity_metric: 0.9383 - val_loss: -0.8741 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9423 - val_specificity_metric: 0.9423
# Epoch 46/60
# 77/77 [==============================] - 67s 868ms/step - loss: -0.8770 - dice_metric: 0.9449 - jaccard_metric: 0.9039 - sensitivity_metric: 0.9384 - specificity_metric: 0.9384 - val_loss: -0.8743 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9054 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 47/60
# 77/77 [==============================] - 71s 917ms/step - loss: -0.8774 - dice_metric: 0.9450 - jaccard_metric: 0.9041 - sensitivity_metric: 0.9385 - specificity_metric: 0.9385 - val_loss: -0.8745 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 48/60
# 77/77 [==============================] - 73s 941ms/step - loss: -0.8778 - dice_metric: 0.9451 - jaccard_metric: 0.9042 - sensitivity_metric: 0.9385 - specificity_metric: 0.9385 - val_loss: -0.8747 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 49/60
# 77/77 [==============================] - 69s 894ms/step - loss: -0.8781 - dice_metric: 0.9452 - jaccard_metric: 0.9044 - sensitivity_metric: 0.9386 - specificity_metric: 0.9386 - val_loss: -0.8749 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 50/60
# 77/77 [==============================] - 69s 883ms/step - loss: -0.8785 - dice_metric: 0.9453 - jaccard_metric: 0.9046 - sensitivity_metric: 0.9387 - specificity_metric: 0.9387 - val_loss: -0.8751 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 51/60
# 77/77 [==============================] - 68s 880ms/step - loss: -0.8789 - dice_metric: 0.9454 - jaccard_metric: 0.9047 - sensitivity_metric: 0.9388 - specificity_metric: 0.9388 - val_loss: -0.8754 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 52/60
# 77/77 [==============================] - 68s 872ms/step - loss: -0.8792 - dice_metric: 0.9455 - jaccard_metric: 0.9048 - sensitivity_metric: 0.9389 - specificity_metric: 0.9389 - val_loss: -0.8756 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9424 - val_specificity_metric: 0.9424
# Epoch 53/60
# 77/77 [==============================] - 68s 873ms/step - loss: -0.8796 - dice_metric: 0.9456 - jaccard_metric: 0.9050 - sensitivity_metric: 0.9389 - specificity_metric: 0.9389 - val_loss: -0.8758 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425
# Epoch 54/60
# 77/77 [==============================] - 69s 892ms/step - loss: -0.8799 - dice_metric: 0.9457 - jaccard_metric: 0.9051 - sensitivity_metric: 0.9390 - specificity_metric: 0.9390 - val_loss: -0.8760 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425
# Epoch 55/60
# 77/77 [==============================] - 69s 883ms/step - loss: -0.8803 - dice_metric: 0.9458 - jaccard_metric: 0.9053 - sensitivity_metric: 0.9391 - specificity_metric: 0.9391 - val_loss: -0.8762 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425
# Epoch 56/60
# 77/77 [==============================] - 69s 889ms/step - loss: -0.8807 - dice_metric: 0.9459 - jaccard_metric: 0.9054 - sensitivity_metric: 0.9392 - specificity_metric: 0.9392 - val_loss: -0.8764 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425
# Epoch 57/60
# 77/77 [==============================] - 68s 884ms/step - loss: -0.8810 - dice_metric: 0.9460 - jaccard_metric: 0.9056 - sensitivity_metric: 0.9392 - specificity_metric: 0.9392 - val_loss: -0.8766 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425
# Epoch 58/60
# 77/77 [==============================] - 69s 894ms/step - loss: -0.8814 - dice_metric: 0.9461 - jaccard_metric: 0.9057 - sensitivity_metric: 0.9393 - specificity_metric: 0.9393 - val_loss: -0.8768 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425
# Epoch 59/60
# 77/77 [==============================] - 68s 878ms/step - loss: -0.8817 - dice_metric: 0.9462 - jaccard_metric: 0.9059 - sensitivity_metric: 0.9394 - specificity_metric: 0.9394 - val_loss: -0.8770 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425
# Epoch 60/60
# 77/77 [==============================] - 67s 868ms/step - loss: -0.8821 - dice_metric: 0.9462 - jaccard_metric: 0.9060 - sensitivity_metric: 0.9395 - specificity_metric: 0.9395 - val_loss: -0.8772 - val_dice_metric: 0.9446 - val_jaccard_metric: 0.9055 - val_sensitivity_metric: 0.9425 - val_specificity_metric: 0.9425

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.94122, standard deviation: 0.09343
# Jaccard Index mean: 0.90124, standard deviation: 0.13994
# Sensitivity mean: 0.93756, standard deviation: 0.11259
# Specificity mean: 0.93756, standard deviation: 0.11259
